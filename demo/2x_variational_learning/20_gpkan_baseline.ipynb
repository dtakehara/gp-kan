# %% [markdown]
# # GP-KANの学習安定化方法調査: ベースライン

# %% [markdown]
# ## 0.背景/目的
# 本notebookでは、GP-KANの変分ベイズ学習用に、baselineとして以下の設定で学習を行い結果を評価する：
# ### モデル構成
# - **ネットワーク構造**: 2層GP-KAN (入力1次元 → 中間層1次元 → 出力1次元)
# - **誘導点数**: 各GPあたり10点
# - **GP構成**: (0,0), (1,0) の2つのガウス過程
#
# ### 学習パラメータ
# - **エポック数**: 400エポック
# - **学習率**: 1e-5
# - **バッチサイズ**: 32
# - **事前学習**: 無効 (pretrain=False)
#
# ### 正則化パラメータ
# - **global_jitter**: 1e-3
# - **baseline_jitter**: 1e-3

# %%
JITTER_VALUE = 1e-3  # Jitter項の値

# %%
SAVELOAD_PATH = "model_20.pt"

# %% [markdown]
# ## 1.問題設定
#
# 真の関数: フーリエ級数
# $$f(t) = \frac{4}{\pi} \sum_{n=1}^{N} \frac{1}{n} \sin(nt), \quad n = 1, 3, 5, \ldots, \quad t \in [0, 1]$$
# ※$N=15$
#
# データ:
# - 合計1,000件: 学習700件/検証150件/評価150件
# - tは$(-1,1)$から一様ランダムサンプリング
#
# モデル:
# - 2層のGPKAN: 入力1次元/中間層1次元/出力1次元
#     - それぞれのGPを(<1層目のindex>,<2層目のindex>)形式で表すことにすると、GPKANは$(0,0),(1,0)$の2つのGPで構成

# %% [markdown]
# ## 2.メイン処理
# 本ノートブックのメイン処理を実行する。実行順は以下の通り：
#
# 2-1.データセット作成
#
# 2-2.GPKANの学習
#
# 2-3.精度評価
#
# 2-4.学習中のカーネル行列ランク可視化

# %% [markdown]
# ### 2-1.データセット作成

# %%
# 初期設定: 必要なライブラリをインポートし、パスを設定
import os
import sys

sys.path.append("../../")
import japanize_matplotlib
import torch.utils.data
from lib import model as gplib
from lib import runner
from torch.utils.data import DataLoader

# %%
import random

import matplotlib.pyplot as plt
import numpy as np
import torch
from torch.utils.data import DataLoader, TensorDataset


# Generate synthetic data with Fourier series function
def set_seed(seed=42):
    """完全な再現性のための乱数シード設定"""
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)


def worker_init_fn(worker_id):
    """DataLoaderワーカープロセス用の乱数シード設定"""
    worker_seed = torch.initial_seed() % 2**32
    np.random.seed(worker_seed)
    random.seed(worker_seed)


set_seed(42)  # 全体の乱数シード設定
num_samples = 1000

# Generate random input points t from [-1, 1]
t = np.random.uniform(-1, 1, num_samples)


# Compute target values: f(t) = (4/π) * Σ(1/n * sin(nt)) for odd n up to N=15
def fourier_series(t, N=15):
    result = np.zeros_like(t)
    for n in range(1, N + 1, 2):  # odd numbers only: 1, 3, 5, 7, 9, 11, 13, 15
        result += (1 / n) * np.sin(n * t)
    return (4 / np.pi) * result


targets = fourier_series(t, N=15)

# Reshape inputs (t is 1D, but we need it as 2D for compatibility)
inputs = t.reshape(-1, 1)

# Convert to PyTorch tensors
X_tensor = torch.FloatTensor(inputs)
y_tensor = torch.FloatTensor(targets).reshape(-1, 1)

# Split data into train, validation, and test sets
train_size = int(0.7 * num_samples)
val_size = int(0.15 * num_samples)
test_size = num_samples - train_size - val_size

X_train = X_tensor[:train_size]
y_train = y_tensor[:train_size]

X_val = X_tensor[train_size : train_size + val_size]
y_val = y_tensor[train_size : train_size + val_size]

X_test = X_tensor[train_size + val_size :]
y_test = y_tensor[train_size + val_size :]

# データを昇順にソート（X_testとy_testを対応を保ちながら）
sorted_indices = torch.argsort(X_test.squeeze())
X_test = X_test[sorted_indices]
y_test = y_test[sorted_indices]

# Create datasets
train_dataset = TensorDataset(X_train, y_train)
val_dataset = TensorDataset(X_val, y_val)
test_dataset = TensorDataset(X_test, y_test)

# Create dataloaders
batch_size = 32

# %%
# Create dataloaders with reproducible worker processes
generator = torch.Generator()
generator.manual_seed(42)

train_dataloader = DataLoader(
    train_dataset,
    batch_size=batch_size,
    shuffle=True,
    num_workers=0,  # Single process for reproducibility
    worker_init_fn=worker_init_fn,
    generator=generator,
)
val_dataloader = DataLoader(
    val_dataset,
    batch_size=batch_size,
    shuffle=False,
    num_workers=0,  # Single process for reproducibility
    worker_init_fn=worker_init_fn,
    generator=generator,
)
test_dataloader = DataLoader(
    test_dataset,
    batch_size=batch_size,
    shuffle=False,
    num_workers=0,  # Single process for reproducibility
    worker_init_fn=worker_init_fn,
    generator=generator,
)

# %%
# サンプル数確認
print(f"Train samples: {len(train_dataset)}")
print(f"Validation samples: {len(val_dataset)}")
print(f"Test samples: {len(test_dataset)}")

# Fourier級数関数のプロット
t_plot = np.linspace(-1, 1, 1000)
y_plot = fourier_series(t_plot, N=15)
plt.figure(figsize=(10, 6))
plt.plot(t_plot, y_plot, "b-", label="Fourier Series (N=15)")
plt.scatter(t, targets, alpha=0.3, s=3, c="red", label="Training Data")
plt.xlabel("t")
plt.ylabel("f(t)")
plt.title("Fourier Series Function")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Train samples: 700
# Validation samples: 150
# Test samples: 150

# %% [markdown]
# ### 2-2.モデル学習

# %%
num_gp_pts = 10  # Number of Gaussian Process points
model = gplib.GP_Model(
    [
        gplib.LayerFused(1, 1, num_gp_pts),
        gplib.LayerFused(1, 1, num_gp_pts),
    ],
    saveload_path=SAVELOAD_PATH,  # Path to save/load the model
)
np.random.seed(42)  # for reproducibility
torch.manual_seed(42)  # for reproducibility
# Out:
# found existing saved model, loading from model_20.pt
# >loaded hyp

# %%
# 精度評価/可視化関数
def plot_result(model):
    # テストデータでの予測
    with torch.no_grad():
        # バッチごとに予測を行う
        test_predictions = []
        test_targets = []
        test_variances = []

        for X_batch, y_batch in test_dataloader:
            pred = model.predict(X_batch).mean
            var = model.predict(X_batch).var
            test_predictions.append(pred)
            test_variances.append(var)
            test_targets.append(y_batch)

        # 結果を結合
        test_predictions = torch.cat(test_predictions, dim=0)
        test_targets = torch.cat(test_targets, dim=0)
        test_variances = torch.cat(test_variances, dim=0)

    # MSE計算
    mse = torch.mean((test_predictions - test_targets) ** 2)
    rmse = torch.sqrt(mse)

    print(f"Test MSE: {mse.item():.6f}")
    print(f"Test RMSE: {rmse.item():.6f}")

    # 可視化用のデータ準備
    t_test = X_test.numpy().flatten()
    y_test_true = y_test.numpy().flatten()
    y_test_pred = test_predictions.numpy().flatten()

    # 真の関数の連続プロット用
    t_continuous = np.linspace(-1, 1, 500)
    y_continuous = fourier_series(t_continuous, N=15)

    # グラフ作成
    plt.figure(figsize=(12, 8))

    # 真の関数
    plt.plot(
        t_continuous,
        y_continuous,
        "b-",
        linewidth=2,
        label="True Function (Fourier Series)",
        alpha=0.8,
    )

    # テストデータの真値
    plt.scatter(
        t_test,
        y_test_true,
        c="red",
        s=30,
        alpha=0.6,
        label="Test Data (True)",
        marker="o",
    )

    # 予測値
    plt.scatter(
        t_test, y_test_pred, c="green", s=30, alpha=0.6, label="Predictions", marker="x"
    )

    # 予測の不確実性を帯で表示
    lower_bound = y_test_pred - 2 * np.sqrt(test_variances.numpy().flatten())
    upper_bound = y_test_pred + 2 * np.sqrt(test_variances.numpy().flatten())
    plt.fill_between(
        t_test,
        lower_bound,
        upper_bound,
        color="lightgreen",
        alpha=0.3,
        label="Prediction Interval(2σ)",
    )

    plt.xlabel("t")
    plt.ylabel("f(t)")
    plt.title(f"GP-KAN Prediction vs True Function\nTest RMSE: {rmse.item():.6f}")
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.show()

    # 残差プロット
    plt.figure(figsize=(10, 6))
    residuals = y_test_pred - y_test_true
    plt.scatter(t_test, residuals, c="purple", s=30, alpha=0.6)
    plt.axhline(y=0, color="red", linestyle="--", alpha=0.7)
    plt.xlabel("t")
    plt.ylabel("Residuals (Predicted - True)")
    plt.title("Residual Plot")
    plt.grid(True, alpha=0.3)
    plt.show()

    # 残差の統計情報
    print(f"\nResidual Statistics:")
    print(f"Mean: {np.mean(residuals):.6f}")
    print(f"Std: {np.std(residuals):.6f}")
    print(f"Min: {np.min(residuals):.6f}")
    print(f"Max: {np.max(residuals):.6f}")

    print("plot completed")
    return 0

# %%
import time

start_time = time.time()

for epoch in range(1):
    runner.train_model(
        train_dataloader,
        val_dataloader,
        model,
        epochs=200,
        learning_rate=1e-5,
        use_gpu=False,  # True,
        pretrain=False,  # True,
        global_jitter=JITTER_VALUE,
        baseline_jitter=JITTER_VALUE,
    )
    model.save_model()  # optionally save the model after training

    # 可視化
    plot_result(model)

end_time = time.time()
training_time = end_time - start_time

print(f"\n学習時間: {training_time:.2f}秒 ({training_time/60:.2f}分)")
# Out:
# epoch 0  , train negloglik: 0.32550,    val negloglik: 1.42542    accuracy: 0.2268 lr: [1e-05]
# epoch 1  , train negloglik: 0.37066,    val negloglik: 1.25876    accuracy: 0.2308 lr: [9e-06]
# epoch 2  , train negloglik: 0.32126,    val negloglik: 0.65656    accuracy: 0.2376 lr: [9e-06]
# epoch 3  , train negloglik: 0.43523,    val negloglik: 0.70200    accuracy: 0.2349 lr: [9e-06]
# epoch 4  , train negloglik: 0.44160,    val negloglik: 0.62937    accuracy: 0.2355 lr: [9e-06]
# epoch 5  , train negloglik: 0.33731,    val negloglik: 0.94056    accuracy: 0.2333 lr: [9e-06]
# epoch 6  , train negloglik: 0.35503,    val negloglik: 1.10866    accuracy: 0.2318 lr: [9e-06]
# epoch 7  , train negloglik: 0.35071,    val negloglik: 0.66825    accuracy: 0.2370 lr: [9e-06]
# epoch 8  , train negloglik: 0.39717,    val negloglik: 1.17953    accuracy: 0.2301 lr: [9e-06]
# epoch 9  , train negloglik: 0.54245,    val negloglik: 1.04763    accuracy: 0.2300 lr: [9e-06]
# epoch 10 , train negloglik: 0.36080,    val negloglik: 0.74239    accuracy: 0.2395 lr: [9e-06]
# epoch 11 , train negloglik: 0.36481,    val negloglik: 1.86817    accuracy: 0.2331 lr: [9e-06]
# epoch 12 , train negloglik: 0.32779,    val negloglik: 0.61582    accuracy: 0.2390 lr: [9e-06]
# epoch 13 , train negloglik: 0.38246,    val negloglik: 0.64143    accuracy: 0.2372 lr: [9e-06]
# epoch 14 , train negloglik: 0.55327,    val negloglik: 0.69288    accuracy: 0.2521 lr: [9e-06]
# epoch 15 , train negloglik: 0.38063,    val negloglik: 1.02116    accuracy: 0.2328 lr: [9e-06]
# epoch 16 , train negloglik: 0.38917,    val negloglik: 0.86161    accuracy: 0.2368 lr: [9e-06]
# epoch 17 , train negloglik: 0.40651,    val negloglik: 0.75599    accuracy: 0.2346 lr: [9e-06]
# epoch 18 , train negloglik: 0.34037,    val negloglik: 1.55916    accuracy: 0.2339 lr: [9e-06]
# epoch 19 , train negloglik: 0.30133,    val negloglik: 0.65715    accuracy: 0.2439 lr: [9e-06]
# epoch 20 , train negloglik: 0.36252,    val negloglik: 1.20860    accuracy: 0.2299 lr: [9e-06]
# epoch 21 , train negloglik: 0.40282,    val negloglik: 0.64255    accuracy: 0.2356 lr: [8.1e-06]
# epoch 22 , train negloglik: 0.38553,    val negloglik: 1.39912    accuracy: 0.2330 lr: [8.1e-06]
# epoch 23 , train negloglik: 0.38916,    val negloglik: 0.68216    accuracy: 0.2408 lr: [8.1e-06]
# epoch 24 , train negloglik: 0.34157,    val negloglik: 0.85290    accuracy: 0.2349 lr: [8.1e-06]
# epoch 25 , train negloglik: 0.40883,    val negloglik: 1.20250    accuracy: 0.2330 lr: [8.1e-06]
# epoch 26 , train negloglik: 0.46905,    val negloglik: 1.36522    accuracy: 0.2330 lr: [8.1e-06]
# epoch 27 , train negloglik: 0.32712,    val negloglik: 1.21842    accuracy: 0.2414 lr: [8.1e-06]
# epoch 28 , train negloglik: 0.30631,    val negloglik: 0.55867    accuracy: 0.2450 lr: [8.1e-06]
# epoch 29 , train negloglik: 0.29063,    val negloglik: 1.05400    accuracy: 0.2397 lr: [8.1e-06]
# epoch 30 , train negloglik: 0.41471,    val negloglik: 0.69601    accuracy: 0.2368 lr: [8.1e-06]
# epoch 31 , train negloglik: 0.40776,    val negloglik: 0.79427    accuracy: 0.2363 lr: [8.1e-06]
# epoch 32 , train negloglik: 0.30034,    val negloglik: 0.95148    accuracy: 0.2437 lr: [8.1e-06]
# epoch 33 , train negloglik: 0.31586,    val negloglik: 0.78857    accuracy: 0.2422 lr: [8.1e-06]
# epoch 34 , train negloglik: 0.32874,    val negloglik: 0.76777    accuracy: 0.2495 lr: [8.1e-06]
# epoch 35 , train negloglik: 0.34355,    val negloglik: 0.91819    accuracy: 0.2354 lr: [8.1e-06]
# epoch 36 , train negloglik: 0.28693,    val negloglik: 0.79333    accuracy: 0.2390 lr: [8.1e-06]
# epoch 37 , train negloglik: 0.28873,    val negloglik: 0.70005    accuracy: 0.2440 lr: [8.1e-06]
# epoch 38 , train negloglik: 0.34328,    val negloglik: 0.64976    accuracy: 0.2454 lr: [8.1e-06]
# epoch 39 , train negloglik: 0.42450,    val negloglik: 0.66973    accuracy: 0.2533 lr: [8.1e-06]
# epoch 40 , train negloglik: 0.45193,    val negloglik: 0.58013    accuracy: 0.2573 lr: [8.1e-06]
# epoch 41 , train negloglik: 0.40789,    val negloglik: 0.55490    accuracy: 0.2546 lr: [7.2900000000000005e-06]
# epoch 42 , train negloglik: 0.35893,    val negloglik: 0.63742    accuracy: 0.2406 lr: [7.2900000000000005e-06]
# epoch 43 , train negloglik: 0.32804,    val negloglik: 1.01731    accuracy: 0.2303 lr: [7.2900000000000005e-06]
# epoch 44 , train negloglik: 0.32632,    val negloglik: 0.51494    accuracy: 0.2418 lr: [7.2900000000000005e-06]
# epoch 45 , train negloglik: 0.27237,    val negloglik: 0.63353    accuracy: 0.2502 lr: [7.2900000000000005e-06]
# epoch 46 , train negloglik: 0.31537,    val negloglik: 0.65423    accuracy: 0.2476 lr: [7.2900000000000005e-06]
# epoch 47 , train negloglik: 0.30458,    val negloglik: 1.03382    accuracy: 0.2474 lr: [7.2900000000000005e-06]
# epoch 48 , train negloglik: 0.31908,    val negloglik: 0.48539    accuracy: 0.2479 lr: [7.2900000000000005e-06]
# epoch 49 , train negloglik: 0.35685,    val negloglik: 1.21180    accuracy: 0.2382 lr: [7.2900000000000005e-06]
# epoch 50 , train negloglik: 0.37031,    val negloglik: 0.76457    accuracy: 0.2595 lr: [7.2900000000000005e-06]
# epoch 51 , train negloglik: 0.29229,    val negloglik: 0.69129    accuracy: 0.2400 lr: [7.2900000000000005e-06]
# epoch 52 , train negloglik: 0.28191,    val negloglik: 0.98592    accuracy: 0.2417 lr: [7.2900000000000005e-06]
# epoch 53 , train negloglik: 0.37905,    val negloglik: 0.77593    accuracy: 0.2572 lr: [7.2900000000000005e-06]
# epoch 54 , train negloglik: 0.28907,    val negloglik: 0.48771    accuracy: 0.2428 lr: [7.2900000000000005e-06]
# epoch 55 , train negloglik: 0.25903,    val negloglik: 0.57529    accuracy: 0.2419 lr: [7.2900000000000005e-06]
# epoch 56 , train negloglik: 0.25943,    val negloglik: 0.78173    accuracy: 0.2451 lr: [7.2900000000000005e-06]
# epoch 57 , train negloglik: 0.29513,    val negloglik: 0.79617    accuracy: 0.2327 lr: [7.2900000000000005e-06]
# epoch 58 , train negloglik: 0.26181,    val negloglik: 0.67383    accuracy: 0.2446 lr: [7.2900000000000005e-06]
# epoch 59 , train negloglik: 0.30149,    val negloglik: 0.61766    accuracy: 0.2489 lr: [7.2900000000000005e-06]
# epoch 60 , train negloglik: 0.29353,    val negloglik: 0.55389    accuracy: 0.2429 lr: [7.2900000000000005e-06]
# epoch 61 , train negloglik: 0.31571,    val negloglik: 0.48947    accuracy: 0.2482 lr: [6.561e-06]
# epoch 62 , train negloglik: 0.33311,    val negloglik: 0.62853    accuracy: 0.2520 lr: [6.561e-06]
# epoch 63 , train negloglik: 0.34017,    val negloglik: 0.82302    accuracy: 0.2500 lr: [6.561e-06]
# epoch 64 , train negloglik: 0.29667,    val negloglik: 0.79817    accuracy: 0.2418 lr: [6.561e-06]
# epoch 65 , train negloglik: 0.30678,    val negloglik: 0.64582    accuracy: 0.2529 lr: [6.561e-06]
# epoch 66 , train negloglik: 0.29199,    val negloglik: 0.65489    accuracy: 0.2445 lr: [6.561e-06]
# epoch 67 , train negloglik: 0.29126,    val negloglik: 0.64160    accuracy: 0.2415 lr: [6.561e-06]
# epoch 68 , train negloglik: 0.27208,    val negloglik: 0.48617    accuracy: 0.2423 lr: [6.561e-06]
# epoch 69 , train negloglik: 0.32002,    val negloglik: 0.51379    accuracy: 0.2437 lr: [6.561e-06]
# epoch 70 , train negloglik: 0.26066,    val negloglik: 0.89914    accuracy: 0.2636 lr: [6.561e-06]
# epoch 71 , train negloglik: 0.26147,    val negloglik: 0.87155    accuracy: 0.2443 lr: [6.561e-06]
# epoch 72 , train negloglik: 0.26948,    val negloglik: 0.81576    accuracy: 0.2473 lr: [6.561e-06]
# epoch 73 , train negloglik: 0.28494,    val negloglik: 0.44994    accuracy: 0.2335 lr: [6.561e-06]
# epoch 74 , train negloglik: 0.28548,    val negloglik: 0.52059    accuracy: 0.2553 lr: [6.561e-06]
# epoch 75 , train negloglik: 0.24739,    val negloglik: 0.59090    accuracy: 0.2656 lr: [6.561e-06]
# epoch 76 , train negloglik: 0.25493,    val negloglik: 0.40482    accuracy: 0.2260 lr: [6.561e-06]
# epoch 77 , train negloglik: 0.29627,    val negloglik: 0.61776    accuracy: 0.2496 lr: [6.561e-06]
# epoch 78 , train negloglik: 0.24862,    val negloglik: 0.75667    accuracy: 0.2357 lr: [6.561e-06]
# epoch 79 , train negloglik: 0.25588,    val negloglik: 0.50223    accuracy: 0.2319 lr: [6.561e-06]
# epoch 80 , train negloglik: 0.23971,    val negloglik: 0.91795    accuracy: 0.2522 lr: [6.561e-06]
# epoch 81 , train negloglik: 0.22356,    val negloglik: 0.55025    accuracy: 0.2290 lr: [5.904900000000001e-06]
# epoch 82 , train negloglik: 0.23942,    val negloglik: 0.70002    accuracy: 0.2413 lr: [5.904900000000001e-06]
# epoch 83 , train negloglik: 0.26018,    val negloglik: 0.49181    accuracy: 0.2450 lr: [5.904900000000001e-06]
# epoch 84 , train negloglik: 0.29058,    val negloglik: 0.47651    accuracy: 0.2430 lr: [5.904900000000001e-06]
# epoch 85 , train negloglik: 0.28013,    val negloglik: 0.49919    accuracy: 0.2348 lr: [5.904900000000001e-06]
# epoch 86 , train negloglik: 0.21140,    val negloglik: 0.49893    accuracy: 0.2416 lr: [5.904900000000001e-06]
# epoch 87 , train negloglik: 0.27141,    val negloglik: 0.51386    accuracy: 0.2464 lr: [5.904900000000001e-06]
# epoch 88 , train negloglik: 0.23607,    val negloglik: 0.48361    accuracy: 0.2618 lr: [5.904900000000001e-06]
# epoch 89 , train negloglik: 0.26120,    val negloglik: 0.81028    accuracy: 0.2330 lr: [5.904900000000001e-06]
# epoch 90 , train negloglik: 0.23511,    val negloglik: 0.44309    accuracy: 0.2324 lr: [5.904900000000001e-06]
# epoch 91 , train negloglik: 0.29274,    val negloglik: 0.57029    accuracy: 0.2489 lr: [5.904900000000001e-06]
# epoch 92 , train negloglik: 0.27889,    val negloglik: 0.43319    accuracy: 0.2342 lr: [5.904900000000001e-06]
# epoch 93 , train negloglik: 0.27688,    val negloglik: 0.40529    accuracy: 0.2482 lr: [5.904900000000001e-06]
# epoch 94 , train negloglik: 0.25412,    val negloglik: 0.52642    accuracy: 0.2432 lr: [5.904900000000001e-06]
# epoch 95 , train negloglik: 0.23403,    val negloglik: 0.73697    accuracy: 0.2312 lr: [5.904900000000001e-06]
# epoch 96 , train negloglik: 0.24450,    val negloglik: 0.46902    accuracy: 0.2638 lr: [5.904900000000001e-06]
# epoch 97 , train negloglik: 0.24472,    val negloglik: 0.43237    accuracy: 0.2342 lr: [5.904900000000001e-06]
# epoch 98 , train negloglik: 0.25162,    val negloglik: 0.43323    accuracy: 0.2385 lr: [5.904900000000001e-06]
# epoch 99 , train negloglik: 0.25705,    val negloglik: 0.54409    accuracy: 0.2409 lr: [5.904900000000001e-06]
# epoch 100, train negloglik: 0.27466,    val negloglik: 0.57852    accuracy: 0.2512 lr: [5.904900000000001e-06]
# epoch 101, train negloglik: 0.21524,    val negloglik: 0.42428    accuracy: 0.2428 lr: [5.314410000000001e-06]
# epoch 102, train negloglik: 0.23814,    val negloglik: 0.59913    accuracy: 0.2375 lr: [5.314410000000001e-06]
# epoch 103, train negloglik: 0.27242,    val negloglik: 0.66434    accuracy: 0.2176 lr: [5.314410000000001e-06]
# epoch 104, train negloglik: 0.23010,    val negloglik: 0.44766    accuracy: 0.2399 lr: [5.314410000000001e-06]
# epoch 105, train negloglik: 0.19588,    val negloglik: 0.51529    accuracy: 0.2392 lr: [5.314410000000001e-06]
# epoch 106, train negloglik: 0.20782,    val negloglik: 0.50819    accuracy: 0.2322 lr: [5.314410000000001e-06]
# epoch 107, train negloglik: 0.25106,    val negloglik: 0.55915    accuracy: 0.2471 lr: [5.314410000000001e-06]
# epoch 108, train negloglik: 0.27767,    val negloglik: 0.44818    accuracy: 0.2502 lr: [5.314410000000001e-06]
# epoch 109, train negloglik: 0.23808,    val negloglik: 0.37460    accuracy: 0.2394 lr: [5.314410000000001e-06]
# epoch 110, train negloglik: 0.24086,    val negloglik: 0.43765    accuracy: 0.2367 lr: [5.314410000000001e-06]
# epoch 111, train negloglik: 0.20233,    val negloglik: 0.39041    accuracy: 0.2391 lr: [5.314410000000001e-06]
# epoch 112, train negloglik: 0.22120,    val negloglik: 0.45085    accuracy: 0.2606 lr: [5.314410000000001e-06]
# epoch 113, train negloglik: 0.24391,    val negloglik: 0.62024    accuracy: 0.2572 lr: [5.314410000000001e-06]
# epoch 114, train negloglik: 0.20965,    val negloglik: 0.75193    accuracy: 0.2307 lr: [5.314410000000001e-06]
# epoch 115, train negloglik: 0.22418,    val negloglik: 0.47586    accuracy: 0.2224 lr: [5.314410000000001e-06]
# epoch 116, train negloglik: 0.18896,    val negloglik: 0.76612    accuracy: 0.2641 lr: [5.314410000000001e-06]
# epoch 117, train negloglik: 0.21007,    val negloglik: 0.40688    accuracy: 0.2454 lr: [5.314410000000001e-06]
# epoch 118, train negloglik: 0.23157,    val negloglik: 0.92532    accuracy: 0.2390 lr: [5.314410000000001e-06]
# epoch 119, train negloglik: 0.20074,    val negloglik: 0.52725    accuracy: 0.2359 lr: [5.314410000000001e-06]
# epoch 120, train negloglik: 0.23447,    val negloglik: 0.79935    accuracy: 0.2760 lr: [5.314410000000001e-06]
# epoch 121, train negloglik: 0.25540,    val negloglik: 0.65187    accuracy: 0.2471 lr: [4.782969000000001e-06]
# epoch 122, train negloglik: 0.20840,    val negloglik: 0.81616    accuracy: 0.2553 lr: [4.782969000000001e-06]
# epoch 123, train negloglik: 0.24159,    val negloglik: 0.51020    accuracy: 0.2297 lr: [4.782969000000001e-06]
# epoch 124, train negloglik: 0.20492,    val negloglik: 0.45716    accuracy: 0.2429 lr: [4.782969000000001e-06]
# epoch 125, train negloglik: 0.21466,    val negloglik: 0.55600    accuracy: 0.2364 lr: [4.782969000000001e-06]
# epoch 126, train negloglik: 0.22190,    val negloglik: 0.43946    accuracy: 0.2243 lr: [4.782969000000001e-06]
# epoch 127, train negloglik: 0.21038,    val negloglik: 0.65657    accuracy: 0.2327 lr: [4.782969000000001e-06]
# epoch 128, train negloglik: 0.21094,    val negloglik: 0.44195    accuracy: 0.2341 lr: [4.782969000000001e-06]
# epoch 129, train negloglik: 0.23247,    val negloglik: 0.39727    accuracy: 0.2336 lr: [4.782969000000001e-06]
# epoch 130, train negloglik: 0.19090,    val negloglik: 0.57204    accuracy: 0.2320 lr: [4.782969000000001e-06]
# epoch 131, train negloglik: 0.20903,    val negloglik: 0.78700    accuracy: 0.2482 lr: [4.782969000000001e-06]
# epoch 132, train negloglik: 0.18537,    val negloglik: 0.56187    accuracy: 0.2346 lr: [4.782969000000001e-06]
# epoch 133, train negloglik: 0.22370,    val negloglik: 0.55885    accuracy: 0.2228 lr: [4.782969000000001e-06]
# epoch 134, train negloglik: 0.18356,    val negloglik: 0.35907    accuracy: 0.2468 lr: [4.782969000000001e-06]
# epoch 135, train negloglik: 0.19279,    val negloglik: 0.52567    accuracy: 0.2319 lr: [4.782969000000001e-06]
# epoch 136, train negloglik: 0.22756,    val negloglik: 0.62831    accuracy: 0.2225 lr: [4.782969000000001e-06]
# epoch 137, train negloglik: 0.19954,    val negloglik: 0.36294    accuracy: 0.2314 lr: [4.782969000000001e-06]
# epoch 138, train negloglik: 0.18952,    val negloglik: 0.67766    accuracy: 0.2216 lr: [4.782969000000001e-06]
# epoch 139, train negloglik: 0.21422,    val negloglik: 0.56478    accuracy: 0.2368 lr: [4.782969000000001e-06]
# epoch 140, train negloglik: 0.21079,    val negloglik: 0.47422    accuracy: 0.2455 lr: [4.782969000000001e-06]
# epoch 141, train negloglik: 0.22821,    val negloglik: 0.53610    accuracy: 0.2313 lr: [4.3046721000000005e-06]
# epoch 142, train negloglik: 0.19740,    val negloglik: 0.45446    accuracy: 0.2547 lr: [4.3046721000000005e-06]
# epoch 143, train negloglik: 0.17839,    val negloglik: 0.37579    accuracy: 0.2423 lr: [4.3046721000000005e-06]
# epoch 144, train negloglik: 0.20311,    val negloglik: 0.46051    accuracy: 0.2354 lr: [4.3046721000000005e-06]
# epoch 145, train negloglik: 0.20808,    val negloglik: 0.50197    accuracy: 0.2328 lr: [4.3046721000000005e-06]
# epoch 146, train negloglik: 0.18477,    val negloglik: 0.51341    accuracy: 0.2334 lr: [4.3046721000000005e-06]
# epoch 147, train negloglik: 0.22384,    val negloglik: 0.41575    accuracy: 0.2410 lr: [4.3046721000000005e-06]
# epoch 148, train negloglik: 0.20658,    val negloglik: 0.64846    accuracy: 0.2457 lr: [4.3046721000000005e-06]
# epoch 149, train negloglik: 0.20117,    val negloglik: 0.41904    accuracy: 0.2398 lr: [4.3046721000000005e-06]
# epoch 150, train negloglik: 0.18042,    val negloglik: 0.49168    accuracy: 0.2396 lr: [4.3046721000000005e-06]
# epoch 151, train negloglik: 0.22647,    val negloglik: 0.45172    accuracy: 0.2276 lr: [4.3046721000000005e-06]
# epoch 152, train negloglik: 0.18107,    val negloglik: 0.55222    accuracy: 0.2125 lr: [4.3046721000000005e-06]
# epoch 153, train negloglik: 0.16884,    val negloglik: 0.59851    accuracy: 0.2241 lr: [4.3046721000000005e-06]
# epoch 154, train negloglik: 0.18597,    val negloglik: 0.48744    accuracy: 0.2152 lr: [4.3046721000000005e-06]
# epoch 155, train negloglik: 0.19394,    val negloglik: 0.51684    accuracy: 0.2352 lr: [4.3046721000000005e-06]
# epoch 156, train negloglik: 0.16717,    val negloglik: 0.62160    accuracy: 0.2279 lr: [4.3046721000000005e-06]
# epoch 157, train negloglik: 0.23986,    val negloglik: 0.44363    accuracy: 0.2128 lr: [4.3046721000000005e-06]
# epoch 158, train negloglik: 0.24023,    val negloglik: 0.47282    accuracy: 0.2133 lr: [4.3046721000000005e-06]
# epoch 159, train negloglik: 0.19758,    val negloglik: 0.65723    accuracy: 0.2421 lr: [4.3046721000000005e-06]
# epoch 160, train negloglik: 0.20357,    val negloglik: 0.29094    accuracy: 0.2428 lr: [4.3046721000000005e-06]
# epoch 161, train negloglik: 0.18805,    val negloglik: 0.34042    accuracy: 0.2331 lr: [3.874204890000001e-06]
# epoch 162, train negloglik: 0.20360,    val negloglik: 0.44005    accuracy: 0.2167 lr: [3.874204890000001e-06]
# epoch 163, train negloglik: 0.21933,    val negloglik: 0.44452    accuracy: 0.2107 lr: [3.874204890000001e-06]
# epoch 164, train negloglik: 0.19395,    val negloglik: 0.69655    accuracy: 0.2063 lr: [3.874204890000001e-06]
# epoch 165, train negloglik: 0.20365,    val negloglik: 0.50180    accuracy: 0.2117 lr: [3.874204890000001e-06]
# epoch 166, train negloglik: 0.20228,    val negloglik: 0.40736    accuracy: 0.2104 lr: [3.874204890000001e-06]
# epoch 167, train negloglik: 0.18494,    val negloglik: 0.48906    accuracy: 0.2274 lr: [3.874204890000001e-06]
# epoch 168, train negloglik: 0.18946,    val negloglik: 0.50333    accuracy: 0.2349 lr: [3.874204890000001e-06]
# epoch 169, train negloglik: 0.18898,    val negloglik: 0.45630    accuracy: 0.2365 lr: [3.874204890000001e-06]
# epoch 170, train negloglik: 0.17016,    val negloglik: 0.52883    accuracy: 0.2600 lr: [3.874204890000001e-06]
# epoch 171, train negloglik: 0.17535,    val negloglik: 0.54812    accuracy: 0.2223 lr: [3.874204890000001e-06]
# epoch 172, train negloglik: 0.15829,    val negloglik: 0.35629    accuracy: 0.2161 lr: [3.874204890000001e-06]
# epoch 173, train negloglik: 0.17571,    val negloglik: 0.55025    accuracy: 0.2191 lr: [3.874204890000001e-06]
# epoch 174, train negloglik: 0.17306,    val negloglik: 0.54470    accuracy: 0.2587 lr: [3.874204890000001e-06]
# epoch 175, train negloglik: 0.21507,    val negloglik: 0.40692    accuracy: 0.2227 lr: [3.874204890000001e-06]
# epoch 176, train negloglik: 0.16972,    val negloglik: 0.37109    accuracy: 0.2131 lr: [3.874204890000001e-06]
# epoch 177, train negloglik: 0.16396,    val negloglik: 0.40937    accuracy: 0.2034 lr: [3.874204890000001e-06]
# epoch 178, train negloglik: 0.20544,    val negloglik: 0.30177    accuracy: 0.2253 lr: [3.874204890000001e-06]
# epoch 179, train negloglik: 0.18868,    val negloglik: 0.51509    accuracy: 0.2374 lr: [3.874204890000001e-06]
# epoch 180, train negloglik: 0.18319,    val negloglik: 0.32451    accuracy: 0.2237 lr: [3.874204890000001e-06]
# epoch 181, train negloglik: 0.18125,    val negloglik: 0.55885    accuracy: 0.2250 lr: [3.4867844010000007e-06]
# epoch 182, train negloglik: 0.18954,    val negloglik: 0.29257    accuracy: 0.2158 lr: [3.4867844010000007e-06]
# epoch 183, train negloglik: 0.17293,    val negloglik: 0.33525    accuracy: 0.2315 lr: [3.4867844010000007e-06]
# epoch 184, train negloglik: 0.15858,    val negloglik: 0.37145    accuracy: 0.2377 lr: [3.4867844010000007e-06]
# epoch 185, train negloglik: 0.17821,    val negloglik: 0.39936    accuracy: 0.2130 lr: [3.4867844010000007e-06]
# epoch 186, train negloglik: 0.16171,    val negloglik: 0.48178    accuracy: 0.2088 lr: [3.4867844010000007e-06]
# epoch 187, train negloglik: 0.18766,    val negloglik: 0.30455    accuracy: 0.2198 lr: [3.4867844010000007e-06]
# epoch 188, train negloglik: 0.16077,    val negloglik: 0.39466    accuracy: 0.2379 lr: [3.4867844010000007e-06]
# epoch 189, train negloglik: 0.16747,    val negloglik: 0.43622    accuracy: 0.2252 lr: [3.4867844010000007e-06]
# epoch 190, train negloglik: 0.17877,    val negloglik: 0.32858    accuracy: 0.2453 lr: [3.4867844010000007e-06]
# epoch 191, train negloglik: 0.15535,    val negloglik: 0.39099    accuracy: 0.2685 lr: [3.4867844010000007e-06]
# epoch 192, train negloglik: 0.15953,    val negloglik: 0.47686    accuracy: 0.2626 lr: [3.4867844010000007e-06]
# epoch 193, train negloglik: 0.16346,    val negloglik: 0.41380    accuracy: 0.2194 lr: [3.4867844010000007e-06]
# epoch 194, train negloglik: 0.19426,    val negloglik: 0.36739    accuracy: 0.2158 lr: [3.4867844010000007e-06]
# epoch 195, train negloglik: 0.20710,    val negloglik: 0.29128    accuracy: 0.2190 lr: [3.4867844010000007e-06]
# epoch 196, train negloglik: 0.16445,    val negloglik: 0.49148    accuracy: 0.2278 lr: [3.4867844010000007e-06]
# epoch 197, train negloglik: 0.14281,    val negloglik: 0.27701    accuracy: 0.2280 lr: [3.4867844010000007e-06]
# epoch 198, train negloglik: 0.17471,    val negloglik: 0.36816    accuracy: 0.2183 lr: [3.4867844010000007e-06]
# epoch 199, train negloglik: 0.16235,    val negloglik: 0.52514    accuracy: 0.2092 lr: [3.4867844010000007e-06]
# Test MSE: 0.122549
# Test RMSE: 0.350070
# Residual Statistics:
# Mean: 0.034601
# Std: 0.348356
# Min: -2.255396
# Max: 0.879983
# plot completed
#
# 学習時間: 24.99秒 (0.42分)

# %% [markdown]
# ## 3.結果評価
# 以下の項目に従ってカーネル行列の分析結果をまとめる：
#
# **カーネル行列分析項目**
# - 各層のカーネル行列ランクと条件数の分析
# - 誘導点の分布と配置の可視化
# - カーネル行列のヒートマップ（Jitter項適用前後）
# - 固有値分布の分析
# - 誘導点間距離の統計的分析

# %%
# 1層目
model.layers[0].save_fig("../outputs/layer_fused0.png")
model.layers[1].save_fig("../outputs/layer_fused1.png")

# %%
# カーネル行列のランク可視化・分析
import matplotlib.pyplot as plt
import numpy as np
import torch


def analyze_kernel_matrices(model):
    """
    GP-KANの各層のカーネル行列ランクと条件数を分析・可視化する
    """
    print("=== カーネル行列分析 ===")

    # 各層の分析
    for layer_idx, layer in enumerate(model.layers):
        print(f"\n--- Layer {layer_idx} ---")

        # 誘導点を取得
        z_range = layer.get_z().detach()  # 入力値
        h_range = layer.h.detach()  # 出力値
        jitter = layer.get_jitter().detach()  # Shape: [1, 1]
        print(
            f"z(誘導点)の範囲: [{z_range.min().item():.4f}, {z_range.max().item():.4f}]"
        )
        print(
            f"h(関数値)の範囲: [{h_range.min().item():.4f}, {h_range.max().item():.4f}]"
        )

        # カーネル行列を計算
        with torch.no_grad():
            # カーネル行列を計算
            lengthscale = layer.l.detach()  # Shape: [1, 1]
            variance = layer.s.detach()  # Shape: [1, 1]

            # Set i=j=1 for processing (assuming we want the first GP component)
            i, j = 0, 0  # Using 0-based indexing for tensor access

            # Get parameters for this specific GP
            z_ij = z_range[i, j, :]  # Shape: [X]
            l_ij = lengthscale[i, j]  # Scalar
            s_ij = variance[i, j]  # Scalar

            # Reshape inducing points for distance computation
            z_ij = z_ij.unsqueeze(1)  # Shape: [X, 1]

            # Compute kernel matrix for this GP
            pairwise_sq_dists = torch.cdist(z_ij, z_ij, p=2) ** 2
            # 誘導点間のカーネル行列
            K = s_ij * torch.exp(-pairwise_sq_dists / (2 * l_ij**2))

            print("計算開始")
            # ランク計算
            rank_clean = torch.linalg.matrix_rank(K)

            # 条件数計算
            cond_clean = torch.linalg.cond(K)

            # 固有値
            eigenvals_clean = torch.linalg.eigvals(K).real

            print("計算完了")

            print(f"カーネル行列ランク: {rank_clean.item()}")
            print(f"条件数: {cond_clean.item():.2e}")
            print(f"最小固有値: {eigenvals_clean.min().item():.2e}")
            print(
                f"パラメータ値 - s_ij: {s_ij.item():.4f}, l_ij: {l_ij.item():.4f}, jitter: {jitter.item():.4f}"
            )

        # 可視化
        fig, axes = plt.subplots(2, 3, figsize=(15, 10))

        # 誘導点の分布
        axes[0, 0].scatter(
            z_range.numpy(),
            h_range.numpy(),
            alpha=0.7,
            s=50,
        )
        axes[0, 0].set_title(f"Layer {layer_idx}: 誘導点分布")
        axes[0, 0].set_xlabel("誘導点位置")
        axes[0, 0].grid(True, alpha=0.3)

        # カーネル行列のヒートマップ
        im1 = axes[0, 1].imshow(K.numpy(), cmap="viridis")
        axes[0, 1].set_title(f"カーネル行列\nRank: {rank_clean.item()}")
        plt.colorbar(im1, ax=axes[0, 1])

        # パラメータ値のプロット
        params = ["s", "l", "jitter"]
        values = [s_ij.item(), l_ij.item(), jitter.item()]
        axes[0, 2].bar(params, values)
        axes[0, 2].set_title("パラメータ値")
        axes[0, 2].set_ylabel("値")
        for i, v in enumerate(values):
            axes[0, 2].text(i, v, f"{v:.4f}", ha="center", va="bottom")

        # 固有値分布
        eigenvals_sorted = torch.sort(eigenvals_clean, descending=True)[0]
        axes[1, 0].semilogy(eigenvals_sorted.numpy(), "o-")
        axes[1, 0].set_title("固有値分布")
        axes[1, 0].set_xlabel("固有値インデックス")
        axes[1, 0].set_ylabel("固有値 (log scale)")
        axes[1, 0].grid(True, alpha=0.3)

        # 条件数とランクの可視化
        metrics = ["Rank", "Condition Number (log)"]
        metric_values = [rank_clean.item(), np.log10(cond_clean.item())]
        axes[1, 1].bar(metrics, metric_values)
        axes[1, 1].set_title("行列特性")
        axes[1, 1].set_ylabel("値")
        for i, v in enumerate(metric_values):
            if i == 0:
                axes[1, 1].text(i, v, f"{int(v)}", ha="center", va="bottom")
            else:
                axes[1, 1].text(i, v, f"{v:.2f}", ha="center", va="bottom")

        # パラメータ値の詳細プロット（対数スケール）
        axes[1, 2].bar(params, np.log10(np.abs(values)))
        axes[1, 2].set_title("パラメータ値 (log10)")
        axes[1, 2].set_ylabel("log10(値)")
        for i, v in enumerate(values):
            axes[1, 2].text(i, np.log10(abs(v)), f"{v:.4f}", ha="center", va="bottom")

        plt.tight_layout()
        plt.show()

        # 誘導点間の距離分析
        distances = torch.cdist(z_ij.unsqueeze(0), z_ij.unsqueeze(0)).squeeze(
            0
        )  # Shape: [X, X]
        min_dist = distances[distances > 0].min()
        max_dist = distances[distances > 0].max()
        mean_dist = distances[distances > 0].mean()

        print(
            f"誘導点間距離 - 最小: {min_dist.item():.4f}, 最大: {max_dist.item():.4f}, 平均: {mean_dist.item():.4f}"
        )

        # 距離分布のヒストグラム
        plt.figure(figsize=(10, 6))
        dist_flat = distances[distances > 0].numpy()
        plt.hist(dist_flat, bins=20, alpha=0.7, edgecolor="black")
        plt.axvline(
            min_dist.item(),
            color="red",
            linestyle="--",
            label=f"最小距離: {min_dist.item():.4f}",
        )
        plt.axvline(
            mean_dist.item(),
            color="green",
            linestyle="--",
            label=f"平均距離: {mean_dist.item():.4f}",
        )
        plt.xlabel("誘導点間距離")
        plt.ylabel("頻度")
        plt.title(f"Layer {layer_idx}: 誘導点間距離分布")
        plt.legend()
        plt.grid(True, alpha=0.3)
        plt.show()


# 実行
analyze_kernel_matrices(model)
# Out:
# === カーネル行列分析 ===
#
# --- Layer 0 ---
# z(誘導点)の範囲: [-1.0000, 0.9971]
# h(関数値)の範囲: [-0.9044, 0.8710]
# 計算開始
# 計算完了
# カーネル行列ランク: 9
# 条件数: 7.17e+07
# 最小固有値: -3.41e+00
# パラメータ値 - s_ij: -0.7675, l_ij: 0.5291, jitter: 0.0025
# /var/folders/sh/nky4c839309dmt8714wl6msr0000gn/T/ipykernel_42844/691919597.py:124: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   plt.tight_layout()
# 誘導点間距離 - 最小: 0.0237, 最大: 1.9971, 平均: 0.9597
# --- Layer 1 ---
# z(誘導点)の範囲: [-0.9832, 0.9809]
# h(関数値)の範囲: [-0.1284, 1.0525]
# 計算開始
# 計算完了
# カーネル行列ランク: 4
# 条件数: 4.71e+08
# 最小固有値: -1.54e-07
# パラメータ値 - s_ij: 0.6990, l_ij: -3.0932, jitter: 0.0021
# 誘導点間距離 - 最小: 0.0115, 最大: 1.9641, 平均: 0.9517

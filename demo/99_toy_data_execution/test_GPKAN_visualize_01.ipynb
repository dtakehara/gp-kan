# %%
import sys
sys.path.append("../../") # add top-level to import path search
from lib import model as gplib
from lib import runner
# from lib.dataset import MNIST
import torch.utils.data
from torch.utils.data import DataLoader

# %% [markdown]
# First, load train, validation and test dataloaders

# %%
import numpy as np
import torch
from torch.utils.data import TensorDataset, DataLoader
import matplotlib.pyplot as plt

# Generate synthetic data with f(x, y) = 2x^2 + y^2
np.random.seed(42)  # for reproducibility
num_samples = 1000

# Generate random input points (x, y) from -1 to 1
x = np.random.uniform(-1, 1, num_samples)
y = np.random.uniform(-1, 1, num_samples)


# Compute target values: f(x, y) = 2x^2 + y^2
targets = 2 * x**2 + y**2

# Reshape inputs
inputs = np.vstack((x, y)).T

# Convert to PyTorch tensors
X_tensor = torch.FloatTensor(inputs)
y_tensor = torch.FloatTensor(targets).reshape(-1, 1)

# Split data into train, validation, and test sets
train_size = int(0.7 * num_samples)
val_size = int(0.15 * num_samples)
test_size = num_samples - train_size - val_size

X_train = X_tensor[:train_size]
y_train = y_tensor[:train_size]

X_val = X_tensor[train_size:train_size+val_size]
y_val = y_tensor[train_size:train_size+val_size]

X_test = X_tensor[train_size+val_size:]
y_test = y_tensor[train_size+val_size:]

# Create datasets
train_dataset = TensorDataset(X_train, y_train)
val_dataset = TensorDataset(X_val, y_val)
test_dataset = TensorDataset(X_test, y_test)

# Create dataloaders
batch_size = 32
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size)

print(f"Train samples: {len(train_dataset)}")
print(f"Validation samples: {len(val_dataset)}")
print(f"Test samples: {len(test_dataset)}")
# Out:
# Train samples: 700
# Validation samples: 150
# Test samples: 150

# %%
# Create a 3D visualization of the function
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# Create a grid of x and y values
x_grid, y_grid = np.meshgrid(np.linspace(-1, 1, 30), np.linspace(-1, 1, 30))
z_grid = 2 * x_grid**2 + y_grid**2  # The target function

# Plot the surface
surface = ax.plot_surface(x_grid, y_grid, z_grid, alpha=0.8)

# Plot the data points
ax.scatter(x, y, targets, c='blue', marker='o', s=2)

# Add labels and a colorbar
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('f(x,y) = 2x² + y²')
ax.set_title('3D Visualization of Target Function')
# Out:
# Text(0.5, 0.92, '3D Visualization of Target Function')

# %% [markdown]
# Load an existing model

# %%
# model = gplib.GP_Model(saveload_path="model80k.pt")
# model.print_model()

# %% [markdown]
# Test the model

# %%
# runner.test_model(test_dataloader, model, use_gpu=True)

# %% [markdown]
# Example MNIST images and model prediction

# %%
# import matplotlib.pyplot as plt
# import numpy as np
# np.set_printoptions(suppress=True, precision=3)
# inputs, labels = next(iter(test_dataloader))
# inputs = inputs.cuda()
# labels = labels.cuda()
# predictions = model.predict(inputs)

# fig, axes = plt.subplots(1, 3)
# for i in range(3):
#     axes[i].imshow(inputs[i].cpu())
#     pred = predictions.mean[i].detach().cpu().numpy()
#     true_label = np.argmax(labels[i].detach().cpu().numpy())
#     pred_max = np.argmax(pred)
#     axes[i].set_title(
#         f"true label: {true_label}\n"
#         f"model prediction: {pred_max}\n"
#         f"raw model mean:\n{pred[:5]}\n{pred[5:]}\n",
#         ha="left",
#         loc="left",
#     )

# fig.set_figwidth(10)
# fig.set_figheight(5)
# fig.tight_layout()

# %% [markdown]
# Train a new model

# %%
# model = gplib.GP_Model(
#     [
#         gplib.GP_conv2D(28, 28, 1, 3, kernel_size=4, stride=2, num_gp_pts=10, use_double_layer=True),
#         gplib.NormaliseGaussian(),
#         gplib.GP_conv2D(13, 13, 3, 3, kernel_size=4, stride=2, num_gp_pts=10, use_double_layer=True),
#         gplib.NormaliseGaussian(),
#         gplib.ReshapeGaussian([-1, 75]),
#         gplib.LayerFused(75, 10, num_gp_pts=10),
#         gplib.NormaliseGaussian(),
#         gplib.LayerFused(10, 10, num_gp_pts=10),
#     ],
#     saveload_path="model.pt",
# )

model = gplib.GP_Model(
    [   
        gplib.LayerFused(2, 1, num_gp_pts=10),
    ],
    saveload_path="model_test01_01.pt",
)
np.random.seed(42)  # for reproducibility
runner.train_model(
    train_dataloader, val_dataloader, model, epochs=500, learning_rate=1e-3, use_gpu=False, # True,
    pretrain=False,# True,
    global_jitter=1e-2, baseline_jitter=1e-2
)
model.save_model() # optionally save the model after training
# Out:
# epoch 0  , train negloglik: 23.95729,    val negloglik: 7.48728    accuracy: 0.3948 lr: [0.001]
# epoch 1  , train negloglik: 4.78644,    val negloglik: 2.80544    accuracy: 0.1799 lr: [0.0009000000000000001]
# epoch 2  , train negloglik: 1.58701,    val negloglik: 0.91800    accuracy: 0.0813 lr: [0.0009000000000000001]
# epoch 3  , train negloglik: 0.71213,    val negloglik: 0.38728    accuracy: 0.0516 lr: [0.0009000000000000001]
# epoch 4  , train negloglik: 0.37370,    val negloglik: 0.16155    accuracy: 0.0607 lr: [0.0009000000000000001]
# epoch 5  , train negloglik: 0.08280,    val negloglik: -0.07558    accuracy: 0.0459 lr: [0.0009000000000000001]
# epoch 6  , train negloglik: -0.26139,    val negloglik: -0.41383    accuracy: 0.0216 lr: [0.0009000000000000001]
# epoch 7  , train negloglik: -0.46529,    val negloglik: -0.58986    accuracy: 0.0150 lr: [0.0009000000000000001]
# epoch 8  , train negloglik: -0.62542,    val negloglik: -0.68717    accuracy: 0.0120 lr: [0.0009000000000000001]
# epoch 9  , train negloglik: -0.72517,    val negloglik: -0.77717    accuracy: 0.0090 lr: [0.0009000000000000001]
# epoch 10 , train negloglik: -0.80459,    val negloglik: -0.83819    accuracy: 0.0069 lr: [0.0009000000000000001]
# epoch 11 , train negloglik: -0.86433,    val negloglik: -0.88587    accuracy: 0.0051 lr: [0.0009000000000000001]
# epoch 12 , train negloglik: -0.90535,    val negloglik: -0.91715    accuracy: 0.0040 lr: [0.0009000000000000001]
# epoch 13 , train negloglik: -0.93565,    val negloglik: -0.94273    accuracy: 0.0031 lr: [0.0009000000000000001]
# epoch 14 , train negloglik: -0.95591,    val negloglik: -0.96204    accuracy: 0.0024 lr: [0.0009000000000000001]
# epoch 15 , train negloglik: -0.97211,    val negloglik: -0.97771    accuracy: 0.0018 lr: [0.0009000000000000001]
# epoch 16 , train negloglik: -0.98444,    val negloglik: -0.98579    accuracy: 0.0015 lr: [0.0009000000000000001]
# epoch 17 , train negloglik: -0.99337,    val negloglik: -0.99480    accuracy: 0.0012 lr: [0.0009000000000000001]
# epoch 18 , train negloglik: -1.00009,    val negloglik: -1.00117    accuracy: 0.0009 lr: [0.0009000000000000001]
# epoch 19 , train negloglik: -1.00557,    val negloglik: -1.00568    accuracy: 0.0008 lr: [0.0009000000000000001]
# epoch 20 , train negloglik: -1.00989,    val negloglik: -1.01021    accuracy: 0.0006 lr: [0.0009000000000000001]
# epoch 21 , train negloglik: -1.01285,    val negloglik: -1.01323    accuracy: 0.0005 lr: [0.0008100000000000001]
# epoch 22 , train negloglik: -1.01549,    val negloglik: -1.01548    accuracy: 0.0004 lr: [0.0008100000000000001]
# epoch 23 , train negloglik: -1.01732,    val negloglik: -1.01735    accuracy: 0.0004 lr: [0.0008100000000000001]
# epoch 24 , train negloglik: -1.01893,    val negloglik: -1.01925    accuracy: 0.0003 lr: [0.0008100000000000001]
# epoch 25 , train negloglik: -1.02045,    val negloglik: -1.02044    accuracy: 0.0003 lr: [0.0008100000000000001]
# epoch 26 , train negloglik: -1.02147,    val negloglik: -1.02153    accuracy: 0.0002 lr: [0.0008100000000000001]
# epoch 27 , train negloglik: -1.02245,    val negloglik: -1.02246    accuracy: 0.0002 lr: [0.0008100000000000001]
# epoch 28 , train negloglik: -1.02327,    val negloglik: -1.02343    accuracy: 0.0002 lr: [0.0008100000000000001]
# epoch 29 , train negloglik: -1.02397,    val negloglik: -1.02407    accuracy: 0.0002 lr: [0.0008100000000000001]
# epoch 30 , train negloglik: -1.02449,    val negloglik: -1.02455    accuracy: 0.0001 lr: [0.0008100000000000001]
# epoch 31 , train negloglik: -1.02500,    val negloglik: -1.02520    accuracy: 0.0001 lr: [0.0008100000000000001]
# epoch 32 , train negloglik: -1.02549,    val negloglik: -1.02552    accuracy: 0.0001 lr: [0.0008100000000000001]
# epoch 33 , train negloglik: -1.02589,    val negloglik: -1.02587    accuracy: 0.0001 lr: [0.0008100000000000001]
# epoch 34 , train negloglik: -1.02625,    val negloglik: -1.02630    accuracy: 0.0001 lr: [0.0008100000000000001]
# epoch 35 , train negloglik: -1.02651,    val negloglik: -1.02664    accuracy: 0.0001 lr: [0.0008100000000000001]
# epoch 36 , train negloglik: -1.02685,    val negloglik: -1.02694    accuracy: 0.0001 lr: [0.0008100000000000001]
# epoch 37 , train negloglik: -1.02706,    val negloglik: -1.02713    accuracy: 0.0001 lr: [0.0008100000000000001]
# epoch 38 , train negloglik: -1.02730,    val negloglik: -1.02741    accuracy: 0.0001 lr: [0.0008100000000000001]
# epoch 39 , train negloglik: -1.02747,    val negloglik: -1.02753    accuracy: 0.0001 lr: [0.0008100000000000001]
# epoch 40 , train negloglik: -1.02767,    val negloglik: -1.02773    accuracy: 0.0001 lr: [0.0008100000000000001]
# epoch 41 , train negloglik: -1.02785,    val negloglik: -1.02792    accuracy: 0.0001 lr: [0.000729]
# epoch 42 , train negloglik: -1.02797,    val negloglik: -1.02800    accuracy: 0.0001 lr: [0.000729]
# epoch 43 , train negloglik: -1.02809,    val negloglik: -1.02819    accuracy: 0.0000 lr: [0.000729]
# epoch 44 , train negloglik: -1.02824,    val negloglik: -1.02829    accuracy: 0.0000 lr: [0.000729]
# epoch 45 , train negloglik: -1.02832,    val negloglik: -1.02838    accuracy: 0.0000 lr: [0.000729]
# epoch 46 , train negloglik: -1.02848,    val negloglik: -1.02849    accuracy: 0.0000 lr: [0.000729]
# epoch 47 , train negloglik: -1.02856,    val negloglik: -1.02852    accuracy: 0.0000 lr: [0.000729]
# epoch 48 , train negloglik: -1.02868,    val negloglik: -1.02875    accuracy: 0.0000 lr: [0.000729]
# epoch 49 , train negloglik: -1.02876,    val negloglik: -1.02882    accuracy: 0.0000 lr: [0.000729]
# epoch 50 , train negloglik: -1.02884,    val negloglik: -1.02893    accuracy: 0.0000 lr: [0.000729]
# epoch 51 , train negloglik: -1.02892,    val negloglik: -1.02893    accuracy: 0.0000 lr: [0.000729]
# epoch 52 , train negloglik: -1.02901,    val negloglik: -1.02907    accuracy: 0.0000 lr: [0.000729]
# epoch 53 , train negloglik: -1.02905,    val negloglik: -1.02912    accuracy: 0.0000 lr: [0.000729]
# epoch 54 , train negloglik: -1.02912,    val negloglik: -1.02913    accuracy: 0.0000 lr: [0.000729]
# epoch 55 , train negloglik: -1.02920,    val negloglik: -1.02918    accuracy: 0.0000 lr: [0.000729]
# epoch 56 , train negloglik: -1.02929,    val negloglik: -1.02930    accuracy: 0.0000 lr: [0.000729]
# epoch 57 , train negloglik: -1.02934,    val negloglik: -1.02934    accuracy: 0.0000 lr: [0.000729]
# epoch 58 , train negloglik: -1.02941,    val negloglik: -1.02941    accuracy: 0.0000 lr: [0.000729]
# epoch 59 , train negloglik: -1.02947,    val negloglik: -1.02946    accuracy: 0.0000 lr: [0.000729]
# epoch 60 , train negloglik: -1.02951,    val negloglik: -1.02957    accuracy: 0.0000 lr: [0.000729]
# epoch 61 , train negloglik: -1.02957,    val negloglik: -1.02960    accuracy: 0.0000 lr: [0.0006561000000000001]
# epoch 62 , train negloglik: -1.02962,    val negloglik: -1.02961    accuracy: 0.0000 lr: [0.0006561000000000001]
# epoch 63 , train negloglik: -1.02967,    val negloglik: -1.02962    accuracy: 0.0000 lr: [0.0006561000000000001]
# epoch 64 , train negloglik: -1.02971,    val negloglik: -1.02971    accuracy: 0.0000 lr: [0.0006561000000000001]
# epoch 65 , train negloglik: -1.02976,    val negloglik: -1.02973    accuracy: 0.0000 lr: [0.0006561000000000001]
# epoch 66 , train negloglik: -1.02978,    val negloglik: -1.02981    accuracy: 0.0000 lr: [0.0006561000000000001]
# epoch 67 , train negloglik: -1.02984,    val negloglik: -1.02978    accuracy: 0.0000 lr: [0.0006561000000000001]
# epoch 68 , train negloglik: -1.02986,    val negloglik: -1.02983    accuracy: 0.0000 lr: [0.0006561000000000001]
# epoch 69 , train negloglik: -1.02988,    val negloglik: -1.02990    accuracy: 0.0000 lr: [0.0006561000000000001]
# epoch 70 , train negloglik: -1.02994,    val negloglik: -1.02992    accuracy: 0.0000 lr: [0.0006561000000000001]
# epoch 71 , train negloglik: -1.02997,    val negloglik: -1.02995    accuracy: 0.0000 lr: [0.0006561000000000001]
# epoch 72 , train negloglik: -1.03001,    val negloglik: -1.03001    accuracy: 0.0000 lr: [0.0006561000000000001]
# epoch 73 , train negloglik: -1.03002,    val negloglik: -1.03002    accuracy: 0.0000 lr: [0.0006561000000000001]
# epoch 74 , train negloglik: -1.03007,    val negloglik: -1.03006    accuracy: 0.0000 lr: [0.0006561000000000001]
# epoch 75 , train negloglik: -1.03009,    val negloglik: -1.03013    accuracy: 0.0000 lr: [0.0006561000000000001]
# epoch 76 , train negloglik: -1.03013,    val negloglik: -1.03006    accuracy: 0.0000 lr: [0.0006561000000000001]
# epoch 77 , train negloglik: -1.03017,    val negloglik: -1.03014    accuracy: 0.0000 lr: [0.0006561000000000001]
# epoch 78 , train negloglik: -1.03020,    val negloglik: -1.03010    accuracy: 0.0000 lr: [0.0006561000000000001]
# epoch 79 , train negloglik: -1.03023,    val negloglik: -1.03021    accuracy: 0.0000 lr: [0.0006561000000000001]
# epoch 80 , train negloglik: -1.03026,    val negloglik: -1.03021    accuracy: 0.0000 lr: [0.0006561000000000001]
# epoch 81 , train negloglik: -1.03028,    val negloglik: -1.03021    accuracy: 0.0000 lr: [0.00059049]
# epoch 82 , train negloglik: -1.03031,    val negloglik: -1.03025    accuracy: 0.0000 lr: [0.00059049]
# epoch 83 , train negloglik: -1.03032,    val negloglik: -1.03017    accuracy: 0.0000 lr: [0.00059049]
# epoch 84 , train negloglik: -1.03034,    val negloglik: -1.03035    accuracy: 0.0000 lr: [0.00059049]
# epoch 85 , train negloglik: -1.03035,    val negloglik: -1.03031    accuracy: 0.0000 lr: [0.00059049]
# epoch 86 , train negloglik: -1.03039,    val negloglik: -1.03037    accuracy: 0.0000 lr: [0.00059049]
# epoch 87 , train negloglik: -1.03041,    val negloglik: -1.03038    accuracy: 0.0000 lr: [0.00059049]
# epoch 88 , train negloglik: -1.03044,    val negloglik: -1.03038    accuracy: 0.0000 lr: [0.00059049]
# epoch 89 , train negloglik: -1.03046,    val negloglik: -1.03035    accuracy: 0.0000 lr: [0.00059049]
# epoch 90 , train negloglik: -1.03049,    val negloglik: -1.03043    accuracy: 0.0000 lr: [0.00059049]
# epoch 91 , train negloglik: -1.03048,    val negloglik: -1.03049    accuracy: 0.0000 lr: [0.00059049]
# epoch 92 , train negloglik: -1.03053,    val negloglik: -1.03046    accuracy: 0.0000 lr: [0.00059049]
# epoch 93 , train negloglik: -1.03054,    val negloglik: -1.03053    accuracy: 0.0000 lr: [0.00059049]
# epoch 94 , train negloglik: -1.03058,    val negloglik: -1.03046    accuracy: 0.0000 lr: [0.00059049]
# epoch 95 , train negloglik: -1.03058,    val negloglik: -1.03055    accuracy: 0.0000 lr: [0.00059049]
# epoch 96 , train negloglik: -1.03059,    val negloglik: -1.03057    accuracy: 0.0000 lr: [0.00059049]
# epoch 97 , train negloglik: -1.03062,    val negloglik: -1.03059    accuracy: 0.0000 lr: [0.00059049]
# epoch 98 , train negloglik: -1.03065,    val negloglik: -1.03064    accuracy: 0.0000 lr: [0.00059049]
# epoch 99 , train negloglik: -1.03066,    val negloglik: -1.03061    accuracy: 0.0000 lr: [0.00059049]
# epoch 100, train negloglik: -1.03067,    val negloglik: -1.03056    accuracy: 0.0000 lr: [0.00059049]
# epoch 101, train negloglik: -1.03068,    val negloglik: -1.03058    accuracy: 0.0000 lr: [0.000531441]
# epoch 102, train negloglik: -1.03070,    val negloglik: -1.03067    accuracy: 0.0000 lr: [0.000531441]
# epoch 103, train negloglik: -1.03070,    val negloglik: -1.03057    accuracy: 0.0000 lr: [0.000531441]
# epoch 104, train negloglik: -1.03074,    val negloglik: -1.03070    accuracy: 0.0000 lr: [0.000531441]
# epoch 105, train negloglik: -1.03076,    val negloglik: -1.03064    accuracy: 0.0000 lr: [0.000531441]
# epoch 106, train negloglik: -1.03077,    val negloglik: -1.03074    accuracy: 0.0000 lr: [0.000531441]
# epoch 107, train negloglik: -1.03078,    val negloglik: -1.03076    accuracy: 0.0000 lr: [0.000531441]
# epoch 108, train negloglik: -1.03079,    val negloglik: -1.03078    accuracy: 0.0000 lr: [0.000531441]
# epoch 109, train negloglik: -1.03080,    val negloglik: -1.03070    accuracy: 0.0000 lr: [0.000531441]
# epoch 110, train negloglik: -1.03080,    val negloglik: -1.03079    accuracy: 0.0000 lr: [0.000531441]
# epoch 111, train negloglik: -1.03082,    val negloglik: -1.03080    accuracy: 0.0000 lr: [0.000531441]
# epoch 112, train negloglik: -1.03084,    val negloglik: -1.03082    accuracy: 0.0000 lr: [0.000531441]
# epoch 113, train negloglik: -1.03086,    val negloglik: -1.03079    accuracy: 0.0000 lr: [0.000531441]
# epoch 114, train negloglik: -1.03088,    val negloglik: -1.03081    accuracy: 0.0000 lr: [0.000531441]
# epoch 115, train negloglik: -1.03088,    val negloglik: -1.03085    accuracy: 0.0000 lr: [0.000531441]
# epoch 116, train negloglik: -1.03091,    val negloglik: -1.03082    accuracy: 0.0000 lr: [0.000531441]
# epoch 117, train negloglik: -1.03090,    val negloglik: -1.03079    accuracy: 0.0000 lr: [0.000531441]
# epoch 118, train negloglik: -1.03092,    val negloglik: -1.03082    accuracy: 0.0000 lr: [0.000531441]
# epoch 119, train negloglik: -1.03094,    val negloglik: -1.03083    accuracy: 0.0000 lr: [0.000531441]
# epoch 120, train negloglik: -1.03095,    val negloglik: -1.03090    accuracy: 0.0000 lr: [0.000531441]
# epoch 121, train negloglik: -1.03096,    val negloglik: -1.03092    accuracy: 0.0000 lr: [0.0004782969]
# epoch 122, train negloglik: -1.03097,    val negloglik: -1.03090    accuracy: 0.0000 lr: [0.0004782969]
# epoch 123, train negloglik: -1.03099,    val negloglik: -1.03093    accuracy: 0.0000 lr: [0.0004782969]
# epoch 124, train negloglik: -1.03100,    val negloglik: -1.03094    accuracy: 0.0000 lr: [0.0004782969]
# epoch 125, train negloglik: -1.03100,    val negloglik: -1.03094    accuracy: 0.0000 lr: [0.0004782969]
# epoch 126, train negloglik: -1.03101,    val negloglik: -1.03093    accuracy: 0.0000 lr: [0.0004782969]
# epoch 127, train negloglik: -1.03102,    val negloglik: -1.03095    accuracy: 0.0000 lr: [0.0004782969]
# epoch 128, train negloglik: -1.03103,    val negloglik: -1.03101    accuracy: 0.0000 lr: [0.0004782969]
# epoch 129, train negloglik: -1.03102,    val negloglik: -1.03100    accuracy: 0.0000 lr: [0.0004782969]
# epoch 130, train negloglik: -1.03104,    val negloglik: -1.03104    accuracy: 0.0000 lr: [0.0004782969]
# epoch 131, train negloglik: -1.03106,    val negloglik: -1.03099    accuracy: 0.0000 lr: [0.0004782969]
# epoch 132, train negloglik: -1.03106,    val negloglik: -1.03097    accuracy: 0.0000 lr: [0.0004782969]
# epoch 133, train negloglik: -1.03106,    val negloglik: -1.03093    accuracy: 0.0000 lr: [0.0004782969]
# epoch 134, train negloglik: -1.03108,    val negloglik: -1.03105    accuracy: 0.0000 lr: [0.0004782969]
# epoch 135, train negloglik: -1.03108,    val negloglik: -1.03096    accuracy: 0.0000 lr: [0.0004782969]
# epoch 136, train negloglik: -1.03110,    val negloglik: -1.03102    accuracy: 0.0000 lr: [0.0004782969]
# epoch 137, train negloglik: -1.03110,    val negloglik: -1.03105    accuracy: 0.0000 lr: [0.0004782969]
# epoch 138, train negloglik: -1.03112,    val negloglik: -1.03108    accuracy: 0.0000 lr: [0.0004782969]
# epoch 139, train negloglik: -1.03111,    val negloglik: -1.03110    accuracy: 0.0000 lr: [0.0004782969]
# epoch 140, train negloglik: -1.03114,    val negloglik: -1.03110    accuracy: 0.0000 lr: [0.0004782969]
# epoch 141, train negloglik: -1.03114,    val negloglik: -1.03109    accuracy: 0.0000 lr: [0.00043046721]
# epoch 142, train negloglik: -1.03115,    val negloglik: -1.03111    accuracy: 0.0000 lr: [0.00043046721]
# epoch 143, train negloglik: -1.03116,    val negloglik: -1.03109    accuracy: 0.0000 lr: [0.00043046721]
# epoch 144, train negloglik: -1.03117,    val negloglik: -1.03111    accuracy: 0.0000 lr: [0.00043046721]
# epoch 145, train negloglik: -1.03116,    val negloglik: -1.03096    accuracy: 0.0000 lr: [0.00043046721]
# epoch 146, train negloglik: -1.03120,    val negloglik: -1.03111    accuracy: 0.0000 lr: [0.00043046721]
# epoch 147, train negloglik: -1.03120,    val negloglik: -1.03115    accuracy: 0.0000 lr: [0.00043046721]
# epoch 148, train negloglik: -1.03120,    val negloglik: -1.03115    accuracy: 0.0000 lr: [0.00043046721]
# epoch 149, train negloglik: -1.03120,    val negloglik: -1.03120    accuracy: 0.0000 lr: [0.00043046721]
# epoch 150, train negloglik: -1.03120,    val negloglik: -1.03115    accuracy: 0.0000 lr: [0.00043046721]
# epoch 151, train negloglik: -1.03121,    val negloglik: -1.03109    accuracy: 0.0000 lr: [0.00043046721]
# epoch 152, train negloglik: -1.03123,    val negloglik: -1.03120    accuracy: 0.0000 lr: [0.00043046721]
# epoch 153, train negloglik: -1.03123,    val negloglik: -1.03116    accuracy: 0.0000 lr: [0.00043046721]
# epoch 154, train negloglik: -1.03124,    val negloglik: -1.03115    accuracy: 0.0000 lr: [0.00043046721]
# epoch 155, train negloglik: -1.03125,    val negloglik: -1.03119    accuracy: 0.0000 lr: [0.00043046721]
# epoch 156, train negloglik: -1.03126,    val negloglik: -1.03118    accuracy: 0.0000 lr: [0.00043046721]
# epoch 157, train negloglik: -1.03125,    val negloglik: -1.03117    accuracy: 0.0000 lr: [0.00043046721]
# epoch 158, train negloglik: -1.03128,    val negloglik: -1.03123    accuracy: 0.0000 lr: [0.00043046721]
# epoch 159, train negloglik: -1.03128,    val negloglik: -1.03124    accuracy: 0.0000 lr: [0.00043046721]
# epoch 160, train negloglik: -1.03129,    val negloglik: -1.03122    accuracy: 0.0000 lr: [0.00043046721]
# epoch 161, train negloglik: -1.03129,    val negloglik: -1.03124    accuracy: 0.0000 lr: [0.000387420489]
# epoch 162, train negloglik: -1.03130,    val negloglik: -1.03118    accuracy: 0.0000 lr: [0.000387420489]
# epoch 163, train negloglik: -1.03131,    val negloglik: -1.03120    accuracy: 0.0000 lr: [0.000387420489]
# epoch 164, train negloglik: -1.03131,    val negloglik: -1.03126    accuracy: 0.0000 lr: [0.000387420489]
# epoch 165, train negloglik: -1.03131,    val negloglik: -1.03127    accuracy: 0.0000 lr: [0.000387420489]
# epoch 166, train negloglik: -1.03132,    val negloglik: -1.03128    accuracy: 0.0000 lr: [0.000387420489]
# epoch 167, train negloglik: -1.03134,    val negloglik: -1.03126    accuracy: 0.0000 lr: [0.000387420489]
# epoch 168, train negloglik: -1.03132,    val negloglik: -1.03128    accuracy: 0.0000 lr: [0.000387420489]
# epoch 169, train negloglik: -1.03133,    val negloglik: -1.03127    accuracy: 0.0000 lr: [0.000387420489]
# epoch 170, train negloglik: -1.03133,    val negloglik: -1.03123    accuracy: 0.0000 lr: [0.000387420489]
# epoch 171, train negloglik: -1.03135,    val negloglik: -1.03131    accuracy: 0.0000 lr: [0.000387420489]
# epoch 172, train negloglik: -1.03135,    val negloglik: -1.03131    accuracy: 0.0000 lr: [0.000387420489]
# epoch 173, train negloglik: -1.03135,    val negloglik: -1.03127    accuracy: 0.0000 lr: [0.000387420489]
# epoch 174, train negloglik: -1.03138,    val negloglik: -1.03133    accuracy: 0.0000 lr: [0.000387420489]
# epoch 175, train negloglik: -1.03139,    val negloglik: -1.03131    accuracy: 0.0000 lr: [0.000387420489]
# epoch 176, train negloglik: -1.03137,    val negloglik: -1.03127    accuracy: 0.0000 lr: [0.000387420489]
# epoch 177, train negloglik: -1.03137,    val negloglik: -1.03132    accuracy: 0.0000 lr: [0.000387420489]
# epoch 178, train negloglik: -1.03139,    val negloglik: -1.03127    accuracy: 0.0000 lr: [0.000387420489]
# epoch 179, train negloglik: -1.03139,    val negloglik: -1.03128    accuracy: 0.0000 lr: [0.000387420489]
# epoch 180, train negloglik: -1.03137,    val negloglik: -1.03130    accuracy: 0.0000 lr: [0.000387420489]
# epoch 181, train negloglik: -1.03139,    val negloglik: -1.03133    accuracy: 0.0000 lr: [0.0003486784401]
# epoch 182, train negloglik: -1.03140,    val negloglik: -1.03137    accuracy: 0.0000 lr: [0.0003486784401]
# epoch 183, train negloglik: -1.03142,    val negloglik: -1.03120    accuracy: 0.0000 lr: [0.0003486784401]
# epoch 184, train negloglik: -1.03141,    val negloglik: -1.03137    accuracy: 0.0000 lr: [0.0003486784401]
# epoch 185, train negloglik: -1.03141,    val negloglik: -1.03136    accuracy: 0.0000 lr: [0.0003486784401]
# epoch 186, train negloglik: -1.03143,    val negloglik: -1.03136    accuracy: 0.0000 lr: [0.0003486784401]
# epoch 187, train negloglik: -1.03143,    val negloglik: -1.03135    accuracy: 0.0000 lr: [0.0003486784401]
# epoch 188, train negloglik: -1.03140,    val negloglik: -1.03133    accuracy: 0.0000 lr: [0.0003486784401]
# epoch 189, train negloglik: -1.03143,    val negloglik: -1.03138    accuracy: 0.0000 lr: [0.0003486784401]
# epoch 190, train negloglik: -1.03144,    val negloglik: -1.03140    accuracy: 0.0000 lr: [0.0003486784401]
# epoch 191, train negloglik: -1.03145,    val negloglik: -1.03137    accuracy: 0.0000 lr: [0.0003486784401]
# epoch 192, train negloglik: -1.03144,    val negloglik: -1.03139    accuracy: 0.0000 lr: [0.0003486784401]
# epoch 193, train negloglik: -1.03145,    val negloglik: -1.03142    accuracy: 0.0000 lr: [0.0003486784401]
# epoch 194, train negloglik: -1.03146,    val negloglik: -1.03138    accuracy: 0.0000 lr: [0.0003486784401]
# epoch 195, train negloglik: -1.03146,    val negloglik: -1.03131    accuracy: 0.0000 lr: [0.0003486784401]
# epoch 196, train negloglik: -1.03146,    val negloglik: -1.03138    accuracy: 0.0000 lr: [0.0003486784401]
# epoch 197, train negloglik: -1.03147,    val negloglik: -1.03138    accuracy: 0.0000 lr: [0.0003486784401]
# epoch 198, train negloglik: -1.03147,    val negloglik: -1.03138    accuracy: 0.0000 lr: [0.0003486784401]
# epoch 199, train negloglik: -1.03145,    val negloglik: -1.03140    accuracy: 0.0000 lr: [0.0003486784401]
# epoch 200, train negloglik: -1.03148,    val negloglik: -1.03144    accuracy: 0.0000 lr: [0.0003486784401]
# epoch 201, train negloglik: -1.03148,    val negloglik: -1.03147    accuracy: 0.0000 lr: [0.00031381059609000004]
# epoch 202, train negloglik: -1.03149,    val negloglik: -1.03140    accuracy: 0.0000 lr: [0.00031381059609000004]
# epoch 203, train negloglik: -1.03148,    val negloglik: -1.03145    accuracy: 0.0000 lr: [0.00031381059609000004]
# epoch 204, train negloglik: -1.03149,    val negloglik: -1.03146    accuracy: 0.0000 lr: [0.00031381059609000004]
# epoch 205, train negloglik: -1.03150,    val negloglik: -1.03146    accuracy: 0.0000 lr: [0.00031381059609000004]
# epoch 206, train negloglik: -1.03150,    val negloglik: -1.03145    accuracy: 0.0000 lr: [0.00031381059609000004]
# epoch 207, train negloglik: -1.03150,    val negloglik: -1.03145    accuracy: 0.0000 lr: [0.00031381059609000004]
# epoch 208, train negloglik: -1.03150,    val negloglik: -1.03148    accuracy: 0.0000 lr: [0.00031381059609000004]
# epoch 209, train negloglik: -1.03151,    val negloglik: -1.03145    accuracy: 0.0000 lr: [0.00031381059609000004]
# epoch 210, train negloglik: -1.03152,    val negloglik: -1.03147    accuracy: 0.0000 lr: [0.00031381059609000004]
# epoch 211, train negloglik: -1.03152,    val negloglik: -1.03142    accuracy: 0.0000 lr: [0.00031381059609000004]
# epoch 212, train negloglik: -1.03151,    val negloglik: -1.03147    accuracy: 0.0000 lr: [0.00031381059609000004]
# epoch 213, train negloglik: -1.03153,    val negloglik: -1.03140    accuracy: 0.0000 lr: [0.00031381059609000004]
# epoch 214, train negloglik: -1.03153,    val negloglik: -1.03147    accuracy: 0.0000 lr: [0.00031381059609000004]
# epoch 215, train negloglik: -1.03153,    val negloglik: -1.03149    accuracy: 0.0000 lr: [0.00031381059609000004]
# epoch 216, train negloglik: -1.03155,    val negloglik: -1.03145    accuracy: 0.0000 lr: [0.00031381059609000004]
# epoch 217, train negloglik: -1.03153,    val negloglik: -1.03149    accuracy: 0.0000 lr: [0.00031381059609000004]
# epoch 218, train negloglik: -1.03153,    val negloglik: -1.03151    accuracy: 0.0000 lr: [0.00031381059609000004]
# epoch 219, train negloglik: -1.03153,    val negloglik: -1.03148    accuracy: 0.0000 lr: [0.00031381059609000004]
# epoch 220, train negloglik: -1.03156,    val negloglik: -1.03154    accuracy: 0.0000 lr: [0.00031381059609000004]
# epoch 221, train negloglik: -1.03156,    val negloglik: -1.03142    accuracy: 0.0000 lr: [0.00028242953648100003]
# epoch 222, train negloglik: -1.03156,    val negloglik: -1.03152    accuracy: 0.0000 lr: [0.00028242953648100003]
# epoch 223, train negloglik: -1.03155,    val negloglik: -1.03148    accuracy: 0.0000 lr: [0.00028242953648100003]
# epoch 224, train negloglik: -1.03158,    val negloglik: -1.03152    accuracy: 0.0000 lr: [0.00028242953648100003]
# epoch 225, train negloglik: -1.03157,    val negloglik: -1.03153    accuracy: 0.0000 lr: [0.00028242953648100003]
# epoch 226, train negloglik: -1.03157,    val negloglik: -1.03150    accuracy: 0.0000 lr: [0.00028242953648100003]
# epoch 227, train negloglik: -1.03158,    val negloglik: -1.03150    accuracy: 0.0000 lr: [0.00028242953648100003]
# epoch
accuracy: 0.0000 lr: [7.976644307687256e-05]
# epoch 472, train negloglik: -1.03190,    val negloglik: -1.03181    accuracy: 0.0000 lr: [7.976644307687256e-05]
# epoch 473, train negloglik: -1.03190,    val negloglik: -1.03180    accuracy: 0.0000 lr: [7.976644307687256e-05]
# epoch 474, train negloglik: -1.03190,    val negloglik: -1.03185    accuracy: 0.0000 lr: [7.976644307687256e-05]
# epoch 475, train negloglik: -1.03190,    val negloglik: -1.03187    accuracy: 0.0000 lr: [7.976644307687256e-05]
# epoch 476, train negloglik: -1.03190,    val negloglik: -1.03182    accuracy: 0.0000 lr: [7.976644307687256e-05]
# epoch 477, train negloglik: -1.03190,    val negloglik: -1.03184    accuracy: 0.0000 lr: [7.976644307687256e-05]
# epoch 478, train negloglik: -1.03190,    val negloglik: -1.03186    accuracy: 0.0000 lr: [7.976644307687256e-05]
# epoch 479, train negloglik: -1.03190,    val negloglik: -1.03183    accuracy: 0.0000 lr: [7.976644307687256e-05]
# epoch 480, train negloglik: -1.03190,    val negloglik: -1.03180    accuracy: 0.0000 lr: [7.976644307687256e-05]
# epoch 481, train negloglik: -1.03190,    val negloglik: -1.03183    accuracy: 0.0000 lr: [7.17897987691853e-05]
# epoch 482, train negloglik: -1.03190,    val negloglik: -1.03182    accuracy: 0.0000 lr: [7.17897987691853e-05]
# epoch 483, train negloglik: -1.03190,    val negloglik: -1.03182    accuracy: 0.0000 lr: [7.17897987691853e-05]
# epoch 484, train negloglik: -1.03191,    val negloglik: -1.03185    accuracy: 0.0000 lr: [7.17897987691853e-05]
# epoch 485, train negloglik: -1.03190,    val negloglik: -1.03184    accuracy: 0.0000 lr: [7.17897987691853e-05]
# epoch 486, train negloglik: -1.03190,    val negloglik: -1.03186    accuracy: 0.0000 lr: [7.17897987691853e-05]
# epoch 487, train negloglik: -1.03190,    val negloglik: -1.03186    accuracy: 0.0000 lr: [7.17897987691853e-05]
# epoch 488, train negloglik: -1.03190,    val negloglik: -1.03186    accuracy: 0.0000 lr: [7.17897987691853e-05]
# epoch 489, train negloglik: -1.03190,    val negloglik: -1.03185    accuracy: 0.0000 lr: [7.17897987691853e-05]
# epoch 490, train negloglik: -1.03192,    val negloglik: -1.03183    accuracy: 0.0000 lr: [7.17897987691853e-05]
# epoch 491, train negloglik: -1.03190,    val negloglik: -1.03184    accuracy: 0.0000 lr: [7.17897987691853e-05]
# epoch 492, train negloglik: -1.03190,    val negloglik: -1.03183    accuracy: 0.0000 lr: [7.17897987691853e-05]
# epoch 493, train negloglik: -1.03191,    val negloglik: -1.03187    accuracy: 0.0000 lr: [7.17897987691853e-05]
# epoch 494, train negloglik: -1.03192,    val negloglik: -1.03180    accuracy: 0.0000 lr: [7.17897987691853e-05]
# epoch 495, train negloglik: -1.03192,    val negloglik: -1.03186    accuracy: 0.0000 lr: [7.17897987691853e-05]
# epoch 496, train negloglik: -1.03190,    val negloglik: -1.03186    accuracy: 0.0000 lr: [7.17897987691853e-05]
# epoch 497, train negloglik: -1.03190,    val negloglik: -1.03188    accuracy: 0.0000 lr: [7.17897987691853e-05]
# epoch 498, train negloglik: -1.03192,    val negloglik: -1.03178    accuracy: 0.0000 lr: [7.17897987691853e-05]
# epoch 499, train negloglik: -1.03191,    val negloglik: -1.03179    accuracy: 0.0000 lr: [7.17897987691853e-05]

# %%
model.print_model()
# Out:
# GP_Model(
#   (layer_0): LayerFused(in=2 out=1 gp_pts_per_neuron=10)
# )
# parameter count:  47

# %%
print([layer[0] for layer in model.named_parameters()])
# Out:
# ['input_noise_log', 'layer_0.z', 'layer_0.h', 'layer_0.l', 'layer_0.s', 'layer_0.jitter']

# %%
# 1層目
model.layers[0].save_fig("./outputs/layer_fused1.png")

# %%
model.layers[0]
# Out:
# LayerFused(in=2 out=1 gp_pts_per_neuron=10)

# %%
# Make predictions on the test set
X_test_tensor = X_test  # X_test is already a tensor
with torch.no_grad():
    predictions = model.predict(X_test_tensor)

# Create a 3D scatter plot of predictions vs actual values
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# Scatter plot
# ax.scatter(X_test[:, 0].numpy(), X_test[:, 1].numpy(), y_test.numpy(), c='blue', marker='o', label='Actual')
ax.scatter(X_test[:, 0].numpy(), X_test[:, 1].numpy(), predictions.mean.numpy(), c='red', marker='o', label='Predicted')
# Plot the surface
surface = ax.plot_surface(x_grid, y_grid, z_grid, alpha=0.8)

# Set labels and title
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('3D Scatter Plot of Model Predictions vs Actual Values')
ax.legend()

# Calculate and print metrics
mse = torch.mean((predictions.mean - y_test)**2).item()
rmse = torch.sqrt(torch.mean((predictions.mean - y_test)**2)).item()
print(f"MSE: {mse:.6f}")
print(f"RMSE: {rmse:.6f}")
# Out:
# MSE: 0.000007
# RMSE: 0.002733

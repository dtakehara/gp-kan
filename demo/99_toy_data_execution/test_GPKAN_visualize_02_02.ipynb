# %%
import sys
sys.path.append("../../") # add top-level to import path search
from lib import model as gplib
from lib import runner
# from lib.dataset import MNIST
import torch.utils.data
from torch.utils.data import DataLoader

# %% [markdown]
# First, load train, validation and test dataloaders

# %%
import numpy as np
import torch
from torch.utils.data import TensorDataset, DataLoader
import matplotlib.pyplot as plt

# Generate synthetic data with f(x, y) = (x+y)^2
np.random.seed(42)  # for reproducibility
num_samples = 1000

# Generate random input points (x, y) from -1 to 1
x = np.random.uniform(-1, 1, num_samples)
y = np.random.uniform(-1, 1, num_samples)


# Compute target values: f(x, y) = (x+y)^2
targets = (x+y)**2

# Reshape inputs
inputs = np.vstack((x, y)).T

# Convert to PyTorch tensors
X_tensor = torch.FloatTensor(inputs)
y_tensor = torch.FloatTensor(targets).reshape(-1, 1)

# Split data into train, validation, and test sets
train_size = int(0.7 * num_samples)
val_size = int(0.15 * num_samples)
test_size = num_samples - train_size - val_size

X_train = X_tensor[:train_size]
y_train = y_tensor[:train_size]

X_val = X_tensor[train_size:train_size+val_size]
y_val = y_tensor[train_size:train_size+val_size]

X_test = X_tensor[train_size+val_size:]
y_test = y_tensor[train_size+val_size:]

# Create datasets
train_dataset = TensorDataset(X_train, y_train)
val_dataset = TensorDataset(X_val, y_val)
test_dataset = TensorDataset(X_test, y_test)

# Create dataloaders
batch_size = 32
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size)

print(f"Train samples: {len(train_dataset)}")
print(f"Validation samples: {len(val_dataset)}")
print(f"Test samples: {len(test_dataset)}")
# Out:
# Train samples: 700
# Validation samples: 150
# Test samples: 150

# %%
# Create a 3D visualization of the function
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# Create a grid of x and y values
x_grid, y_grid = np.meshgrid(np.linspace(-1, 1, 30), np.linspace(-1, 1, 30))
z_grid = (x_grid+y_grid)**2  # The target function


# Plot the surface
surface = ax.plot_surface(x_grid, y_grid, z_grid, alpha=0.8)

# Plot the data points
ax.scatter(x, y, targets, c='blue', marker='o', s=2)

# Add labels and a colorbar
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('f(x,y) = (x+y)^2')
ax.set_title('3D Visualization of Target Function')
# Out:
# Text(0.5, 0.92, '3D Visualization of Target Function')

# %% [markdown]
# Train a new model

# %%
# model = gplib.GP_Model(
#     [
#         gplib.GP_conv2D(28, 28, 1, 3, kernel_size=4, stride=2, num_gp_pts=10, use_double_layer=True),
#         gplib.NormaliseGaussian(),
#         gplib.GP_conv2D(13, 13, 3, 3, kernel_size=4, stride=2, num_gp_pts=10, use_double_layer=True),
#         gplib.NormaliseGaussian(),
#         gplib.ReshapeGaussian([-1, 75]),
#         gplib.LayerFused(75, 10, num_gp_pts=10),
#         gplib.NormaliseGaussian(),
#         gplib.LayerFused(10, 10, num_gp_pts=10),
#     ],
#     saveload_path="model.pt",
# )

model = gplib.GP_Model(
    [   
        gplib.LayerFused(2, 10, num_gp_pts=2),
        gplib.LayerFused(10, 1, num_gp_pts=2),
    ],
    saveload_path="model_test02_02.pt",
)
np.random.seed(42)  # for reproducibility
runner.train_model(
    train_dataloader, val_dataloader, model, epochs=500, learning_rate=1e-3, use_gpu=False, # True,
    pretrain=False,# True,
    global_jitter=1e-3, baseline_jitter=1e-3
)
model.save_model() # optionally save the model after training
# Out:
# epoch 0  , train negloglik: 1.76023,    val negloglik: 1.10786    accuracy: 0.6319 lr: [0.001]
# epoch 1  , train negloglik: 1.15789,    val negloglik: 1.10827    accuracy: 0.6110 lr: [0.0009000000000000001]
# epoch 2  , train negloglik: 1.11456,    val negloglik: 1.05992    accuracy: 0.5884 lr: [0.0009000000000000001]
# epoch 3  , train negloglik: 1.08502,    val negloglik: 1.03263    accuracy: 0.5605 lr: [0.0009000000000000001]
# epoch 4  , train negloglik: 1.05778,    val negloglik: 1.00435    accuracy: 0.5401 lr: [0.0009000000000000001]
# epoch 5  , train negloglik: 1.03115,    val negloglik: 0.97788    accuracy: 0.5153 lr: [0.0009000000000000001]
# epoch 6  , train negloglik: 1.00402,    val negloglik: 0.94996    accuracy: 0.4968 lr: [0.0009000000000000001]
# epoch 7  , train negloglik: 0.97696,    val negloglik: 0.92253    accuracy: 0.4779 lr: [0.0009000000000000001]
# epoch 8  , train negloglik: 0.94953,    val negloglik: 0.89563    accuracy: 0.4552 lr: [0.0009000000000000001]
# epoch 9  , train negloglik: 0.92248,    val negloglik: 0.86858    accuracy: 0.4346 lr: [0.0009000000000000001]
# epoch 10 , train negloglik: 0.89498,    val negloglik: 0.84095    accuracy: 0.4159 lr: [0.0009000000000000001]
# epoch 11 , train negloglik: 0.86549,    val negloglik: 0.81378    accuracy: 0.3923 lr: [0.0009000000000000001]
# epoch 12 , train negloglik: 0.83750,    val negloglik: 0.78509    accuracy: 0.3788 lr: [0.0009000000000000001]
# epoch 13 , train negloglik: 0.80744,    val negloglik: 0.75653    accuracy: 0.3554 lr: [0.0009000000000000001]
# epoch 14 , train negloglik: 0.77747,    val negloglik: 0.72745    accuracy: 0.3349 lr: [0.0009000000000000001]
# epoch 15 , train negloglik: 0.74594,    val negloglik: 0.69697    accuracy: 0.3166 lr: [0.0009000000000000001]
# epoch 16 , train negloglik: 0.71358,    val negloglik: 0.66675    accuracy: 0.2953 lr: [0.0009000000000000001]
# epoch 17 , train negloglik: 0.68128,    val negloglik: 0.63595    accuracy: 0.2747 lr: [0.0009000000000000001]
# epoch 18 , train negloglik: 0.64768,    val negloglik: 0.60405    accuracy: 0.2547 lr: [0.0009000000000000001]
# epoch 19 , train negloglik: 0.61321,    val negloglik: 0.57022    accuracy: 0.2386 lr: [0.0009000000000000001]
# epoch 20 , train negloglik: 0.57787,    val negloglik: 0.53750    accuracy: 0.2174 lr: [0.0009000000000000001]
# epoch 21 , train negloglik: 0.54402,    val negloglik: 0.50555    accuracy: 0.2047 lr: [0.0008100000000000001]
# epoch 22 , train negloglik: 0.51043,    val negloglik: 0.47352    accuracy: 0.1884 lr: [0.0008100000000000001]
# epoch 23 , train negloglik: 0.47631,    val negloglik: 0.44083    accuracy: 0.1731 lr: [0.0008100000000000001]
# epoch 24 , train negloglik: 0.44183,    val negloglik: 0.40794    accuracy: 0.1587 lr: [0.0008100000000000001]
# epoch 25 , train negloglik: 0.40750,    val negloglik: 0.37566    accuracy: 0.1432 lr: [0.0008100000000000001]
# epoch 26 , train negloglik: 0.37251,    val negloglik: 0.33981    accuracy: 0.1330 lr: [0.0008100000000000001]
# epoch 27 , train negloglik: 0.33616,    val negloglik: 0.30556    accuracy: 0.1191 lr: [0.0008100000000000001]
# epoch 28 , train negloglik: 0.30033,    val negloglik: 0.26991    accuracy: 0.1107 lr: [0.0008100000000000001]
# epoch 29 , train negloglik: 0.26455,    val negloglik: 0.23721    accuracy: 0.0959 lr: [0.0008100000000000001]
# epoch 30 , train negloglik: 0.22789,    val negloglik: 0.19939    accuracy: 0.0890 lr: [0.0008100000000000001]
# epoch 31 , train negloglik: 0.19143,    val negloglik: 0.16387    accuracy: 0.0811 lr: [0.0008100000000000001]
# epoch 32 , train negloglik: 0.15552,    val negloglik: 0.12917    accuracy: 0.0724 lr: [0.0008100000000000001]
# epoch 33 , train negloglik: 0.11969,    val negloglik: 0.09468    accuracy: 0.0654 lr: [0.0008100000000000001]
# epoch 34 , train negloglik: 0.08450,    val negloglik: 0.06026    accuracy: 0.0588 lr: [0.0008100000000000001]
# epoch 35 , train negloglik: 0.04952,    val negloglik: 0.02609    accuracy: 0.0542 lr: [0.0008100000000000001]
# epoch 36 , train negloglik: 0.01565,    val negloglik: -0.00701    accuracy: 0.0495 lr: [0.0008100000000000001]
# epoch 37 , train negloglik: -0.01752,    val negloglik: -0.03997    accuracy: 0.0459 lr: [0.0008100000000000001]
# epoch 38 , train negloglik: -0.05017,    val negloglik: -0.07125    accuracy: 0.0422 lr: [0.0008100000000000001]
# epoch 39 , train negloglik: -0.08166,    val negloglik: -0.10411    accuracy: 0.0402 lr: [0.0008100000000000001]
# epoch 40 , train negloglik: -0.11150,    val negloglik: -0.13461    accuracy: 0.0379 lr: [0.0008100000000000001]
# epoch 41 , train negloglik: -0.14063,    val negloglik: -0.16098    accuracy: 0.0362 lr: [0.000729]
# epoch 42 , train negloglik: -0.16623,    val negloglik: -0.18396    accuracy: 0.0345 lr: [0.000729]
# epoch 43 , train negloglik: -0.19088,    val negloglik: -0.20336    accuracy: 0.0334 lr: [0.000729]
# epoch 44 , train negloglik: -0.21467,    val negloglik: -0.23443    accuracy: 0.0319 lr: [0.000729]
# epoch 45 , train negloglik: -0.23921,    val negloglik: -0.25820    accuracy: 0.0307 lr: [0.000729]
# epoch 46 , train negloglik: -0.26219,    val negloglik: -0.28350    accuracy: 0.0299 lr: [0.000729]
# epoch 47 , train negloglik: -0.28431,    val negloglik: -0.30543    accuracy: 0.0290 lr: [0.000729]
# epoch 48 , train negloglik: -0.30478,    val negloglik: -0.32497    accuracy: 0.0285 lr: [0.000729]
# epoch 49 , train negloglik: -0.32512,    val negloglik: -0.34601    accuracy: 0.0277 lr: [0.000729]
# epoch 50 , train negloglik: -0.34486,    val negloglik: -0.36772    accuracy: 0.0270 lr: [0.000729]
# epoch 51 , train negloglik: -0.36162,    val negloglik: -0.38819    accuracy: 0.0271 lr: [0.000729]
# epoch 52 , train negloglik: -0.37964,    val negloglik: -0.40550    accuracy: 0.0260 lr: [0.000729]
# epoch 53 , train negloglik: -0.39921,    val negloglik: -0.41533    accuracy: 0.0259 lr: [0.000729]
# epoch 54 , train negloglik: -0.41512,    val negloglik: -0.44159    accuracy: 0.0252 lr: [0.000729]
# epoch 55 , train negloglik: -0.43081,    val negloglik: -0.45776    accuracy: 0.0247 lr: [0.000729]
# epoch 56 , train negloglik: -0.44787,    val negloglik: -0.47331    accuracy: 0.0246 lr: [0.000729]
# epoch 57 , train negloglik: -0.45972,    val negloglik: -0.48801    accuracy: 0.0241 lr: [0.000729]
# epoch 58 , train negloglik: -0.47674,    val negloglik: -0.50232    accuracy: 0.0235 lr: [0.000729]
# epoch 59 , train negloglik: -0.49217,    val negloglik: -0.51345    accuracy: 0.0231 lr: [0.000729]
# epoch 60 , train negloglik: -0.50511,    val negloglik: -0.53234    accuracy: 0.0229 lr: [0.000729]
# epoch 61 , train negloglik: -0.51710,    val negloglik: -0.53903    accuracy: 0.0220 lr: [0.0006561000000000001]
# epoch 62 , train negloglik: -0.52850,    val negloglik: -0.55120    accuracy: 0.0221 lr: [0.0006561000000000001]
# epoch 63 , train negloglik: -0.53912,    val negloglik: -0.56378    accuracy: 0.0219 lr: [0.0006561000000000001]
# epoch 64 , train negloglik: -0.54746,    val negloglik: -0.57270    accuracy: 0.0212 lr: [0.0006561000000000001]
# epoch 65 , train negloglik: -0.55792,    val negloglik: -0.58734    accuracy: 0.0213 lr: [0.0006561000000000001]
# epoch 66 , train negloglik: -0.56770,    val negloglik: -0.59664    accuracy: 0.0214 lr: [0.0006561000000000001]
# epoch 67 , train negloglik: -0.57897,    val negloglik: -0.59671    accuracy: 0.0211 lr: [0.0006561000000000001]
# epoch 68 , train negloglik: -0.58589,    val negloglik: -0.61577    accuracy: 0.0207 lr: [0.0006561000000000001]
# epoch 69 , train negloglik: -0.59454,    val negloglik: -0.62478    accuracy: 0.0204 lr: [0.0006561000000000001]
# epoch 70 , train negloglik: -0.60177,    val negloglik: -0.62147    accuracy: 0.0202 lr: [0.0006561000000000001]
# epoch 71 , train negloglik: -0.61034,    val negloglik: -0.63708    accuracy: 0.0201 lr: [0.0006561000000000001]
# epoch 72 , train negloglik: -0.62030,    val negloglik: -0.64950    accuracy: 0.0198 lr: [0.0006561000000000001]
# epoch 73 , train negloglik: -0.62507,    val negloglik: -0.65702    accuracy: 0.0194 lr: [0.0006561000000000001]
# epoch 74 , train negloglik: -0.63326,    val negloglik: -0.66484    accuracy: 0.0191 lr: [0.0006561000000000001]
# epoch 75 , train negloglik: -0.63620,    val negloglik: -0.66493    accuracy: 0.0190 lr: [0.0006561000000000001]
# epoch 76 , train negloglik: -0.64052,    val negloglik: -0.67720    accuracy: 0.0192 lr: [0.0006561000000000001]
# epoch 77 , train negloglik: -0.65466,    val negloglik: -0.68497    accuracy: 0.0182 lr: [0.0006561000000000001]
# epoch 78 , train negloglik: -0.66257,    val negloglik: -0.68887    accuracy: 0.0184 lr: [0.0006561000000000001]
# epoch 79 , train negloglik: -0.67101,    val negloglik: -0.69465    accuracy: 0.0190 lr: [0.0006561000000000001]
# epoch 80 , train negloglik: -0.67546,    val negloglik: -0.70019    accuracy: 0.0179 lr: [0.0006561000000000001]
# epoch 81 , train negloglik: -0.67918,    val negloglik: -0.69044    accuracy: 0.0207 lr: [0.00059049]
# epoch 82 , train negloglik: -0.68143,    val negloglik: -0.69694    accuracy: 0.0181 lr: [0.00059049]
# epoch 83 , train negloglik: -0.68644,    val negloglik: -0.72264    accuracy: 0.0172 lr: [0.00059049]
# epoch 84 , train negloglik: -0.69668,    val negloglik: -0.72623    accuracy: 0.0169 lr: [0.00059049]
# epoch 85 , train negloglik: -0.70112,    val negloglik: -0.73392    accuracy: 0.0170 lr: [0.00059049]
# epoch 86 , train negloglik: -0.70776,    val negloglik: -0.73402    accuracy: 0.0170 lr: [0.00059049]
# epoch 87 , train negloglik: -0.71361,    val negloglik: -0.73844    accuracy: 0.0167 lr: [0.00059049]
# epoch 88 , train negloglik: -0.70604,    val negloglik: -0.74720    accuracy: 0.0164 lr: [0.00059049]
# epoch 89 , train negloglik: -0.71328,    val negloglik: -0.75033    accuracy: 0.0169 lr: [0.00059049]
# epoch 90 , train negloglik: -0.72281,    val negloglik: -0.74877    accuracy: 0.0168 lr: [0.00059049]
# epoch 91 , train negloglik: -0.73115,    val negloglik: -0.76039    accuracy: 0.0160 lr: [0.00059049]
# epoch 92 , train negloglik: -0.72855,    val negloglik: -0.76485    accuracy: 0.0159 lr: [0.00059049]
# epoch 93 , train negloglik: -0.73167,    val negloglik: -0.76875    accuracy: 0.0160 lr: [0.00059049]
# epoch 94 , train negloglik: -0.74249,    val negloglik: -0.73904    accuracy: 0.0171 lr: [0.00059049]
# epoch 95 , train negloglik: -0.73682,    val negloglik: -0.76181    accuracy: 0.0164 lr: [0.00059049]
# epoch 96 , train negloglik: -0.73597,    val negloglik: -0.73479    accuracy: 0.0175 lr: [0.00059049]
# epoch 97 , train negloglik: -0.74312,    val negloglik: -0.75238    accuracy: 0.0165 lr: [0.00059049]
# epoch 98 , train negloglik: -0.73831,    val negloglik: -0.78242    accuracy: 0.0153 lr: [0.00059049]
# epoch 99 , train negloglik: -0.74483,    val negloglik: -0.77591    accuracy: 0.0156 lr: [0.00059049]
# epoch 100, train negloglik: -0.76148,    val negloglik: -0.79226    accuracy: 0.0148 lr: [0.00059049]
# epoch 101, train negloglik: -0.76463,    val negloglik: -0.78991    accuracy: 0.0156 lr: [0.000531441]
# epoch 102, train negloglik: -0.76415,    val negloglik: -0.79539    accuracy: 0.0146 lr: [0.000531441]
# epoch 103, train negloglik: -0.76874,    val negloglik: -0.80450    accuracy: 0.0148 lr: [0.000531441]
# epoch 104, train negloglik: -0.77438,    val negloglik: -0.81169    accuracy: 0.0145 lr: [0.000531441]
# epoch 105, train negloglik: -0.77972,    val negloglik: -0.80875    accuracy: 0.0145 lr: [0.000531441]
# epoch 106, train negloglik: -0.78568,    val negloglik: -0.80915    accuracy: 0.0146 lr: [0.000531441]
# epoch 107, train negloglik: -0.79020,    val negloglik: -0.81908    accuracy: 0.0139 lr: [0.000531441]
# epoch 108, train negloglik: -0.79123,    val negloglik: -0.81915    accuracy: 0.0140 lr: [0.000531441]
# epoch 109, train negloglik: -0.79374,    val negloglik: -0.81373    accuracy: 0.0143 lr: [0.000531441]
# epoch 110, train negloglik: -0.77861,    val negloglik: -0.81918    accuracy: 0.0144 lr: [0.000531441]
# epoch 111, train negloglik: -0.79528,    val negloglik: -0.82465    accuracy: 0.0141 lr: [0.000531441]
# epoch 112, train negloglik: -0.80170,    val negloglik: -0.83607    accuracy: 0.0136 lr: [0.000531441]
# epoch 113, train negloglik: -0.79950,    val negloglik: -0.83132    accuracy: 0.0134 lr: [0.000531441]
# epoch 114, train negloglik: -0.80154,    val negloglik: -0.82298    accuracy: 0.0138 lr: [0.000531441]
# epoch 115, train negloglik: -0.81225,    val negloglik: -0.84223    accuracy: 0.0133 lr: [0.000531441]
# epoch 116, train negloglik: -0.81335,    val negloglik: -0.84304    accuracy: 0.0133 lr: [0.000531441]
# epoch 117, train negloglik: -0.81759,    val negloglik: -0.81808    accuracy: 0.0144 lr: [0.000531441]
# epoch 118, train negloglik: -0.81196,    val negloglik: -0.84871    accuracy: 0.0131 lr: [0.000531441]
# epoch 119, train negloglik: -0.82273,    val negloglik: -0.85493    accuracy: 0.0126 lr: [0.000531441]
# epoch 120, train negloglik: -0.82229,    val negloglik: -0.84504    accuracy: 0.0129 lr: [0.000531441]
# epoch 121, train negloglik: -0.82737,    val negloglik: -0.83818    accuracy: 0.0132 lr: [0.0004782969]
# epoch 122, train negloglik: -0.82527,    val negloglik: -0.85815    accuracy: 0.0131 lr: [0.0004782969]
# epoch 123, train negloglik: -0.83379,    val negloglik: -0.85286    accuracy: 0.0126 lr: [0.0004782969]
# epoch 124, train negloglik: -0.82386,    val negloglik: -0.86244    accuracy: 0.0123 lr: [0.0004782969]
# epoch 125, train negloglik: -0.83529,    val negloglik: -0.86791    accuracy: 0.0123 lr: [0.0004782969]
# epoch 126, train negloglik: -0.83332,    val negloglik: -0.84184    accuracy: 0.0130 lr: [0.0004782969]
# epoch 127, train negloglik: -0.83833,    val negloglik: -0.87602    accuracy: 0.0121 lr: [0.0004782969]
# epoch 128, train negloglik: -0.83864,    val negloglik: -0.87446    accuracy: 0.0120 lr: [0.0004782969]
# epoch 129, train negloglik: -0.84161,    val negloglik: -0.87246    accuracy: 0.0122 lr: [0.0004782969]
# epoch 130, train negloglik: -0.84364,    val negloglik: -0.87112    accuracy: 0.0118 lr: [0.0004782969]
# epoch 131, train negloglik: -0.84836,    val negloglik: -0.87736    accuracy: 0.0118 lr: [0.0004782969]
# epoch 132, train negloglik: -0.85234,    val negloglik: -0.88352    accuracy: 0.0116 lr: [0.0004782969]
# epoch 133, train negloglik: -0.85878,    val negloglik: -0.88752    accuracy: 0.0114 lr: [0.0004782969]
# epoch 134, train negloglik: -0.85409,    val negloglik: -0.88883    accuracy: 0.0115 lr: [0.0004782969]
# epoch 135, train negloglik: -0.85638,    val negloglik: -0.89111    accuracy: 0.0113 lr: [0.0004782969]
# epoch 136, train negloglik: -0.86234,    val negloglik: -0.88394    accuracy: 0.0114 lr: [0.0004782969]
# epoch 137, train negloglik: -0.86638,    val negloglik: -0.88714    accuracy: 0.0114 lr: [0.0004782969]
# epoch 138, train negloglik: -0.86016,    val negloglik: -0.86900    accuracy: 0.0136 lr: [0.0004782969]
# epoch 139, train negloglik: -0.86074,    val negloglik: -0.89953    accuracy: 0.0110 lr: [0.0004782969]
# epoch 140, train negloglik: -0.86459,    val negloglik: -0.89461    accuracy: 0.0109 lr: [0.0004782969]
# epoch 141, train negloglik: -0.87468,    val negloglik: -0.90083    accuracy: 0.0113 lr: [0.00043046721]
# epoch 142, train negloglik: -0.87177,    val negloglik: -0.87649    accuracy: 0.0128 lr: [0.00043046721]
# epoch 143, train negloglik: -0.87171,    val negloglik: -0.89954    accuracy: 0.0118 lr: [0.00043046721]
# epoch 144, train negloglik: -0.87628,    val negloglik: -0.90745    accuracy: 0.0106 lr: [0.00043046721]
# epoch 145, train negloglik: -0.87967,    val negloglik: -0.90767    accuracy: 0.0106 lr: [0.00043046721]
# epoch 146, train negloglik: -0.88599,    val negloglik: -0.91238    accuracy: 0.0105 lr: [0.00043046721]
# epoch 147, train negloglik: -0.88087,    val negloglik: -0.91387    accuracy: 0.0104 lr: [0.00043046721]
# epoch 148, train negloglik: -0.88918,    val negloglik: -0.88972    accuracy: 0.0112 lr: [0.00043046721]
# epoch 149, train negloglik: -0.88601,    val negloglik: -0.91081    accuracy: 0.0109 lr: [0.00043046721]
# epoch 150, train negloglik: -0.88749,    val negloglik: -0.91668    accuracy: 0.0108 lr: [0.00043046721]
# epoch 151, train negloglik: -0.88631,    val negloglik: -0.91833    accuracy: 0.0105 lr: [0.00043046721]
# epoch 152, train negloglik: -0.89313,    val negloglik: -0.92169    accuracy: 0.0100 lr: [0.00043046721]
# epoch 153, train negloglik: -0.88597,    val negloglik: -0.91640    accuracy: 0.0101 lr: [0.00043046721]
# epoch 154, train negloglik: -0.88851,    val negloglik: -0.89305    accuracy: 0.0108 lr: [0.00043046721]
# epoch 155, train negloglik: -0.89266,    val negloglik: -0.91309    accuracy: 0.0104 lr: [0.00043046721]
# epoch 156, train negloglik: -0.89906,    val negloglik: -0.92881    accuracy: 0.0098 lr: [0.00043046721]
# epoch 157, train negloglik: -0.88859,    val negloglik: -0.91462    accuracy: 0.0103 lr: [0.00043046721]
# epoch 158, train negloglik: -0.89786,    val negloglik: -0.93023    accuracy: 0.0098 lr: [0.00043046721]
# epoch 159, train negloglik: -0.90139,    val negloglik: -0.89670    accuracy: 0.0110 lr: [0.00043046721]
# epoch 160, train negloglik: -0.90869,    val negloglik: -0.92820    accuracy: 0.0100 lr: [0.00043046721]
# epoch 161, train negloglik: -0.91114,    val negloglik: -0.93791    accuracy: 0.0095 lr: [0.000387420489]
# epoch 162, train negloglik: -0.91296,    val negloglik: -0.93335    accuracy: 0.0096 lr: [0.000387420489]
# epoch 163, train negloglik: -0.91486,    val negloglik: -0.94113    accuracy: 0.0094 lr: [0.000387420489]
# epoch 164, train negloglik: -0.91402,    val negloglik: -0.93842    accuracy: 0.0094 lr: [0.000387420489]
# epoch 165, train negloglik: -0.90816,    val negloglik: -0.94021    accuracy: 0.0096 lr: [0.000387420489]
# epoch 166, train negloglik: -0.89253,    val negloglik: -0.93971    accuracy: 0.0097 lr: [0.000387420489]
# epoch 167, train negloglik: -0.91859,    val negloglik: -0.94326    accuracy: 0.0094 lr: [0.000387420489]
# epoch 168, train negloglik: -0.91497,    val negloglik: -0.93932    accuracy: 0.0099 lr: [0.000387420489]
# epoch 169, train negloglik: -0.92355,    val negloglik: -0.94843    accuracy: 0.0091 lr: [0.000387420489]
# epoch 170, train negloglik: -0.92173,    val negloglik: -0.91183    accuracy: 0.0111 lr: [0.000387420489]
# epoch 171, train negloglik: -0.92017,    val negloglik: -0.95278    accuracy: 0.0091 lr: [0.000387420489]
# epoch 172, train negloglik: -0.92899,    val negloglik: -0.95041    accuracy: 0.0089 lr: [0.000387420489]
# epoch 173, train negloglik: -0.92408,    val negloglik: -0.88986    accuracy: 0.0108 lr: [0.000387420489]
# epoch 174, train negloglik: -0.91639,    val negloglik: -0.95265    accuracy: 0.0090 lr: [0.000387420489]
# epoch 175, train negloglik: -0.92068,    val negloglik: -0.94564    accuracy: 0.0092 lr: [0.000387420489]
# epoch 176, train negloglik: -0.92731,    val negloglik: -0.95626    accuracy: 0.0088 lr: [0.000387420489]
# epoch 177, train negloglik: -0.92432,    val negloglik: -0.94912    accuracy: 0.0089 lr: [0.000387420489]
# epoch 178, train negloglik: -0.93092,    val negloglik: -0.95826    accuracy: 0.0086 lr: [0.000387420489]
# epoch 179, train negloglik: -0.93712,    val negloglik: -0.94024    accuracy: 0.0091 lr: [0.000387420489]
# epoch 180, train negloglik: -0.93619,    val negloglik: -0.94299    accuracy: 0.0091 lr: [0.000387420489]
# epoch 181, train negloglik: -0.93715,    val negloglik: -0.94671    accuracy: 0.0089 lr: [0.0003486784401]
# epoch 182, train negloglik: -0.93914,    val negloglik: -0.95224    accuracy: 0.0088 lr: [0.0003486784401]
# epoch 183, train negloglik: -0.94077,    val negloglik: -0.96694    accuracy: 0.0083 lr: [0.0003486784401]
# epoch 184, train negloglik: -0.93562,    val negloglik: -0.96456    accuracy: 0.0085 lr: [0.0003486784401]
# epoch 185, train negloglik: -0.94150,    val negloglik: -0.95568    accuracy: 0.0091 lr: [0.0003486784401]
# epoch 186, train negloglik: -0.94039,    val negloglik: -0.95858    accuracy: 0.0088 lr: [0.0003486784401]
# epoch 187, train negloglik: -0.94503,    val negloglik: -0.97012    accuracy: 0.0082 lr: [0.0003486784401]
# epoch 188, train negloglik: -0.94690,    val negloglik: -0.92422    accuracy: 0.0101 lr: [0.0003486784401]
# epoch 189, train negloglik: -0.93247,    val negloglik: -0.97412    accuracy: 0.0082 lr: [0.0003486784401]
# epoch 190, train negloglik: -0.94338,    val negloglik: -0.96235    accuracy: 0.0084 lr: [0.0003486784401]
# epoch 191, train negloglik: -0.94771,    val negloglik: -0.97296    accuracy: 0.0081 lr: [0.0003486784401]
# epoch 192, train negloglik: -0.95264,    val negloglik: -0.97280    accuracy: 0.0081 lr: [0.0003486784401]
# epoch 193, train negloglik: -0.94916,    val negloglik: -0.95483    accuracy: 0.0086 lr: [0.0003486784401]
# epoch 194, train negloglik: -0.95340,    val negloglik: -0.96462    accuracy: 0.0082 lr: [0.0003486784401]
# epoch 195, train negloglik: -0.95662,    val negloglik: -0.97669    accuracy: 0.0079 lr: [0.0003486784401]
# epoch 196, train negloglik: -0.95766,    val negloglik: -0.98146    accuracy: 0.0079 lr: [0.0003486784401]
# epoch 197, train negloglik: -0.96062,    val negloglik: -0.97992    accuracy: 0.0078 lr: [0.0003486784401]
# epoch 198, train negloglik: -0.95800,    val negloglik: -0.98164    accuracy: 0.0077 lr: [0.0003486784401]
# epoch 199, train negloglik: -0.95546,    val negloglik: -0.98594    accuracy: 0.0077 lr: [0.0003486784401]
# epoch 200, train negloglik: -0.95721,    val negloglik: -0.98264    accuracy: 0.0077 lr: [0.0003486784401]
# epoch 201, train negloglik: -0.96051,    val negloglik: -0.98557    accuracy: 0.0076 lr: [0.00031381059609000004]
# epoch 202, train negloglik: -0.95867,    val negloglik: -0.98826    accuracy: 0.0076 lr: [0.00031381059609000004]
# epoch 203, train negloglik: -0.96119,    val negloglik: -0.97165    accuracy: 0.0082 lr: [0.00031381059609000004]
# epoch 204, train negloglik: -0.96333,    val negloglik: -0.96744    accuracy: 0.0089 lr: [0.00031381059609000004]
# epoch 205, train negloglik: -0.96288,    val negloglik: -0.99031    accuracy: 0.0075 lr: [0.00031381059609000004]
# epoch 206, train negloglik: -0.97133,    val negloglik: -0.98491    accuracy: 0.0079 lr: [0.00031381059609000004]
# epoch 207, train negloglik: -0.96451,    val negloglik: -0.95437    accuracy: 0.0087 lr: [0.00031381059609000004]
# epoch 208, train negloglik: -0.95727,    val negloglik: -0.99114    accuracy: 0.0076 lr: [0.00031381059609000004]
# epoch 209, train negloglik: -0.97210,    val negloglik: -0.99245    accuracy: 0.0074 lr: [0.00031381059609000004]
# epoch 210, train negloglik: -0.97130,    val negloglik: -0.99216    accuracy: 0.0076 lr: [0.00031381059609000004]
# epoch 211, train negloglik: -0.97059,    val negloglik: -0.97780    accuracy: 0.0081 lr: [0.00031381059609000004]
# epoch 212, train negloglik: -0.97054,    val negloglik: -0.98572    accuracy: 0.0080 lr: [0.00031381059609000004]
# epoch 213, train negloglik: -0.97301,    val negloglik: -0.98529    accuracy: 0.0079 lr: [0.00031381059609000004]
# epoch 214, train negloglik: -0.96864,    val negloglik: -0.99627    accuracy: 0.0075 lr: [0.00031381059609000004]
# epoch 215, train negloglik: -0.96701,    val negloglik: -0.99462    accuracy: 0.0074 lr: [0.00031381059609000004]
# epoch 216, train negloglik: -0.97187,    val negloglik: -1.00199    accuracy: 0.0071 lr: [0.00031381059609000004]
# epoch 217, train negloglik: -0.97685,    val negloglik: -1.00092    accuracy: 0.0071 lr: [0.00031381059609000004]
# epoch 218, train negloglik: -0.97626,    val negloglik: -0.99876    accuracy: 0.0073 lr: [0.00031381059609000004]
# epoch 219, train negloglik: -0.98178,    val negloglik: -1.00068    accuracy: 0.0072 lr: [0.00031381059609000004]
# epoch 220, train negloglik: -0.98190,    val negloglik: -1.00355    accuracy: 0.0070 lr: [0.00031381059609000004]
# epoch 221, train negloglik: -0.97875,    val negloglik: -0.99727    accuracy: 0.0074 lr: [0.00028242953648100003]
# epoch 222, train negloglik: -0.98642,    val negloglik: -1.00412    accuracy: 0.0070 lr: [0.00028242953648100003]
# epoch 223, train negloglik: -0.98724,    val negloglik: -1.00682    accuracy: 0.0070 lr: [0.00028242953648100003]
# epoch 224, train negloglik: -0.98812,    val negloglik: -1.00550    accuracy: 0.0070 lr: [0.00028242953648100003]
# epoch 225, train negloglik: -0.98692,    val negloglik: -1.00079    accuracy: 0.0071 lr: [0.00028242953648100003]
# epoch 226, train negloglik: -0.98108,    val negloglik: -1.00535    accuracy: 0.0071 lr: [0.00028242953648100003]
# epoch 227, train negloglik: -0.98518,    val negloglik: -0.99904    accuracy: 0.0074 lr: [0.00028242953648100003]
# epoch 228, train negloglik: -0.98992,    val negloglik: -1.00816    accuracy: 0.0069 lr: [0.00028242953648100003]
# epoch 229, train negloglik: -0.99104,    val negloglik: -1.00932    accuracy: 0.0070 lr: [0.00028242953648100003]
# epoch 230, train negloglik: -0.99233,    val negloglik: -0.99972    accuracy: 0.0074 lr: [0.00028242953648100003]
# epoch 231, train negloglik: -0.99041,    val negloglik: -1.00248    accuracy: 0.0073 lr: [0.00028242953648100003]
# epoch 232, train negloglik: -0.99594,    val negloglik: -1.00495    accuracy: 0.0069 lr: [0.00028242953648100003]
# epoch 233, train negloglik: -0.99456,    val negloglik: -1.00644    accuracy: 0.0070 lr: [0.00028242953648100003]
# epoch 234, train negloglik: -0.99493,    val negloglik: -1.00407    accuracy: 0.0073 lr: [0.00028242953648100003]
# epoch 235, train negloglik: -0.99429,    val negloglik: -1.01465    accuracy: 0.0067 lr: [0.00028242953648100003]
# epoch 236, train negloglik: -0.98801,    val negloglik: -1.01490    accuracy: 0.0067 lr: [0.00028242953648100003]
# epoch 237, train negloglik: -0.99712,    val negloglik: -1.00951    accuracy: 0.0068 lr: [0.00028242953648100003]
# epoch 238, train negloglik: -0.99832,    val negloglik: -1.01090    accuracy: 0.0070 lr: [0.00028242953648100003]
# epoch 239, train negloglik: -0.99773,    val negloglik: -1.00443    accuracy: 0.0071 lr: [0.00028242953648100003]
# epoch 240, train negloglik: -0.99353,    val negloglik: -1.01759    accuracy: 0.0067 lr: [0.00028242953648100003]
# epoch 241, train negloglik: -0.99949,    val negloglik: -1.00685    accuracy: 0.0069 lr: [0.00025418658283290005]
# epoch 242, train negloglik: -0.99897,    val negloglik: -1.01608    accuracy: 0.0068 lr: [0.00025418658283290005]
# epoch 243, train negloglik: -1.00220,    val negloglik: -1.00420    accuracy: 0.0072 lr: [0.00025418658283290005]
# epoch 244, train negloglik: -0.99966,    val negloglik: -1.02088    accuracy: 0.0066 lr: [0.00025418658283290005]
# epoch 245, train negloglik: -1.00381,    val negloglik: -1.02176    accuracy: 0.0065 lr: [0.00025418658283290005]
# epoch 246, train negloglik: -1.00582,    val negloglik: -1.02301    accuracy: 0.0064 lr: [0.00025418658283290005]
# epoch 247, train negloglik: -0.99808,    val negloglik: -1.02194    accuracy: 0.0064 lr: [0.00025418658283290005]
# epoch 248, train negloglik: -1.00251,    val negloglik: -1.02028    accuracy: 0.0065 lr: [0.00025418658283290005]
# epoch 249, train negloglik: -1.00414,    val negloglik: -1.02092    accuracy: 0.0065 lr: [0.00025418658283290005]
# epoch 250, train negloglik: -0.99395,    val negloglik: -1.00409    accuracy: 0.0071 lr: [0.00025418658283290005]
# epoch 251, train negloglik: -1.00197,    val negloglik: -1.02458    accuracy: 0.0064 lr: [0.00025418658283290005]
# epoch 252, train negloglik: -1.00618,    val negloglik: -1.02403    accuracy: 0.0064 lr: [0.00025418658283290005]
# epoch 253, train negloglik: -1.01019,    val negloglik: -1.02455    accuracy: 0.0065 lr: [0.00025418658283290005]
# epoch 254, train negloglik: -1.00971,    val negloglik: -1.02267    accuracy: 0.0066 lr: [0.00025418658283290005]
# epoch 255, train negloglik: -1.00656,    val negloglik: -1.01410    accuracy: 0.0067 lr: [0.00025418658283290005]
# epoch 256, train negloglik: -1.00358,    val negloglik: -1.02672    accuracy: 0.0064 lr: [0.00025418658283290005]
# epoch 257, train negloglik: -1.00637,    val negloglik: -1.00940    accuracy: 0.0068 lr: [0.00025418658283290005]
# epoch 258, train negloglik: -1.01225,    val negloglik: -1.02923    accuracy: 0.0063 lr: [0.00025418658283290005]
# epoch 259, train negloglik: -1.01145,    val negloglik: -1.03033    accuracy: 0.0062 lr: [0.00025418658283290005]
# epoch 260, train negloglik: -1.01010,    val negloglik: -1.02877    accuracy: 0.0064 lr: [0.00025418658283290005]
# epoch 261, train negloglik: -1.01434,    val negloglik: -1.03109    accuracy: 0.0062 lr: [0.00022876792454961005]
# epoch 262, train negloglik: -1.01263,    val negloglik: -1.02796    accuracy: 0.0064 lr: [0.00022876792454961005]
# epoch 263, train negloglik: -1.01397,    val negloglik: -1.02440    accuracy: 0.0064 lr: [0.00022876792454961005]
# epoch 264, train negloglik: -1.01646,    val negloglik: -1.02926    accuracy: 0.0063 lr: [0.00022876792454961005]
# epoch 265, train negloglik: -1.01765,    val negloglik: -1.03375    accuracy: 0.0062 lr: [0.00022876792454961005]
# epoch 266, train negloglik: -1.01791,    val negloglik: -1.02969    accuracy: 0.0062 lr: [0.00022876792454961005]
# epoch 267, train negloglik: -1.01549,    val negloglik: -1.02560    accuracy: 0.0066 lr: [0.00022876792454961005]
# epoch 268, train negloglik: -1.01760,    val negloglik: -1.03536    accuracy: 0.0061 lr: [0.00022876792454961005]
# epoch 269, train negloglik: -1.01405,    val negloglik: -1.03118    accuracy: 0.0062 lr: [0.00022876792454961005]
# epoch 270, train negloglik: -1.01869,    val negloglik: -1.03659    accuracy: 0.0060 lr: [0.00022876792454961005]
# epoch 271, train negloglik: -1.01889,    val negloglik: -1.02215    accuracy: 0.0064 lr: [0.00022876792454961005]
# epoch 272, train negloglik: -1.01497,    val negloglik: -1.01954    accuracy: 0.0069 lr: [0.00022876792454961005]
# epoch 273, train negloglik: -1.02058,    val negloglik: -1.03134    accuracy: 0.0063 lr: [0.00022876792454961005]
# epoch 274, train negloglik: -1.02167,    val negloglik: -1.03485    accuracy: 0.0060 lr: [0.00022876792454961005]
# epoch 275, train negloglik: -1.02422,    val negloglik: -1.03806    accuracy: 0.0060 lr: [0.00022876792454961005]
# epoch 276, train negloglik: -1.02216,    val negloglik: -1.02051    accuracy: 0.0065 lr: [0.00022876792454961005]
# epoch 277, train negloglik: -1.01830,    val negloglik: -1.04005    accuracy: 0.0060 lr: [0.00022876792454961005]
# epoch 278, train negloglik: -1.02494,    val negloglik: -1.02558    accuracy: 0.0064 lr: [0.00022876792454961005]
# epoch 279, train negloglik: -1.02404,    val negloglik: -1.03375    accuracy: 0.0063 lr: [0.00022876792454961005]
# epoch 280, train negloglik: -1.02554,    val negloglik: -1.04120    accuracy: 0.0058 lr: [0.00022876792454961005]
# epoch 281, train negloglik: -1.02390,    val negloglik: -1.04041    accuracy: 0.0060 lr: [0.00020589113209464906]
# epoch 282, train negloglik: -1.02374,    val negloglik: -1.03812    accuracy: 0.0061 lr: [0.00020589113209464906]
# epoch 283, train negloglik: -1.02621,    val negloglik: -1.03977    accuracy: 0.0060 lr: [0.00020589113209464906]
# epoch 284, train negloglik: -1.02708,    val negloglik: -1.04409    accuracy: 0.0058 lr: [0.00020589113209464906]
# epoch 285, train negloglik: -1.02516,    val negloglik: -1.02612    accuracy: 0.0063 lr: [0.00020589113209464906]
# epoch 286, train negloglik: -1.02549,    val negloglik: -1.04303    accuracy: 0.0059 lr: [0.00020589113209464906]
# epoch 287, train negloglik: -1.02733,    val negloglik: -1.03423    accuracy: 0.0061 lr: [0.00020589113209464906]
# epoch 288, train negloglik: -1.02708,    val negloglik: -1.04438    accuracy: 0.0058 lr: [0.00020589113209464906]
# epoch 289, train negloglik: -1.02888,    val negloglik: -1.03886    accuracy: 0.0060 lr: [0.00020589113209464906]
# epoch 290, train negloglik: -1.02936,    val negloglik: -1.04474    accuracy: 0.0058 lr: [0.00020589113209464906]
# epoch 291, train negloglik: -1.02818,    val negloglik: -1.04286    accuracy: 0.0060 lr: [0.00020589113209464906]
# epoch 292, train negloglik: -1.03259,    val negloglik: -1.04160    accuracy: 0.0059 lr: [0.00020589113209464906]
# epoch 293, train negloglik: -1.02936,    val negloglik: -1.04032    accuracy: 0.0060 lr: [0.00020589113209464906]
# epoch 294, train negloglik: -1.02591,    val negloglik: -1.03282    accuracy: 0.0061 lr: [0.00020589113209464906]
# epoch 295, train negloglik: -1.02146,    val negloglik: -1.04299    accuracy: 0.0060 lr: [0.00020589113209464906]
# epoch 296, train negloglik: -1.03258,    val negloglik: -1.04396    accuracy: 0.0059 lr: [0.00020589113209464906]
# epoch 297, train negloglik: -1.03275,    val negloglik: -1.04494    accuracy: 0.0058 lr: [0.00020589113209464906]
# epoch 298, train negloglik: -1.03107,    val negloglik: -1.04410    accuracy: 0.0058 lr: [0.00020589113209464906]
# epoch 299, train negloglik: -1.03280,    val negloglik: -1.04729    accuracy: 0.0057 lr: [0.00020589113209464906]
# epoch 300, train negloglik: -1.03340,    val negloglik: -1.04771    accuracy: 0.0057 lr: [0.00020589113209464906]
# epoch 301, train negloglik: -1.03410,    val negloglik: -1.04561    accuracy: 0.0059 lr: [0.00018530201888518417]
# epoch 302, train negloglik: -1.03482,    val negloglik: -1.04434    accuracy: 0.0059 lr: [0.00018530201888518417]
# epoch 303, train negloglik: -1.03453,    val negloglik: -1.04895    accuracy: 0.0056 lr: [0.00018530201888518417]
# epoch 304, train negloglik: -1.03725,    val negloglik: -1.04024    accuracy: 0.0059 lr: [0.00018530201888518417]
# epoch 305, train negloglik: -1.03684,    val negloglik: -1.05116    accuracy: 0.0056 lr: [0.00018530201888518417]
# epoch 306, train negloglik: -1.03279,    val negloglik: -1.05059    accuracy: 0.0056 lr: [0.00018530201888518417]
# epoch 307, train negloglik: -1.03918,    val negloglik: -1.04538    accuracy: 0.0058 lr: [0.00018530201888518417]
# epoch 308, train negloglik: -1.03840,    val negloglik: -1.04223    accuracy: 0.0058 lr: [0.00018530201888518417]
# epoch 309, train negloglik: -1.03254,    val negloglik: -1.04913    accuracy: 0.0057 lr: [0.00018530201888518417]
# epoch 310, train negloglik: -1.03565,    val negloglik: -1.04086    accuracy: 0.0059 lr: [0.00018530201888518417]
# epoch 311, train negloglik: -1.03862,    val negloglik: -1.05261    accuracy: 0.0055 lr: [0.00018530201888518417]
# epoch 312, train negloglik: -1.03566,    val negloglik: -1.04668    accuracy: 0.0059 lr: [0.00018530201888518417]
# epoch 313, train negloglik: -1.03824,    val negloglik: -1.04387    accuracy: 0.0058 lr: [0.00018530201888518417]
# epoch 314, train negloglik: -1.04168,    val negloglik: -1.05248    accuracy: 0.0056 lr: [0.00018530201888518417]
# epoch 315, train negloglik: -1.04043,    val negloglik: -1.03173    accuracy: 0.0061 lr: [0.00018530201888518417]
# epoch 316, train negloglik: -1.03876,    val negloglik: -1.05545    accuracy: 0.0055 lr: [0.00018530201888518417]
# epoch 317, train negloglik: -1.04259,    val negloglik: -1.04843    accuracy: 0.0059 lr: [0.00018530201888518417]
# epoch 318, train negloglik: -1.03356,    val negloglik: -1.04445    accuracy: 0.0058 lr: [0.00018530201888518417]
# epoch 319, train negloglik: -1.04195,    val negloglik: -1.05386    accuracy: 0.0057 lr: [0.00018530201888518417]
# epoch 320, train negloglik: -1.04379,    val negloglik: -1.05637    accuracy: 0.0055 lr: [0.00018530201888518417]
# epoch 321, train negloglik: -1.04311,    val negloglik: -1.04697    accuracy: 0.0057 lr: [0.00016677181699666576]
# epoch 322, train negloglik: -1.03823,    val negloglik: -1.05639    accuracy: 0.0056 lr: [0.00016677181699666576]
# epoch 323, train negloglik: -1.04252,    val negloglik: -1.05019    accuracy: 0.0057 lr: [0.00016677181699666576]
# epoch 324, train negloglik: -1.04005,    val negloglik: -1.05666    accuracy: 0.0054 lr: [0.00016677181699666576]
# epoch 325, train negloglik: -1.04370,    val negloglik: -1.05721    accuracy: 0.0055 lr: [0.00016677181699666576]
# epoch 326, train negloglik: -1.04436,    val negloglik: -1.05847    accuracy: 0.0054 lr: [0.00016677181699666576]
# epoch 327, train negloglik: -1.04601,    val negloglik: -1.05219    accuracy: 0.0056 lr: [0.00016677181699666576]
# epoch 328, train negloglik: -1.04301,    val negloglik: -1.05023    accuracy: 0.0057 lr: [0.00016677181699666576]
# epoch 329, train negloglik: -1.03832,    val negloglik: -1.05999    accuracy: 0.0054 lr: [0.00016677181699666576]
# epoch 330, train negloglik: -1.04410,    val negloglik: -1.05677    accuracy: 0.0055 lr: [0.00016677181699666576]
# epoch 331, train negloglik: -1.04589,    val negloglik: -1.04894    accuracy: 0.0057 lr: [0.00016677181699666576]
# epoch 332, train negloglik: -1.04785,    val negloglik: -1.05945    accuracy: 0.0053 lr: [0.00016677181699666576]
# epoch 333, train negloglik: -1.04578,    val negloglik: -1.05841    accuracy: 0.0055 lr: [0.00016677181699666576]
# epoch 334, train negloglik: -1.04975,    val negloglik: -1.06274    accuracy: 0.0053 lr: [0.00016677181699666576]
# epoch 335, train negloglik: -1.04990,    val negloglik: -1.06227    accuracy: 0.0053 lr: [0.00016677181699666576]
# epoch 336, train negloglik: -1.04726,    val negloglik: -1.06160    accuracy: 0.0053 lr: [0.00016677181699666576]
# epoch 337, train negloglik: -1.04844,    val negloglik: -1.06082    accuracy: 0.0054 lr: [0.00016677181699666576]
# epoch 338, train negloglik: -1.05002,    val negloglik: -1.05618    accuracy: 0.0055 lr: [0.00016677181699666576]
# epoch 339, train negloglik: -1.05229,    val negloglik: -1.04652    accuracy: 0.0057 lr: [0.00016677181699666576]
# epoch 340, train negloglik: -1.05087,    val negloglik: -1.06255    accuracy: 0.0053 lr: [0.00016677181699666576]
# epoch 341, train negloglik: -1.05240,    val negloglik: -1.06376    accuracy: 0.0053 lr: [0.0001500946352969992]
# epoch 342, train negloglik: -1.05191,    val negloglik: -1.05006    accuracy: 0.0057 lr: [0.0001500946352969992]
# epoch 343, train negloglik: -1.05199,    val negloglik: -1.06465    accuracy: 0.0052 lr: [0.0001500946352969992]
# epoch 344, train negloglik: -1.05098,    val negloglik: -1.06521    accuracy: 0.0053 lr: [0.0001500946352969992]
# epoch 345, train negloglik: -1.05421,    val negloglik: -1.05980    accuracy: 0.0054 lr: [0.0001500946352969992]
# epoch 346, train negloglik: -1.05374,    val negloglik: -1.06378    accuracy: 0.0053 lr: [0.0001500946352969992]
# epoch 347, train negloglik: -1.04988,    val negloglik: -1.03399    accuracy: 0.0060 lr: [0.0001500946352969992]
# epoch 348, train negloglik: -1.04604,    val negloglik: -1.06517    accuracy: 0.0053 lr: [0.0001500946352969992]
# epoch 349, train negloglik: -1.05367,    val negloglik: -1.06623    accuracy: 0.0052 lr: [0.0001500946352969992]
# epoch 350, train negloglik: -1.05474,    val negloglik: -1.06688    accuracy: 0.0052 lr: [0.0001500946352969992]
# epoch 351, train negloglik: -1.05253,    val negloglik: -1.06149    accuracy: 0.0054 lr: [0.0001500946352969992]
# epoch 352, train negloglik: -1.05732,    val negloglik: -1.05651    accuracy: 0.0055 lr: [0.0001500946352969992]
# epoch 353, train negloglik: -1.05410,    val negloglik: -1.06598    accuracy: 0.0052 lr: [0.0001500946352969992]
# epoch 354, train negloglik: -1.05593,    val negloglik: -1.06080    accuracy: 0.0054 lr: [0.0001500946352969992]
# epoch 355, train negloglik: -1.05546,    val negloglik: -1.06486    accuracy: 0.0053 lr: [0.0001500946352969992]
# epoch 356, train negloglik: -1.05360,    val negloglik: -1.06812    accuracy: 0.0052 lr: [0.0001500946352969992]
# epoch 357, train negloglik: -1.05372,    val negloglik: -1.06597    accuracy: 0.0052 lr: [0.0001500946352969992]
# epoch 358, train negloglik: -1.05510,    val negloglik: -1.05593    accuracy: 0.0055 lr: [0.0001500946352969992]
# epoch 359, train negloglik: -1.05838,    val negloglik: -1.06926    accuracy: 0.0051 lr: [0.0001500946352969992]
# epoch 360, train negloglik: -1.05205,    val negloglik: -1.05971    accuracy: 0.0056 lr: [0.0001500946352969992]
# epoch 361, train negloglik: -1.05366,    val negloglik: -1.06449    accuracy: 0.0053 lr: [0.0001350851717672993]
# epoch 362, train negloglik: -1.05353,    val negloglik: -1.05091    accuracy: 0.0056 lr: [0.0001350851717672993]
# epoch 363, train negloglik: -1.05783,    val negloglik: -1.06930    accuracy: 0.0052 lr: [0.0001350851717672993]
# epoch 364, train negloglik: -1.05296,    val negloglik: -1.07041    accuracy: 0.0051 lr: [0.0001350851717672993]
# epoch 365, train negloglik: -1.05697,    val negloglik: -1.06699    accuracy: 0.0052 lr: [0.0001350851717672993]
# epoch 366, train negloglik: -1.05889,    val negloglik: -1.06862    accuracy: 0.0052 lr: [0.0001350851717672993]
# epoch 367, train negloglik: -1.05545,    val negloglik: -1.05943    accuracy: 0.0054 lr: [0.0001350851717672993]
# epoch 368, train negloglik: -1.05891,    val negloglik: -1.06930    accuracy: 0.0051 lr: [0.0001350851717672993]
# epoch 369, train negloglik: -1.06056,    val negloglik: -1.07032    accuracy: 0.0051 lr: [0.0001350851717672993]
# epoch 370, train negloglik: -1.05947,    val negloglik: -1.06776    accuracy: 0.0052 lr: [0.0001350851717672993]
# epoch 371, train negloglik: -1.05655,    val negloglik: -1.07034    accuracy: 0.0051 lr: [0.0001350851717672993]
# epoch 372, train negloglik: -1.05896,    val negloglik: -1.06949    accuracy: 0.0052 lr: [0.0001350851717672993]
# epoch 373, train negloglik: -1.05868,    val negloglik: -1.06684    accuracy: 0.0053 lr: [0.0001350851717672993]
# epoch 374, train negloglik: -1.06042,    val negloglik: -1.06862    accuracy: 0.0052 lr: [0.0001350851717672993]
# epoch 375, train negloglik: -1.05600,    val negloglik: -1.07377    accuracy: 0.0050 lr: [0.0001350851717672993]
# epoch 376, train negloglik: -1.06206,    val negloglik: -1.06882    accuracy: 0.0051 lr: [0.0001350851717672993]
# epoch 377, train negloglik: -1.06338,    val negloglik: -1.06569    accuracy: 0.0053 lr: [0.0001350851717672993]
# epoch 378, train negloglik: -1.06150,    val negloglik: -1.07371    accuracy: 0.0050 lr: [0.0001350851717672993]
# epoch 379, train negloglik: -1.06253,    val negloglik: -1.07012    accuracy: 0.0051 lr: [0.0001350851717672993]
# epoch 380, train negloglik: -1.05967,    val negloglik: -1.07055    accuracy: 0.0051 lr: [0.0001350851717672993]
# epoch 381, train negloglik: -1.06301,    val negloglik: -1.07194    accuracy: 0.0051 lr: [0.00012157665459056936]
# epoch 382, train negloglik: -1.06140,    val negloglik: -1.07551    accuracy: 0.0050 lr: [0.00012157665459056936]
# epoch 383, train negloglik: -1.06391,    val negloglik: -1.06964    accuracy: 0.0052 lr: [0.00012157665459056936]
# epoch 384, train negloglik: -1.06244,    val negloglik: -1.07406    accuracy: 0.0050 lr: [0.00012157665459056936]
# epoch 385, train negloglik: -1.06370,    val negloglik: -1.07292    accuracy: 0.0051 lr: [0.00012157665459056936]
# epoch 386, train negloglik: -1.06317,    val negloglik: -1.06730    accuracy: 0.0052 lr: [0.00012157665459056936]
# epoch 387, train negloglik: -1.06282,    val negloglik: -1.07209    accuracy: 0.0050 lr: [0.00012157665459056936]
# epoch 388, train negloglik: -1.06538,    val negloglik: -1.06909    accuracy: 0.0053 lr: [0.00012157665459056936]
# epoch 389, train negloglik: -1.06311,    val negloglik: -1.07280    accuracy: 0.0050 lr: [0.00012157665459056936]
# epoch 390, train negloglik: -1.06429,    val negloglik: -1.07181    accuracy: 0.0051 lr: [0.00012157665459056936]
# epoch 391, train negloglik: -1.06632,    val negloglik: -1.07665    accuracy: 0.0050 lr: [0.00012157665459056936]
# epoch 392, train negloglik: -1.06278,    val negloglik: -1.07560    accuracy: 0.0050 lr: [0.00012157665459056936]
# epoch 393, train negloglik: -1.06619,    val negloglik: -1.07667    accuracy: 0.0049 lr: [0.00012157665459056936]
# epoch 394, train negloglik: -1.06416,    val negloglik: -1.07469    accuracy: 0.0050 lr: [0.00012157665459056936]
# epoch 395, train negloglik: -1.06679,    val negloglik: -1.07078    accuracy: 0.0051 lr: [0.00012157665459056936]
# epoch 396, train negloglik: -1.06569,    val negloglik: -1.07365    accuracy: 0.0051 lr: [0.00012157665459056936]
# epoch 397, train negloglik: -1.06525,    val negloglik: -1.07670    accuracy: 0.0049 lr: [0.00012157665459056936]
# epoch 398, train negloglik: -1.06327,    val negloglik: -1.07367    accuracy: 0.0050 lr: [0.00012157665459056936]
# epoch 399, train negloglik: -1.06795,    val negloglik: -1.07554    accuracy: 0.0050 lr: [0.00012157665459056936]
# epoch 400, train negloglik: -1.06806,    val negloglik: -1.07128    accuracy: 0.0051 lr: [0.00012157665459056936]
# epoch 401, train negloglik: -1.06768,    val negloglik: -1.07269    accuracy: 0.0051 lr: [0.00010941898913151243]
# epoch 402, train negloglik: -1.06617,    val negloglik: -1.07935    accuracy: 0.0048 lr: [0.00010941898913151243]
# epoch 403, train negloglik: -1.06828,    val negloglik: -1.07245    accuracy: 0.0051 lr: [0.00010941898913151243]
# epoch 404, train negloglik: -1.06579,    val negloglik: -1.07285    accuracy: 0.0050 lr: [0.00010941898913151243]
# epoch 405, train negloglik: -1.06719,    val negloglik: -1.07631    accuracy: 0.0050 lr: [0.00010941898913151243]
# epoch 406, train negloglik: -1.06933,    val negloglik: -1.07960    accuracy: 0.0049 lr: [0.00010941898913151243]
# epoch 407, train negloglik: -1.06816,    val negloglik: -1.07963    accuracy: 0.0049 lr: [0.00010941898913151243]
# epoch 408, train negloglik: -1.07010,    val negloglik: -1.07380    accuracy: 0.0051 lr: [0.00010941898913151243]
# epoch 409, train negloglik: -1.06547,    val negloglik: -1.07799    accuracy: 0.0050 lr: [0.00010941898913151243]
# epoch 410, train negloglik: -1.07037,    val negloglik: -1.07893    accuracy: 0.0049 lr: [0.00010941898913151243]
# epoch 411, train negloglik: -1.06971,    val negloglik: -1.07457    accuracy: 0.0051 lr: [0.00010941898913151243]
# epoch 412, train negloglik: -1.07019,    val negloglik: -1.08051    accuracy: 0.0048 lr: [0.00010941898913151243]
# epoch 413, train negloglik: -1.06794,    val negloglik: -1.08096    accuracy: 0.0048 lr: [0.00010941898913151243]
# epoch 414, train negloglik: -1.06991,    val negloglik: -1.07783    accuracy: 0.0049 lr: [0.00010941898913151243]
# epoch 415, train negloglik: -1.06936,    val negloglik: -1.07560    accuracy: 0.0050 lr: [0.00010941898913151243]
# epoch 416, train negloglik: -1.07189,    val negloglik: -1.08094    accuracy: 0.0048 lr: [0.00010941898913151243]
# epoch 417, train negloglik: -1.07112,    val negloglik: -1.07826    accuracy: 0.0049 lr: [0.00010941898913151243]
# epoch 418, train negloglik: -1.07183,    val negloglik: -1.08158    accuracy: 0.0048 lr: [0.00010941898913151243]
# epoch 419, train negloglik: -1.07188,    val negloglik: -1.07676    accuracy: 0.0050 lr: [0.00010941898913151243]
# epoch 420, train negloglik: -1.07024,    val negloglik: -1.08133    accuracy: 0.0048 lr: [0.00010941898913151243]
# epoch 421, train negloglik: -1.07333,    val negloglik: -1.07984    accuracy: 0.0049 lr: [9.847709021836118e-05]
# epoch 422, train negloglik: -1.07226,    val negloglik: -1.07689    accuracy: 0.0050 lr: [9.847709021836118e-05]
# epoch 423, train negloglik: -1.07162,    val negloglik: -1.08243    accuracy: 0.0048 lr: [9.847709021836118e-05]
# epoch 424, train negloglik: -1.07312,    val negloglik: -1.07429    accuracy: 0.0050 lr: [9.847709021836118e-05]
# epoch 425, train negloglik: -1.07101,    val negloglik: -1.07978    accuracy: 0.0050 lr: [9.847709021836118e-05]
# epoch 426, train negloglik: -1.07291,    val negloglik: -1.08241    accuracy: 0.0048 lr: [9.847709021836118e-05]
# epoch 427, train negloglik: -1.07362,    val negloglik: -1.07892    accuracy: 0.0050 lr: [9.847709021836118e-05]
# epoch 428, train negloglik: -1.07299,    val negloglik: -1.08250    accuracy: 0.0048 lr: [9.847709021836118e-05]
# epoch 429, train negloglik: -1.07236,    val negloglik: -1.08095    accuracy: 0.0048 lr: [9.847709021836118e-05]
# epoch 430, train negloglik: -1.07071,    val negloglik: -1.08361    accuracy: 0.0048 lr: [9.847709021836118e-05]
# epoch 431, train negloglik: -1.07118,    val negloglik: -1.08308    accuracy: 0.0048 lr: [9.847709021836118e-05]
# epoch 432, train negloglik: -1.07386,    val negloglik: -1.08349    accuracy: 0.0048 lr: [9.847709021836118e-05]
# epoch 433, train negloglik: -1.07503,    val negloglik: -1.08016    accuracy: 0.0049 lr: [9.847709021836118e-05]
# epoch 434, train negloglik: -1.06912,    val negloglik: -1.08386    accuracy: 0.0048 lr: [9.847709021836118e-05]
# epoch 435, train negloglik: -1.07442,    val negloglik: -1.08338    accuracy: 0.0048 lr: [9.847709021836118e-05]
# epoch 436, train negloglik: -1.07522,    val negloglik: -1.08264    accuracy: 0.0048 lr: [9.847709021836118e-05]
# epoch 437, train negloglik: -1.07388,    val negloglik: -1.08375    accuracy: 0.0048 lr: [9.847709021836118e-05]
# epoch 438, train negloglik: -1.07586,    val negloglik: -1.08430    accuracy: 0.0048 lr: [9.847709021836118e-05]
# epoch 439, train negloglik: -1.07470,    val negloglik: -1.08527    accuracy: 0.0047 lr: [9.847709021836118e-05]
# epoch 440, train negloglik: -1.07498,    val negloglik: -1.08414    accuracy: 0.0048 lr: [9.847709021836118e-05]
# epoch 441, train negloglik: -1.07712,    val negloglik: -1.08195    accuracy: 0.0048 lr: [8.862938119652506e-05]
# epoch 442, train negloglik: -1.07733,    val negloglik: -1.08463    accuracy: 0.0048 lr: [8.862938119652506e-05]
# epoch 443, train negloglik: -1.07574,    val negloglik: -1.08107    accuracy: 0.0049 lr: [8.862938119652506e-05]
# epoch 444, train negloglik: -1.07536,    val negloglik: -1.08212    accuracy: 0.0049 lr: [8.862938119652506e-05]
# epoch 445, train negloglik: -1.07364,    val negloglik: -1.08631    accuracy: 0.0047 lr: [8.862938119652506e-05]
# epoch 446, train negloglik: -1.07670,    val negloglik: -1.07535    accuracy: 0.0050 lr: [8.862938119652506e-05]
# epoch 447, train negloglik: -1.07302,    val negloglik: -1.08107    accuracy: 0.0048 lr: [8.862938119652506e-05]
# epoch 448, train negloglik: -1.07718,    val negloglik: -1.08586    accuracy: 0.0047 lr: [8.862938119652506e-05]
# epoch 449, train negloglik: -1.07693,    val negloglik: -1.08316    accuracy: 0.0048 lr: [8.862938119652506e-05]
# epoch 450, train negloglik: -1.07576,    val negloglik: -1.08698    accuracy: 0.0047 lr: [8.862938119652506e-05]
# epoch 451, train negloglik: -1.07733,    val negloglik: -1.08529    accuracy: 0.0048 lr: [8.862938119652506e-05]
# epoch 452, train negloglik: -1.07792,    val negloglik: -1.08305    accuracy: 0.0048 lr: [8.862938119652506e-05]
# epoch 453, train negloglik: -1.07539,    val negloglik: -1.08717    accuracy: 0.0047 lr: [8.862938119652506e-05]
# epoch 454, train negloglik: -1.07853,    val negloglik: -1.08478    accuracy: 0.0048 lr: [8.862938119652506e-05]
# epoch 455, train negloglik: -1.07884,    val negloglik: -1.08729    accuracy: 0.0047 lr: [8.862938119652506e-05]
# epoch 456, train negloglik: -1.07550,    val negloglik: -1.08823    accuracy: 0.0047 lr: [8.862938119652506e-05]
# epoch 457, train negloglik: -1.07860,    val negloglik: -1.08098    accuracy: 0.0048 lr: [8.862938119652506e-05]
# epoch 458, train negloglik: -1.07628,    val negloglik: -1.08586    accuracy: 0.0048 lr: [8.862938119652506e-05]
# epoch 459, train negloglik: -1.07814,    val negloglik: -1.08694    accuracy: 0.0047 lr: [8.862938119652506e-05]
# epoch 460, train negloglik: -1.07609,    val negloglik: -1.08814    accuracy: 0.0047 lr: [8.862938119652506e-05]
# epoch 461, train negloglik: -1.07821,    val negloglik: -1.08767    accuracy: 0.0047 lr: [7.976644307687256e-05]
# epoch 462, train negloglik: -1.07846,    val negloglik: -1.08419    accuracy: 0.0048 lr: [7.976644307687256e-05]
# epoch 463, train negloglik: -1.07919,    val negloglik: -1.08200    accuracy: 0.0048 lr: [7.976644307687256e-05]
# epoch 464, train negloglik: -1.07863,    val negloglik: -1.08579    accuracy: 0.0047 lr: [7.976644307687256e-05]
# epoch 465, train negloglik: -1.07961,    val negloglik: -1.08584    accuracy: 0.0047 lr: [7.976644307687256e-05]
# epoch 466, train negloglik: -1.08003,    val negloglik: -1.08216    accuracy: 0.0048 lr: [7.976644307687256e-05]
# epoch 467, train negloglik: -1.07877,    val negloglik: -1.08412    accuracy: 0.0048 lr: [7.976644307687256e-05]
# epoch 468, train negloglik: -1.08009,    val negloglik: -1.08837    accuracy: 0.0047 lr: [7.976644307687256e-05]
# epoch 469, train negloglik: -1.07929,    val negloglik: -1.08889    accuracy: 0.0047 lr: [7.976644307687256e-05]
# epoch 470, train negloglik: -1.07878,    val negloglik: -1.08786    accuracy: 0.0047 lr: [7.976644307687256e-05]
# epoch 471, train negloglik: -1.07908,    val negloglik: -1.08573    accuracy: 0.0047 lr: [7.976644307687256e-05]
# epoch 472, train negloglik: -1.08027,    val negloglik: -1.07357    accuracy: 0.0050 lr: [7.976644307687256e-05]
# epoch 473, train negloglik: -1.07952,    val negloglik: -1.08407    accuracy: 0.0047 lr: [7.976644307687256e-05]
# epoch 474, train negloglik: -1.07936,    val negloglik: -1.08388    accuracy: 0.0048 lr: [7.976644307687256e-05]
# epoch 475, train negloglik: -1.08004,    val negloglik: -1.08799    accuracy: 0.0047 lr: [7.976644307687256e-05]
# epoch 476, train negloglik: -1.08034,    val negloglik: -1.09092    accuracy: 0.0046 lr: [7.976644307687256e-05]
# epoch 477, train negloglik: -1.08083,    val negloglik: -1.08838    accuracy: 0.0047 lr: [7.976644307687256e-05]
# epoch 478, train negloglik: -1.08168,    val negloglik: -1.08964    accuracy: 0.0046 lr: [7.976644307687256e-05]
# epoch 479, train negloglik: -1.08134,    val negloglik: -1.09064    accuracy: 0.0046 lr: [7.976644307687256e-05]
# epoch 480, train negloglik: -1.08162,    val negloglik: -1.08767    accuracy: 0.0047 lr: [7.976644307687256e-05]
# epoch 481, train negloglik: -1.08233,    val negloglik: -1.09138    accuracy: 0.0046 lr: [7.17897987691853e-05]
# epoch 482, train negloglik: -1.08186,    val negloglik: -1.09005    accuracy: 0.0046 lr: [7.17897987691853e-05]
# epoch 483, train negloglik: -1.08040,    val negloglik: -1.08850    accuracy: 0.0047 lr: [7.17897987691853e-05]
# epoch 484, train negloglik: -1.07856,    val negloglik: -1.08825    accuracy: 0.0047 lr: [7.17897987691853e-05]
# epoch 485, train negloglik: -1.08180,    val negloglik: -1.09009    accuracy: 0.0046 lr: [7.17897987691853e-05]
# epoch 486, train negloglik: -1.08155,    val negloglik: -1.08747    accuracy: 0.0047 lr: [7.17897987691853e-05]
# epoch 487, train negloglik: -1.08282,    val negloglik: -1.08254    accuracy: 0.0048 lr: [7.17897987691853e-05]
# epoch 488, train negloglik: -1.08075,    val negloglik: -1.08984    accuracy: 0.0046 lr: [7.17897987691853e-05]
# epoch 489, train negloglik: -1.08149,    val negloglik: -1.09216    accuracy: 0.0046 lr: [7.17897987691853e-05]
# epoch 490, train negloglik: -1.08155,    val negloglik: -1.08822    accuracy: 0.0047 lr: [7.17897987691853e-05]
# epoch 491, train negloglik: -1.08243,    val negloglik: -1.08896    accuracy: 0.0046 lr: [7.17897987691853e-05]
# epoch 492, train negloglik: -1.08346,    val negloglik: -1.09073    accuracy: 0.0046 lr: [7.17897987691853e-05]
# epoch 493, train negloglik: -1.08424,    val negloglik: -1.09222    accuracy: 0.0046 lr: [7.17897987691853e-05]
# epoch 494, train negloglik: -1.08324,    val negloglik: -1.09065    accuracy: 0.0047 lr: [7.17897987691853e-05]
# epoch 495, train negloglik: -1.08247,    val negloglik: -1.08987    accuracy: 0.0047 lr: [7.17897987691853e-05]
# epoch 496, train negloglik: -1.08212,    val negloglik: -1.09096    accuracy: 0.0046 lr: [7.17897987691853e-05]
# epoch 497, train negloglik: -1.08274,    val negloglik: -1.09096    accuracy: 0.0047 lr: [7.17897987691853e-05]
# epoch 498, train negloglik: -1.08407,    val negloglik: -1.09233    accuracy: 0.0046 lr: [7.17897987691853e-05]
# epoch 499, train negloglik: -1.08383,    val negloglik: -1.09154    accuracy: 0.0046 lr: [7.17897987691853e-05]

# %%
model.print_model()
# Out:
# GP_Model(
#   (layer_0): LayerFused(in=2 out=10 gp_pts_per_neuron=2)
#   (layer_1): LayerFused(in=10 out=1 gp_pts_per_neuron=2)
# )
# parameter count:  211

# %%
print([layer[0] for layer in model.named_parameters()])
# Out:
# ['input_noise_log', 'layer_0.z', 'layer_0.h', 'layer_0.l', 'layer_0.s', 'layer_0.jitter', 'layer_1.z', 'layer_1.h', 'layer_1.l', 'layer_1.s', 'layer_1.jitter']

# %%
# 1層目
model.layers[0].save_fig("./outputs/layer_fused1.png")

# %%
model.layers[1].save_fig("./outputs/layer_fused2.png")

# %%
# Make predictions on the test set
X_test_tensor = X_test  # X_test is already a tensor
with torch.no_grad():
    predictions = model.predict(X_test_tensor)

# Create a 3D scatter plot of predictions vs actual values
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# Scatter plot
# ax.scatter(X_test[:, 0].numpy(), X_test[:, 1].numpy(), y_test.numpy(), c='blue', marker='o', label='Actual')
ax.scatter(X_test[:, 0].numpy(), X_test[:, 1].numpy(), predictions.mean.numpy(), c='red', marker='o', label='Predicted')
# Plot the surface
surface = ax.plot_surface(x_grid, y_grid, z_grid, alpha=0.8)

# Set labels and title
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('3D Scatter Plot of Model Predictions vs Actual Values')
ax.legend()

# Calculate and print metrics
mse = torch.mean((predictions.mean - y_test)**2).item()
rmse = torch.sqrt(torch.mean((predictions.mean - y_test)**2)).item()
print(f"MSE: {mse:.6f}")
print(f"RMSE: {rmse:.6f}")
# Out:
# MSE: 0.004859
# RMSE: 0.069706

# %%
import sys
sys.path.append("../../") # add top-level to import path search
from lib import model as gplib
from lib import runner
# from lib.dataset import MNIST
import torch.utils.data
from torch.utils.data import DataLoader

# %% [markdown]
# First, load train, validation and test dataloaders

# %%
import numpy as np
import torch
from torch.utils.data import TensorDataset, DataLoader
import matplotlib.pyplot as plt

# Generate synthetic data with f(x, y) = (x+y)^2
np.random.seed(42)  # for reproducibility
num_samples = 1000

# Generate random input points (x, y) from -1 to 1
x = np.random.uniform(-1, 1, num_samples)
y = np.random.uniform(-1, 1, num_samples)


# Compute target values: f(x, y) = (x+y)^2
targets = (x+y)**2

# Reshape inputs
inputs = np.vstack((x, y)).T

# Convert to PyTorch tensors
X_tensor = torch.FloatTensor(inputs)
y_tensor = torch.FloatTensor(targets).reshape(-1, 1)

# Split data into train, validation, and test sets
train_size = int(0.7 * num_samples)
val_size = int(0.15 * num_samples)
test_size = num_samples - train_size - val_size

X_train = X_tensor[:train_size]
y_train = y_tensor[:train_size]

X_val = X_tensor[train_size:train_size+val_size]
y_val = y_tensor[train_size:train_size+val_size]

X_test = X_tensor[train_size+val_size:]
y_test = y_tensor[train_size+val_size:]

# Create datasets
train_dataset = TensorDataset(X_train, y_train)
val_dataset = TensorDataset(X_val, y_val)
test_dataset = TensorDataset(X_test, y_test)

# Create dataloaders
batch_size = 32
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size)

print(f"Train samples: {len(train_dataset)}")
print(f"Validation samples: {len(val_dataset)}")
print(f"Test samples: {len(test_dataset)}")
# Out:
# Train samples: 700
# Validation samples: 150
# Test samples: 150

# %%
# Create a 3D visualization of the function
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# Create a grid of x and y values
x_grid, y_grid = np.meshgrid(np.linspace(-1, 1, 30), np.linspace(-1, 1, 30))
z_grid = (x_grid+y_grid)**2  # The target function


# Plot the surface
surface = ax.plot_surface(x_grid, y_grid, z_grid, alpha=0.8)

# Plot the data points
ax.scatter(x, y, targets, c='blue', marker='o', s=2)

# Add labels and a colorbar
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('f(x,y) = (x+y)^2')
ax.set_title('3D Visualization of Target Function')
# Out:
# Text(0.5, 0.92, '3D Visualization of Target Function')

# %% [markdown]
# Train a new model

# %%
# model = gplib.GP_Model(
#     [
#         gplib.GP_conv2D(28, 28, 1, 3, kernel_size=4, stride=2, num_gp_pts=10, use_double_layer=True),
#         gplib.NormaliseGaussian(),
#         gplib.GP_conv2D(13, 13, 3, 3, kernel_size=4, stride=2, num_gp_pts=10, use_double_layer=True),
#         gplib.NormaliseGaussian(),
#         gplib.ReshapeGaussian([-1, 75]),
#         gplib.LayerFused(75, 10, num_gp_pts=10),
#         gplib.NormaliseGaussian(),
#         gplib.LayerFused(10, 10, num_gp_pts=10),
#     ],
#     saveload_path="model.pt",
# )

model = gplib.GP_Model(
    [   
        gplib.LayerFused(2, 1, num_gp_pts=2),
        gplib.LayerFused(1, 1, num_gp_pts=2),
    ],
    saveload_path="model_test02_01.pt",
)
np.random.seed(42)  # for reproducibility
runner.train_model(
    train_dataloader, val_dataloader, model, epochs=500, learning_rate=1e-3, use_gpu=False, # True,
    pretrain=False,# True,
    global_jitter=1e-3, baseline_jitter=1e-3
)
model.save_model() # optionally save the model after training
# Out:
# epoch 0  , train negloglik: 1.92545,    val negloglik: 1.06566    accuracy: 0.8385 lr: [0.001]
# epoch 1  , train negloglik: 1.12503,    val negloglik: 1.03910    accuracy: 0.7952 lr: [0.0009000000000000001]
# epoch 2  , train negloglik: 1.05283,    val negloglik: 0.97694    accuracy: 0.7838 lr: [0.0009000000000000001]
# epoch 3  , train negloglik: 0.96220,    val negloglik: 0.92561    accuracy: 0.7789 lr: [0.0009000000000000001]
# epoch 4  , train negloglik: 0.94420,    val negloglik: 0.91469    accuracy: 0.7647 lr: [0.0009000000000000001]
# epoch 5  , train negloglik: 0.93542,    val negloglik: 0.90328    accuracy: 0.7593 lr: [0.0009000000000000001]
# epoch 6  , train negloglik: 0.92642,    val negloglik: 0.89427    accuracy: 0.7526 lr: [0.0009000000000000001]
# epoch 7  , train negloglik: 0.91688,    val negloglik: 0.88535    accuracy: 0.7485 lr: [0.0009000000000000001]
# epoch 8  , train negloglik: 0.90854,    val negloglik: 0.88775    accuracy: 0.7440 lr: [0.0009000000000000001]
# epoch 9  , train negloglik: 0.89966,    val negloglik: 0.87131    accuracy: 0.7371 lr: [0.0009000000000000001]
# epoch 10 , train negloglik: 0.89206,    val negloglik: 0.86904    accuracy: 0.7305 lr: [0.0009000000000000001]
# epoch 11 , train negloglik: 0.88522,    val negloglik: 0.86382    accuracy: 0.7288 lr: [0.0009000000000000001]
# epoch 12 , train negloglik: 0.87813,    val negloglik: 0.86035    accuracy: 0.7259 lr: [0.0009000000000000001]
# epoch 13 , train negloglik: 0.87234,    val negloglik: 0.84860    accuracy: 0.7235 lr: [0.0009000000000000001]
# epoch 14 , train negloglik: 0.86557,    val negloglik: 0.84957    accuracy: 0.7179 lr: [0.0009000000000000001]
# epoch 15 , train negloglik: 0.85982,    val negloglik: 0.84486    accuracy: 0.7137 lr: [0.0009000000000000001]
# epoch 16 , train negloglik: 0.85479,    val negloglik: 0.84088    accuracy: 0.7123 lr: [0.0009000000000000001]
# epoch 17 , train negloglik: 0.84928,    val negloglik: 0.83464    accuracy: 0.7102 lr: [0.0009000000000000001]
# epoch 18 , train negloglik: 0.84505,    val negloglik: 0.83596    accuracy: 0.7046 lr: [0.0009000000000000001]
# epoch 19 , train negloglik: 0.83993,    val negloglik: 0.82695    accuracy: 0.7068 lr: [0.0009000000000000001]
# epoch 20 , train negloglik: 0.83598,    val negloglik: 0.82508    accuracy: 0.7013 lr: [0.0009000000000000001]
# epoch 21 , train negloglik: 0.83204,    val negloglik: 0.82525    accuracy: 0.7007 lr: [0.0008100000000000001]
# epoch 22 , train negloglik: 0.82798,    val negloglik: 0.81859    accuracy: 0.6993 lr: [0.0008100000000000001]
# epoch 23 , train negloglik: 0.82459,    val negloglik: 0.82051    accuracy: 0.6992 lr: [0.0008100000000000001]
# epoch 24 , train negloglik: 0.82079,    val negloglik: 0.81353    accuracy: 0.6981 lr: [0.0008100000000000001]
# epoch 25 , train negloglik: 0.81719,    val negloglik: 0.81411    accuracy: 0.6942 lr: [0.0008100000000000001]
# epoch 26 , train negloglik: 0.81322,    val negloglik: 0.81089    accuracy: 0.6948 lr: [0.0008100000000000001]
# epoch 27 , train negloglik: 0.81042,    val negloglik: 0.80874    accuracy: 0.6964 lr: [0.0008100000000000001]
# epoch 28 , train negloglik: 0.80690,    val negloglik: 0.80986    accuracy: 0.6934 lr: [0.0008100000000000001]
# epoch 29 , train negloglik: 0.80339,    val negloglik: 0.80386    accuracy: 0.6947 lr: [0.0008100000000000001]
# epoch 30 , train negloglik: 0.80152,    val negloglik: 0.79852    accuracy: 0.6938 lr: [0.0008100000000000001]
# epoch 31 , train negloglik: 0.79815,    val negloglik: 0.79907    accuracy: 0.6963 lr: [0.0008100000000000001]
# epoch 32 , train negloglik: 0.79543,    val negloglik: 0.79799    accuracy: 0.6924 lr: [0.0008100000000000001]
# epoch 33 , train negloglik: 0.79120,    val negloglik: 0.79191    accuracy: 0.6932 lr: [0.0008100000000000001]
# epoch 34 , train negloglik: 0.78803,    val negloglik: 0.79173    accuracy: 0.6917 lr: [0.0008100000000000001]
# epoch 35 , train negloglik: 0.78548,    val negloglik: 0.79133    accuracy: 0.6936 lr: [0.0008100000000000001]
# epoch 36 , train negloglik: 0.78199,    val negloglik: 0.78643    accuracy: 0.6920 lr: [0.0008100000000000001]
# epoch 37 , train negloglik: 0.77963,    val negloglik: 0.78490    accuracy: 0.6929 lr: [0.0008100000000000001]
# epoch 38 , train negloglik: 0.77666,    val negloglik: 0.78320    accuracy: 0.6949 lr: [0.0008100000000000001]
# epoch 39 , train negloglik: 0.77298,    val negloglik: 0.77983    accuracy: 0.6921 lr: [0.0008100000000000001]
# epoch 40 , train negloglik: 0.77113,    val negloglik: 0.77744    accuracy: 0.6908 lr: [0.0008100000000000001]
# epoch 41 , train negloglik: 0.76763,    val negloglik: 0.77592    accuracy: 0.6936 lr: [0.000729]
# epoch 42 , train negloglik: 0.76557,    val negloglik: 0.77138    accuracy: 0.6935 lr: [0.000729]
# epoch 43 , train negloglik: 0.76267,    val negloglik: 0.76946    accuracy: 0.6940 lr: [0.000729]
# epoch 44 , train negloglik: 0.76017,    val negloglik: 0.76810    accuracy: 0.6927 lr: [0.000729]
# epoch 45 , train negloglik: 0.75852,    val negloglik: 0.76725    accuracy: 0.6945 lr: [0.000729]
# epoch 46 , train negloglik: 0.75552,    val negloglik: 0.76152    accuracy: 0.6932 lr: [0.000729]
# epoch 47 , train negloglik: 0.75264,    val negloglik: 0.76072    accuracy: 0.6955 lr: [0.000729]
# epoch 48 , train negloglik: 0.75076,    val negloglik: 0.75700    accuracy: 0.6990 lr: [0.000729]
# epoch 49 , train negloglik: 0.74839,    val negloglik: 0.75650    accuracy: 0.6970 lr: [0.000729]
# epoch 50 , train negloglik: 0.74619,    val negloglik: 0.75168    accuracy: 0.6965 lr: [0.000729]
# epoch 51 , train negloglik: 0.74390,    val negloglik: 0.75251    accuracy: 0.6927 lr: [0.000729]
# epoch 52 , train negloglik: 0.74315,    val negloglik: 0.74618    accuracy: 0.7025 lr: [0.000729]
# epoch 53 , train negloglik: 0.73907,    val negloglik: 0.74568    accuracy: 0.7011 lr: [0.000729]
# epoch 54 , train negloglik: 0.73496,    val negloglik: 0.74416    accuracy: 0.6972 lr: [0.000729]
# epoch 55 , train negloglik: 0.73263,    val negloglik: 0.74003    accuracy: 0.7006 lr: [0.000729]
# epoch 56 , train negloglik: 0.73001,    val negloglik: 0.73712    accuracy: 0.7028 lr: [0.000729]
# epoch 57 , train negloglik: 0.72753,    val negloglik: 0.73509    accuracy: 0.7018 lr: [0.000729]
# epoch 58 , train negloglik: 0.72529,    val negloglik: 0.73435    accuracy: 0.7030 lr: [0.000729]
# epoch 59 , train negloglik: 0.72206,    val negloglik: 0.73113    accuracy: 0.7067 lr: [0.000729]
# epoch 60 , train negloglik: 0.71947,    val negloglik: 0.72786    accuracy: 0.7058 lr: [0.000729]
# epoch 61 , train negloglik: 0.71848,    val negloglik: 0.72539    accuracy: 0.7050 lr: [0.0006561000000000001]
# epoch 62 , train negloglik: 0.71580,    val negloglik: 0.72174    accuracy: 0.7069 lr: [0.0006561000000000001]
# epoch 63 , train negloglik: 0.71246,    val negloglik: 0.72266    accuracy: 0.7083 lr: [0.0006561000000000001]
# epoch 64 , train negloglik: 0.71061,    val negloglik: 0.71689    accuracy: 0.7069 lr: [0.0006561000000000001]
# epoch 65 , train negloglik: 0.70902,    val negloglik: 0.71746    accuracy: 0.7101 lr: [0.0006561000000000001]
# epoch 66 , train negloglik: 0.70631,    val negloglik: 0.71488    accuracy: 0.7083 lr: [0.0006561000000000001]
# epoch 67 , train negloglik: 0.70408,    val negloglik: 0.71090    accuracy: 0.7123 lr: [0.0006561000000000001]
# epoch 68 , train negloglik: 0.70090,    val negloglik: 0.70894    accuracy: 0.7125 lr: [0.0006561000000000001]
# epoch 69 , train negloglik: 0.69863,    val negloglik: 0.70577    accuracy: 0.7111 lr: [0.0006561000000000001]
# epoch 70 , train negloglik: 0.69647,    val negloglik: 0.70481    accuracy: 0.7145 lr: [0.0006561000000000001]
# epoch 71 , train negloglik: 0.69420,    val negloglik: 0.69978    accuracy: 0.7167 lr: [0.0006561000000000001]
# epoch 72 , train negloglik: 0.69124,    val negloglik: 0.69921    accuracy: 0.7149 lr: [0.0006561000000000001]
# epoch 73 , train negloglik: 0.69106,    val negloglik: 0.69746    accuracy: 0.7157 lr: [0.0006561000000000001]
# epoch 74 , train negloglik: 0.68748,    val negloglik: 0.69102    accuracy: 0.7222 lr: [0.0006561000000000001]
# epoch 75 , train negloglik: 0.68427,    val negloglik: 0.69207    accuracy: 0.7206 lr: [0.0006561000000000001]
# epoch 76 , train negloglik: 0.68232,    val negloglik: 0.68805    accuracy: 0.7239 lr: [0.0006561000000000001]
# epoch 77 , train negloglik: 0.68045,    val negloglik: 0.68787    accuracy: 0.7254 lr: [0.0006561000000000001]
# epoch 78 , train negloglik: 0.67955,    val negloglik: 0.68421    accuracy: 0.7273 lr: [0.0006561000000000001]
# epoch 79 , train negloglik: 0.67611,    val negloglik: 0.68167    accuracy: 0.7271 lr: [0.0006561000000000001]
# epoch 80 , train negloglik: 0.67286,    val negloglik: 0.67754    accuracy: 0.7281 lr: [0.0006561000000000001]
# epoch 81 , train negloglik: 0.66977,    val negloglik: 0.67755    accuracy: 0.7284 lr: [0.00059049]
# epoch 82 , train negloglik: 0.67016,    val negloglik: 0.67523    accuracy: 0.7290 lr: [0.00059049]
# epoch 83 , train negloglik: 0.66594,    val negloglik: 0.66850    accuracy: 0.7302 lr: [0.00059049]
# epoch 84 , train negloglik: 0.66353,    val negloglik: 0.67022    accuracy: 0.7325 lr: [0.00059049]
# epoch 85 , train negloglik: 0.66221,    val negloglik: 0.66800    accuracy: 0.7304 lr: [0.00059049]
# epoch 86 , train negloglik: 0.65949,    val negloglik: 0.66365    accuracy: 0.7348 lr: [0.00059049]
# epoch 87 , train negloglik: 0.65723,    val negloglik: 0.66376    accuracy: 0.7392 lr: [0.00059049]
# epoch 88 , train negloglik: 0.65578,    val negloglik: 0.65914    accuracy: 0.7382 lr: [0.00059049]
# epoch 89 , train negloglik: 0.65324,    val negloglik: 0.66003    accuracy: 0.7395 lr: [0.00059049]
# epoch 90 , train negloglik: 0.65006,    val negloglik: 0.65367    accuracy: 0.7389 lr: [0.00059049]
# epoch 91 , train negloglik: 0.64875,    val negloglik: 0.65178    accuracy: 0.7417 lr: [0.00059049]
# epoch 92 , train negloglik: 0.64664,    val negloglik: 0.65042    accuracy: 0.7406 lr: [0.00059049]
# epoch 93 , train negloglik: 0.64399,    val negloglik: 0.64591    accuracy: 0.7443 lr: [0.00059049]
# epoch 94 , train negloglik: 0.64107,    val negloglik: 0.64367    accuracy: 0.7444 lr: [0.00059049]
# epoch 95 , train negloglik: 0.63937,    val negloglik: 0.64342    accuracy: 0.7461 lr: [0.00059049]
# epoch 96 , train negloglik: 0.63697,    val negloglik: 0.63891    accuracy: 0.7447 lr: [0.00059049]
# epoch 97 , train negloglik: 0.63517,    val negloglik: 0.64187    accuracy: 0.7487 lr: [0.00059049]
# epoch 98 , train negloglik: 0.63299,    val negloglik: 0.63247    accuracy: 0.7493 lr: [0.00059049]
# epoch 99 , train negloglik: 0.63090,    val negloglik: 0.63550    accuracy: 0.7496 lr: [0.00059049]
# epoch 100, train negloglik: 0.62838,    val negloglik: 0.62876    accuracy: 0.7546 lr: [0.00059049]
# epoch 101, train negloglik: 0.62662,    val negloglik: 0.62882    accuracy: 0.7549 lr: [0.000531441]
# epoch 102, train negloglik: 0.62360,    val negloglik: 0.62797    accuracy: 0.7520 lr: [0.000531441]
# epoch 103, train negloglik: 0.62282,    val negloglik: 0.62250    accuracy: 0.7536 lr: [0.000531441]
# epoch 104, train negloglik: 0.61964,    val negloglik: 0.62043    accuracy: 0.7583 lr: [0.000531441]
# epoch 105, train negloglik: 0.61851,    val negloglik: 0.61794    accuracy: 0.7563 lr: [0.000531441]
# epoch 106, train negloglik: 0.61629,    val negloglik: 0.61580    accuracy: 0.7574 lr: [0.000531441]
# epoch 107, train negloglik: 0.61444,    val negloglik: 0.61152    accuracy: 0.7600 lr: [0.000531441]
# epoch 108, train negloglik: 0.61191,    val negloglik: 0.61220    accuracy: 0.7597 lr: [0.000531441]
# epoch 109, train negloglik: 0.60965,    val negloglik: 0.60868    accuracy: 0.7640 lr: [0.000531441]
# epoch 110, train negloglik: 0.60934,    val negloglik: 0.60622    accuracy: 0.7649 lr: [0.000531441]
# epoch 111, train negloglik: 0.60600,    val negloglik: 0.60569    accuracy: 0.7648 lr: [0.000531441]
# epoch 112, train negloglik: 0.60639,    val negloglik: 0.60649    accuracy: 0.7623 lr: [0.000531441]
# epoch 113, train negloglik: 0.60283,    val negloglik: 0.60023    accuracy: 0.7653 lr: [0.000531441]
# epoch 114, train negloglik: 0.60043,    val negloglik: 0.60287    accuracy: 0.7674 lr: [0.000531441]
# epoch 115, train negloglik: 0.59767,    val negloglik: 0.59588    accuracy: 0.7670 lr: [0.000531441]
# epoch 116, train negloglik: 0.59590,    val negloglik: 0.59641    accuracy: 0.7683 lr: [0.000531441]
# epoch 117, train negloglik: 0.59373,    val negloglik: 0.58999    accuracy: 0.7686 lr: [0.000531441]
# epoch 118, train negloglik: 0.59155,    val negloglik: 0.58929    accuracy: 0.7699 lr: [0.000531441]
# epoch 119, train negloglik: 0.58965,    val negloglik: 0.58844    accuracy: 0.7744 lr: [0.000531441]
# epoch 120, train negloglik: 0.58735,    val negloglik: 0.58723    accuracy: 0.7719 lr: [0.000531441]
# epoch 121, train negloglik: 0.58632,    val negloglik: 0.58319    accuracy: 0.7746 lr: [0.0004782969]
# epoch 122, train negloglik: 0.58327,    val negloglik: 0.57939    accuracy: 0.7771 lr: [0.0004782969]
# epoch 123, train negloglik: 0.58189,    val negloglik: 0.57822    accuracy: 0.7788 lr: [0.0004782969]
# epoch 124, train negloglik: 0.58019,    val negloglik: 0.57738    accuracy: 0.7771 lr: [0.0004782969]
# epoch 125, train negloglik: 0.57693,    val negloglik: 0.57199    accuracy: 0.7781 lr: [0.0004782969]
# epoch 126, train negloglik: 0.57618,    val negloglik: 0.57321    accuracy: 0.7790 lr: [0.0004782969]
# epoch 127, train negloglik: 0.57345,    val negloglik: 0.57070    accuracy: 0.7805 lr: [0.0004782969]
# epoch 128, train negloglik: 0.57187,    val negloglik: 0.56851    accuracy: 0.7853 lr: [0.0004782969]
# epoch 129, train negloglik: 0.57394,    val negloglik: 0.56538    accuracy: 0.7828 lr: [0.0004782969]
# epoch 130, train negloglik: 0.56934,    val negloglik: 0.56332    accuracy: 0.7821 lr: [0.0004782969]
# epoch 131, train negloglik: 0.56786,    val negloglik: 0.56481    accuracy: 0.7839 lr: [0.0004782969]
# epoch 132, train negloglik: 0.56674,    val negloglik: 0.55828    accuracy: 0.7825 lr: [0.0004782969]
# epoch 133, train negloglik: 0.56389,    val negloglik: 0.55745    accuracy: 0.7886 lr: [0.0004782969]
# epoch 134, train negloglik: 0.56166,    val negloglik: 0.55709    accuracy: 0.7874 lr: [0.0004782969]
# epoch 135, train negloglik: 0.55952,    val negloglik: 0.55530    accuracy: 0.7871 lr: [0.0004782969]
# epoch 136, train negloglik: 0.55762,    val negloglik: 0.55258    accuracy: 0.7895 lr: [0.0004782969]
# epoch 137, train negloglik: 0.55739,    val negloglik: 0.55060    accuracy: 0.7874 lr: [0.0004782969]
# epoch 138, train negloglik: 0.55484,    val negloglik: 0.54925    accuracy: 0.7898 lr: [0.0004782969]
# epoch 139, train negloglik: 0.55361,    val negloglik: 0.54809    accuracy: 0.7895 lr: [0.0004782969]
# epoch 140, train negloglik: 0.55378,    val negloglik: 0.54203    accuracy: 0.7924 lr: [0.0004782969]
# epoch 141, train negloglik: 0.54941,    val negloglik: 0.54418    accuracy: 0.7938 lr: [0.00043046721]
# epoch 142, train negloglik: 0.54708,    val negloglik: 0.54158    accuracy: 0.7920 lr: [0.00043046721]
# epoch 143, train negloglik: 0.54595,    val negloglik: 0.54209    accuracy: 0.7942 lr: [0.00043046721]
# epoch 144, train negloglik: 0.54421,    val negloglik: 0.53655    accuracy: 0.7958 lr: [0.00043046721]
# epoch 145, train negloglik: 0.54276,    val negloglik: 0.53929    accuracy: 0.7946 lr: [0.00043046721]
# epoch 146, train negloglik: 0.54169,    val negloglik: 0.53282    accuracy: 0.7965 lr: [0.00043046721]
# epoch 147, train negloglik: 0.54033,    val negloglik: 0.53077    accuracy: 0.7971 lr: [0.00043046721]
# epoch 148, train negloglik: 0.53995,    val negloglik: 0.53214    accuracy: 0.7967 lr: [0.00043046721]
# epoch 149, train negloglik: 0.53682,    val negloglik: 0.52673    accuracy: 0.7992 lr: [0.00043046721]
# epoch 150, train negloglik: 0.53481,    val negloglik: 0.52814    accuracy: 0.7979 lr: [0.00043046721]
# epoch 151, train negloglik: 0.53325,    val negloglik: 0.52343    accuracy: 0.7997 lr: [0.00043046721]
# epoch 152, train negloglik: 0.53401,    val negloglik: 0.52378    accuracy: 0.7998 lr: [0.00043046721]
# epoch 153, train negloglik: 0.53159,    val negloglik: 0.52271    accuracy: 0.8019 lr: [0.00043046721]
# epoch 154, train negloglik: 0.52987,    val negloglik: 0.52384    accuracy: 0.8039 lr: [0.00043046721]
# epoch 155, train negloglik: 0.52720,    val negloglik: 0.51871    accuracy: 0.8016 lr: [0.00043046721]
# epoch 156, train negloglik: 0.52602,    val negloglik: 0.52027    accuracy: 0.8043 lr: [0.00043046721]
# epoch 157, train negloglik: 0.52451,    val negloglik: 0.51678    accuracy: 0.8036 lr: [0.00043046721]
# epoch 158, train negloglik: 0.52348,    val negloglik: 0.51397    accuracy: 0.8029 lr: [0.00043046721]
# epoch 159, train negloglik: 0.52262,    val negloglik: 0.51357    accuracy: 0.8028 lr: [0.00043046721]
# epoch 160, train negloglik: 0.52004,    val negloglik: 0.50942    accuracy: 0.8048 lr: [0.00043046721]
# epoch 161, train negloglik: 0.51864,    val negloglik: 0.50901    accuracy: 0.8079 lr: [0.000387420489]
# epoch 162, train negloglik: 0.51770,    val negloglik: 0.50929    accuracy: 0.8054 lr: [0.000387420489]
# epoch 163, train negloglik: 0.51641,    val negloglik: 0.50814    accuracy: 0.8046 lr: [0.000387420489]
# epoch 164, train negloglik: 0.51424,    val negloglik: 0.50644    accuracy: 0.8098 lr: [0.000387420489]
# epoch 165, train negloglik: 0.51364,    val negloglik: 0.50316    accuracy: 0.8103 lr: [0.000387420489]
# epoch 166, train negloglik: 0.51193,    val negloglik: 0.50248    accuracy: 0.8088 lr: [0.000387420489]
# epoch 167, train negloglik: 0.51083,    val negloglik: 0.49933    accuracy: 0.8079 lr: [0.000387420489]
# epoch 168, train negloglik: 0.51019,    val negloglik: 0.50001    accuracy: 0.8074 lr: [0.000387420489]
# epoch 169, train negloglik: 0.50814,    val negloglik: 0.49991    accuracy: 0.8128 lr: [0.000387420489]
# epoch 170, train negloglik: 0.50756,    val negloglik: 0.49571    accuracy: 0.8111 lr: [0.000387420489]
# epoch 171, train negloglik: 0.50627,    val negloglik: 0.49655    accuracy: 0.8104 lr: [0.000387420489]
# epoch 172, train negloglik: 0.50669,    val negloglik: 0.49311    accuracy: 0.8096 lr: [0.000387420489]
# epoch 173, train negloglik: 0.50274,    val negloglik: 0.49585    accuracy: 0.8118 lr: [0.000387420489]
# epoch 174, train negloglik: 0.50316,    val negloglik: 0.49139    accuracy: 0.8142 lr: [0.000387420489]
# epoch 175, train negloglik: 0.50069,    val negloglik: 0.49518    accuracy: 0.8127 lr: [0.000387420489]
# epoch 176, train negloglik: 0.49938,    val negloglik: 0.49022    accuracy: 0.8149 lr: [0.000387420489]
# epoch 177, train negloglik: 0.49904,    val negloglik: 0.48605    accuracy: 0.8123 lr: [0.000387420489]
# epoch 178, train negloglik: 0.49833,    val negloglik: 0.48294    accuracy: 0.8122 lr: [0.000387420489]
# epoch 179, train negloglik: 0.49741,    val negloglik: 0.48485    accuracy: 0.8154 lr: [0.000387420489]
# epoch 180, train negloglik: 0.49532,    val negloglik: 0.48748    accuracy: 0.8173 lr: [0.000387420489]
# epoch 181, train negloglik: 0.49275,    val negloglik: 0.48030    accuracy: 0.8154 lr: [0.0003486784401]
# epoch 182, train negloglik: 0.49268,    val negloglik: 0.48367    accuracy: 0.8137 lr: [0.0003486784401]
# epoch 183, train negloglik: 0.49060,    val negloglik: 0.47948    accuracy: 0.8160 lr: [0.0003486784401]
# epoch 184, train negloglik: 0.49080,    val negloglik: 0.48045    accuracy: 0.8165 lr: [0.0003486784401]
# epoch 185, train negloglik: 0.48929,    val negloglik: 0.48135    accuracy: 0.8145 lr: [0.0003486784401]
# epoch 186, train negloglik: 0.48782,    val negloglik: 0.47639    accuracy: 0.8176 lr: [0.0003486784401]
# epoch 187, train negloglik: 0.48771,    val negloglik: 0.47460    accuracy: 0.8178 lr: [0.0003486784401]
# epoch 188, train negloglik: 0.48518,    val negloglik: 0.47567    accuracy: 0.8176 lr: [0.0003486784401]
# epoch 189, train negloglik: 0.48451,    val negloglik: 0.47253    accuracy: 0.8176 lr: [0.0003486784401]
# epoch 190, train negloglik: 0.48421,    val negloglik: 0.47356    accuracy: 0.8202 lr: [0.0003486784401]
# epoch 191, train negloglik: 0.48315,    val negloglik: 0.47065    accuracy: 0.8171 lr: [0.0003486784401]
# epoch 192, train negloglik: 0.48144,    val negloglik: 0.47011    accuracy: 0.8198 lr: [0.0003486784401]
# epoch 193, train negloglik: 0.48063,    val negloglik: 0.47105    accuracy: 0.8192 lr: [0.0003486784401]
# epoch 194, train negloglik: 0.48090,    val negloglik: 0.46750    accuracy: 0.8209 lr: [0.0003486784401]
# epoch 195, train negloglik: 0.47946,    val negloglik: 0.46590    accuracy: 0.8215 lr: [0.0003486784401]
# epoch 196, train negloglik: 0.47927,    val negloglik: 0.46741    accuracy: 0.8214 lr: [0.0003486784401]
# epoch 197, train negloglik: 0.47689,    val negloglik: 0.46610    accuracy: 0.8210 lr: [0.0003486784401]
# epoch 198, train negloglik: 0.47570,    val negloglik: 0.46419    accuracy: 0.8226 lr: [0.0003486784401]
# epoch 199, train negloglik: 0.47667,    val negloglik: 0.46200    accuracy: 0.8219 lr: [0.0003486784401]
# epoch 200, train negloglik: 0.47510,    val negloglik: 0.46336    accuracy: 0.8219 lr: [0.0003486784401]
# epoch 201, train negloglik: 0.47222,    val negloglik: 0.46374    accuracy: 0.8203 lr: [0.00031381059609000004]
# epoch 202, train negloglik: 0.47091,    val negloglik: 0.45863    accuracy: 0.8235 lr: [0.00031381059609000004]
# epoch 203, train negloglik: 0.47159,    val negloglik: 0.46084    accuracy: 0.8219 lr: [0.00031381059609000004]
# epoch 204, train negloglik: 0.46947,    val negloglik: 0.45859    accuracy: 0.8214 lr: [0.00031381059609000004]
# epoch 205, train negloglik: 0.46980,    val negloglik: 0.45642    accuracy: 0.8235 lr: [0.00031381059609000004]
# epoch 206, train negloglik: 0.46908,    val negloglik: 0.45525    accuracy: 0.8237 lr: [0.00031381059609000004]
# epoch 207, train negloglik: 0.46719,    val negloglik: 0.45719    accuracy: 0.8236 lr: [0.00031381059609000004]
# epoch 208, train negloglik: 0.46730,    val negloglik: 0.45306    accuracy: 0.8254 lr: [0.00031381059609000004]
# epoch 209, train negloglik: 0.46592,    val negloglik: 0.45715    accuracy: 0.8254 lr: [0.00031381059609000004]
# epoch 210, train negloglik: 0.46611,    val negloglik: 0.45597    accuracy: 0.8221 lr: [0.00031381059609000004]
# epoch 211, train negloglik: 0.46427,    val negloglik: 0.45187    accuracy: 0.8233 lr: [0.00031381059609000004]
# epoch 212, train negloglik: 0.46292,    val negloglik: 0.45141    accuracy: 0.8257 lr: [0.00031381059609000004]
# epoch 213, train negloglik: 0.46234,    val negloglik: 0.45290    accuracy: 0.8248 lr: [0.00031381059609000004]
# epoch 214, train negloglik: 0.46179,    val negloglik: 0.44846    accuracy: 0.8264 lr: [0.00031381059609000004]
# epoch 215, train negloglik: 0.46122,    val negloglik: 0.44743    accuracy: 0.8250 lr: [0.00031381059609000004]
# epoch 216, train negloglik: 0.46054,    val negloglik: 0.44735    accuracy: 0.8262 lr: [0.00031381059609000004]
# epoch 217, train negloglik: 0.45894,    val negloglik: 0.44938    accuracy: 0.8261 lr: [0.00031381059609000004]
# epoch 218, train negloglik: 0.45845,    val negloglik: 0.44603    accuracy: 0.8300 lr: [0.00031381059609000004]
# epoch 219, train negloglik: 0.45994,    val negloglik: 0.44509    accuracy: 0.8280 lr: [0.00031381059609000004]
# epoch 220, train negloglik: 0.45781,    val negloglik: 0.44549    accuracy: 0.8275 lr: [0.00031381059609000004]
# epoch 221, train negloglik: 0.45646,    val negloglik: 0.44251    accuracy: 0.8259 lr: [0.00028242953648100003]
# epoch 222, train negloglik: 0.45616,    val negloglik: 0.44675    accuracy: 0.8276 lr: [0.00028242953648100003]
# epoch 223, train negloglik: 0.45635,    val negloglik: 0.44037    accuracy: 0.8286 lr: [0.00028242953648100003]
# epoch 224, train negloglik: 0.45388,    val negloglik: 0.44206    accuracy: 0.8266 lr: [0.00028242953648100003]
# epoch 225, train negloglik: 0.45305,    val negloglik: 0.44488    accuracy: 0.8278 lr: [0.00028242953648100003]
# epoch 226, train negloglik: 0.45255,    val negloglik: 0.44043    accuracy: 0.8295 lr: [0.00028242953648100003]
# epoch 227, train negloglik: 0.45160,    val negloglik: 0.44159    accuracy: 0.8285 lr: [0.00028242953648100003]
# epoch 228, train negloglik: 0.45172,    val negloglik: 0.44083    accuracy: 0.8258 lr: [0.00028242953648100003]
# epoch 229, train negloglik: 0.45183,    val negloglik: 0.43725    accuracy: 0.8264 lr: [0.00028242953648100003]
# epoch 230, train negloglik: 0.45107,    val negloglik: 0.43631    accuracy: 0.8290 lr: [0.00028242953648100003]
# epoch 231, train negloglik: 0.45081,    val negloglik: 0.44163    accuracy: 0.8279 lr: [0.00028242953648100003]
# epoch 232, train negloglik: 0.44995,    val negloglik: 0.43939    accuracy: 0.8313 lr: [0.00028242953648100003]
# epoch 233, train negloglik: 0.44873,    val negloglik: 0.43474    accuracy: 0.8291 lr: [0.00028242953648100003]
# epoch 234, train negloglik: 0.44725,    val negloglik: 0.43591    accuracy: 0.8297 lr: [0.00028242953648100003]
# epoch 235, train negloglik: 0.44673,    val negloglik: 0.43292    accuracy: 0.8310 lr: [0.00028242953648100003]
# epoch 236, train negloglik: 0.44590,    val negloglik: 0.43527    accuracy: 0.8319 lr: [0.00028242953648100003]
# epoch 237, train negloglik: 0.44487,    val negloglik: 0.43371    accuracy: 0.8316 lr: [0.00028242953648100003]
# epoch 238, train negloglik: 0.44419,    val negloglik: 0.43239    accuracy: 0.8317 lr: [0.00028242953648100003]
# epoch 239, train negloglik: 0.44377,    val negloglik: 0.43388    accuracy: 0.8305 lr: [0.00028242953648100003]
# epoch 240, train negloglik: 0.44466,    val negloglik: 0.42941    accuracy: 0.8300 lr: [0.00028242953648100003]
# epoch 241, train negloglik: 0.44225,    val negloglik: 0.43046    accuracy: 0.8308 lr: [0.00025418658283290005]
# epoch 242, train negloglik: 0.44350,    val negloglik: 0.42922    accuracy: 0.8308 lr: [0.00025418658283290005]
# epoch 243, train negloglik: 0.44223,    val negloglik: 0.42774    accuracy: 0.8328 lr: [0.00025418658283290005]
# epoch 244, train negloglik: 0.44112,    val negloglik: 0.42878    accuracy: 0.8329 lr: [0.00025418658283290005]
# epoch 245, train negloglik: 0.44047,    val negloglik: 0.42790    accuracy: 0.8318 lr: [0.00025418658283290005]
# epoch 246, train negloglik: 0.44072,    val negloglik: 0.42500    accuracy: 0.8317 lr: [0.00025418658283290005]
# epoch 247, train negloglik: 0.44030,    val negloglik: 0.42738    accuracy: 0.8306 lr: [0.00025418658283290005]
# epoch 248, train negloglik: 0.43836,    val negloglik: 0.42724    accuracy: 0.8341 lr: [0.00025418658283290005]
# epoch 249, train negloglik: 0.43876,    val negloglik: 0.42698    accuracy: 0.8330 lr: [0.00025418658283290005]
# epoch 250, train negloglik: 0.43858,    val negloglik: 0.42716    accuracy: 0.8339 lr: [0.00025418658283290005]
# epoch 251, train negloglik: 0.43791,    val negloglik: 0.42352    accuracy: 0.8327 lr: [0.00025418658283290005]
# epoch 252, train negloglik: 0.43640,    val negloglik: 0.42296    accuracy: 0.8335 lr: [0.00025418658283290005]
# epoch 253, train negloglik: 0.43654,    val negloglik: 0.42358    accuracy: 0.8347 lr: [0.00025418658283290005]
# epoch 254, train negloglik: 0.43638,    val negloglik: 0.42063    accuracy: 0.8337 lr: [0.00025418658283290005]
# epoch 255, train negloglik: 0.43502,    val negloglik: 0.42186    accuracy: 0.8341 lr: [0.00025418658283290005]
# epoch 256, train negloglik: 0.43484,    val negloglik: 0.41858    accuracy: 0.8328 lr: [0.00025418658283290005]
# epoch 257, train negloglik: 0.43293,    val negloglik: 0.42145    accuracy: 0.8359 lr: [0.00025418658283290005]
# epoch 258, train negloglik: 0.43332,    val negloglik: 0.42102    accuracy: 0.8350 lr: [0.00025418658283290005]
# epoch 259, train negloglik: 0.43365,    val negloglik: 0.41858    accuracy: 0.8332 lr: [0.00025418658283290005]
# epoch 260, train negloglik: 0.43319,    val negloglik: 0.41721    accuracy: 0.8328 lr: [0.00025418658283290005]
# epoch 261, train negloglik: 0.43285,    val negloglik: 0.41960    accuracy: 0.8363 lr: [0.00022876792454961005]
# epoch 262, train negloglik: 0.43168,    val negloglik: 0.41627    accuracy: 0.8345 lr: [0.00022876792454961005]
# epoch 263, train negloglik: 0.43056,    val negloglik: 0.41677    accuracy: 0.8348 lr: [0.00022876792454961005]
# epoch 264, train negloglik: 0.43006,    val negloglik: 0.41663    accuracy: 0.8343 lr: [0.00022876792454961005]
# epoch 265, train negloglik: 0.42935,    val negloglik: 0.41792    accuracy: 0.8367 lr: [0.00022876792454961005]
# epoch 266, train negloglik: 0.42924,    val negloglik: 0.41563    accuracy: 0.8361 lr: [0.00022876792454961005]
# epoch 267, train negloglik: 0.42846,    val negloglik: 0.41696    accuracy: 0.8354 lr: [0.00022876792454961005]
# epoch 268, train negloglik: 0.42850,    val negloglik: 0.41784    accuracy: 0.8366 lr: [0.00022876792454961005]
# epoch 269, train negloglik: 0.42850,    val negloglik: 0.41494    accuracy: 0.8362 lr: [0.00022876792454961005]
# epoch 270, train negloglik: 0.42719,    val negloglik: 0.41273    accuracy: 0.8364 lr: [0.00022876792454961005]
# epoch 271, train negloglik: 0.42687,    val negloglik: 0.41583    accuracy: 0.8353 lr: [0.00022876792454961005]
# epoch 272, train negloglik: 0.42624,    val negloglik: 0.41305    accuracy: 0.8368 lr: [0.00022876792454961005]
# epoch 273, train negloglik: 0.42544,    val negloglik: 0.41300    accuracy: 0.8377 lr: [0.00022876792454961005]
# epoch 274, train negloglik: 0.42540,    val negloglik: 0.41377    accuracy: 0.8375 lr: [0.00022876792454961005]
# epoch 275, train negloglik: 0.42530,    val negloglik: 0.41580    accuracy: 0.8357 lr: [0.00022876792454961005]
# epoch 276, train negloglik: 0.42660,    val negloglik: 0.41058    accuracy: 0.8374 lr: [0.00022876792454961005]
# epoch 277, train negloglik: 0.42388,    val negloglik: 0.40825    accuracy: 0.8378 lr: [0.00022876792454961005]
# epoch 278, train negloglik: 0.42633,    val negloglik: 0.40973    accuracy: 0.8388 lr: [0.00022876792454961005]
# epoch 279, train negloglik: 0.42376,    val negloglik: 0.41252    accuracy: 0.8363 lr: [0.00022876792454961005]
# epoch 280, train negloglik: 0.42391,    val negloglik: 0.41078    accuracy: 0.8371 lr: [0.00022876792454961005]
# epoch 281, train negloglik: 0.42223,    val negloglik: 0.41295    accuracy: 0.8362 lr: [0.00020589113209464906]
# epoch 282, train negloglik: 0.42573,    val negloglik: 0.41075    accuracy: 0.8361 lr: [0.00020589113209464906]
# epoch 283, train negloglik: 0.42246,    val negloglik: 0.40750    accuracy: 0.8365 lr: [0.00020589113209464906]
# epoch 284, train negloglik: 0.42156,    val negloglik: 0.40823    accuracy: 0.8371 lr: [0.00020589113209464906]
# epoch 285, train negloglik: 0.42055,    val negloglik: 0.40907    accuracy: 0.8392 lr: [0.00020589113209464906]
# epoch 286, train negloglik: 0.42043,    val negloglik: 0.40698    accuracy: 0.8390 lr: [0.00020589113209464906]
# epoch 287, train negloglik: 0.42012,    val negloglik: 0.40776    accuracy: 0.8394 lr: [0.00020589113209464906]
# epoch 288, train negloglik: 0.42164,    val negloglik: 0.40415    accuracy: 0.8389 lr: [0.00020589113209464906]
# epoch 289, train negloglik: 0.41889,    val negloglik: 0.40666    accuracy: 0.8366 lr: [0.00020589113209464906]
# epoch 290, train negloglik: 0.41920,    val negloglik: 0.40258    accuracy: 0.8385 lr: [0.00020589113209464906]
# epoch 291, train negloglik: 0.41958,    val negloglik: 0.40349    accuracy: 0.8389 lr: [0.00020589113209464906]
# epoch 292, train negloglik: 0.41761,    val negloglik: 0.40332    accuracy: 0.8386 lr: [0.00020589113209464906]
# epoch 293, train negloglik: 0.41779,    val negloglik: 0.40369    accuracy: 0.8367 lr: [0.00020589113209464906]
# epoch 294, train negloglik: 0.41683,    val negloglik: 0.40170    accuracy: 0.8399 lr: [0.00020589113209464906]
# epoch 295, train negloglik: 0.41654,    val negloglik: 0.40813    accuracy: 0.8408 lr: [0.00020589113209464906]
# epoch 296, train negloglik: 0.41687,    val negloglik: 0.40236    accuracy: 0.8411 lr: [0.00020589113209464906]
# epoch 297, train negloglik: 0.41565,    val negloglik: 0.40237    accuracy: 0.8399 lr: [0.00020589113209464906]
# epoch 298, train negloglik: 0.41606,    val negloglik: 0.40050    accuracy: 0.8370 lr: [0.00020589113209464906]
# epoch 299, train negloglik: 0.41534,    val negloglik: 0.40463    accuracy: 0.8403 lr: [0.00020589113209464906]
# epoch 300, train negloglik: 0.41464,    val negloglik: 0.40162    accuracy: 0.8416 lr: [0.00020589113209464906]
# epoch 301, train negloglik: 0.41516,    val negloglik: 0.40183    accuracy: 0.8383 lr: [0.00018530201888518417]
# epoch 302, train negloglik: 0.41475,    val negloglik: 0.39909    accuracy: 0.8406 lr: [0.00018530201888518417]
# epoch 303, train negloglik: 0.41421,    val negloglik: 0.39964    accuracy: 0.8402 lr: [0.00018530201888518417]
# epoch 304, train negloglik: 0.41365,    val negloglik: 0.40061    accuracy: 0.8390 lr: [0.00018530201888518417]
# epoch 305, train negloglik: 0.41327,    val negloglik: 0.40053    accuracy: 0.8399 lr: [0.00018530201888518417]
# epoch 306, train negloglik: 0.41279,    val negloglik: 0.39732    accuracy: 0.8390 lr: [0.00018530201888518417]
# epoch 307, train negloglik: 0.41262,    val negloglik: 0.40229    accuracy: 0.8394 lr: [0.00018530201888518417]
# epoch 308, train negloglik: 0.41218,    val negloglik: 0.39845    accuracy: 0.8408 lr: [0.00018530201888518417]
# epoch 309, train negloglik: 0.41359,    val negloglik: 0.39519    accuracy: 0.8404 lr: [0.00018530201888518417]
# epoch 310, train negloglik: 0.41267,    val negloglik: 0.39677    accuracy: 0.8399 lr: [0.00018530201888518417]
# epoch 311, train negloglik: 0.41050,    val negloglik: 0.39738    accuracy: 0.8402 lr: [0.00018530201888518417]
# epoch 312, train negloglik: 0.41075,    val negloglik: 0.39778    accuracy: 0.8417 lr: [0.00018530201888518417]
# epoch 313, train negloglik: 0.41084,    val negloglik: 0.39607    accuracy: 0.8412 lr: [0.00018530201888518417]
# epoch 314, train negloglik: 0.41109,    val negloglik: 0.39803    accuracy: 0.8426 lr: [0.00018530201888518417]
# epoch 315, train negloglik: 0.40834,    val negloglik: 0.39403    accuracy: 0.8423 lr: [0.00018530201888518417]
# epoch 316, train negloglik: 0.40921,    val negloglik: 0.39766    accuracy: 0.8409 lr: [0.00018530201888518417]
# epoch 317, train negloglik: 0.40943,    val negloglik: 0.39298    accuracy: 0.8409 lr: [0.00018530201888518417]
# epoch 318, train negloglik: 0.40920,    val negloglik: 0.39580    accuracy: 0.8427 lr: [0.00018530201888518417]
# epoch 319, train negloglik: 0.40858,    val negloglik: 0.39735    accuracy: 0.8419 lr: [0.00018530201888518417]
# epoch 320, train negloglik: 0.40786,    val negloglik: 0.39306    accuracy: 0.8409 lr: [0.00018530201888518417]
# epoch 321, train negloglik: 0.40785,    val negloglik: 0.39874    accuracy: 0.8404 lr: [0.00016677181699666576]
# epoch 322, train negloglik: 0.40850,    val negloglik: 0.39494    accuracy: 0.8406 lr: [0.00016677181699666576]
# epoch 323, train negloglik: 0.40728,    val negloglik: 0.38998    accuracy: 0.8415 lr: [0.00016677181699666576]
# epoch 324, train negloglik: 0.40853,    val negloglik: 0.39283    accuracy: 0.8413 lr: [0.00016677181699666576]
# epoch 325, train negloglik: 0.40612,    val negloglik: 0.39312    accuracy: 0.8413 lr: [0.00016677181699666576]
# epoch 326, train negloglik: 0.40684,    val negloglik: 0.39163    accuracy: 0.8417 lr: [0.00016677181699666576]
# epoch 327, train negloglik: 0.40617,    val negloglik: 0.39214    accuracy: 0.8412 lr: [0.00016677181699666576]
# epoch 328, train negloglik: 0.40628,    val negloglik: 0.39158    accuracy: 0.8419 lr: [0.00016677181699666576]
# epoch 329, train negloglik: 0.40514,    val negloglik: 0.39283    accuracy: 0.8427 lr: [0.00016677181699666576]
# epoch 330, train negloglik: 0.40478,    val negloglik: 0.39459    accuracy: 0.8434 lr: [0.00016677181699666576]
# epoch 331, train negloglik: 0.40518,    val negloglik: 0.39107    accuracy: 0.8425 lr: [0.00016677181699666576]
# epoch 332, train negloglik: 0.40542,    val negloglik: 0.39157    accuracy: 0.8425 lr: [0.00016677181699666576]
# epoch 333, train negloglik: 0.40448,    val negloglik: 0.39085    accuracy: 0.8437 lr: [0.00016677181699666576]
# epoch 334, train negloglik: 0.40393,    val negloglik: 0.39041    accuracy: 0.8434 lr: [0.00016677181699666576]
# epoch 335, train negloglik: 0.40382,    val negloglik: 0.38903    accuracy: 0.8422 lr: [0.00016677181699666576]
# epoch 336, train negloglik: 0.40530,    val negloglik: 0.39037    accuracy: 0.8426 lr: [0.00016677181699666576]
# epoch 337, train negloglik: 0.40265,    val negloglik: 0.39005    accuracy: 0.8429 lr: [0.00016677181699666576]
# epoch 338, train negloglik: 0.40379,    val negloglik: 0.39198    accuracy: 0.8426 lr: [0.00016677181699666576]
# epoch 339, train negloglik: 0.40521,    val negloglik: 0.39104    accuracy: 0.8439 lr: [0.00016677181699666576]
# epoch 340, train negloglik: 0.40431,    val negloglik: 0.38862    accuracy: 0.8438 lr: [0.00016677181699666576]
# epoch 341, train negloglik: 0.40221,    val negloglik: 0.38844    accuracy: 0.8421 lr: [0.0001500946352969992]
# epoch 342, train negloglik: 0.40139,    val negloglik: 0.38660    accuracy: 0.8422 lr: [0.0001500946352969992]
# epoch 343, train negloglik: 0.40119,    val negloglik: 0.38769    accuracy: 0.8443 lr: [0.0001500946352969992]
# epoch 344, train negloglik: 0.40148,    val negloglik: 0.38638    accuracy: 0.8434 lr: [0.0001500946352969992]
# epoch 345, train negloglik: 0.40120,    val negloglik: 0.38579    accuracy: 0.8428 lr: [0.0001500946352969992]
# epoch 346, train negloglik: 0.40098,    val negloglik: 0.39052    accuracy: 0.8440 lr: [0.0001500946352969992]
# epoch 347, train negloglik: 0.40144,    val negloglik: 0.38478    accuracy: 0.8444 lr: [0.0001500946352969992]
# epoch 348, train negloglik: 0.39991,    val negloglik: 0.38732    accuracy: 0.8425 lr: [0.0001500946352969992]
# epoch 349, train negloglik: 0.40053,    val negloglik: 0.38463    accuracy: 0.8430 lr: [0.0001500946352969992]
# epoch 350, train negloglik: 0.40035,    val negloglik: 0.38504    accuracy: 0.8437 lr: [0.0001500946352969992]
# epoch 351, train negloglik: 0.40030,    val negloglik: 0.38270    accuracy: 0.8440 lr: [0.0001500946352969992]
# epoch 352, train negloglik: 0.40025,    val negloglik: 0.38587    accuracy: 0.8454 lr: [0.0001500946352969992]
# epoch 353, train negloglik: 0.39982,    val negloglik: 0.38548    accuracy: 0.8438 lr: [0.0001500946352969992]
# epoch 354, train negloglik: 0.39874,    val negloglik: 0.38386    accuracy: 0.8449 lr: [0.0001500946352969992]
# epoch 355, train negloglik: 0.39832,    val negloglik: 0.38611    accuracy: 0.8450 lr: [0.0001500946352969992]
# epoch 356, train negloglik: 0.39857,    val negloglik: 0.38462    accuracy: 0.8440 lr: [0.0001500946352969992]
# epoch 357, train negloglik: 0.39838,    val negloglik: 0.38355    accuracy: 0.8440 lr: [0.0001500946352969992]
# epoch 358, train negloglik: 0.39806,    val negloglik: 0.38252    accuracy: 0.8446 lr: [0.0001500946352969992]
# epoch 359, train negloglik: 0.39768,    val negloglik: 0.38226    accuracy: 0.8456 lr: [0.0001500946352969992]
# epoch 360, train negloglik: 0.39746,    val negloglik: 0.38303    accuracy: 0.8451 lr: [0.0001500946352969992]
# epoch 361, train negloglik: 0.39792,    val negloglik: 0.38385    accuracy: 0.8464 lr: [0.0001350851717672993]
# epoch 362, train negloglik: 0.39744,    val negloglik: 0.38265    accuracy: 0.8447 lr: [0.0001350851717672993]
# epoch 363, train negloglik: 0.39766,    val negloglik: 0.38556    accuracy: 0.8441 lr: [0.0001350851717672993]
# epoch 364, train negloglik: 0.39781,    val negloglik: 0.38298    accuracy: 0.8438 lr: [0.0001350851717672993]
# epoch 365, train negloglik: 0.39784,    val negloglik: 0.37911    accuracy: 0.8452 lr: [0.0001350851717672993]
# epoch 366, train negloglik: 0.39640,    val negloglik: 0.38154    accuracy: 0.8448 lr: [0.0001350851717672993]
# epoch 367, train negloglik: 0.39604,    val negloglik: 0.38218    accuracy: 0.8456 lr: [0.0001350851717672993]
# epoch 368, train negloglik: 0.39628,    val negloglik: 0.38307    accuracy: 0.8461 lr: [0.0001350851717672993]
# epoch 369, train negloglik: 0.39632,    val negloglik: 0.38005    accuracy: 0.8452 lr: [0.0001350851717672993]
# epoch 370, train negloglik: 0.39531,    val negloglik: 0.38136    accuracy: 0.8452 lr: [0.0001350851717672993]
# epoch 371, train negloglik: 0.39496,    val negloglik: 0.37979    accuracy: 0.8456 lr: [0.0001350851717672993]
# epoch 372, train negloglik: 0.39604,    val negloglik: 0.37970    accuracy: 0.8438 lr: [0.0001350851717672993]
# epoch 373, train negloglik: 0.39461,    val negloglik: 0.37981    accuracy: 0.8460 lr: [0.0001350851717672993]
# epoch 374, train negloglik: 0.39557,    val negloglik: 0.37968    accuracy: 0.8457 lr: [0.0001350851717672993]
# epoch 375, train negloglik: 0.39516,    val negloglik: 0.37829    accuracy: 0.8459 lr: [0.0001350851717672993]
# epoch 376, train negloglik: 0.39510,    val negloglik: 0.38070    accuracy: 0.8454 lr: [0.0001350851717672993]
# epoch 377, train negloglik: 0.39353,    val negloglik: 0.37839    accuracy: 0.8468 lr: [0.0001350851717672993]
# epoch 378, train negloglik: 0.39302,    val negloglik: 0.37940    accuracy: 0.8460 lr: [0.0001350851717672993]
# epoch 379, train negloglik: 0.39371,    val negloglik: 0.37934    accuracy: 0.8453 lr: [0.0001350851717672993]
# epoch 380, train negloglik: 0.39319,    val negloglik: 0.37862    accuracy: 0.8463 lr: [0.0001350851717672993]
# epoch 381, train negloglik: 0.39323,    val negloglik: 0.37860    accuracy: 0.8470 lr: [0.00012157665459056936]
# epoch 382, train negloglik: 0.39249,    val negloglik: 0.37884    accuracy: 0.8461 lr: [0.00012157665459056936]
# epoch 383, train negloglik: 0.39328,    val negloglik: 0.37738    accuracy: 0.8453 lr: [0.00012157665459056936]
# epoch 384, train negloglik: 0.39234,    val negloglik: 0.38084    accuracy: 0.8464 lr: [0.00012157665459056936]
# epoch 385, train negloglik: 0.39195,    val negloglik: 0.37740    accuracy: 0.8465 lr: [0.00012157665459056936]
# epoch 386, train negloglik: 0.39171,    val negloglik: 0.37736    accuracy: 0.8461 lr: [0.00012157665459056936]
# epoch 387, train negloglik: 0.39284,    val negloglik: 0.37761    accuracy: 0.8454 lr: [0.00012157665459056936]
# epoch 388, train negloglik: 0.39361,    val negloglik: 0.37812    accuracy: 0.8469 lr: [0.00012157665459056936]
# epoch 389, train negloglik: 0.39191,    val negloglik: 0.37569    accuracy: 0.8463 lr: [0.00012157665459056936]
# epoch 390, train negloglik: 0.39161,    val negloglik: 0.37781    accuracy: 0.8466 lr: [0.00012157665459056936]
# epoch 391, train negloglik: 0.39186,    val negloglik: 0.37907    accuracy: 0.8461 lr: [0.00012157665459056936]
# epoch 392, train negloglik: 0.39189,    val negloglik: 0.37676    accuracy: 0.8456 lr: [0.00012157665459056936]
# epoch 393, train negloglik: 0.39083,    val negloglik: 0.37603    accuracy: 0.8470 lr: [0.00012157665459056936]
# epoch 394, train negloglik: 0.39195,    val negloglik: 0.37567    accuracy: 0.8479 lr: [0.00012157665459056936]
# epoch 395, train negloglik: 0.39071,    val negloglik: 0.37782    accuracy: 0.8458 lr: [0.00012157665459056936]
# epoch 396, train negloglik: 0.38969,    val negloglik: 0.37622    accuracy: 0.8460 lr: [0.00012157665459056936]
# epoch 397, train negloglik: 0.39000,    val negloglik: 0.37448    accuracy: 0.8468 lr: [0.00012157665459056936]
# epoch 398, train negloglik: 0.38957,    val negloglik: 0.37360    accuracy: 0.8464 lr: [0.00012157665459056936]
# epoch 399, train negloglik: 0.38924,    val negloglik: 0.37655    accuracy: 0.8478 lr: [0.00012157665459056936]
# epoch 400, train negloglik: 0.38974,    val negloglik: 0.37786    accuracy: 0.8473 lr: [0.00012157665459056936]
# epoch 401, train negloglik: 0.38923,    val negloglik: 0.37421    accuracy: 0.8468 lr: [0.00010941898913151243]
# epoch 402, train negloglik: 0.38947,    val negloglik: 0.37294    accuracy: 0.8474 lr: [0.00010941898913151243]
# epoch 403, train negloglik: 0.38958,    val negloglik: 0.37606    accuracy: 0.8471 lr: [0.00010941898913151243]
# epoch 404, train negloglik: 0.38982,    val negloglik: 0.37543    accuracy: 0.8473 lr: [0.00010941898913151243]
# epoch 405, train negloglik: 0.38912,    val negloglik: 0.37407    accuracy: 0.8470 lr: [0.00010941898913151243]
# epoch 406, train negloglik: 0.38879,    val negloglik: 0.37468    accuracy: 0.8474 lr: [0.00010941898913151243]
# epoch 407, train negloglik: 0.38953,    val negloglik: 0.37501    accuracy: 0.8470 lr: [0.00010941898913151243]
# epoch 408, train negloglik: 0.38971,    val negloglik: 0.37575    accuracy: 0.8470 lr: [0.00010941898913151243]
# epoch 409, train negloglik: 0.38846,    val negloglik: 0.37623    accuracy: 0.8470 lr: [0.00010941898913151243]
# epoch 410, train negloglik: 0.38852,    val negloglik: 0.37283    accuracy: 0.8479 lr: [0.00010941898913151243]
# epoch 411, train negloglik: 0.38803,    val negloglik: 0.37346    accuracy: 0.8472 lr: [0.00010941898913151243]
# epoch 412, train negloglik: 0.38775,    val negloglik: 0.37316    accuracy: 0.8481 lr: [0.00010941898913151243]
# epoch 413, train negloglik: 0.38726,    val negloglik: 0.37545    accuracy: 0.8490 lr: [0.00010941898913151243]
# epoch 414, train negloglik: 0.38737,    val negloglik: 0.37512    accuracy: 0.8477 lr: [0.00010941898913151243]
# epoch 415, train negloglik: 0.38687,    val negloglik: 0.37216    accuracy: 0.8482 lr: [0.00010941898913151243]
# epoch 416, train negloglik: 0.38698,    val negloglik: 0.37708    accuracy: 0.8481 lr: [0.00010941898913151243]
# epoch 417, train negloglik: 0.38737,    val negloglik: 0.37059    accuracy: 0.8473 lr: [0.00010941898913151243]
# epoch 418, train negloglik: 0.38753,    val negloglik: 0.37354    accuracy: 0.8472 lr: [0.00010941898913151243]
# epoch 419, train negloglik: 0.38667,    val negloglik: 0.37084    accuracy: 0.8475 lr: [0.00010941898913151243]
# epoch 420, train negloglik: 0.38711,    val negloglik: 0.37039    accuracy: 0.8470 lr: [0.00010941898913151243]
# epoch 421, train negloglik: 0.38668,    val negloglik: 0.37175    accuracy: 0.8479 lr: [9.847709021836118e-05]
# epoch 422, train negloglik: 0.38656,    val negloglik: 0.37159    accuracy: 0.8475 lr: [9.847709021836118e-05]
# epoch 423, train negloglik: 0.38602,    val negloglik: 0.37239    accuracy: 0.8480 lr: [9.847709021836118e-05]
# epoch 424, train negloglik: 0.38515,    val negloglik: 0.37178    accuracy: 0.8481 lr: [9.847709021836118e-05]
# epoch 425, train negloglik: 0.38576,    val negloglik: 0.37161    accuracy: 0.8482 lr: [9.847709021836118e-05]
# epoch 426, train negloglik: 0.38522,    val negloglik: 0.37040    accuracy: 0.8489 lr: [9.847709021836118e-05]
# epoch 427, train negloglik: 0.38548,    val negloglik: 0.36869    accuracy: 0.8492 lr: [9.847709021836118e-05]
# epoch 428, train negloglik: 0.38671,    val negloglik: 0.37031    accuracy: 0.8496 lr: [9.847709021836118e-05]
# epoch 429, train negloglik: 0.38488,    val negloglik: 0.37265    accuracy: 0.8477 lr: [9.847709021836118e-05]
# epoch 430, train negloglik: 0.38520,    val negloglik: 0.36857    accuracy: 0.8492 lr: [9.847709021836118e-05]
# epoch 431, train negloglik: 0.38581,    val negloglik: 0.36970    accuracy: 0.8485 lr: [9.847709021836118e-05]
# epoch 432, train negloglik: 0.38498,    val negloglik: 0.37031    accuracy: 0.8489 lr: [9.847709021836118e-05]
# epoch 433, train negloglik: 0.38503,    val negloglik: 0.37137    accuracy: 0.8497 lr: [9.847709021836118e-05]
# epoch 434, train negloglik: 0.38440,    val negloglik: 0.37023    accuracy: 0.8495 lr: [9.847709021836118e-05]
# epoch 435, train negloglik: 0.38514,    val negloglik: 0.36704    accuracy: 0.8493 lr: [9.847709021836118e-05]
# epoch 436, train negloglik: 0.38404,    val negloglik: 0.37157    accuracy: 0.8485 lr: [9.847709021836118e-05]
# epoch 437, train negloglik: 0.39583,    val negloglik: 0.37392    accuracy: 0.8506 lr: [9.847709021836118e-05]
# epoch 438, train negloglik: 0.38601,    val negloglik: 0.37219    accuracy: 0.8481 lr: [9.847709021836118e-05]
# epoch 439, train negloglik: 0.38675,    val negloglik: 0.36889    accuracy: 0.8492 lr: [9.847709021836118e-05]
# epoch 440, train negloglik: 0.38394,    val negloglik: 0.36792    accuracy: 0.8481 lr: [9.847709021836118e-05]
# epoch 441, train negloglik: 0.38468,    val negloglik: 0.36868    accuracy: 0.8489 lr: [8.862938119652506e-05]
# epoch 442, train negloglik: 0.38336,    val negloglik: 0.36885    accuracy: 0.8492 lr: [8.862938119652506e-05]
# epoch 443, train negloglik: 0.38312,    val negloglik: 0.36834    accuracy: 0.8491 lr: [8.862938119652506e-05]
# epoch 444, train negloglik: 0.38428,    val negloglik: 0.37084    accuracy: 0.8486 lr: [8.862938119652506e-05]
# epoch 445, train negloglik: 0.38449,    val negloglik: 0.36691    accuracy: 0.8491 lr: [8.862938119652506e-05]
# epoch 446, train negloglik: 0.38361,    val negloglik: 0.37078    accuracy: 0.8490 lr: [8.862938119652506e-05]
# epoch 447, train negloglik: 0.38438,    val negloglik: 0.36787    accuracy: 0.8492 lr: [8.862938119652506e-05]
# epoch 448, train negloglik: 0.38422,    val negloglik: 0.37054    accuracy: 0.8490 lr: [8.862938119652506e-05]
# epoch 449, train negloglik: 0.38392,    val negloglik: 0.36683    accuracy: 0.8488 lr: [8.862938119652506e-05]
# epoch 450, train negloglik: 0.38402,    val negloglik: 0.36675    accuracy: 0.8492 lr: [8.862938119652506e-05]
# epoch 451, train negloglik: 0.38297,    val negloglik: 0.36661    accuracy: 0.8492 lr: [8.862938119652506e-05]
# epoch 452, train negloglik: 0.38244,    val negloglik: 0.36659    accuracy: 0.8492 lr: [8.862938119652506e-05]
# epoch 453, train negloglik: 0.38322,    val negloglik: 0.36588    accuracy: 0.8480 lr: [8.862938119652506e-05]
# epoch 454, train negloglik: 0.38277,    val negloglik: 0.36922    accuracy: 0.8494 lr: [8.862938119652506e-05]
# epoch 455, train negloglik: 0.38325,    val negloglik: 0.36622    accuracy: 0.8501 lr: [8.862938119652506e-05]
# epoch 456, train negloglik: 0.38196,    val negloglik: 0.36949    accuracy: 0.8495 lr: [8.862938119652506e-05]
# epoch 457, train negloglik: 0.38383,    val negloglik: 0.36507    accuracy: 0.8490 lr: [8.862938119652506e-05]
# epoch 458, train negloglik: 0.38237,    val negloglik: 0.36719    accuracy: 0.8488 lr: [8.862938119652506e-05]
# epoch 459, train negloglik: 0.38224,    val negloglik: 0.36843    accuracy: 0.8488 lr: [8.862938119652506e-05]
# epoch 460, train negloglik: 0.38253,    val negloglik: 0.36894    accuracy: 0.8494 lr: [8.862938119652506e-05]
# epoch 461, train negloglik: 0.38214,    val negloglik: 0.36765    accuracy: 0.8499 lr: [7.976644307687256e-05]
# epoch 462, train negloglik: 0.38223,    val negloglik: 0.36540    accuracy: 0.8495 lr: [7.976644307687256e-05]
# epoch 463, train negloglik: 0.38138,    val negloglik: 0.36546    accuracy: 0.8500 lr: [7.976644307687256e-05]
# epoch 464, train negloglik: 0.38114,    val negloglik: 0.36689    accuracy: 0.8499 lr: [7.976644307687256e-05]
# epoch 465, train negloglik: 0.38081,    val negloglik: 0.36662    accuracy: 0.8498 lr: [7.976644307687256e-05]
# epoch 466, train negloglik: 0.38173,    val negloglik: 0.36478    accuracy: 0.8492 lr: [7.976644307687256e-05]
# epoch 467, train negloglik: 0.38079,    val negloglik: 0.36719    accuracy: 0.8489 lr: [7.976644307687256e-05]
# epoch 468, train negloglik: 0.38113,    val negloglik: 0.36475    accuracy: 0.8495 lr: [7.976644307687256e-05]
# epoch 469, train negloglik: 0.38117,    val negloglik: 0.36767    accuracy: 0.8500 lr: [7.976644307687256e-05]
# epoch 470, train negloglik: 0.38160,    val negloglik: 0.36572    accuracy: 0.8496 lr: [7.976644307687256e-05]
# epoch 471, train negloglik: 0.38061,    val negloglik: 0.36576    accuracy: 0.8490 lr: [7.976644307687256e-05]
# epoch 472, train negloglik: 0.38056,    val negloglik: 0.36325    accuracy: 0.8489 lr: [7.976644307687256e-05]
# epoch 473, train negloglik: 0.38031,    val negloglik: 0.36575    accuracy: 0.8497 lr: [7.976644307687256e-05]
# epoch 474, train negloglik: 0.38055,    val negloglik: 0.36349    accuracy: 0.8498 lr: [7.976644307687256e-05]
# epoch 475, train negloglik: 0.38058,    val negloglik: 0.36457    accuracy: 0.8494 lr: [7.976644307687256e-05]
# epoch 476, train negloglik: 0.38093,    val negloglik: 0.36256    accuracy: 0.8495 lr: [7.976644307687256e-05]
# epoch 477, train negloglik: 0.38034,    val negloglik: 0.36496    accuracy: 0.8499 lr: [7.976644307687256e-05]
# epoch 478, train negloglik: 0.37986,    val negloglik: 0.36486    accuracy: 0.8497 lr: [7.976644307687256e-05]
# epoch 479, train negloglik: 0.38048,    val negloglik: 0.36466    accuracy: 0.8501 lr: [7.976644307687256e-05]
# epoch 480, train negloglik: 0.38022,    val negloglik: 0.36127    accuracy: 0.8499 lr: [7.976644307687256e-05]
# epoch 481, train negloglik: 0.37983,    val negloglik: 0.36577    accuracy: 0.8494 lr: [7.17897987691853e-05]
# epoch 482, train negloglik: 0.37890,    val negloglik: 0.36531    accuracy: 0.8505 lr: [7.17897987691853e-05]
# epoch 483, train negloglik: 0.37918,    val negloglik: 0.36439    accuracy: 0.8498 lr: [7.17897987691853e-05]
# epoch 484, train negloglik: 0.37943,    val negloglik: 0.36282    accuracy: 0.8495 lr: [7.17897987691853e-05]
# epoch 485, train negloglik: 0.37917,    val negloglik: 0.36432    accuracy: 0.8497 lr: [7.17897987691853e-05]
# epoch 486, train negloglik: 0.38025,    val negloglik: 0.36069    accuracy: 0.8500 lr: [7.17897987691853e-05]
# epoch 487, train negloglik: 0.37996,    val negloglik: 0.36401    accuracy: 0.8494 lr: [7.17897987691853e-05]
# epoch 488, train negloglik: 0.37910,    val negloglik: 0.36427    accuracy: 0.8494 lr: [7.17897987691853e-05]
# epoch 489, train negloglik: 0.37843,    val negloglik: 0.36399    accuracy: 0.8496 lr: [7.17897987691853e-05]
# epoch 490, train negloglik: 0.37909,    val negloglik: 0.36257    accuracy: 0.8494 lr: [7.17897987691853e-05]
# epoch 491, train negloglik: 0.37893,    val negloglik: 0.36166    accuracy: 0.8497 lr: [7.17897987691853e-05]
# epoch 492, train negloglik: 0.37820,    val negloglik: 0.36393    accuracy: 0.8499 lr: [7.17897987691853e-05]
# epoch 493, train negloglik: 0.37911,    val negloglik: 0.36183    accuracy: 0.8499 lr: [7.17897987691853e-05]
# epoch 494, train negloglik: 0.50796,    val negloglik: 0.56477    accuracy: 0.8421 lr: [7.17897987691853e-05]
# epoch 495, train negloglik: 0.67900,    val negloglik: 0.57822    accuracy: 0.8410 lr: [7.17897987691853e-05]
# epoch 496, train negloglik: 0.67193,    val negloglik: 0.56383    accuracy: 0.8398 lr: [7.17897987691853e-05]
# epoch 497, train negloglik: 0.65442,    val negloglik: 0.54867    accuracy: 0.8384 lr: [7.17897987691853e-05]
# epoch 498, train negloglik: 0.63562,    val negloglik: 0.53501    accuracy: 0.8365 lr: [7.17897987691853e-05]
# epoch 499, train negloglik: 0.61748,    val negloglik: 0.52010    accuracy: 0.8343 lr: [7.17897987691853e-05]

# %%
model.print_model()
# Out:
# GP_Model(
#   (layer_0): LayerFused(in=2 out=1 gp_pts_per_neuron=4)
#   (layer_1): LayerFused(in=1 out=1 gp_pts_per_neuron=4)
# )
# parameter count:  34

# %%
print([layer[0] for layer in model.named_parameters()])
# Out:
# ['input_noise_log', 'layer_0.z', 'layer_0.h', 'layer_0.l', 'layer_0.s', 'layer_0.jitter', 'layer_1.z', 'layer_1.h', 'layer_1.l', 'layer_1.s', 'layer_1.jitter']

# %%
# 1層目
model.layers[0].save_fig("./outputs/layer_fused1.png")

# %%
model.layers[1].save_fig("./outputs/layer_fused2.png")

# %%
# Make predictions on the test set
X_test_tensor = X_test  # X_test is already a tensor
with torch.no_grad():
    predictions = model.predict(X_test_tensor)

# Create a 3D scatter plot of predictions vs actual values
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# Scatter plot
# ax.scatter(X_test[:, 0].numpy(), X_test[:, 1].numpy(), y_test.numpy(), c='blue', marker='o', label='Actual')
ax.scatter(X_test[:, 0].numpy(), X_test[:, 1].numpy(), predictions.mean.numpy(), c='red', marker='o', label='Predicted')
# Plot the surface
surface = ax.plot_surface(x_grid, y_grid, z_grid, alpha=0.8)

# Set labels and title
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('3D Scatter Plot of Model Predictions vs Actual Values')
ax.legend()

# Calculate and print metrics
mse = torch.mean((predictions.mean - y_test)**2).item()
rmse = torch.sqrt(torch.mean((predictions.mean - y_test)**2)).item()
print(f"MSE: {mse:.6f}")
print(f"RMSE: {rmse:.6f}")
# Out:
# MSE: 0.001659
# RMSE: 0.040726

# %% [markdown]
# # GP-KANの学習安定化方法調査: b.正規化項調整

# %% [markdown]
# ## 0.背景/目的
# GP-KANの学習(誘導点・カーネルパラメータの同時学習)時、処理がうまくいかない現象が発生していた。
#
# 原因として考えられるのは以下の通り：
#
# * a. カーネル行列のJitter項が大きい※1ため、出力層以外の誘導点が縦に並んでいる(x軸:入力,y軸:中間層出力)
# * b. バッチサイズが小さいことで、ミニバッチデータに偏りが生じる
# * c. 損失関数(負の対数尤度)は誘導点が近いほど小さい値を取るため、カーネル行列が縮退しやすい
#
# ※1. 関数値を取る確率変数 $f\sim GP(m(\cdot),k(\cdot, \cdot))$ と独立なノイズが多く含まれることに相当する。
# ここで、GPの出力 $y$ に対して
# $$
# y = f(x)+\epsilon,\ \ \  \epsilon\sim \mathcal{N}(0, \sigma_\epsilon^2)
# $$
#
# そのため、以下の追加実験を行いGP-KANの学習が安定しない原因のあたりをつける。
#
# * a. Jitter項のパラメータ設定値を小さくして学習実行
# * b. バッチサイズ(現在32; 学習データ全体750件)を小さくする
# * c. 誘導点が近づかないようなペナルティ項入れて学習
#
# 本notebookでは、<span style="color: red;">b.の検証として</span>以下設定で学習を行い結果を評価する：
# ### モデル構成
# - **ネットワーク構造**: 2層GP-KAN (入力1次元 → 中間層1次元 → 出力1次元)
# - **誘導点数**: 各GPあたり10点
# - **GP構成**: (0,0), (1,0) の2つのガウス過程
#
# ### 学習パラメータ
# - **エポック数**: 400エポック
# - **学習率**: 1e-5
# - **バッチサイズ**: 32
# - **事前学習**: 無効 (pretrain=False)
#
# ### 正則化パラメータ
# - **global_jitter**: <span style="color: red;">**1e-4**</span>
# - **baseline_jitter**: 1e-3

# %%
GLOBAL_JITTER_VALUE = 1e-4
BASELINE_JITTER_VALUE = 1e-3

# %%
SAVELOAD_PATH = "model_12_b1.pt"

# %% [markdown]
# ## 1.問題設定
#
# 真の関数: フーリエ級数
# $$f(t) = \frac{4}{\pi} \sum_{n=1}^{N} \frac{1}{n} \sin(nt), \quad n = 1, 3, 5, \ldots, \quad t \in [0, 1]$$
# ※$N=15$
#
# データ:
# - 合計1,000件: 学習700件/検証150件/評価150件
# - tは$(-1,1)$から一様ランダムサンプリング
#
# モデル:
# - 2層のGPKAN: 入力1次元/中間層1次元/出力1次元
#     - それぞれのGPを(<1層目のindex>,<2層目のindex>)形式で表すことにすると、GPKANは$(0,0),(1,0)$の2つのGPで構成

# %% [markdown]
# ## 2.メイン処理
# 本ノートブックのメイン処理を実行する。実行順は以下の通り：
#
# 2-1.データセット作成
#
# 2-2.GPKANの学習
#
# 2-3.精度評価
#
# 2-4.学習中のカーネル行列ランク可視化

# %% [markdown]
# ### 2-1.データセット作成

# %%
# 初期設定: 必要なライブラリをインポートし、パスを設定
import os
import sys

sys.path.append("../")
import japanize_matplotlib
import torch.utils.data
from lib import model as gplib
from lib import runner
from torch.utils.data import DataLoader

# %%
import random

import matplotlib.pyplot as plt
import numpy as np
import torch
from torch.utils.data import DataLoader, TensorDataset


# Generate synthetic data with Fourier series function
def set_seed(seed=42):
    """完全な再現性のための乱数シード設定"""
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)


def worker_init_fn(worker_id):
    """DataLoaderワーカープロセス用の乱数シード設定"""
    worker_seed = torch.initial_seed() % 2**32
    np.random.seed(worker_seed)
    random.seed(worker_seed)


set_seed(42)  # 全体の乱数シード設定
num_samples = 1000

# Generate random input points t from [-1, 1]
t = np.random.uniform(-1, 1, num_samples)


# Compute target values: f(t) = (4/π) * Σ(1/n * sin(nt)) for odd n up to N=15
def fourier_series(t, N=15):
    result = np.zeros_like(t)
    for n in range(1, N + 1, 2):  # odd numbers only: 1, 3, 5, 7, 9, 11, 13, 15
        result += (1 / n) * np.sin(n * t)
    return (4 / np.pi) * result


targets = fourier_series(t, N=15)

# Reshape inputs (t is 1D, but we need it as 2D for compatibility)
inputs = t.reshape(-1, 1)

# Convert to PyTorch tensors
X_tensor = torch.FloatTensor(inputs)
y_tensor = torch.FloatTensor(targets).reshape(-1, 1)

# Split data into train, validation, and test sets
train_size = int(0.7 * num_samples)
val_size = int(0.15 * num_samples)
test_size = num_samples - train_size - val_size

X_train = X_tensor[:train_size]
y_train = y_tensor[:train_size]

X_val = X_tensor[train_size : train_size + val_size]
y_val = y_tensor[train_size : train_size + val_size]

X_test = X_tensor[train_size + val_size :]
y_test = y_tensor[train_size + val_size :]

# データを昇順にソート（X_testとy_testを対応を保ちながら）
sorted_indices = torch.argsort(X_test.squeeze())
X_test = X_test[sorted_indices]
y_test = y_test[sorted_indices]

# Create datasets
train_dataset = TensorDataset(X_train, y_train)
val_dataset = TensorDataset(X_val, y_val)
test_dataset = TensorDataset(X_test, y_test)

# Create dataloaders
batch_size = 32

# %%
# Create dataloaders with reproducible worker processes
generator = torch.Generator()
generator.manual_seed(42)

train_dataloader = DataLoader(
    train_dataset,
    batch_size=batch_size,
    shuffle=True,
    num_workers=0,  # Single process for reproducibility
    worker_init_fn=worker_init_fn,
    generator=generator,
)
val_dataloader = DataLoader(
    val_dataset,
    batch_size=batch_size,
    shuffle=False,
    num_workers=0,  # Single process for reproducibility
    worker_init_fn=worker_init_fn,
    generator=generator,
)
test_dataloader = DataLoader(
    test_dataset,
    batch_size=batch_size,
    shuffle=False,
    num_workers=0,  # Single process for reproducibility
    worker_init_fn=worker_init_fn,
    generator=generator,
)

# %%
# サンプル数確認
print(f"Train samples: {len(train_dataset)}")
print(f"Validation samples: {len(val_dataset)}")
print(f"Test samples: {len(test_dataset)}")

# Fourier級数関数のプロット
t_plot = np.linspace(-1, 1, 1000)
y_plot = fourier_series(t_plot, N=15)
plt.figure(figsize=(10, 6))
plt.plot(t_plot, y_plot, "b-", label="Fourier Series (N=15)")
plt.scatter(t, targets, alpha=0.3, s=3, c="red", label="Training Data")
plt.xlabel("t")
plt.ylabel("f(t)")
plt.title("Fourier Series Function")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Train samples: 700
# Validation samples: 150
# Test samples: 150

# %%
# y（目的変数）の分布をヒストグラムで可視化
plt.figure(figsize=(15, 10))


# 学習データのヒストグラム
plt.subplot(1, 1, 1)
plt.hist(
    y_train.numpy().flatten(), bins=30, alpha=0.7, color="green", edgecolor="black"
)
plt.xlabel("y (target values)")
plt.ylabel("Frequency")
plt.title("Training Data Distribution")
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()


# 値の分布特性
print(f"\n=== 値の分布特性 ===")
print(f"正の値の割合: {np.sum(targets > 0) / len(targets) * 100:.1f}%")
print(f"負の値の割合: {np.sum(targets < 0) / len(targets) * 100:.1f}%")
print(
    f"ゼロ近傍(-0.1 < y < 0.1)の割合: {np.sum(np.abs(targets) < 0.1) / len(targets) * 100:.1f}%"
)
# Out:
# === 値の分布特性 ===
# 正の値の割合: 49.7%
# 負の値の割合: 50.3%
# ゼロ近傍(-0.1 < y < 0.1)の割合: 1.3%

# %% [markdown]
# ### 2-2.モデル学習

# %%
num_gp_pts = 10  # Number of Gaussian Process points
model = gplib.GP_Model(
    [
        gplib.LayerFused(1, 1, num_gp_pts),
        gplib.LayerFused(1, 1, num_gp_pts),
    ],
    saveload_path=SAVELOAD_PATH,  # Path to save/load the model
)
np.random.seed(42)  # for reproducibility
torch.manual_seed(42)

# %%
# 精度評価/可視化関数
def plot_result(model):
    # テストデータでの予測
    with torch.no_grad():
        # バッチごとに予測を行う
        test_predictions = []
        test_targets = []
        test_variances = []

        for X_batch, y_batch in test_dataloader:
            pred = model.predict(X_batch).mean
            var = model.predict(X_batch).var
            test_predictions.append(pred)
            test_variances.append(var)
            test_targets.append(y_batch)

        # 結果を結合
        test_predictions = torch.cat(test_predictions, dim=0)
        test_targets = torch.cat(test_targets, dim=0)
        test_variances = torch.cat(test_variances, dim=0)

    # MSE計算
    mse = torch.mean((test_predictions - test_targets) ** 2)
    rmse = torch.sqrt(mse)

    print(f"Test MSE: {mse.item():.6f}")
    print(f"Test RMSE: {rmse.item():.6f}")

    # 可視化用のデータ準備
    t_test = X_test.numpy().flatten()
    y_test_true = y_test.numpy().flatten()
    y_test_pred = test_predictions.numpy().flatten()

    # 真の関数の連続プロット用
    t_continuous = np.linspace(-1, 1, 500)
    y_continuous = fourier_series(t_continuous, N=15)

    # グラフ作成
    plt.figure(figsize=(12, 8))

    # 真の関数
    plt.plot(
        t_continuous,
        y_continuous,
        "b-",
        linewidth=2,
        label="True Function (Fourier Series)",
        alpha=0.8,
    )

    # テストデータの真値
    plt.scatter(
        t_test,
        y_test_true,
        c="red",
        s=30,
        alpha=0.6,
        label="Test Data (True)",
        marker="o",
    )

    # 予測値
    plt.scatter(
        t_test, y_test_pred, c="green", s=30, alpha=0.6, label="Predictions", marker="x"
    )

    # 予測の不確実性を帯で表示
    lower_bound = y_test_pred - 1.96 * np.sqrt(test_variances.numpy().flatten())
    upper_bound = y_test_pred + 1.96 * np.sqrt(test_variances.numpy().flatten())
    plt.fill_between(
        t_test,
        lower_bound,
        upper_bound,
        color="lightgreen",
        alpha=0.3,
        label="95% Prediction Interval",
    )

    plt.xlabel("t")
    plt.ylabel("f(t)")
    plt.title(f"GP-KAN Prediction vs True Function\nTest RMSE: {rmse.item():.6f}")
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.show()

    # 残差プロット
    plt.figure(figsize=(10, 6))
    residuals = y_test_pred - y_test_true
    plt.scatter(t_test, residuals, c="purple", s=30, alpha=0.6)
    plt.axhline(y=0, color="red", linestyle="--", alpha=0.7)
    plt.xlabel("t")
    plt.ylabel("Residuals (Predicted - True)")
    plt.title("Residual Plot")
    plt.grid(True, alpha=0.3)
    plt.show()

    # 残差の統計情報
    print(f"\nResidual Statistics:")
    print(f"Mean: {np.mean(residuals):.6f}")
    print(f"Std: {np.std(residuals):.6f}")
    print(f"Min: {np.min(residuals):.6f}")
    print(f"Max: {np.max(residuals):.6f}")

    print("plot completed")
    return 0

# %%
for epoch in range(1):
    runner.train_model(
        train_dataloader,
        val_dataloader,
        model,
        epochs=400,
        learning_rate=1e-5,
        use_gpu=False,  # True,
        pretrain=False,  # True,
        global_jitter=GLOBAL_JITTER_VALUE,
        baseline_jitter=BASELINE_JITTER_VALUE,
    )
    model.save_model()  # optionally save the model after training

    # 可視化
    plot_result(model)
# Out:
# epoch 0  , train negloglik: 1225.18545,    val negloglik: 1.56334    accuracy: 0.5154 lr: [1e-05]
# epoch 1  , train negloglik: 1.53383,    val negloglik: 1.51508    accuracy: 0.9044 lr: [9e-06]
# epoch 2  , train negloglik: 1.50394,    val negloglik: 1.48849    accuracy: 0.9377 lr: [9e-06]
# epoch 3  , train negloglik: 1.48276,    val negloglik: 1.46995    accuracy: 0.9479 lr: [9e-06]
# epoch 4  , train negloglik: 1.46373,    val negloglik: 1.44789    accuracy: 0.9264 lr: [9e-06]
# epoch 5  , train negloglik: 1.44346,    val negloglik: 1.43225    accuracy: 0.9452 lr: [9e-06]
# epoch 6  , train negloglik: 1.42714,    val negloglik: 1.40812    accuracy: 0.9050 lr: [9e-06]
# epoch 7  , train negloglik: 1.40559,    val negloglik: 1.39445    accuracy: 0.9093 lr: [9e-06]
# epoch 8  , train negloglik: 1.39223,    val negloglik: 1.37969    accuracy: 0.9173 lr: [9e-06]
# epoch 9  , train negloglik: 1.37918,    val negloglik: 1.36861    accuracy: 0.9292 lr: [9e-06]
# epoch 10 , train negloglik: 1.36886,    val negloglik: 1.35937    accuracy: 0.9116 lr: [9e-06]
# epoch 11 , train negloglik: 1.36162,    val negloglik: 1.35248    accuracy: 0.9012 lr: [9e-06]
# epoch 12 , train negloglik: 1.35519,    val negloglik: 1.34928    accuracy: 0.9023 lr: [9e-06]
# epoch 13 , train negloglik: 1.35230,    val negloglik: 1.34810    accuracy: 0.9060 lr: [9e-06]
# epoch 14 , train negloglik: 1.35223,    val negloglik: 1.35045    accuracy: 0.9338 lr: [9e-06]
# epoch 15 , train negloglik: 1.35188,    val negloglik: 1.35044    accuracy: 0.9336 lr: [9e-06]
# epoch 16 , train negloglik: 1.35045,    val negloglik: 1.34759    accuracy: 0.9087 lr: [9e-06]
# epoch 17 , train negloglik: 1.35040,    val negloglik: 1.34615    accuracy: 0.8962 lr: [9e-06]
# epoch 18 , train negloglik: 1.35077,    val negloglik: 1.34584    accuracy: 0.8950 lr: [9e-06]
# epoch 19 , train negloglik: 1.34958,    val negloglik: 1.34702    accuracy: 0.9119 lr: [9e-06]
# epoch 20 , train negloglik: 1.34931,    val negloglik: 1.34889    accuracy: 0.9339 lr: [9e-06]
# epoch 21 , train negloglik: 1.34807,    val negloglik: 1.34729    accuracy: 0.9194 lr: [8.1e-06]
# epoch 22 , train negloglik: 1.34930,    val negloglik: 1.34734    accuracy: 0.9210 lr: [8.1e-06]
# epoch 23 , train negloglik: 1.34834,    val negloglik: 1.34479    accuracy: 0.8983 lr: [8.1e-06]
# epoch 24 , train negloglik: 1.34621,    val negloglik: 1.34570    accuracy: 0.9122 lr: [8.1e-06]
# epoch 25 , train negloglik: 1.34680,    val negloglik: 1.34525    accuracy: 0.9088 lr: [8.1e-06]
# epoch 26 , train negloglik: 1.34681,    val negloglik: 1.34440    accuracy: 0.9026 lr: [8.1e-06]
# epoch 27 , train negloglik: 1.34638,    val negloglik: 1.34469    accuracy: 0.9101 lr: [8.1e-06]
# epoch 28 , train negloglik: 1.34661,    val negloglik: 1.34424    accuracy: 0.9075 lr: [8.1e-06]
# epoch 29 , train negloglik: 1.34598,    val negloglik: 1.35135    accuracy: 0.9702 lr: [8.1e-06]
# epoch 30 , train negloglik: 1.34669,    val negloglik: 1.34495    accuracy: 0.9187 lr: [8.1e-06]
# epoch 31 , train negloglik: 1.34576,    val negloglik: 1.34196    accuracy: 0.8896 lr: [8.1e-06]
# epoch 32 , train negloglik: 1.34624,    val negloglik: 1.34177    accuracy: 0.8909 lr: [8.1e-06]
# epoch 33 , train negloglik: 1.34294,    val negloglik: 1.34101    accuracy: 0.8814 lr: [8.1e-06]
# epoch 34 , train negloglik: 1.34491,    val negloglik: 1.34436    accuracy: 0.9214 lr: [8.1e-06]
# epoch 35 , train negloglik: 1.34438,    val negloglik: 1.34349    accuracy: 0.9154 lr: [8.1e-06]
# epoch 36 , train negloglik: 1.34522,    val negloglik: 1.33988    accuracy: 0.8787 lr: [8.1e-06]
# epoch 37 , train negloglik: 1.34310,    val negloglik: 1.34310    accuracy: 0.9190 lr: [8.1e-06]
# epoch 38 , train negloglik: 1.34208,    val negloglik: 1.34237    accuracy: 0.9112 lr: [8.1e-06]
# epoch 39 , train negloglik: 1.34376,    val negloglik: 1.34100    accuracy: 0.9039 lr: [8.1e-06]
# epoch 40 , train negloglik: 1.34089,    val negloglik: 1.33758    accuracy: 0.8661 lr: [8.1e-06]
# epoch 41 , train negloglik: 1.33995,    val negloglik: 1.33924    accuracy: 0.8878 lr: [7.2900000000000005e-06]
# epoch 42 , train negloglik: 1.34257,    val negloglik: 1.33830    accuracy: 0.8821 lr: [7.2900000000000005e-06]
# epoch 43 , train negloglik: 1.34141,    val negloglik: 1.33913    accuracy: 0.8932 lr: [7.2900000000000005e-06]
# epoch 44 , train negloglik: 1.34189,    val negloglik: 1.33883    accuracy: 0.8941 lr: [7.2900000000000005e-06]
# epoch 45 , train negloglik: 1.34041,    val negloglik: 1.33654    accuracy: 0.8679 lr: [7.2900000000000005e-06]
# epoch 46 , train negloglik: 1.34035,    val negloglik: 1.34330    accuracy: 0.9377 lr: [7.2900000000000005e-06]
# epoch 47 , train negloglik: 1.34020,    val negloglik: 1.33926    accuracy: 0.9025 lr: [7.2900000000000005e-06]
# epoch 48 , train negloglik: 1.33963,    val negloglik: 1.34040    accuracy: 0.9177 lr: [7.2900000000000005e-06]
# epoch 49 , train negloglik: 1.33831,    val negloglik: 1.33708    accuracy: 0.8861 lr: [7.2900000000000005e-06]
# epoch 50 , train negloglik: 1.34008,    val negloglik: 1.33816    accuracy: 0.9006 lr: [7.2900000000000005e-06]
# epoch 51 , train negloglik: 1.33917,    val negloglik: 1.34094    accuracy: 0.9277 lr: [7.2900000000000005e-06]
# epoch 52 , train negloglik: 1.33800,    val negloglik: 1.33749    accuracy: 0.8979 lr: [7.2900000000000005e-06]
# epoch 53 , train negloglik: 1.33899,    val negloglik: 1.33694    accuracy: 0.8962 lr: [7.2900000000000005e-06]
# epoch 54 , train negloglik: 1.33888,    val negloglik: 1.33770    accuracy: 0.9065 lr: [7.2900000000000005e-06]
# epoch 55 , train negloglik: 1.33635,    val negloglik: 1.33863    accuracy: 0.9177 lr: [7.2900000000000005e-06]
# epoch 56 , train negloglik: 1.33776,    val negloglik: 1.33458    accuracy: 0.8777 lr: [7.2900000000000005e-06]
# epoch 57 , train negloglik: 1.33768,    val negloglik: 1.33793    accuracy: 0.9138 lr: [7.2900000000000005e-06]
# epoch 58 , train negloglik: 1.33698,    val negloglik: 1.33329    accuracy: 0.8683 lr: [7.2900000000000005e-06]
# epoch 59 , train negloglik: 1.33567,    val negloglik: 1.33746    accuracy: 0.9149 lr: [7.2900000000000005e-06]
# epoch 60 , train negloglik: 1.33488,    val negloglik: 1.33953    accuracy: 0.9336 lr: [7.2900000000000005e-06]
# epoch 61 , train negloglik: 1.33664,    val negloglik: 1.33539    accuracy: 0.8997 lr: [6.561e-06]
# epoch 62 , train negloglik: 1.33590,    val negloglik: 1.33474    accuracy: 0.8953 lr: [6.561e-06]
# epoch 63 , train negloglik: 1.33449,    val negloglik: 1.33138    accuracy: 0.8563 lr: [6.561e-06]
# epoch 64 , train negloglik: 1.33554,    val negloglik: 1.33356    accuracy: 0.8868 lr: [6.561e-06]
# epoch 65 , train negloglik: 1.33353,    val negloglik: 1.33618    accuracy: 0.9128 lr: [6.561e-06]
# epoch 66 , train negloglik: 1.33429,    val negloglik: 1.33164    accuracy: 0.8727 lr: [6.561e-06]
# epoch 67 , train negloglik: 1.33469,    val negloglik: 1.33437    accuracy: 0.9013 lr: [6.561e-06]
# epoch 68 , train negloglik: 1.33708,    val negloglik: 1.33230    accuracy: 0.8812 lr: [6.561e-06]
# epoch 69 , train negloglik: 1.33404,    val negloglik: 1.33216    accuracy: 0.8846 lr: [6.561e-06]
# epoch 70 , train negloglik: 1.33257,    val negloglik: 1.33268    accuracy: 0.8907 lr: [6.561e-06]
# epoch 71 , train negloglik: 1.33261,    val negloglik: 1.33144    accuracy: 0.8809 lr: [6.561e-06]
# epoch 72 , train negloglik: 1.33257,    val negloglik: 1.33268    accuracy: 0.8979 lr: [6.561e-06]
# epoch 73 , train negloglik: 1.33410,    val negloglik: 1.33171    accuracy: 0.8877 lr: [6.561e-06]
# epoch 74 , train negloglik: 1.33164,    val negloglik: 1.33226    accuracy: 0.8949 lr: [6.561e-06]
# epoch 75 , train negloglik: 1.33429,    val negloglik: 1.33596    accuracy: 0.9290 lr: [6.561e-06]
# epoch 76 , train negloglik: 1.33287,    val negloglik: 1.33341    accuracy: 0.9091 lr: [6.561e-06]
# epoch 77 , train negloglik: 1.33334,    val negloglik: 1.33470    accuracy: 0.9215 lr: [6.561e-06]
# epoch 78 , train negloglik: 1.33040,    val negloglik: 1.32683    accuracy: 0.8396 lr: [6.561e-06]
# epoch 79 , train negloglik: 1.33170,    val negloglik: 1.33343    accuracy: 0.9151 lr: [6.561e-06]
# epoch 80 , train negloglik: 1.33203,    val negloglik: 1.32825    accuracy: 0.8683 lr: [6.561e-06]
# epoch 81 , train negloglik: 1.33050,    val negloglik: 1.32892    accuracy: 0.8778 lr: [5.904900000000001e-06]
# epoch 82 , train negloglik: 1.33125,    val negloglik: 1.32824    accuracy: 0.8715 lr: [5.904900000000001e-06]
# epoch 83 , train negloglik: 1.32987,    val negloglik: 1.33095    accuracy: 0.9023 lr: [5.904900000000001e-06]
# epoch 84 , train negloglik: 1.33111,    val negloglik: 1.32700    accuracy: 0.8633 lr: [5.904900000000001e-06]
# epoch 85 , train negloglik: 1.33069,    val negloglik: 1.32741    accuracy: 0.8700 lr: [5.904900000000001e-06]
# epoch 86 , train negloglik: 1.32983,    val negloglik: 1.32638    accuracy: 0.8599 lr: [5.904900000000001e-06]
# epoch 87 , train negloglik: 1.33001,    val negloglik: 1.32665    accuracy: 0.8644 lr: [5.904900000000001e-06]
# epoch 88 , train negloglik: 1.32951,    val negloglik: 1.32923    accuracy: 0.8902 lr: [5.904900000000001e-06]
# epoch 89 , train negloglik: 1.33009,    val negloglik: 1.32714    accuracy: 0.8736 lr: [5.904900000000001e-06]
# epoch 90 , train negloglik: 1.32955,    val negloglik: 1.32815    accuracy: 0.8872 lr: [5.904900000000001e-06]
# epoch 91 , train negloglik: 1.32836,    val negloglik: 1.32984    accuracy: 0.9035 lr: [5.904900000000001e-06]
# epoch 92 , train negloglik: 1.32814,    val negloglik: 1.32810    accuracy: 0.8890 lr: [5.904900000000001e-06]
# epoch 93 , train negloglik: 1.32860,    val negloglik: 1.32764    accuracy: 0.8885 lr: [5.904900000000001e-06]
# epoch 94 , train negloglik: 1.32811,    val negloglik: 1.32494    accuracy: 0.8616 lr: [5.904900000000001e-06]
# epoch 95 , train negloglik: 1.32701,    val negloglik: 1.32508    accuracy: 0.8653 lr: [5.904900000000001e-06]
# epoch 96 , train negloglik: 1.32745,    val negloglik: 1.32678    accuracy: 0.8844 lr: [5.904900000000001e-06]
# epoch 97 , train negloglik: 1.32695,    val negloglik: 1.32629    accuracy: 0.8809 lr: [5.904900000000001e-06]
# epoch 98 , train negloglik: 1.32753,    val negloglik: 1.32402    accuracy: 0.8575 lr: [5.904900000000001e-06]
# epoch 99 , train negloglik: 1.32839,    val negloglik: 1.32498    accuracy: 0.8729 lr: [5.904900000000001e-06]
# epoch 100, train negloglik: 1.32625,    val negloglik: 1.32619    accuracy: 0.8871 lr: [5.904900000000001e-06]
# epoch 101, train negloglik: 1.32519,    val negloglik: 1.32545    accuracy: 0.8819 lr: [5.314410000000001e-06]
# epoch 102, train negloglik: 1.32445,    val negloglik: 1.32779    accuracy: 0.9034 lr: [5.314410000000001e-06]
# epoch 103, train negloglik: 1.32598,    val negloglik: 1.32621    accuracy: 0.8917 lr: [5.314410000000001e-06]
# epoch 104, train negloglik: 1.32453,    val negloglik: 1.32571    accuracy: 0.8855 lr: [5.314410000000001e-06]
# epoch 105, train negloglik: 1.32475,    val negloglik: 1.32310    accuracy: 0.8641 lr: [5.314410000000001e-06]
# epoch 106, train negloglik: 1.32587,    val negloglik: 1.32038    accuracy: 0.8320 lr: [5.314410000000001e-06]
# epoch 107, train negloglik: 1.32412,    val negloglik: 1.32294    accuracy: 0.8674 lr: [5.314410000000001e-06]
# epoch 108, train negloglik: 1.32342,    val negloglik: 1.32628    accuracy: 0.8989 lr: [5.314410000000001e-06]
# epoch 109, train negloglik: 1.32463,    val negloglik: 1.32205    accuracy: 0.8596 lr: [5.314410000000001e-06]
# epoch 110, train negloglik: 1.32459,    val negloglik: 1.32303    accuracy: 0.8732 lr: [5.314410000000001e-06]
# epoch 111, train negloglik: 1.32467,    val negloglik: 1.32170    accuracy: 0.8645 lr: [5.314410000000001e-06]
# epoch 112, train negloglik: 1.32350,    val negloglik: 1.32417    accuracy: 0.8893 lr: [5.314410000000001e-06]
# epoch 113, train negloglik: 1.32308,    val negloglik: 1.32624    accuracy: 0.9063 lr: [5.314410000000001e-06]
# epoch 114, train negloglik: 1.32308,    val negloglik: 1.32250    accuracy: 0.8770 lr: [5.314410000000001e-06]
# epoch 115, train negloglik: 1.32341,    val negloglik: 1.31856    accuracy: 0.8318 lr: [5.314410000000001e-06]
# epoch 116, train negloglik: 1.32381,    val negloglik: 1.31995    accuracy: 0.8528 lr: [5.314410000000001e-06]
# epoch 117, train negloglik: 1.32244,    val negloglik: 1.32407    accuracy: 0.8959 lr: [5.314410000000001e-06]
# epoch 118, train negloglik: 1.32085,    val negloglik: 1.32383    accuracy: 0.8938 lr: [5.314410000000001e-06]
# epoch 119, train negloglik: 1.32269,    val negloglik: 1.32125    accuracy: 0.8723 lr: [5.314410000000001e-06]
# epoch 120, train negloglik: 1.32100,    val negloglik: 1.32208    accuracy: 0.8806 lr: [5.314410000000001e-06]
# epoch 121, train negloglik: 1.32116,    val negloglik: 1.32515    accuracy: 0.9084 lr: [4.782969000000001e-06]
# epoch 122, train negloglik: 1.32135,    val negloglik: 1.32616    accuracy: 0.9165 lr: [4.782969000000001e-06]
# epoch 123, train negloglik: 1.32149,    val negloglik: 1.31950    accuracy: 0.8611 lr: [4.782969000000001e-06]
# epoch 124, train negloglik: 1.32177,    val negloglik: 1.31829    accuracy: 0.8500 lr: [4.782969000000001e-06]
# epoch 125, train negloglik: 1.31949,    val negloglik: 1.32007    accuracy: 0.8701 lr: [4.782969000000001e-06]
# epoch 126, train negloglik: 1.32009,    val negloglik: 1.32144    accuracy: 0.8828 lr: [4.782969000000001e-06]
# epoch 127, train negloglik: 1.31928,    val negloglik: 1.31876    accuracy: 0.8618 lr: [4.782969000000001e-06]
# epoch 128, train negloglik: 1.31903,    val negloglik: 1.32018    accuracy: 0.8754 lr: [4.782969000000001e-06]
# epoch 129, train negloglik: 1.31881,    val negloglik: 1.31811    accuracy: 0.8575 lr: [4.782969000000001e-06]
# epoch 130, train negloglik: 1.32017,    val negloglik: 1.32560    accuracy: 0.9220 lr: [4.782969000000001e-06]
# epoch 131, train negloglik: 1.31914,    val negloglik: 1.31829    accuracy: 0.8651 lr: [4.782969000000001e-06]
# epoch 132, train negloglik: 1.31932,    val negloglik: 1.31797    accuracy: 0.8619 lr: [4.782969000000001e-06]
# epoch 133, train negloglik: 1.31899,    val negloglik: 1.31691    accuracy: 0.8533 lr: [4.782969000000001e-06]
# epoch 134, train negloglik: 1.31823,    val negloglik: 1.32086    accuracy: 0.8916 lr: [4.782969000000001e-06]
# epoch 135, train negloglik: 1.31864,    val negloglik: 1.31972    accuracy: 0.8835 lr: [4.782969000000001e-06]
# epoch 136, train negloglik: 1.31918,    val negloglik: 1.31743    accuracy: 0.8634 lr: [4.782969000000001e-06]
# epoch 137, train negloglik: 1.31854,    val negloglik: 1.31694    accuracy: 0.8613 lr: [4.782969000000001e-06]
# epoch 138, train negloglik: 1.31900,    val negloglik: 1.31679    accuracy: 0.8618 lr: [4.782969000000001e-06]
# epoch 139, train negloglik: 1.31789,    val negloglik: 1.31654    accuracy: 0.8617 lr: [4.782969000000001e-06]
# epoch 140, train negloglik: 1.31738,    val negloglik: 1.31748    accuracy: 0.8712 lr: [4.782969000000001e-06]
# epoch 141, train negloglik: 1.31672,    val negloglik: 1.31752    accuracy: 0.8722 lr: [4.3046721000000005e-06]
# epoch 142, train negloglik: 1.31652,    val negloglik: 1.32081    accuracy: 0.9019 lr: [4.3046721000000005e-06]
# epoch 143, train negloglik: 1.31653,    val negloglik: 1.31413    accuracy: 0.8406 lr: [4.3046721000000005e-06]
# epoch 144, train negloglik: 1.31615,    val negloglik: 1.32052    accuracy: 0.9017 lr: [4.3046721000000005e-06]
# epoch 145, train negloglik: 1.31722,    val negloglik: 1.31380    accuracy: 0.8429 lr: [4.3046721000000005e-06]
# epoch 146, train negloglik: 1.31721,    val negloglik: 1.31408    accuracy: 0.8463 lr: [4.3046721000000005e-06]
# epoch 147, train negloglik: 1.31594,    val negloglik: 1.31637    accuracy: 0.8703 lr: [4.3046721000000005e-06]
# epoch 148, train negloglik: 1.31510,    val negloglik: 1.31492    accuracy: 0.8562 lr: [4.3046721000000005e-06]
# epoch 149, train negloglik: 1.31615,    val negloglik: 1.31966    accuracy: 0.8996 lr: [4.3046721000000005e-06]
# epoch 150, train negloglik: 1.31392,    val negloglik: 1.31614    accuracy: 0.8727 lr: [4.3046721000000005e-06]
# epoch 151, train negloglik: 1.31578,    val negloglik: 1.31334    accuracy: 0.8465 lr: [4.3046721000000005e-06]
# epoch 152, train negloglik: 1.31524,    val negloglik: 1.31416    accuracy: 0.8561 lr: [4.3046721000000005e-06]
# epoch 153, train negloglik: 1.31499,    val negloglik: 1.31125    accuracy: 0.8250 lr: [4.3046721000000005e-06]
# epoch 154, train negloglik: 1.31427,    val negloglik: 1.31501    accuracy: 0.8679 lr: [4.3046721000000005e-06]
# epoch 155, train negloglik: 1.31443,    val negloglik: 1.31341    accuracy: 0.8532 lr: [4.3046721000000005e-06]
# epoch 156, train negloglik: 1.31532,    val negloglik: 1.31430    accuracy: 0.8601 lr: [4.3046721000000005e-06]
# epoch 157, train negloglik: 1.31158,    val negloglik: 1.31405    accuracy: 0.8637 lr: [4.3046721000000005e-06]
# epoch 158, train negloglik: 1.31543,    val negloglik: 1.31320    accuracy: 0.8544 lr: [4.3046721000000005e-06]
# epoch 159, train negloglik: 1.31195,    val negloglik: 1.31304    accuracy: 0.8566 lr: [4.3046721000000005e-06]
# epoch 160, train negloglik: 1.31456,    val negloglik: 1.31408    accuracy: 0.8672 lr: [4.3046721000000005e-06]
# epoch 161, train negloglik: 1.31377,    val negloglik: 1.31505    accuracy: 0.8785 lr: [3.874204890000001e-06]
# epoch 162, train negloglik: 1.31341,    val negloglik: 1.31296    accuracy: 0.8594 lr: [3.874204890000001e-06]
# epoch 163, train negloglik: 1.31350,    val negloglik: 1.31244    accuracy: 0.8560 lr: [3.874204890000001e-06]
# epoch 164, train negloglik: 1.31215,    val negloglik: 1.30981    accuracy: 0.8291 lr: [3.874204890000001e-06]
# epoch 165, train negloglik: 1.31530,    val negloglik: 1.31319    accuracy: 0.8660 lr: [3.874204890000001e-06]
# epoch 166, train negloglik: 1.31237,    val negloglik: 1.31149    accuracy: 0.8509 lr: [3.874204890000001e-06]
# epoch 167, train negloglik: 1.31227,    val negloglik: 1.31191    accuracy: 0.8564 lr: [3.874204890000001e-06]
# epoch 168, train negloglik: 1.30904,    val negloglik: 1.31008    accuracy: 0.8388 lr: [3.874204890000001e-06]
# epoch 169, train negloglik: 1.31076,    val negloglik: 1.31197    accuracy: 0.8598 lr: [3.874204890000001e-06]
# epoch 170, train negloglik: 1.31081,    val negloglik: 1.30973    accuracy: 0.8408 lr: [3.874204890000001e-06]
# epoch 171, train negloglik: 1.31089,    val negloglik: 1.31218    accuracy: 0.8617 lr: [3.874204890000001e-06]
# epoch 172, train negloglik: 1.31078,    val negloglik: 1.30929    accuracy: 0.8381 lr: [3.874204890000001e-06]
# epoch 173, train negloglik: 1.31173,    val negloglik: 1.31318    accuracy: 0.8755 lr: [3.874204890000001e-06]
# epoch 174, train negloglik: 1.31066,    val negloglik: 1.30864    accuracy: 0.8331 lr: [3.874204890000001e-06]
# epoch 175, train negloglik: 1.31194,    val negloglik: 1.30939    accuracy: 0.8422 lr: [3.874204890000001e-06]
# epoch 176, train negloglik: 1.31046,    val negloglik: 1.30987    accuracy: 0.8480 lr: [3.874204890000001e-06]
# epoch 177, train negloglik: 1.30907,    val negloglik: 1.30892    accuracy: 0.8408 lr: [3.874204890000001e-06]
# epoch 178, train negloglik: 1.30947,    val negloglik: 1.31147    accuracy: 0.8674 lr: [3.874204890000001e-06]
# epoch 179, train negloglik: 1.30957,    val negloglik: 1.31155    accuracy: 0.8673 lr: [3.874204890000001e-06]
# epoch 180, train negloglik: 1.30976,    val negloglik: 1.30731    accuracy: 0.8285 lr: [3.874204890000001e-06]
# epoch 181, train negloglik: 1.30806,    val negloglik: 1.31184    accuracy: 0.8733 lr: [3.4867844010000007e-06]
# epoch 182, train negloglik: 1.31044,    val negloglik: 1.31047    accuracy: 0.8638 lr: [3.4867844010000007e-06]
# epoch 183, train negloglik: 1.30707,    val negloglik: 1.30825    accuracy: 0.8451 lr: [3.4867844010000007e-06]
# epoch 184, train negloglik: 1.30938,    val negloglik: 1.30583    accuracy: 0.8170 lr: [3.4867844010000007e-06]
# epoch 185, train negloglik: 1.30881,    val negloglik: 1.30659    accuracy: 0.8283 lr: [3.4867844010000007e-06]
# epoch 186, train negloglik: 1.30734,    val negloglik: 1.30641    accuracy: 0.8294 lr: [3.4867844010000007e-06]
# epoch 187, train negloglik: 1.30950,    val negloglik: 1.30849    accuracy: 0.8532 lr: [3.4867844010000007e-06]
# epoch 188, train negloglik: 1.30576,    val negloglik: 1.30866    accuracy: 0.8529 lr: [3.4867844010000007e-06]
# epoch 189, train negloglik: 1.30953,    val negloglik: 1.30829    accuracy: 0.8520 lr: [3.4867844010000007e-06]
# epoch 190, train negloglik: 1.30723,    val negloglik: 1.30890    accuracy: 0.8581 lr: [3.4867844010000007e-06]
# epoch 191, train negloglik: 1.30783,    val negloglik: 1.30965    accuracy: 0.8664 lr: [3.4867844010000007e-06]
# epoch 192, train negloglik: 1.30685,    val negloglik: 1.30457    accuracy: 0.8189 lr: [3.4867844010000007e-06]
# epoch 193, train negloglik: 1.30785,    val negloglik: 1.30718    accuracy: 0.8483 lr: [3.4867844010000007e-06]
# epoch 194, train negloglik: 1.30803,    val negloglik: 1.30591    accuracy: 0.8316 lr: [3.4867844010000007e-06]
# epoch 195, train negloglik: 1.30697,    val negloglik: 1.30841    accuracy: 0.8631 lr: [3.4867844010000007e-06]
# epoch 196, train negloglik: 1.30814,    val negloglik: 1.30605    accuracy: 0.8412 lr: [3.4867844010000007e-06]
# epoch 197, train negloglik: 1.30767,    val negloglik: 1.30753    accuracy: 0.8542 lr: [3.4867844010000007e-06]
# epoch 198, train negloglik: 1.30800,    val negloglik: 1.30596    accuracy: 0.8428 lr: [3.4867844010000007e-06]
# epoch 199, train negloglik: 1.30506,    val negloglik: 1.30551    accuracy: 0.8383 lr: [3.4867844010000007e-06]
# epoch 200, train negloglik: 1.30576,    val negloglik: 1.30387    accuracy: 0.8208 lr: [3.4867844010000007e-06]
# epoch 201, train negloglik: 1.30639,    val negloglik: 1.30546    accuracy: 0.8399 lr: [3.1381059609000006e-06]
# epoch 202, train negloglik: 1.30588,    val negloglik: 1.30669    accuracy: 0.8540 lr: [3.1381059609000006e-06]
# epoch 203, train negloglik: 1.30655,    val negloglik: 1.30587    accuracy: 0.8449 lr: [3.1381059609000006e-06]
# epoch 204, train negloglik: 1.30607,    val negloglik: 1.30399    accuracy: 0.8283 lr: [3.1381059609000006e-06]
# epoch 205, train negloglik: 1.30470,    val negloglik: 1.30226    accuracy: 0.8058 lr: [3.1381059609000006e-06]
# epoch 206, train negloglik: 1.30626,    val negloglik: 1.30547    accuracy: 0.8479 lr: [3.1381059609000006e-06]
# epoch 207, train negloglik: 1.30398,    val negloglik: 1.30458    accuracy: 0.8379 lr: [3.1381059609000006e-06]
# epoch 208, train negloglik: 1.30438,    val negloglik: 1.30511    accuracy: 0.8434 lr: [3.1381059609000006e-06]
# epoch 209, train negloglik: 1.30535,    val negloglik: 1.30944    accuracy: 0.8816 lr: [3.1381059609000006e-06]
# epoch 210, train negloglik: 1.30495,    val negloglik: 1.30340    accuracy: 0.8293 lr: [3.1381059609000006e-06]
# epoch 211, train negloglik: 1.30465,    val negloglik: 1.30382    accuracy: 0.8317 lr: [3.1381059609000006e-06]
# epoch 212, train negloglik: 1.30408,    val negloglik: 1.30474    accuracy: 0.8468 lr: [3.1381059609000006e-06]
# epoch 213, train negloglik: 1.30298,    val negloglik: 1.30323    accuracy: 0.8317 lr: [3.1381059609000006e-06]
# epoch 214, train negloglik: 1.30531,    val negloglik: 1.30423    accuracy: 0.8428 lr: [3.1381059609000006e-06]
# epoch 215, train negloglik: 1.30606,    val negloglik: 1.30681    accuracy: 0.8657 lr: [3.1381059609000006e-06]
# epoch 216, train negloglik: 1.30208,    val negloglik: 1.30559    accuracy: 0.8571 lr: [3.1381059609000006e-06]
# epoch 217, train negloglik: 1.30359,    val negloglik: 1.30345    accuracy: 0.8402 lr: [3.1381059609000006e-06]
# epoch 218, train negloglik: 1.30459,    val negloglik: 1.30410    accuracy: 0.8443 lr: [3.1381059609000006e-06]
# epoch 219, train negloglik: 1.30204,    val negloglik: 1.30236    accuracy: 0.8294 lr: [3.1381059609000006e-06]
# epoch 220, train negloglik: 1.30185,    val negloglik: 1.30122    accuracy: 0.8178 lr: [3.1381059609000006e-06]
# epoch 221, train negloglik: 1.30313,    val negloglik: 1.30163    accuracy: 0.8261 lr: [2.8242953648100006e-06]
# epoch 222, train negloglik: 1.30268,    val negloglik: 1.30083    accuracy: 0.8168 lr: [2.8242953648100006e-06]
# epoch 223, train negloglik: 1.30369,    val negloglik: 1.30326    accuracy: 0.8431 lr: [2.8242953648100006e-06]
# epoch 224, train negloglik: 1.30386,    val negloglik: 1.30527    accuracy: 0.8636 lr: [2.8242953648100006e-06]
# epoch 225, train negloglik: 1.30210,    val negloglik: 1.30030    accuracy: 0.8182 lr: [2.8242953648100006e-06]
# epoch 226, train negloglik: 1.30103,    val negloglik: 1.30238    accuracy: 0.8390 lr: [2.8242953648100006e-06]
# epoch 227, train negloglik: 1.30471,    val negloglik: 1.30122    accuracy: 0.8300 lr: [2.8242953648100006e-06]
# epoch 228, train negloglik: 1.30153,    val negloglik: 1.30190    accuracy: 0.8367 lr: [2.8242953648100006e-06]
# epoch 229, train negloglik: 1.30339,    val negloglik: 1.30160    accuracy: 0.8318 lr: [2.8242953648100006e-06]
# epoch 230, train negloglik: 1.30348,    val negloglik: 1.30068    accuracy: 0.8231 lr: [2.8242953648100006e-06]
# epoch 231, train negloglik: 1.30093,    val negloglik: 1.29881    accuracy: 0.8070 lr: [2.8242953648100006e-06]
# epoch 232, train negloglik: 1.30106,    val negloglik: 1.30829    accuracy: 0.8915 lr: [2.8242953648100006e-06]
# epoch 233, train negloglik: 1.30306,    val negloglik: 1.30171    accuracy: 0.8408 lr: [2.8242953648100006e-06]
# epoch 234, train negloglik: 1.29987,    val negloglik: 1.30050    accuracy: 0.8302 lr: [2.8242953648100006e-06]
# epoch 235, train negloglik: 1.30016,    val negloglik: 1.30049    accuracy: 0.8299 lr: [2.8242953648100006e-06]
# epoch 236, train negloglik: 1.30263,    val negloglik: 1.29947    accuracy: 0.8206 lr: [2.8242953648100006e-06]
# epoch 237, train negloglik: 1.30074,    val negloglik: 1.29969    accuracy: 0.8222 lr: [2.8242953648100006e-06]
# epoch 238, train negloglik: 1.30062,    val negloglik: 1.30058    accuracy: 0.8346 lr: [2.8242953648100006e-06]
# epoch 239, train negloglik: 1.30239,    val negloglik: 1.29899    accuracy: 0.8199 lr: [2.8242953648100006e-06]
# epoch 240, train negloglik: 1.29885,    val negloglik: 1.29813    accuracy: 0.8101 lr: [2.8242953648100006e-06]
# epoch 241, train negloglik: 1.29889,    val negloglik: 1.29977    accuracy: 0.8326 lr: [2.5418658283290006e-06]
# epoch 242, train negloglik: 1.30104,    val negloglik: 1.30186    accuracy: 0.8509 lr: [2.5418658283290006e-06]
# epoch 243, train negloglik: 1.29937,    val negloglik: 1.29958    accuracy: 0.8305 lr: [2.5418658283290006e-06]
# epoch 244, train negloglik: 1.29744,    val negloglik: 1.30051    accuracy: 0.8418 lr: [2.5418658283290006e-06]
# epoch 245, train negloglik: 1.29955,    val negloglik: 1.29931    accuracy: 0.8304 lr: [2.5418658283290006e-06]
# epoch 246, train negloglik: 1.30080,    val negloglik: 1.29824    accuracy: 0.8185 lr: [2.5418658283290006e-06]
# epoch 247, train negloglik: 1.29755,    val negloglik: 1.29810    accuracy: 0.8200 lr: [2.5418658283290006e-06]
# epoch 248, train negloglik: 1.29891,    val negloglik: 1.29654    accuracy: 0.7963 lr: [2.5418658283290006e-06]
# epoch 249, train negloglik: 1.29887,    val negloglik: 1.30097    accuracy: 0.8467 lr: [2.5418658283290006e-06]
# epoch 250, train negloglik: 1.30020,    val negloglik: 1.29669    accuracy: 0.8065 lr: [2.5418658283290006e-06]
# epoch 251, train negloglik: 1.29718,    val negloglik: 1.29778    accuracy: 0.8200 lr: [2.5418658283290006e-06]
# epoch 252, train negloglik: 1.29756,    val negloglik: 1.29822    accuracy: 0.8258 lr: [2.5418658283290006e-06]
# epoch 253, train negloglik: 1.29977,    val negloglik: 1.30140    accuracy: 0.8575 lr: [2.5418658283290006e-06]
# epoch 254, train negloglik: 1.29966,    val negloglik: 1.29942    accuracy: 0.8412 lr: [2.5418658283290006e-06]
# epoch 255, train negloglik: 1.29643,    val negloglik: 1.29825    accuracy: 0.8310 lr: [2.5418658283290006e-06]
# epoch 256, train negloglik: 1.29802,    val negloglik: 1.29953    accuracy: 0.8432 lr: [2.5418658283290006e-06]
# epoch 257, train negloglik: 1.29953,    val negloglik: 1.30306    accuracy: 0.8738 lr: [2.5418658283290006e-06]
# epoch 258, train negloglik: 1.29843,    val negloglik: 1.29641    accuracy: 0.8131 lr: [2.5418658283290006e-06]
# epoch 259, train negloglik: 1.29576,    val negloglik: 1.29758    accuracy: 0.8251 lr: [2.5418658283290006e-06]
# epoch 260, train negloglik: 1.29822,    val negloglik: 1.29820    accuracy: 0.8338 lr: [2.5418658283290006e-06]
# epoch 261, train negloglik: 1.29962,    val negloglik: 1.30136    accuracy: 0.8607 lr: [2.2876792454961005e-06]
# epoch 262, train negloglik: 1.29646,    val negloglik: 1.29483    accuracy: 0.8005 lr: [2.2876792454961005e-06]
# epoch 263, train negloglik: 1.29677,    val negloglik: 1.29731    accuracy: 0.8277 lr: [2.2876792454961005e-06]
# epoch 264, train negloglik: 1.29863,    val negloglik: 1.29746    accuracy: 0.8299 lr: [2.2876792454961005e-06]
# epoch 265, train negloglik: 1.29819,    val negloglik: 1.29944    accuracy: 0.8489 lr: [2.2876792454961005e-06]
# epoch 266, train negloglik: 1.29515,    val negloglik: 1.29413    accuracy: 0.7932 lr: [2.2876792454961005e-06]
# epoch 267, train negloglik: 1.29456,    val negloglik: 1.29564    accuracy: 0.8171 lr: [2.2876792454961005e-06]
# epoch 268, train negloglik: 1.29737,    val negloglik: 1.29861    accuracy: 0.8440 lr: [2.2876792454961005e-06]
# epoch 269, train negloglik: 1.29813,    val negloglik: 1.29781    accuracy: 0.8414 lr: [2.2876792454961005e-06]
# epoch 270, train negloglik: 1.29554,    val negloglik: 1.29659    accuracy: 0.8278 lr: [2.2876792454961005e-06]
# epoch 271, train negloglik: 1.29433,    val negloglik: 1.29939    accuracy: 0.8549 lr: [2.2876792454961005e-06]
# epoch 272, train negloglik: 1.29803,    val negloglik: 1.29906    accuracy: 0.8512 lr: [2.2876792454961005e-06]
# epoch 273, train negloglik: 1.29832,    val negloglik: 1.29555    accuracy: 0.8191 lr: [2.2876792454961005e-06]
# epoch 274, train negloglik: 1.29553,    val negloglik: 1.29396    accuracy: 0.8047 lr: [2.2876792454961005e-06]
# epoch 275, train negloglik: 1.29387,    val negloglik: 1.29578    accuracy: 0.8266 lr: [2.2876792454961005e-06]
# epoch 276, train negloglik: 1.29582,    val negloglik: 1.30035    accuracy: 0.8637 lr: [2.2876792454961005e-06]
# epoch 277, train negloglik: 1.29663,    val negloglik: 1.30057    accuracy: 0.8672 lr: [2.2876792454961005e-06]
# epoch 278, train negloglik: 1.29718,    val negloglik: 1.29497    accuracy: 0.8192 lr: [2.2876792454961005e-06]
# epoch 279, train negloglik: 1.29441,    val negloglik: 1.29421    accuracy: 0.8133 lr: [2.2876792454961005e-06]
# epoch 280, train negloglik: 1.29679,    val negloglik: 1.29633    accuracy: 0.8345 lr: [2.2876792454961005e-06]
# epoch 281, train negloglik: 1.29551,    val negloglik: 1.29731    accuracy: 0.8427 lr: [2.0589113209464906e-06]
# epoch 282, train negloglik: 1.29662,    val negloglik: 1.29372    accuracy: 0.8108 lr: [2.0589113209464906e-06]
# epoch 283, train negloglik: 1.29214,    val negloglik: 1.29278    accuracy: 0.7997 lr: [2.0589113209464906e-06]
# epoch 284, train negloglik: 1.29304,    val negloglik: 1.29464    accuracy: 0.8262 lr: [2.0589113209464906e-06]
# epoch 285, train negloglik: 1.29411,    val negloglik: 1.29548    accuracy: 0.8329 lr: [2.0589113209464906e-06]
# epoch 286, train negloglik: 1.29613,    val negloglik: 1.29477    accuracy: 0.8231 lr: [2.0589113209464906e-06]
# epoch 287, train negloglik: 1.29585,    val negloglik: 1.29730    accuracy: 0.8499 lr: [2.0589113209464906e-06]
# epoch 288, train negloglik: 1.29278,    val negloglik: 1.29234    accuracy: 0.8023 lr: [2.0589113209464906e-06]
# epoch 289, train negloglik: 1.29355,    val negloglik: 1.29573    accuracy: 0.8377 lr: [2.0589113209464906e-06]
# epoch 290, train negloglik: 1.29454,    val negloglik: 1.29278    accuracy: 0.8070 lr: [2.0589113209464906e-06]
# epoch 291, train negloglik: 1.29572,    val negloglik: 1.29481    accuracy: 0.8307 lr: [2.0589113209464906e-06]
# epoch 292, train negloglik: 1.29540,    val negloglik: 1.29386    accuracy: 0.8215 lr: [2.0589113209464906e-06]
# epoch 293, train negloglik: 1.29318,    val negloglik: 1.29280    accuracy: 0.8097 lr: [2.0589113209464906e-06]
# epoch 294, train negloglik: 1.29400,    val negloglik: 1.29450    accuracy: 0.8307 lr: [2.0589113209464906e-06]
# epoch 295, train negloglik: 1.29495,    val negloglik: 1.29386    accuracy: 0.8247 lr: [2.0589113209464906e-06]
# epoch 296, train negloglik: 1.29506,    val negloglik: 1.29506    accuracy: 0.8373 lr: [2.0589113209464906e-06]
# epoch 297, train negloglik: 1.29446,    val negloglik: 1.29094    accuracy: 0.7931 lr: [2.0589113209464906e-06]
# epoch 298, train negloglik: 1.29212,    val negloglik: 1.29450    accuracy: 0.8308 lr: [2.0589113209464906e-06]
# epoch 299, train negloglik: 1.29453,    val negloglik: 1.29149    accuracy: 0.8022 lr: [2.0589113209464906e-06]
# epoch 300, train negloglik: 1.29542,    val negloglik: 1.29244    accuracy: 0.8126 lr: [2.0589113209464906e-06]
# epoch 301, train negloglik: 1.29385,    val negloglik: 1.29266    accuracy: 0.8166 lr: [1.8530201888518416e-06]
# epoch 302, train negloglik: 1.29283,    val negloglik: 1.29094    accuracy: 0.7970 lr: [1.8530201888518416e-06]
# epoch 303, train negloglik: 1.29204,    val negloglik: 1.29387    accuracy: 0.8301 lr: [1.8530201888518416e-06]
# epoch 304, train negloglik: 1.29280,    val negloglik: 1.29264    accuracy: 0.8194 lr: [1.8530201888518416e-06]
# epoch 305, train negloglik: 1.29387,    val negloglik: 1.29134    accuracy: 0.8083 lr: [1.8530201888518416e-06]
# epoch 306, train negloglik: 1.29288,    val negloglik: 1.29225    accuracy: 0.8162 lr: [1.8530201888518416e-06]
# epoch 307, train negloglik: 1.29355,    val negloglik: 1.29334    accuracy: 0.8285 lr: [1.8530201888518416e-06]
# epoch 308, train negloglik: 1.29141,    val negloglik: 1.29435    accuracy: 0.8390 lr: [1.8530201888518416e-06]
# epoch 309, train negloglik: 1.29155,    val negloglik: 1.29272    accuracy: 0.8236 lr: [1.8530201888518416e-06]
# epoch 310, train negloglik: 1.29261,    val negloglik: 1.29046    accuracy: 0.7982 lr: [1.8530201888518416e-06]
# epoch 311, train negloglik: 1.29286,    val negloglik: 1.29066    accuracy: 0.8067 lr: [1.8530201888518416e-06]
# epoch 312, train negloglik: 1.29271,    val negloglik: 1.29731    accuracy: 0.8637 lr: [1.8530201888518416e-06]
# epoch 313, train negloglik: 1.29185,    val negloglik: 1.29003    accuracy: 0.8029 lr: [1.8530201888518416e-06]
# epoch 314, train negloglik: 1.29255,    val negloglik: 1.29296    accuracy: 0.8322 lr: [1.8530201888518416e-06]
# epoch 315, train negloglik: 1.29208,    val negloglik: 1.29250    accuracy: 0.8271 lr: [1.8530201888518416e-06]
# epoch 316, train negloglik: 1.29276,    val negloglik: 1.29677    accuracy: 0.8616 lr: [1.8530201888518416e-06]
# epoch 317, train negloglik: 1.29214,    val negloglik: 1.29074    accuracy: 0.8109 lr: [1.8530201888518416e-06]
# epoch 318, train negloglik: 1.29084,    val negloglik: 1.29119    accuracy: 0.8164 lr: [1.8530201888518416e-06]
# epoch 319, train negloglik: 1.29179,    val negloglik: 1.28954    accuracy: 0.8023 lr: [1.8530201888518416e-06]
# epoch 320, train negloglik: 1.29004,    val negloglik: 1.29239    accuracy: 0.8312 lr: [1.8530201888518416e-06]
# epoch 321, train negloglik: 1.29099,    val negloglik: 1.28987    accuracy: 0.8054 lr: [1.6677181699666574e-06]
# epoch 322, train negloglik: 1.29093,    val negloglik: 1.29271    accuracy: 0.8335 lr: [1.6677181699666574e-06]
# epoch 323, train negloglik: 1.29132,    val negloglik: 1.29162    accuracy: 0.8239 lr: [1.6677181699666574e-06]
# epoch 324, train negloglik: 1.28880,    val negloglik: 1.28922    accuracy: 0.8031 lr: [1.6677181699666574e-06]
# epoch 325, train negloglik: 1.29278,    val negloglik: 1.29100    accuracy: 0.8206 lr: [1.6677181699666574e-06]
# epoch 326, train negloglik: 1.29077,    val negloglik: 1.29105    accuracy: 0.8212 lr: [1.6677181699666574e-06]
# epoch 327, train negloglik: 1.29111,    val negloglik: 1.29178    accuracy: 0.8286 lr: [1.6677181699666574e-06]
# epoch 328, train negloglik: 1.28980,    val negloglik: 1.29381    accuracy: 0.8465 lr: [1.6677181699666574e-06]
# epoch 329, train negloglik: 1.29115,    val negloglik: 1.29199    accuracy: 0.8323 lr: [1.6677181699666574e-06]
# epoch 330, train negloglik: 1.28953,    val negloglik: 1.28971    accuracy: 0.8119 lr: [1.6677181699666574e-06]
# epoch 331, train negloglik: 1.29106,    val negloglik: 1.29155    accuracy: 0.8282 lr: [1.6677181699666574e-06]
# epoch 332, train negloglik: 1.28959,    val negloglik: 1.29077    accuracy: 0.8218 lr: [1.6677181699666574e-06]
# epoch 333, train negloglik: 1.28979,    val negloglik: 1.28836    accuracy: 0.7977 lr: [1.6677181699666574e-06]
# epoch 334, train negloglik: 1.28955,    val negloglik: 1.29112    accuracy: 0.8281 lr: [1.6677181699666574e-06]
# epoch 335, train negloglik: 1.29064,    val negloglik: 1.29102    accuracy: 0.8285 lr: [1.6677181699666574e-06]
# epoch 336, train negloglik: 1.28939,    val negloglik: 1.28768    accuracy: 0.7962 lr: [1.6677181699666574e-06]
# epoch 337, train negloglik: 1.29108,    val negloglik: 1.29066    accuracy: 0.8230 lr: [1.6677181699666574e-06]
# epoch 338, train negloglik: 1.28900,    val negloglik: 1.28827    accuracy: 0.7994 lr: [1.6677181699666574e-06]
# epoch 339, train negloglik: 1.28807,    val negloglik: 1.29162    accuracy: 0.8343 lr: [1.6677181699666574e-06]
# epoch 340, train negloglik: 1.28756,    val negloglik: 1.28965    accuracy: 0.8172 lr: [1.6677181699666574e-06]
# epoch 341, train negloglik: 1.28923,    val negloglik: 1.29233    accuracy: 0.8426 lr: [1.5009463529699917e-06]
# epoch 342, train negloglik: 1.28811,    val negloglik: 1.28922    accuracy: 0.8148 lr: [1.5009463529699917e-06]
# epoch 343, train negloglik: 1.29078,    val negloglik: 1.28766    accuracy: 0.7975 lr: [1.5009463529699917e-06]
# epoch 344, train negloglik: 1.28891,    val negloglik: 1.28977    accuracy: 0.8210 lr: [1.5009463529699917e-06]
# epoch 345, train negloglik: 1.28817,    val negloglik: 1.28705    accuracy: 0.7905 lr: [1.5009463529699917e-06]
# epoch 346, train negloglik: 1.28903,    val negloglik: 1.28727    accuracy: 0.7991 lr: [1.5009463529699917e-06]
# epoch 347, train negloglik: 1.28927,    val negloglik: 1.29169    accuracy: 0.8381 lr: [1.5009463529699917e-06]
# epoch 348, train negloglik: 1.29120,    val negloglik: 1.28853    accuracy: 0.8120 lr: [1.5009463529699917e-06]
# epoch 349, train negloglik: 1.28823,    val negloglik: 1.28688    accuracy: 0.7938 lr: [1.5009463529699917e-06]
# epoch 350, train negloglik: 1.28781,    val negloglik: 1.28901    accuracy: 0.8169 lr: [1.5009463529699917e-06]
# epoch 351, train negloglik: 1.28861,    val negloglik: 1.28836    accuracy: 0.8143 lr: [1.5009463529699917e-06]
# epoch 352, train negloglik: 1.28782,    val negloglik: 1.28789    accuracy: 0.8100 lr: [1.5009463529699917e-06]
# epoch 353, train negloglik: 1.28654,    val negloglik: 1.28873    accuracy: 0.8164 lr: [1.5009463529699917e-06]
# epoch 354, train negloglik: 1.29074,    val negloglik: 1.28785    accuracy: 0.8089 lr: [1.5009463529699917e-06]
# epoch 355, train negloglik: 1.28728,    val negloglik: 1.28852    accuracy: 0.8184 lr: [1.5009463529699917e-06]
# epoch 356, train negloglik: 1.28672,    val negloglik: 1.28929    accuracy: 0.8218 lr: [1.5009463529699917e-06]
# epoch 357, train negloglik: 1.28712,    val negloglik: 1.28724    accuracy: 0.8036 lr: [1.5009463529699917e-06]
# epoch 358, train negloglik: 1.28756,    val negloglik: 1.29051    accuracy: 0.8358 lr: [1.5009463529699917e-06]
# epoch 359, train negloglik: 1.28736,    val negloglik: 1.28733    accuracy: 0.8068 lr: [1.5009463529699917e-06]
# epoch 360, train negloglik: 1.28807,    val negloglik: 1.29158    accuracy: 0.8456 lr: [1.5009463529699917e-06]
# epoch 361, train negloglik: 1.28909,    val negloglik: 1.28753    accuracy: 0.8110 lr: [1.3508517176729926e-06]
# epoch 362, train negloglik: 1.28588,    val negloglik: 1.28680    accuracy: 0.8027 lr: [1.3508517176729926e-06]
# epoch 363, train negloglik: 1.28614,    val negloglik: 1.28666    accuracy: 0.8014 lr: [1.3508517176729926e-06]
# epoch 364, train negloglik: 1.28519,    val negloglik: 1.28484    accuracy: 0.7817 lr: [1.3508517176729926e-06]
# epoch 365, train negloglik: 1.28726,    val negloglik: 1.28699    accuracy: 0.8062 lr: [1.3508517176729926e-06]
# epoch 366, train negloglik: 1.28514,    val negloglik: 1.28719    accuracy: 0.8083 lr: [1.3508517176729926e-06]
# epoch 367, train negloglik: 1.28881,    val negloglik: 1.28944    accuracy: 0.8312 lr: [1.3508517176729926e-06]
# epoch 368, train negloglik: 1.28817,    val negloglik: 1.28673    accuracy: 0.8072 lr: [1.3508517176729926e-06]
# epoch 369, train negloglik: 1.28944,    val negloglik: 1.29075    accuracy: 0.8430 lr: [1.3508517176729926e-06]
# epoch 370, train negloglik: 1.28828,    val negloglik: 1.28679    accuracy: 0.8078 lr: [1.3508517176729926e-06]
# epoch 371, train negloglik: 1.28512,    val negloglik: 1.28604    accuracy: 0.8021 lr: [1.3508517176729926e-06]
# epoch 372, train negloglik: 1.28403,    val negloglik: 1.28476    accuracy: 0.7873 lr: [1.3508517176729926e-06]
# epoch 373, train negloglik: 1.28703,    val negloglik: 1.28613    accuracy: 0.8038 lr: [1.3508517176729926e-06]
# epoch 374, train negloglik: 1.28379,    val negloglik: 1.28929    accuracy: 0.8324 lr: [1.3508517176729926e-06]
# epoch 375, train negloglik: 1.28623,    val negloglik: 1.28460    accuracy: 0.7878 lr: [1.3508517176729926e-06]
# epoch 376, train negloglik: 1.28559,    val negloglik: 1.28553    accuracy: 0.7988 lr: [1.3508517176729926e-06]
# epoch 377, train negloglik: 1.28660,    val negloglik: 1.28886    accuracy: 0.8301 lr: [1.3508517176729926e-06]
# epoch 378, train negloglik: 1.28862,    val negloglik: 1.28630    accuracy: 0.8060 lr: [1.3508517176729926e-06]
# epoch 379, train negloglik: 1.28689,    val negloglik: 1.28557    accuracy: 0.8001 lr: [1.3508517176729926e-06]
# epoch 380, train negloglik: 1.28434,    val negloglik: 1.28734    accuracy: 0.8202 lr: [1.3508517176729926e-06]
# epoch 381, train negloglik: 1.28557,    val negloglik: 1.28520    accuracy: 0.7994 lr: [1.2157665459056933e-06]
# epoch 382, train negloglik: 1.28440,    val negloglik: 1.28518    accuracy: 0.8002 lr: [1.2157665459056933e-06]
# epoch 383, train negloglik: 1.28615,    val negloglik: 1.28684    accuracy: 0.8197 lr: [1.2157665459056933e-06]
# epoch 384, train negloglik: 1.28401,    val negloglik: 1.28579    accuracy: 0.8060 lr: [1.2157665459056933e-06]
# epoch 385, train negloglik: 1.28433,    val negloglik: 1.28813    accuracy: 0.8259 lr: [1.2157665459056933e-06]
# epoch 386, train negloglik: 1.28715,    val negloglik: 1.28681    accuracy: 0.8168 lr: [1.2157665459056933e-06]
# epoch 387, train negloglik: 1.28723,    val negloglik: 1.28515    accuracy: 0.8022 lr: [1.2157665459056933e-06]
# epoch 388, train negloglik: 1.28763,    val negloglik: 1.28866    accuracy: 0.8355 lr: [1.2157665459056933e-06]
# epoch 389, train negloglik: 1.28697,    val negloglik: 1.28713    accuracy: 0.8184 lr: [1.2157665459056933e-06]
# epoch 390, train negloglik: 1.28535,    val negloglik: 1.28645    accuracy: 0.8163 lr: [1.2157665459056933e-06]
# epoch 391, train negloglik: 1.28631,    val negloglik: 1.28619    accuracy: 0.8159 lr: [1.2157665459056933e-06]
# epoch 392, train negloglik: 1.28445,    val negloglik: 1.28536    accuracy: 0.8094 lr: [1.2157665459056933e-06]
# epoch 393, train negloglik: 1.28475,    val negloglik: 1.28487    accuracy: 0.8017 lr: [1.2157665459056933e-06]
# epoch 394, train negloglik: 1.28349,    val negloglik: 1.28348    accuracy: 0.7903 lr: [1.2157665459056933e-06]
# epoch 395, train negloglik: 1.28454,    val negloglik: 1.28478    accuracy: 0.8044 lr: [1.2157665459056933e-06]
# epoch 396, train negloglik: 1.28663,    val negloglik: 1.28603    accuracy: 0.8185 lr: [1.2157665459056933e-06]
# epoch 397, train negloglik: 1.28596,    val negloglik: 1.29063    accuracy: 0.8533 lr: [1.2157665459056933e-06]
# epoch 398, train negloglik: 1.28752,    val negloglik: 1.28557    accuracy: 0.8109 lr: [1.2157665459056933e-06]
# epoch 399, train negloglik: 1.28418,    val negloglik: 1.28714    accuracy: 0.8265 lr: [1.2157665459056933e-06]
# Test MSE: 0.892925
# Test RMSE: 0.944947
# Residual Statistics:
# Mean: 0.325722
# Std: 0.887034
# Min: -0.895099
# Max: 1.385029
# plot completed

# %% [markdown]
# ## 2-3.結果評価
# 以下の項目に従ってカーネル行列の分析結果をまとめる：
#
# **カーネル行列分析項目**
# - 各層のカーネル行列ランクと条件数の分析
# - 誘導点の分布と配置の可視化
# - カーネル行列のヒートマップ（Jitter項適用前後）
# - 固有値分布の分析
# - 誘導点間距離の統計的分析

# %%
# 1層目
model.layers[0].save_fig("./outputs/layer_fused0.png")
model.layers[1].save_fig("./outputs/layer_fused1.png")

# %%
# カーネル行列のランク可視化・分析
import matplotlib.pyplot as plt
import numpy as np
import torch


def analyze_kernel_matrices(model):
    """
    GP-KANの各層のカーネル行列ランクと条件数を分析・可視化する
    """
    print("=== カーネル行列分析 ===")

    # 各層の分析
    for layer_idx, layer in enumerate(model.layers):
        print(f"\n--- Layer {layer_idx} ---")

        # 誘導点を取得
        z_range = layer.get_z().detach()  # 入力値
        h_range = layer.h.detach()  # 出力値
        jitter = layer.get_jitter().detach()  # Shape: [1, 1]
        print(
            f"z(誘導点)の範囲: [{z_range.min().item():.4f}, {z_range.max().item():.4f}]"
        )
        print(
            f"h(関数値)の範囲: [{h_range.min().item():.4f}, {h_range.max().item():.4f}]"
        )

        # カーネル行列を計算
        with torch.no_grad():
            # カーネル行列を計算
            lengthscale = layer.l.detach()  # Shape: [1, 1]
            variance = layer.s.detach()  # Shape: [1, 1]

            # Set i=j=1 for processing (assuming we want the first GP component)
            i, j = 0, 0  # Using 0-based indexing for tensor access

            # Get parameters for this specific GP
            z_ij = z_range[i, j, :]  # Shape: [X]
            l_ij = lengthscale[i, j]  # Scalar
            s_ij = variance[i, j]  # Scalar

            # Reshape inducing points for distance computation
            z_ij = z_ij.unsqueeze(1)  # Shape: [X, 1]

            # Compute kernel matrix for this GP
            pairwise_sq_dists = torch.cdist(z_ij, z_ij, p=2) ** 2
            # 誘導点間のカーネル行列
            K = s_ij * torch.exp(-pairwise_sq_dists / (2 * l_ij**2))

            print("計算開始")
            # ランク計算
            rank_clean = torch.linalg.matrix_rank(K)

            # 条件数計算
            cond_clean = torch.linalg.cond(K)

            # 固有値
            eigenvals_clean = torch.linalg.eigvals(K).real

            print("計算完了")

            print(f"カーネル行列ランク: {rank_clean.item()}")
            print(f"条件数: {cond_clean.item():.2e}")
            print(f"最小固有値: {eigenvals_clean.min().item():.2e}")
            print(
                f"パラメータ値 - s_ij: {s_ij.item():.4f}, l_ij: {l_ij.item():.4f}, jitter: {jitter.item():.4f}"
            )

        # 可視化
        fig, axes = plt.subplots(2, 3, figsize=(15, 10))

        # 誘導点の分布
        axes[0, 0].scatter(
            z_range.numpy(),
            h_range.numpy(),
            alpha=0.7,
            s=50,
        )
        axes[0, 0].set_title(f"Layer {layer_idx}: 誘導点分布")
        axes[0, 0].set_xlabel("誘導点位置")
        axes[0, 0].grid(True, alpha=0.3)

        # カーネル行列のヒートマップ
        im1 = axes[0, 1].imshow(K.numpy(), cmap="viridis")
        axes[0, 1].set_title(f"カーネル行列\nRank: {rank_clean.item()}")
        plt.colorbar(im1, ax=axes[0, 1])

        # パラメータ値のプロット
        params = ["s", "l", "jitter"]
        values = [s_ij.item(), l_ij.item(), jitter.item()]
        axes[0, 2].bar(params, values)
        axes[0, 2].set_title("パラメータ値")
        axes[0, 2].set_ylabel("値")
        for i, v in enumerate(values):
            axes[0, 2].text(i, v, f"{v:.4f}", ha="center", va="bottom")

        # 固有値分布
        eigenvals_sorted = torch.sort(eigenvals_clean, descending=True)[0]
        axes[1, 0].semilogy(eigenvals_sorted.numpy(), "o-")
        axes[1, 0].set_title("固有値分布")
        axes[1, 0].set_xlabel("固有値インデックス")
        axes[1, 0].set_ylabel("固有値 (log scale)")
        axes[1, 0].grid(True, alpha=0.3)

        # 条件数とランクの可視化
        metrics = ["Rank", "Condition Number (log)"]
        metric_values = [rank_clean.item(), np.log10(cond_clean.item())]
        axes[1, 1].bar(metrics, metric_values)
        axes[1, 1].set_title("行列特性")
        axes[1, 1].set_ylabel("値")
        for i, v in enumerate(metric_values):
            if i == 0:
                axes[1, 1].text(i, v, f"{int(v)}", ha="center", va="bottom")
            else:
                axes[1, 1].text(i, v, f"{v:.2f}", ha="center", va="bottom")

        # パラメータ値の詳細プロット（対数スケール）
        axes[1, 2].bar(params, np.log10(np.abs(values)))
        axes[1, 2].set_title("パラメータ値 (log10)")
        axes[1, 2].set_ylabel("log10(値)")
        for i, v in enumerate(values):
            axes[1, 2].text(i, np.log10(abs(v)), f"{v:.4f}", ha="center", va="bottom")

        plt.tight_layout()
        plt.show()

        # 誘導点間の距離分析
        distances = torch.cdist(z_ij.unsqueeze(0), z_ij.unsqueeze(0)).squeeze(
            0
        )  # Shape: [X, X]
        min_dist = distances[distances > 0].min()
        max_dist = distances[distances > 0].max()
        mean_dist = distances[distances > 0].mean()

        print(
            f"誘導点間距離 - 最小: {min_dist.item():.4f}, 最大: {max_dist.item():.4f}, 平均: {mean_dist.item():.4f}"
        )

        # 距離分布のヒストグラム
        plt.figure(figsize=(10, 6))
        dist_flat = distances[distances > 0].numpy()
        plt.hist(dist_flat, bins=20, alpha=0.7, edgecolor="black")
        plt.axvline(
            min_dist.item(),
            color="red",
            linestyle="--",
            label=f"最小距離: {min_dist.item():.4f}",
        )
        plt.axvline(
            mean_dist.item(),
            color="green",
            linestyle="--",
            label=f"平均距離: {mean_dist.item():.4f}",
        )
        plt.xlabel("誘導点間距離")
        plt.ylabel("頻度")
        plt.title(f"Layer {layer_idx}: 誘導点間距離分布")
        plt.legend()
        plt.grid(True, alpha=0.3)
        plt.show()


# 実行
analyze_kernel_matrices(model)
# Out:
# === カーネル行列分析 ===
#
# --- Layer 0 ---
# z(誘導点)の範囲: [-1.0000, 1.0000]
# h(関数値)の範囲: [-0.9857, 2.0776]
# 計算開始
# 計算完了
# カーネル行列ランク: 3
# 条件数: 1.17e+17
# 最小固有値: -2.13e+01
# パラメータ値 - s_ij: -2.1901, l_ij: 5.4097, jitter: 0.0047
# 誘導点間距離 - 最小: 0.0000, 最大: 2.0000, 平均: 1.1124
# --- Layer 1 ---
# z(誘導点)の範囲: [-1.0000, 1.0000]
# h(関数値)の範囲: [-0.4432, 1.0181]
# 計算開始
# 計算完了
# カーネル行列ランク: 4
# 条件数: 2.76e+09
# 最小固有値: -6.56e-08
# パラメータ値 - s_ij: 0.7532, l_ij: -3.8382, jitter: 0.0025
# 誘導点間距離 - 最小: 0.0002, 最大: 2.0000, 平均: 1.0184

# %% [markdown]
# ### 考察
# 第一層の誘導点が端点に集中してしまった
#
# →GLOBAL_JITTER: s,lが発散してしまったため学習がうまくいかなかったと考えられる。一方カーネル行列(ノイズ項付き)は正則性が維持され、パラメータ更新処理自体は動作した。

# %% [markdown]
# # GP-KANの学習安定化方法調査: ベースライン

# %% [markdown]
# ## 0.背景/目的
# GP-KANの学習(誘導点・カーネルパラメータの同時学習)時、処理がうまくいかない現象が発生していた。
#
# 原因として考えられるのは以下の通り：
#
# * a. バッチサイズが小さいことで、ミニバッチデータに偏りが生じる
# * b. カーネル行列のJitter項が大きい※1ため、出力層以外の誘導点が縦に並んでいる(x軸:入力,y軸:中間層出力)
# * c. 損失関数(負の対数尤度)は誘導点が近いほど小さい値を取るため、カーネル行列が縮退しやすい
#
# ※1. 関数値を取る確率変数 $f\sim GP(m(\cdot),k(\cdot, \cdot))$ と独立なノイズが多く含まれることに相当する。
# ここで、GPの出力 $y$ に対して
# $$
# y = f(x)+\epsilon,\ \ \  \epsilon\sim \mathcal{N}(0, \sigma_\epsilon^2)
# $$
#
# そのため、以下の追加実験を行いGP-KANの学習が安定しない原因のあたりをつける。
#
# * a. バッチサイズ(現在32; 学習データ全体750件)を大きくする
# * b. Jitter項のパラメータ設定値を小さくして学習実行
# * c. 誘導点が近づかないようなペナルティ項入れて学習
#
# 本notebookでは、baselineとして02のnotebookに基本準拠した以下の設定で学習を行い結果を評価する：
# ### モデル構成
# - **ネットワーク構造**: 2層GP-KAN (入力1次元 → 中間層1次元 → 出力1次元)
# - **誘導点数**: 各GPあたり10点
# - **GP構成**: (0,0), (1,0) の2つのガウス過程
#
# ### 学習パラメータ
# - **エポック数**: 400エポック→可視化する数が多すぎて分かりづらくなっていたので、まとめて結果表示
# - **学習率**: 1e-4
# - **バッチサイズ**: 32
# - **事前学習**: 無効 (pretrain=False)
#
# ### 正則化パラメータ
# - **global_jitter**: 1e-3
# - **baseline_jitter**: 1e-3

# %%
JITTER_VALUE = 1e-3  # Jitter項の値

# %%
SAVELOAD_PATH = "model_12__0.pt"

# %% [markdown]
# ## 1.問題設定
#
# 真の関数: フーリエ級数
# $$f(t) = \frac{4}{\pi} \sum_{n=1}^{N} \frac{1}{n} \sin(nt), \quad n = 1, 3, 5, \ldots, \quad t \in [0, 1]$$
# ※$N=15$
#
# データ:
# - 合計1,000件: 学習700件/検証150件/評価150件
# - tは$(-1,1)$から一様ランダムサンプリング
#
# モデル:
# - 2層のGPKAN: 入力1次元/中間層1次元/出力1次元
#     - それぞれのGPを(<1層目のindex>,<2層目のindex>)形式で表すことにすると、GPKANは$(0,0),(1,0)$の2つのGPで構成

# %% [markdown]
# ## 2.メイン処理
# 本ノートブックのメイン処理を実行する。実行順は以下の通り：
#
# 2-1.データセット作成
#
# 2-2.GPKANの学習
#
# 2-3.精度評価
#
# 2-4.学習中のカーネル行列ランク可視化

# %% [markdown]
# ### 2-1.データセット作成

# %%
# 初期設定: 必要なライブラリをインポートし、パスを設定
import os
import sys

sys.path.append("../")
import japanize_matplotlib
import torch.utils.data
from lib import model as gplib
from lib import runner
from torch.utils.data import DataLoader

# %%
import random

import matplotlib.pyplot as plt
import numpy as np
import torch
from torch.utils.data import DataLoader, TensorDataset


# Generate synthetic data with Fourier series function
def set_seed(seed=42):
    """完全な再現性のための乱数シード設定"""
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)


def worker_init_fn(worker_id):
    """DataLoaderワーカープロセス用の乱数シード設定"""
    worker_seed = torch.initial_seed() % 2**32
    np.random.seed(worker_seed)
    random.seed(worker_seed)


set_seed(42)  # 全体の乱数シード設定
num_samples = 1000

# Generate random input points t from [-1, 1]
t = np.random.uniform(-1, 1, num_samples)


# Compute target values: f(t) = (4/π) * Σ(1/n * sin(nt)) for odd n up to N=15
def fourier_series(t, N=15):
    result = np.zeros_like(t)
    for n in range(1, N + 1, 2):  # odd numbers only: 1, 3, 5, 7, 9, 11, 13, 15
        result += (1 / n) * np.sin(n * t)
    return (4 / np.pi) * result


targets = fourier_series(t, N=15)

# Reshape inputs (t is 1D, but we need it as 2D for compatibility)
inputs = t.reshape(-1, 1)

# Convert to PyTorch tensors
X_tensor = torch.FloatTensor(inputs)
y_tensor = torch.FloatTensor(targets).reshape(-1, 1)

# Split data into train, validation, and test sets
train_size = int(0.7 * num_samples)
val_size = int(0.15 * num_samples)
test_size = num_samples - train_size - val_size

X_train = X_tensor[:train_size]
y_train = y_tensor[:train_size]

X_val = X_tensor[train_size : train_size + val_size]
y_val = y_tensor[train_size : train_size + val_size]

X_test = X_tensor[train_size + val_size :]
y_test = y_tensor[train_size + val_size :]

# データを昇順にソート（X_testとy_testを対応を保ちながら）
sorted_indices = torch.argsort(X_test.squeeze())
X_test = X_test[sorted_indices]
y_test = y_test[sorted_indices]

# Create datasets
train_dataset = TensorDataset(X_train, y_train)
val_dataset = TensorDataset(X_val, y_val)
test_dataset = TensorDataset(X_test, y_test)

# Create dataloaders
batch_size = 32

# %%
# Create dataloaders with reproducible worker processes
generator = torch.Generator()
generator.manual_seed(42)

train_dataloader = DataLoader(
    train_dataset,
    batch_size=batch_size,
    shuffle=True,
    num_workers=0,  # Single process for reproducibility
    worker_init_fn=worker_init_fn,
    generator=generator,
)
val_dataloader = DataLoader(
    val_dataset,
    batch_size=batch_size,
    shuffle=False,
    num_workers=0,  # Single process for reproducibility
    worker_init_fn=worker_init_fn,
    generator=generator,
)
test_dataloader = DataLoader(
    test_dataset,
    batch_size=batch_size,
    shuffle=False,
    num_workers=0,  # Single process for reproducibility
    worker_init_fn=worker_init_fn,
    generator=generator,
)

# %%
# サンプル数確認
print(f"Train samples: {len(train_dataset)}")
print(f"Validation samples: {len(val_dataset)}")
print(f"Test samples: {len(test_dataset)}")

# Fourier級数関数のプロット
t_plot = np.linspace(-1, 1, 1000)
y_plot = fourier_series(t_plot, N=15)
plt.figure(figsize=(10, 6))
plt.plot(t_plot, y_plot, "b-", label="Fourier Series (N=15)")
plt.scatter(t, targets, alpha=0.3, s=3, c="red", label="Training Data")
plt.xlabel("t")
plt.ylabel("f(t)")
plt.title("Fourier Series Function")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Train samples: 700
# Validation samples: 150
# Test samples: 150

# %%
# y（目的変数）の分布をヒストグラムで可視化
plt.figure(figsize=(15, 10))


# 学習データのヒストグラム
plt.subplot(1, 1, 1)
plt.hist(
    y_train.numpy().flatten(), bins=30, alpha=0.7, color="green", edgecolor="black"
)
plt.xlabel("y (target values)")
plt.ylabel("Frequency")
plt.title("Training Data Distribution")
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()


# 値の分布特性
print(f"\n=== 値の分布特性 ===")
print(f"正の値の割合: {np.sum(targets > 0) / len(targets) * 100:.1f}%")
print(f"負の値の割合: {np.sum(targets < 0) / len(targets) * 100:.1f}%")
print(
    f"ゼロ近傍(-0.1 < y < 0.1)の割合: {np.sum(np.abs(targets) < 0.1) / len(targets) * 100:.1f}%"
)
# Out:
# === 値の分布特性 ===
# 正の値の割合: 49.7%
# 負の値の割合: 50.3%
# ゼロ近傍(-0.1 < y < 0.1)の割合: 1.3%

# %% [markdown]
# ### 2-2.モデル学習

# %%
num_gp_pts = 10  # Number of Gaussian Process points
model = gplib.GP_Model(
    [
        gplib.LayerFused(1, 1, num_gp_pts),
        gplib.LayerFused(1, 1, num_gp_pts),
    ],
    saveload_path=SAVELOAD_PATH,  # Path to save/load the model
)
np.random.seed(42)  # for reproducibility
torch.manual_seed(42)  # for reproducibility

# %%
# 精度評価/可視化関数
def plot_result(model):
    # テストデータでの予測
    with torch.no_grad():
        # バッチごとに予測を行う
        test_predictions = []
        test_targets = []
        test_variances = []

        for X_batch, y_batch in test_dataloader:
            pred = model.predict(X_batch).mean
            var = model.predict(X_batch).var
            test_predictions.append(pred)
            test_variances.append(var)
            test_targets.append(y_batch)

        # 結果を結合
        test_predictions = torch.cat(test_predictions, dim=0)
        test_targets = torch.cat(test_targets, dim=0)
        test_variances = torch.cat(test_variances, dim=0)

    # MSE計算
    mse = torch.mean((test_predictions - test_targets) ** 2)
    rmse = torch.sqrt(mse)

    print(f"Test MSE: {mse.item():.6f}")
    print(f"Test RMSE: {rmse.item():.6f}")

    # 可視化用のデータ準備
    t_test = X_test.numpy().flatten()
    y_test_true = y_test.numpy().flatten()
    y_test_pred = test_predictions.numpy().flatten()

    # 真の関数の連続プロット用
    t_continuous = np.linspace(-1, 1, 500)
    y_continuous = fourier_series(t_continuous, N=15)

    # グラフ作成
    plt.figure(figsize=(12, 8))

    # 真の関数
    plt.plot(
        t_continuous,
        y_continuous,
        "b-",
        linewidth=2,
        label="True Function (Fourier Series)",
        alpha=0.8,
    )

    # テストデータの真値
    plt.scatter(
        t_test,
        y_test_true,
        c="red",
        s=30,
        alpha=0.6,
        label="Test Data (True)",
        marker="o",
    )

    # 予測値
    plt.scatter(
        t_test, y_test_pred, c="green", s=30, alpha=0.6, label="Predictions", marker="x"
    )

    # 予測の不確実性を帯で表示
    lower_bound = y_test_pred - 2 * np.sqrt(test_variances.numpy().flatten())
    upper_bound = y_test_pred + 2 * np.sqrt(test_variances.numpy().flatten())
    plt.fill_between(
        t_test,
        lower_bound,
        upper_bound,
        color="lightgreen",
        alpha=0.3,
        label="Prediction Interval(2σ)",
    )

    plt.xlabel("t")
    plt.ylabel("f(t)")
    plt.title(f"GP-KAN Prediction vs True Function\nTest RMSE: {rmse.item():.6f}")
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.show()

    # 残差プロット
    plt.figure(figsize=(10, 6))
    residuals = y_test_pred - y_test_true
    plt.scatter(t_test, residuals, c="purple", s=30, alpha=0.6)
    plt.axhline(y=0, color="red", linestyle="--", alpha=0.7)
    plt.xlabel("t")
    plt.ylabel("Residuals (Predicted - True)")
    plt.title("Residual Plot")
    plt.grid(True, alpha=0.3)
    plt.show()

    # 残差の統計情報
    print(f"\nResidual Statistics:")
    print(f"Mean: {np.mean(residuals):.6f}")
    print(f"Std: {np.std(residuals):.6f}")
    print(f"Min: {np.min(residuals):.6f}")
    print(f"Max: {np.max(residuals):.6f}")

    print("plot completed")
    return 0

# %%
for epoch in range(1):
    runner.train_model(
        train_dataloader,
        val_dataloader,
        model,
        epochs=400,
        learning_rate=1e-4,
        use_gpu=False,  # True,
        pretrain=False,  # True,
        global_jitter=JITTER_VALUE,
        baseline_jitter=JITTER_VALUE,
    )
    model.save_model()  # optionally save the model after training

    # 可視化
    plot_result(model)
# Out:
# epoch 0  , train negloglik: 214.68653,    val negloglik: 1.87109    accuracy: 1.1675 lr: [0.0001]
# epoch 1  , train negloglik: 1.95193,    val negloglik: 1.99843    accuracy: 0.9785 lr: [9e-05]
# epoch 2  , train negloglik: 1.99702,    val negloglik: 1.99467    accuracy: 0.9787 lr: [9e-05]
# epoch 3  , train negloglik: 1.98722,    val negloglik: 1.98174    accuracy: 0.9787 lr: [9e-05]
# epoch 4  , train negloglik: 1.97371,    val negloglik: 1.96803    accuracy: 0.9787 lr: [9e-05]
# epoch 5  , train negloglik: 1.95997,    val negloglik: 1.95439    accuracy: 0.9787 lr: [9e-05]
# epoch 6  , train negloglik: 1.94635,    val negloglik: 1.94091    accuracy: 0.9787 lr: [9e-05]
# epoch 7  , train negloglik: 1.93288,    val negloglik: 1.92758    accuracy: 0.9787 lr: [9e-05]
# epoch 8  , train negloglik: 1.91957,    val negloglik: 1.91441    accuracy: 0.9787 lr: [9e-05]
# epoch 9  , train negloglik: 1.90643,    val negloglik: 1.90140    accuracy: 0.9787 lr: [9e-05]
# epoch 10 , train negloglik: 1.89343,    val negloglik: 1.88857    accuracy: 0.9787 lr: [9e-05]
# epoch 11 , train negloglik: 1.88064,    val negloglik: 1.87588    accuracy: 0.9787 lr: [9e-05]
# epoch 12 , train negloglik: 1.86797,    val negloglik: 1.86339    accuracy: 0.9786 lr: [9e-05]
# epoch 13 , train negloglik: 1.85549,    val negloglik: 1.85107    accuracy: 0.9786 lr: [9e-05]
# epoch 14 , train negloglik: 1.84320,    val negloglik: 1.83891    accuracy: 0.9786 lr: [9e-05]
# epoch 15 , train negloglik: 1.83107,    val negloglik: 1.82693    accuracy: 0.9786 lr: [9e-05]
# epoch 16 , train negloglik: 1.81911,    val negloglik: 1.81516    accuracy: 0.9786 lr: [9e-05]
# epoch 17 , train negloglik: 1.80736,    val negloglik: 1.80353    accuracy: 0.9786 lr: [9e-05]
# epoch 18 , train negloglik: 1.79576,    val negloglik: 1.79211    accuracy: 0.9786 lr: [9e-05]
# epoch 19 , train negloglik: 1.78435,    val negloglik: 1.78088    accuracy: 0.9786 lr: [9e-05]
# epoch 20 , train negloglik: 1.77314,    val negloglik: 1.76983    accuracy: 0.9786 lr: [9e-05]
# epoch 21 , train negloglik: 1.76263,    val negloglik: 1.76004    accuracy: 0.9786 lr: [8.1e-05]
# epoch 22 , train negloglik: 1.75285,    val negloglik: 1.75041    accuracy: 0.9786 lr: [8.1e-05]
# epoch 23 , train negloglik: 1.74323,    val negloglik: 1.74095    accuracy: 0.9785 lr: [8.1e-05]
# epoch 24 , train negloglik: 1.73378,    val negloglik: 1.73162    accuracy: 0.9786 lr: [8.1e-05]
# epoch 25 , train negloglik: 1.72446,    val negloglik: 1.72247    accuracy: 0.9785 lr: [8.1e-05]
# epoch 26 , train negloglik: 1.71531,    val negloglik: 1.71347    accuracy: 0.9785 lr: [8.1e-05]
# epoch 27 , train negloglik: 1.70632,    val negloglik: 1.70463    accuracy: 0.9785 lr: [8.1e-05]
# epoch 28 , train negloglik: 1.69749,    val negloglik: 1.69594    accuracy: 0.9785 lr: [8.1e-05]
# epoch 29 , train negloglik: 1.68879,    val negloglik: 1.68745    accuracy: 0.9785 lr: [8.1e-05]
# epoch 30 , train negloglik: 1.68029,    val negloglik: 1.67906    accuracy: 0.9785 lr: [8.1e-05]
# epoch 31 , train negloglik: 1.67193,    val negloglik: 1.67086    accuracy: 0.9785 lr: [8.1e-05]
# epoch 32 , train negloglik: 1.66373,    val negloglik: 1.66281    accuracy: 0.9785 lr: [8.1e-05]
# epoch 33 , train negloglik: 1.65569,    val negloglik: 1.65492    accuracy: 0.9785 lr: [8.1e-05]
# epoch 34 , train negloglik: 1.64780,    val negloglik: 1.64720    accuracy: 0.9785 lr: [8.1e-05]
# epoch 35 , train negloglik: 1.64007,    val negloglik: 1.63965    accuracy: 0.9785 lr: [8.1e-05]
# epoch 36 , train negloglik: 1.63251,    val negloglik: 1.63226    accuracy: 0.9785 lr: [8.1e-05]
# epoch 37 , train negloglik: 1.62512,    val negloglik: 1.62501    accuracy: 0.9785 lr: [8.1e-05]
# epoch 38 , train negloglik: 1.61787,    val negloglik: 1.61792    accuracy: 0.9785 lr: [8.1e-05]
# epoch 39 , train negloglik: 1.61076,    val negloglik: 1.61102    accuracy: 0.9785 lr: [8.1e-05]
# epoch 40 , train negloglik: 1.60386,    val negloglik: 1.60423    accuracy: 0.9785 lr: [8.1e-05]
# epoch 41 , train negloglik: 1.59739,    val negloglik: 1.59828    accuracy: 0.9785 lr: [7.290000000000001e-05]
# epoch 42 , train negloglik: 1.59142,    val negloglik: 1.59245    accuracy: 0.9785 lr: [7.290000000000001e-05]
# epoch 43 , train negloglik: 1.58557,    val negloglik: 1.58677    accuracy: 0.9785 lr: [7.290000000000001e-05]
# epoch 44 , train negloglik: 1.57987,    val negloglik: 1.58119    accuracy: 0.9785 lr: [7.290000000000001e-05]
# epoch 45 , train negloglik: 1.57428,    val negloglik: 1.57573    accuracy: 0.9785 lr: [7.290000000000001e-05]
# epoch 46 , train negloglik: 1.56881,    val negloglik: 1.57041    accuracy: 0.9785 lr: [7.290000000000001e-05]
# epoch 47 , train negloglik: 1.56347,    val negloglik: 1.56521    accuracy: 0.9785 lr: [7.290000000000001e-05]
# epoch 48 , train negloglik: 1.55825,    val negloglik: 1.56013    accuracy: 0.9785 lr: [7.290000000000001e-05]
# epoch 49 , train negloglik: 1.55315,    val negloglik: 1.55516    accuracy: 0.9784 lr: [7.290000000000001e-05]
# epoch 50 , train negloglik: 1.54817,    val negloglik: 1.55032    accuracy: 0.9784 lr: [7.290000000000001e-05]
# epoch 51 , train negloglik: 1.54330,    val negloglik: 1.54561    accuracy: 0.9784 lr: [7.290000000000001e-05]
# epoch 52 , train negloglik: 1.53857,    val negloglik: 1.54100    accuracy: 0.9784 lr: [7.290000000000001e-05]
# epoch 53 , train negloglik: 1.53393,    val negloglik: 1.53652    accuracy: 0.9784 lr: [7.290000000000001e-05]
# epoch 54 , train negloglik: 1.52943,    val negloglik: 1.53215    accuracy: 0.9784 lr: [7.290000000000001e-05]
# epoch 55 , train negloglik: 1.52503,    val negloglik: 1.52788    accuracy: 0.9784 lr: [7.290000000000001e-05]
# epoch 56 , train negloglik: 1.52074,    val negloglik: 1.52373    accuracy: 0.9784 lr: [7.290000000000001e-05]
# epoch 57 , train negloglik: 1.51656,    val negloglik: 1.51970    accuracy: 0.9784 lr: [7.290000000000001e-05]
# epoch 58 , train negloglik: 1.51250,    val negloglik: 1.51577    accuracy: 0.9784 lr: [7.290000000000001e-05]
# epoch 59 , train negloglik: 1.50854,    val negloglik: 1.51196    accuracy: 0.9784 lr: [7.290000000000001e-05]
# epoch 60 , train negloglik: 1.50469,    val negloglik: 1.50824    accuracy: 0.9784 lr: [7.290000000000001e-05]
# epoch 61 , train negloglik: 1.50113,    val negloglik: 1.50498    accuracy: 0.9784 lr: [6.561000000000002e-05]
# epoch 62 , train negloglik: 1.49783,    val negloglik: 1.50182    accuracy: 0.9784 lr: [6.561000000000002e-05]
# epoch 63 , train negloglik: 1.49464,    val negloglik: 1.49872    accuracy: 0.9784 lr: [6.561000000000002e-05]
# epoch 64 , train negloglik: 1.49151,    val negloglik: 1.49571    accuracy: 0.9784 lr: [6.561000000000002e-05]
# epoch 65 , train negloglik: 1.48848,    val negloglik: 1.49278    accuracy: 0.9784 lr: [6.561000000000002e-05]
# epoch 66 , train negloglik: 1.48551,    val negloglik: 1.48994    accuracy: 0.9784 lr: [6.561000000000002e-05]
# epoch 67 , train negloglik: 1.48263,    val negloglik: 1.48716    accuracy: 0.9784 lr: [6.561000000000002e-05]
# epoch 68 , train negloglik: 1.47983,    val negloglik: 1.48446    accuracy: 0.9784 lr: [6.561000000000002e-05]
# epoch 69 , train negloglik: 1.47709,    val negloglik: 1.48186    accuracy: 0.9784 lr: [6.561000000000002e-05]
# epoch 70 , train negloglik: 1.47444,    val negloglik: 1.47930    accuracy: 0.9784 lr: [6.561000000000002e-05]
# epoch 71 , train negloglik: 1.47185,    val negloglik: 1.47683    accuracy: 0.9784 lr: [6.561000000000002e-05]
# epoch 72 , train negloglik: 1.46934,    val negloglik: 1.47442    accuracy: 0.9784 lr: [6.561000000000002e-05]
# epoch 73 , train negloglik: 1.46689,    val negloglik: 1.47209    accuracy: 0.9784 lr: [6.561000000000002e-05]
# epoch 74 , train negloglik: 1.46452,    val negloglik: 1.46981    accuracy: 0.9784 lr: [6.561000000000002e-05]
# epoch 75 , train negloglik: 1.46221,    val negloglik: 1.46761    accuracy: 0.9784 lr: [6.561000000000002e-05]
# epoch 76 , train negloglik: 1.45998,    val negloglik: 1.46546    accuracy: 0.9784 lr: [6.561000000000002e-05]
# epoch 77 , train negloglik: 1.45779,    val negloglik: 1.46340    accuracy: 0.9784 lr: [6.561000000000002e-05]
# epoch 78 , train negloglik: 1.45570,    val negloglik: 1.46137    accuracy: 0.9784 lr: [6.561000000000002e-05]
# epoch 79 , train negloglik: 1.45363,    val negloglik: 1.45944    accuracy: 0.9784 lr: [6.561000000000002e-05]
# epoch 80 , train negloglik: 1.45164,    val negloglik: 1.45756    accuracy: 0.9784 lr: [6.561000000000002e-05]
# epoch 81 , train negloglik: 1.44982,    val negloglik: 1.45590    accuracy: 0.9784 lr: [5.904900000000002e-05]
# epoch 82 , train negloglik: 1.44813,    val negloglik: 1.45429    accuracy: 0.9784 lr: [5.904900000000002e-05]
# epoch 83 , train negloglik: 1.44649,    val negloglik: 1.45272    accuracy: 0.9784 lr: [5.904900000000002e-05]
# epoch 84 , train negloglik: 1.44489,    val negloglik: 1.45122    accuracy: 0.9784 lr: [5.904900000000002e-05]
# epoch 85 , train negloglik: 1.44334,    val negloglik: 1.44975    accuracy: 0.9784 lr: [5.904900000000002e-05]
# epoch 86 , train negloglik: 1.44183,    val negloglik: 1.44833    accuracy: 0.9784 lr: [5.904900000000002e-05]
# epoch 87 , train negloglik: 1.44036,    val negloglik: 1.44695    accuracy: 0.9784 lr: [5.904900000000002e-05]
# epoch 88 , train negloglik: 1.43894,    val negloglik: 1.44560    accuracy: 0.9784 lr: [5.904900000000002e-05]
# epoch 89 , train negloglik: 1.43756,    val negloglik: 1.44429    accuracy: 0.9784 lr: [5.904900000000002e-05]
# epoch 90 , train negloglik: 1.43622,    val negloglik: 1.44302    accuracy: 0.9784 lr: [5.904900000000002e-05]
# epoch 91 , train negloglik: 1.43491,    val negloglik: 1.44179    accuracy: 0.9784 lr: [5.904900000000002e-05]
# epoch 92 , train negloglik: 1.43364,    val negloglik: 1.44061    accuracy: 0.9784 lr: [5.904900000000002e-05]
# epoch 93 , train negloglik: 1.43242,    val negloglik: 1.43945    accuracy: 0.9784 lr: [5.904900000000002e-05]
# epoch 94 , train negloglik: 1.43122,    val negloglik: 1.43833    accuracy: 0.9784 lr: [5.904900000000002e-05]
# epoch 95 , train negloglik: 1.43007,    val negloglik: 1.43725    accuracy: 0.9784 lr: [5.904900000000002e-05]
# epoch 96 , train negloglik: 1.42894,    val negloglik: 1.43620    accuracy: 0.9784 lr: [5.904900000000002e-05]
# epoch 97 , train negloglik: 1.42785,    val negloglik: 1.43518    accuracy: 0.9784 lr: [5.904900000000002e-05]
# epoch 98 , train negloglik: 1.42680,    val negloglik: 1.43419    accuracy: 0.9784 lr: [5.904900000000002e-05]
# epoch 99 , train negloglik: 1.42577,    val negloglik: 1.43324    accuracy: 0.9784 lr: [5.904900000000002e-05]
# epoch 100, train negloglik: 1.42478,    val negloglik: 1.43232    accuracy: 0.9784 lr: [5.904900000000002e-05]
# epoch 101, train negloglik: 1.42386,    val negloglik: 1.43151    accuracy: 0.9784 lr: [5.314410000000002e-05]
# epoch 102, train negloglik: 1.42302,    val negloglik: 1.43073    accuracy: 0.9784 lr: [5.314410000000002e-05]
# epoch 103, train negloglik: 1.42221,    val negloglik: 1.42997    accuracy: 0.9784 lr: [5.314410000000002e-05]
# epoch 104, train negloglik: 1.42141,    val negloglik: 1.42923    accuracy: 0.9784 lr: [5.314410000000002e-05]
# epoch 105, train negloglik: 1.42064,    val negloglik: 1.42852    accuracy: 0.9784 lr: [5.314410000000002e-05]
# epoch 106, train negloglik: 1.41989,    val negloglik: 1.42782    accuracy: 0.9784 lr: [5.314410000000002e-05]
# epoch 107, train negloglik: 1.41916,    val negloglik: 1.42715    accuracy: 0.9784 lr: [5.314410000000002e-05]
# epoch 108, train negloglik: 1.41845,    val negloglik: 1.42650    accuracy: 0.9784 lr: [5.314410000000002e-05]
# epoch 109, train negloglik: 1.41776,    val negloglik: 1.42587    accuracy: 0.9784 lr: [5.314410000000002e-05]
# epoch 110, train negloglik: 1.41710,    val negloglik: 1.42525    accuracy: 0.9784 lr: [5.314410000000002e-05]
# epoch 111, train negloglik: 1.41645,    val negloglik: 1.42465    accuracy: 0.9784 lr: [5.314410000000002e-05]
# epoch 112, train negloglik: 1.41582,    val negloglik: 1.42407    accuracy: 0.9784 lr: [5.314410000000002e-05]
# epoch 113, train negloglik: 1.41521,    val negloglik: 1.42352    accuracy: 0.9784 lr: [5.314410000000002e-05]
# epoch 114, train negloglik: 1.41462,    val negloglik: 1.42296    accuracy: 0.9784 lr: [5.314410000000002e-05]
# epoch 115, train negloglik: 1.41403,    val negloglik: 1.42245    accuracy: 0.9784 lr: [5.314410000000002e-05]
# epoch 116, train negloglik: 1.41349,    val negloglik: 1.42193    accuracy: 0.9784 lr: [5.314410000000002e-05]
# epoch 117, train negloglik: 1.41295,    val negloglik: 1.42143    accuracy: 0.9784 lr: [5.314410000000002e-05]
# epoch 118, train negloglik: 1.41241,    val negloglik: 1.42097    accuracy: 0.9784 lr: [5.314410000000002e-05]
# epoch 119, train negloglik: 1.41191,    val negloglik: 1.42049    accuracy: 0.9784 lr: [5.314410000000002e-05]
# epoch 120, train negloglik: 1.41141,    val negloglik: 1.42006    accuracy: 0.9784 lr: [5.314410000000002e-05]
# epoch 121, train negloglik: 1.41096,    val negloglik: 1.41966    accuracy: 0.9784 lr: [4.782969000000002e-05]
# epoch 122, train negloglik: 1.41054,    val negloglik: 1.41928    accuracy: 0.9784 lr: [4.782969000000002e-05]
# epoch 123, train negloglik: 1.41013,    val negloglik: 1.41891    accuracy: 0.9784 lr: [4.782969000000002e-05]
# epoch 124, train negloglik: 1.40973,    val negloglik: 1.41856    accuracy: 0.9784 lr: [4.782969000000002e-05]
# epoch 125, train negloglik: 1.40935,    val negloglik: 1.41821    accuracy: 0.9784 lr: [4.782969000000002e-05]
# epoch 126, train negloglik: 1.40897,    val negloglik: 1.41788    accuracy: 0.9784 lr: [4.782969000000002e-05]
# epoch 127, train negloglik: 1.40861,    val negloglik: 1.41755    accuracy: 0.9784 lr: [4.782969000000002e-05]
# epoch 128, train negloglik: 1.40825,    val negloglik: 1.41723    accuracy: 0.9784 lr: [4.782969000000002e-05]
# epoch 129, train negloglik: 1.40791,    val negloglik: 1.41692    accuracy: 0.9784 lr: [4.782969000000002e-05]
# epoch 130, train negloglik: 1.40757,    val negloglik: 1.41662    accuracy: 0.9783 lr: [4.782969000000002e-05]
# epoch 131, train negloglik: 1.40725,    val negloglik: 1.41633    accuracy: 0.9783 lr: [4.782969000000002e-05]
# epoch 132, train negloglik: 1.40694,    val negloglik: 1.41605    accuracy: 0.9784 lr: [4.782969000000002e-05]
# epoch 133, train negloglik: 1.40662,    val negloglik: 1.41578    accuracy: 0.9784 lr: [4.782969000000002e-05]
# epoch 134, train negloglik: 1.40633,    val negloglik: 1.41552    accuracy: 0.9783 lr: [4.782969000000002e-05]
# epoch 135, train negloglik: 1.40604,    val negloglik: 1.41525    accuracy: 0.9783 lr: [4.782969000000002e-05]
# epoch 136, train negloglik: 1.40576,    val negloglik: 1.41501    accuracy: 0.9783 lr: [4.782969000000002e-05]
# epoch 137, train negloglik: 1.40548,    val negloglik: 1.41477    accuracy: 0.9783 lr: [4.782969000000002e-05]
# epoch 138, train negloglik: 1.40522,    val negloglik: 1.41454    accuracy: 0.9783 lr: [4.782969000000002e-05]
# epoch 139, train negloglik: 1.40496,    val negloglik: 1.41431    accuracy: 0.9783 lr: [4.782969000000002e-05]
# epoch 140, train negloglik: 1.40471,    val negloglik: 1.41409    accuracy: 0.9783 lr: [4.782969000000002e-05]
# epoch 141, train negloglik: 1.40448,    val negloglik: 1.41390    accuracy: 0.9783 lr: [4.304672100000002e-05]
# epoch 142, train negloglik: 1.40426,    val negloglik: 1.41371    accuracy: 0.9783 lr: [4.304672100000002e-05]
# epoch 143, train negloglik: 1.40405,    val negloglik: 1.41353    accuracy: 0.9783 lr: [4.304672100000002e-05]
# epoch 144, train negloglik: 1.40385,    val negloglik: 1.41336    accuracy: 0.9783 lr: [4.304672100000002e-05]
# epoch 145, train negloglik: 1.40365,    val negloglik: 1.41318    accuracy: 0.9783 lr: [4.304672100000002e-05]
# epoch 146, train negloglik: 1.40346,    val negloglik: 1.41302    accuracy: 0.9783 lr: [4.304672100000002e-05]
# epoch 147, train negloglik: 1.40328,    val negloglik: 1.41286    accuracy: 0.9783 lr: [4.304672100000002e-05]
# epoch 148, train negloglik: 1.40309,    val negloglik: 1.41270    accuracy: 0.9783 lr: [4.304672100000002e-05]
# epoch 149, train negloglik: 1.40292,    val negloglik: 1.41255    accuracy: 0.9783 lr: [4.304672100000002e-05]
# epoch 150, train negloglik: 1.40274,    val negloglik: 1.41240    accuracy: 0.9783 lr: [4.304672100000002e-05]
# epoch 151, train negloglik: 1.40258,    val negloglik: 1.41226    accuracy: 0.9783 lr: [4.304672100000002e-05]
# epoch 152, train negloglik: 1.40241,    val negloglik: 1.41211    accuracy: 0.9783 lr: [4.304672100000002e-05]
# epoch 153, train negloglik: 1.40225,    val negloglik: 1.41198    accuracy: 0.9783 lr: [4.304672100000002e-05]
# epoch 154, train negloglik: 1.40210,    val negloglik: 1.41185    accuracy: 0.9783 lr: [4.304672100000002e-05]
# epoch 155, train negloglik: 1.40195,    val negloglik: 1.41172    accuracy: 0.9783 lr: [4.304672100000002e-05]
# epoch 156, train negloglik: 1.40180,    val negloglik: 1.41160    accuracy: 0.9783 lr: [4.304672100000002e-05]
# epoch 157, train negloglik: 1.40166,    val negloglik: 1.41148    accuracy: 0.9783 lr: [4.304672100000002e-05]
# epoch 158, train negloglik: 1.40152,    val negloglik: 1.41137    accuracy: 0.9783 lr: [4.304672100000002e-05]
# epoch 159, train negloglik: 1.40139,    val negloglik: 1.41125    accuracy: 0.9783 lr: [4.304672100000002e-05]
# epoch 160, train negloglik: 1.40125,    val negloglik: 1.41115    accuracy: 0.9783 lr: [4.304672100000002e-05]
# epoch 161, train negloglik: 1.40113,    val negloglik: 1.41105    accuracy: 0.9783 lr: [3.874204890000002e-05]
# epoch 162, train negloglik: 1.40102,    val negloglik: 1.41095    accuracy: 0.9783 lr: [3.874204890000002e-05]
# epoch 163, train negloglik: 1.40091,    val negloglik: 1.41086    accuracy: 0.9783 lr: [3.874204890000002e-05]
# epoch 164, train negloglik: 1.40080,    val negloglik: 1.41077    accuracy: 0.9783 lr: [3.874204890000002e-05]
# epoch 165, train negloglik: 1.40070,    val negloglik: 1.41069    accuracy: 0.9783 lr: [3.874204890000002e-05]
# epoch 166, train negloglik: 1.40060,    val negloglik: 1.41060    accuracy: 0.9783 lr: [3.874204890000002e-05]
# epoch 167, train negloglik: 1.40050,    val negloglik: 1.41052    accuracy: 0.9783 lr: [3.874204890000002e-05]
# epoch 168, train negloglik: 1.40040,    val negloglik: 1.41045    accuracy: 0.9783 lr: [3.874204890000002e-05]
# epoch 169, train negloglik: 1.40031,    val negloglik: 1.41037    accuracy: 0.9783 lr: [3.874204890000002e-05]
# epoch 170, train negloglik: 1.40021,    val negloglik: 1.41029    accuracy: 0.9783 lr: [3.874204890000002e-05]
# epoch 171, train negloglik: 1.40012,    val negloglik: 1.41022    accuracy: 0.9783 lr: [3.874204890000002e-05]
# epoch 172, train negloglik: 1.40004,    val negloglik: 1.41015    accuracy: 0.9783 lr: [3.874204890000002e-05]
# epoch 173, train negloglik: 1.39995,    val negloglik: 1.41008    accuracy: 0.9783 lr: [3.874204890000002e-05]
# epoch 174, train negloglik: 1.39987,    val negloglik: 1.41002    accuracy: 0.9783 lr: [3.874204890000002e-05]
# epoch 175, train negloglik: 1.39979,    val negloglik: 1.40995    accuracy: 0.9783 lr: [3.874204890000002e-05]
# epoch 176, train negloglik: 1.39971,    val negloglik: 1.40989    accuracy: 0.9783 lr: [3.874204890000002e-05]
# epoch 177, train negloglik: 1.39963,    val negloglik: 1.40982    accuracy: 0.9783 lr: [3.874204890000002e-05]
# epoch 178, train negloglik: 1.39955,    val negloglik: 1.40976    accuracy: 0.9783 lr: [3.874204890000002e-05]
# epoch 179, train negloglik: 1.39948,    val negloglik: 1.40971    accuracy: 0.9783 lr: [3.874204890000002e-05]
# epoch 180, train negloglik: 1.39941,    val negloglik: 1.40965    accuracy: 0.9783 lr: [3.874204890000002e-05]
# epoch 181, train negloglik: 1.39934,    val negloglik: 1.40960    accuracy: 0.9783 lr: [3.4867844010000016e-05]
# epoch 182, train negloglik: 1.39928,    val negloglik: 1.40955    accuracy: 0.9783 lr: [3.4867844010000016e-05]
# epoch 183, train negloglik: 1.39922,    val negloglik: 1.40951    accuracy: 0.9783 lr: [3.4867844010000016e-05]
# epoch 184, train negloglik: 1.39916,    val negloglik: 1.40946    accuracy: 0.9783 lr: [3.4867844010000016e-05]
# epoch 185, train negloglik: 1.39911,    val negloglik: 1.40942    accuracy: 0.9783 lr: [3.4867844010000016e-05]
# epoch 186, train negloglik: 1.39905,    val negloglik: 1.40937    accuracy: 0.9783 lr: [3.4867844010000016e-05]
# epoch 187, train negloglik: 1.39900,    val negloglik: 1.40933    accuracy: 0.9783 lr: [3.4867844010000016e-05]
# epoch 188, train negloglik: 1.39894,    val negloglik: 1.40929    accuracy: 0.9783 lr: [3.4867844010000016e-05]
# epoch 189, train negloglik: 1.39889,    val negloglik: 1.40925    accuracy: 0.9783 lr: [3.4867844010000016e-05]
# epoch 190, train negloglik: 1.39884,    val negloglik: 1.40921    accuracy: 0.9783 lr: [3.4867844010000016e-05]
# epoch 191, train negloglik: 1.39879,    val negloglik: 1.40917    accuracy: 0.9783 lr: [3.4867844010000016e-05]
# epoch 192, train negloglik: 1.39874,    val negloglik: 1.40914    accuracy: 0.9783 lr: [3.4867844010000016e-05]
# epoch 193, train negloglik: 1.39869,    val negloglik: 1.40910    accuracy: 0.9783 lr: [3.4867844010000016e-05]
# epoch 194, train negloglik: 1.39865,    val negloglik: 1.40907    accuracy: 0.9783 lr: [3.4867844010000016e-05]
# epoch 195, train negloglik: 1.39860,    val negloglik: 1.40903    accuracy: 0.9783 lr: [3.4867844010000016e-05]
# epoch 196, train negloglik: 1.39856,    val negloglik: 1.40900    accuracy: 0.9783 lr: [3.4867844010000016e-05]
# epoch 197, train negloglik: 1.39851,    val negloglik: 1.40897    accuracy: 0.9783 lr: [3.4867844010000016e-05]
# epoch 198, train negloglik: 1.39847,    val negloglik: 1.40894    accuracy: 0.9783 lr: [3.4867844010000016e-05]
# epoch 199, train negloglik: 1.39843,    val negloglik: 1.40891    accuracy: 0.9783 lr: [3.4867844010000016e-05]
# epoch 200, train negloglik: 1.39839,    val negloglik: 1.40888    accuracy: 0.9783 lr: [3.4867844010000016e-05]
# epoch 201, train negloglik: 1.39835,    val negloglik: 1.40885    accuracy: 0.9783 lr: [3.138105960900002e-05]
# epoch 202, train negloglik: 1.39832,    val negloglik: 1.40882    accuracy: 0.9783 lr: [3.138105960900002e-05]
# epoch 203, train negloglik: 1.39828,    val negloglik: 1.40880    accuracy: 0.9783 lr: [3.138105960900002e-05]
# epoch 204, train negloglik: 1.39825,    val negloglik: 1.40878    accuracy: 0.9783 lr: [3.138105960900002e-05]
# epoch 205, train negloglik: 1.39821,    val negloglik: 1.40875    accuracy: 0.9783 lr: [3.138105960900002e-05]
# epoch 206, train negloglik: 1.39818,    val negloglik: 1.40873    accuracy: 0.9783 lr: [3.138105960900002e-05]
# epoch 207, train negloglik: 1.39815,    val negloglik: 1.40871    accuracy: 0.9783 lr: [3.138105960900002e-05]
# epoch 208, train negloglik: 1.39812,    val negloglik: 1.40869    accuracy: 0.9783 lr: [3.138105960900002e-05]
# epoch 209, train negloglik: 1.39809,    val negloglik: 1.40867    accuracy: 0.9783 lr: [3.138105960900002e-05]
# epoch 210, train negloglik: 1.39806,    val negloglik: 1.40864    accuracy: 0.9783 lr: [3.138105960900002e-05]
# epoch 211, train negloglik: 1.39803,    val negloglik: 1.40863    accuracy: 0.9783 lr: [3.138105960900002e-05]
# epoch 212, train negloglik: 1.39800,    val negloglik: 1.40860    accuracy: 0.9783 lr: [3.138105960900002e-05]
# epoch 213, train negloglik: 1.39798,    val negloglik: 1.40859    accuracy: 0.9783 lr: [3.138105960900002e-05]
# epoch 214, train negloglik: 1.39795,    val negloglik: 1.40857    accuracy: 0.9783 lr: [3.138105960900002e-05]
# epoch 215, train negloglik: 1.39792,    val negloglik: 1.40855    accuracy: 0.9783 lr: [3.138105960900002e-05]
# epoch 216, train negloglik: 1.39790,    val negloglik: 1.40853    accuracy: 0.9783 lr: [3.138105960900002e-05]
# epoch 217, train negloglik: 1.39787,    val negloglik: 1.40852    accuracy: 0.9783 lr: [3.138105960900002e-05]
# epoch 218, train negloglik: 1.39785,    val negloglik: 1.40850    accuracy: 0.9783 lr: [3.138105960900002e-05]
# epoch 219, train negloglik: 1.39782,    val negloglik: 1.40848    accuracy: 0.9783 lr: [3.138105960900002e-05]
# epoch 220, train negloglik: 1.39780,    val negloglik: 1.40847    accuracy: 0.9783 lr: [3.138105960900002e-05]
# epoch 221, train negloglik: 1.39778,    val negloglik: 1.40845    accuracy: 0.9783 lr: [2.8242953648100018e-05]
# epoch 222, train negloglik: 1.39776,    val negloglik: 1.40844    accuracy: 0.9783 lr: [2.8242953648100018e-05]
# epoch 223, train negloglik: 1.39774,    val negloglik: 1.40842    accuracy: 0.9783 lr: [2.8242953648100018e-05]
# epoch 224, train negloglik: 1.39772,    val negloglik: 1.40841    accuracy: 0.9783 lr: [2.8242953648100018e-05]
# epoch 225, train negloglik: 1.39770,    val negloglik: 1.40840    accuracy: 0.9783 lr: [2.8242953648100018e-05]
# epoch 226, train negloglik: 1.39768,    val negloglik: 1.40839    accuracy: 0.9783 lr: [2.8242953648100018e-05]
# epoch 227, train negloglik: 1.39766,    val negloglik: 1.40838    accuracy: 0.9783 lr: [2.8242953648100018e-05]
# epoch 228, train negloglik: 1.39764,    val negloglik: 1.40836    accuracy: 0.9783 lr: [2.8242953648100018e-05]
# epoch 229, train negloglik: 1.39762,    val negloglik: 1.40835    accuracy: 0.9783 lr: [2.8242953648100018e-05]
# epoch 230, train negloglik: 1.39760,    val negloglik: 1.40834    accuracy: 0.9783 lr: [2.8242953648100018e-05]
# epoch 231, train negloglik: 1.39759,    val negloglik: 1.40833    accuracy: 0.9783 lr: [2.8242953648100018e-05]
# epoch 232, train negloglik: 1.39757,    val negloglik: 1.40832    accuracy: 0.9783 lr: [2.8242953648100018e-05]
# epoch 233, train negloglik: 1.39755,    val negloglik: 1.40831    accuracy: 0.9783 lr: [2.8242953648100018e-05]
# epoch 234, train negloglik: 1.39753,    val negloglik: 1.40830    accuracy: 0.9783 lr: [2.8242953648100018e-05]
# epoch 235, train negloglik: 1.39752,    val negloglik: 1.40829    accuracy: 0.9783 lr: [2.8242953648100018e-05]
# epoch 236, train negloglik: 1.39750,    val negloglik: 1.40828    accuracy: 0.9783 lr: [2.8242953648100018e-05]
# epoch 237, train negloglik: 1.39749,    val negloglik: 1.40827    accuracy: 0.9783 lr: [2.8242953648100018e-05]
# epoch 238, train negloglik: 1.39747,    val negloglik: 1.40826    accuracy: 0.9783 lr: [2.8242953648100018e-05]
# epoch 239, train negloglik: 1.39746,    val negloglik: 1.40825    accuracy: 0.9783 lr: [2.8242953648100018e-05]
# epoch 240, train negloglik: 1.39744,    val negloglik: 1.40824    accuracy: 0.9783 lr: [2.8242953648100018e-05]
# epoch 241, train negloglik: 1.39743,    val negloglik: 1.40823    accuracy: 0.9783 lr: [2.5418658283290016e-05]
# epoch 242, train negloglik: 1.39742,    val negloglik: 1.40823    accuracy: 0.9783 lr: [2.5418658283290016e-05]
# epoch 243, train negloglik: 1.39740,    val negloglik: 1.40822    accuracy: 0.9783 lr: [2.5418658283290016e-05]
# epoch 244, train negloglik: 1.39739,    val negloglik: 1.40821    accuracy: 0.9783 lr: [2.5418658283290016e-05]
# epoch 245, train negloglik: 1.39738,    val negloglik: 1.40821    accuracy: 0.9783 lr: [2.5418658283290016e-05]
# epoch 246, train negloglik: 1.39737,    val negloglik: 1.40820    accuracy: 0.9783 lr: [2.5418658283290016e-05]
# epoch 247, train negloglik: 1.39736,    val negloglik: 1.40819    accuracy: 0.9783 lr: [2.5418658283290016e-05]
# epoch 248, train negloglik: 1.39734,    val negloglik: 1.40819    accuracy: 0.9783 lr: [2.5418658283290016e-05]
# epoch 249, train negloglik: 1.39733,    val negloglik: 1.40818    accuracy: 0.9783 lr: [2.5418658283290016e-05]
# epoch 250, train negloglik: 1.39732,    val negloglik: 1.40817    accuracy: 0.9783 lr: [2.5418658283290016e-05]
# epoch 251, train negloglik: 1.39731,    val negloglik: 1.40817    accuracy: 0.9783 lr: [2.5418658283290016e-05]
# epoch 252, train negloglik: 1.39730,    val negloglik: 1.40816    accuracy: 0.9783 lr: [2.5418658283290016e-05]
# epoch 253, train negloglik: 1.39729,    val negloglik: 1.40816    accuracy: 0.9783 lr: [2.5418658283290016e-05]
# epoch 254, train negloglik: 1.39728,    val negloglik: 1.40815    accuracy: 0.9783 lr: [2.5418658283290016e-05]
# epoch 255, train negloglik: 1.39727,    val negloglik: 1.40815    accuracy: 0.9783 lr: [2.5418658283290016e-05]
# epoch 256, train negloglik: 1.39726,    val negloglik: 1.40814    accuracy: 0.9783 lr: [2.5418658283290016e-05]
# epoch 257, train negloglik: 1.39725,    val negloglik: 1.40813    accuracy: 0.9783 lr: [2.5418658283290016e-05]
# epoch 258, train negloglik: 1.39724,    val negloglik: 1.40813    accuracy: 0.9783 lr: [2.5418658283290016e-05]
# epoch 259, train negloglik: 1.39723,    val negloglik: 1.40812    accuracy: 0.9783 lr: [2.5418658283290016e-05]
# epoch 260, train negloglik: 1.39722,    val negloglik: 1.40812    accuracy: 0.9783 lr: [2.5418658283290016e-05]
# epoch 261, train negloglik: 1.39721,    val negloglik: 1.40812    accuracy: 0.9783 lr: [2.2876792454961016e-05]
# epoch 262, train negloglik: 1.39720,    val negloglik: 1.40811    accuracy: 0.9783 lr: [2.2876792454961016e-05]
# epoch 263, train negloglik: 1.39720,    val negloglik: 1.40811    accuracy: 0.9783 lr: [2.2876792454961016e-05]
# epoch 264, train negloglik: 1.39719,    val negloglik: 1.40810    accuracy: 0.9783 lr: [2.2876792454961016e-05]
# epoch 265, train negloglik: 1.39718,    val negloglik: 1.40810    accuracy: 0.9783 lr: [2.2876792454961016e-05]
# epoch 266, train negloglik: 1.39717,    val negloglik: 1.40810    accuracy: 0.9783 lr: [2.2876792454961016e-05]
# epoch 267, train negloglik: 1.39717,    val negloglik: 1.40809    accuracy: 0.9783 lr: [2.2876792454961016e-05]
# epoch 268, train negloglik: 1.39716,    val negloglik: 1.40809    accuracy: 0.9783 lr: [2.2876792454961016e-05]
# epoch 269, train negloglik: 1.39715,    val negloglik: 1.40809    accuracy: 0.9783 lr: [2.2876792454961016e-05]
# epoch 270, train negloglik: 1.39714,    val negloglik: 1.40808    accuracy: 0.9783 lr: [2.2876792454961016e-05]
# epoch 271, train negloglik: 1.39714,    val negloglik: 1.40808    accuracy: 0.9783 lr: [2.2876792454961016e-05]
# epoch 272, train negloglik: 1.39713,    val negloglik: 1.40808    accuracy: 0.9783 lr: [2.2876792454961016e-05]
# epoch 273, train negloglik: 1.39712,    val negloglik: 1.40807    accuracy: 0.9783 lr: [2.2876792454961016e-05]
# epoch 274, train negloglik: 1.39712,    val negloglik: 1.40807    accuracy: 0.9783 lr: [2.2876792454961016e-05]
# epoch 275, train negloglik: 1.39711,    val negloglik: 1.40807    accuracy: 0.9783 lr: [2.2876792454961016e-05]
# epoch 276, train negloglik: 1.39710,    val negloglik: 1.40806    accuracy: 0.9783 lr: [2.2876792454961016e-05]
# epoch 277, train negloglik: 1.39710,    val negloglik: 1.40806    accuracy: 0.9783 lr: [2.2876792454961016e-05]
# epoch 278, train negloglik: 1.39709,    val negloglik: 1.40806    accuracy: 0.9783 lr: [2.2876792454961016e-05]
# epoch 279, train negloglik: 1.39708,    val negloglik: 1.40806    accuracy: 0.9783 lr: [2.2876792454961016e-05]
# epoch 280, train negloglik: 1.39708,    val negloglik: 1.40805    accuracy: 0.9783 lr: [2.2876792454961016e-05]
# epoch 281, train negloglik: 1.39707,    val negloglik: 1.40805    accuracy: 0.9783 lr: [2.0589113209464913e-05]
# epoch 282, train negloglik: 1.39707,    val negloglik: 1.40805    accuracy: 0.9783 lr: [2.0589113209464913e-05]
# epoch 283, train negloglik: 1.39706,    val negloglik: 1.40805    accuracy: 0.9783 lr: [2.0589113209464913e-05]
# epoch 284, train negloglik: 1.39706,    val negloglik: 1.40804    accuracy: 0.9783 lr: [2.0589113209464913e-05]
# epoch 285, train negloglik: 1.39705,    val negloglik: 1.40804    accuracy: 0.9783 lr: [2.0589113209464913e-05]
# epoch 286, train negloglik: 1.39705,    val negloglik: 1.40804    accuracy: 0.9783 lr: [2.0589113209464913e-05]
# epoch 287, train negloglik: 1.39704,    val negloglik: 1.40804    accuracy: 0.9783 lr: [2.0589113209464913e-05]
# epoch 288, train negloglik: 1.39704,    val negloglik: 1.40804    accuracy: 0.9783 lr: [2.0589113209464913e-05]
# epoch 289, train negloglik: 1.39703,    val negloglik: 1.40803    accuracy: 0.9783 lr: [2.0589113209464913e-05]
# epoch 290, train negloglik: 1.39703,    val negloglik: 1.40803    accuracy: 0.9783 lr: [2.0589113209464913e-05]
# epoch 291, train negloglik: 1.39702,    val negloglik: 1.40803    accuracy: 0.9783 lr: [2.0589113209464913e-05]
# epoch 292, train negloglik: 1.39702,    val negloglik: 1.40803    accuracy: 0.9783 lr: [2.0589113209464913e-05]
# epoch 293, train negloglik: 1.39701,    val negloglik: 1.40803    accuracy: 0.9783 lr: [2.0589113209464913e-05]
# epoch 294, train negloglik: 1.39701,    val negloglik: 1.40803    accuracy: 0.9783 lr: [2.0589113209464913e-05]
# epoch 295, train negloglik: 1.39701,    val negloglik: 1.40802    accuracy: 0.9783 lr: [2.0589113209464913e-05]
# epoch 296, train negloglik: 1.39700,    val negloglik: 1.40802    accuracy: 0.9783 lr: [2.0589113209464913e-05]
# epoch 297, train negloglik: 1.39700,    val negloglik: 1.40802    accuracy: 0.9783 lr: [2.0589113209464913e-05]
# epoch 298, train negloglik: 1.39699,    val negloglik: 1.40802    accuracy: 0.9783 lr: [2.0589113209464913e-05]
# epoch 299, train negloglik: 1.39699,    val negloglik: 1.40802    accuracy: 0.9783 lr: [2.0589113209464913e-05]
# epoch 300, train negloglik: 1.39698,    val negloglik: 1.40802    accuracy: 0.9783 lr: [2.0589113209464913e-05]
# epoch 301, train negloglik: 1.39698,    val negloglik: 1.40802    accuracy: 0.9783 lr: [1.8530201888518422e-05]
# epoch 302, train negloglik: 1.39698,    val negloglik: 1.40801    accuracy: 0.9783 lr: [1.8530201888518422e-05]
# epoch 303, train negloglik: 1.39697,    val negloglik: 1.40801    accuracy: 0.9783 lr: [1.8530201888518422e-05]
# epoch 304, train negloglik: 1.39697,    val negloglik: 1.40801    accuracy: 0.9783 lr: [1.8530201888518422e-05]
# epoch 305, train negloglik: 1.39697,    val negloglik: 1.40801    accuracy: 0.9783 lr: [1.8530201888518422e-05]
# epoch 306, train negloglik: 1.39696,    val negloglik: 1.40801    accuracy: 0.9783 lr: [1.8530201888518422e-05]
# epoch 307, train negloglik: 1.39696,    val negloglik: 1.40801    accuracy: 0.9783 lr: [1.8530201888518422e-05]
# epoch 308, train negloglik: 1.39696,    val negloglik: 1.40801    accuracy: 0.9783 lr: [1.8530201888518422e-05]
# epoch 309, train negloglik: 1.39695,    val negloglik: 1.40801    accuracy: 0.9783 lr: [1.8530201888518422e-05]
# epoch 310, train negloglik: 1.39695,    val negloglik: 1.40801    accuracy: 0.9783 lr: [1.8530201888518422e-05]
# epoch 311, train negloglik: 1.39695,    val negloglik: 1.40800    accuracy: 0.9783 lr: [1.8530201888518422e-05]
# epoch 312, train negloglik: 1.39694,    val negloglik: 1.40800    accuracy: 0.9783 lr: [1.8530201888518422e-05]
# epoch 313, train negloglik: 1.39694,    val negloglik: 1.40800    accuracy: 0.9783 lr: [1.8530201888518422e-05]
# epoch 314, train negloglik: 1.39694,    val negloglik: 1.40800    accuracy: 0.9783 lr: [1.8530201888518422e-05]
# epoch 315, train negloglik: 1.39693,    val negloglik: 1.40800    accuracy: 0.9783 lr: [1.8530201888518422e-05]
# epoch 316, train negloglik: 1.39693,    val negloglik: 1.40800    accuracy: 0.9783 lr: [1.8530201888518422e-05]
# epoch 317, train negloglik: 1.39693,    val negloglik: 1.40800    accuracy: 0.9783 lr: [1.8530201888518422e-05]
# epoch 318, train negloglik: 1.39693,    val negloglik: 1.40800    accuracy: 0.9783 lr: [1.8530201888518422e-05]
# epoch 319, train negloglik: 1.39692,    val negloglik: 1.40800    accuracy: 0.9783 lr: [1.8530201888518422e-05]
# epoch 320, train negloglik: 1.39692,    val negloglik: 1.40800    accuracy: 0.9783 lr: [1.8530201888518422e-05]
# epoch 321, train negloglik: 1.39692,    val negloglik: 1.40800    accuracy: 0.9783 lr: [1.667718169966658e-05]
# epoch 322, train negloglik: 1.39691,    val negloglik: 1.40800    accuracy: 0.9783 lr: [1.667718169966658e-05]
# epoch 323, train negloglik: 1.39691,    val negloglik: 1.40800    accuracy: 0.9783 lr: [1.667718169966658e-05]
# epoch 324, train negloglik: 1.39691,    val negloglik: 1.40800    accuracy: 0.9783 lr: [1.667718169966658e-05]
# epoch 325, train negloglik: 1.39691,    val negloglik: 1.40799    accuracy: 0.9783 lr: [1.667718169966658e-05]
# epoch 326, train negloglik: 1.39690,    val negloglik: 1.40799    accuracy: 0.9783 lr: [1.667718169966658e-05]
# epoch 327, train negloglik: 1.39690,    val negloglik: 1.40799    accuracy: 0.9783 lr: [1.667718169966658e-05]
# epoch 328, train negloglik: 1.39690,    val negloglik: 1.40799    accuracy: 0.9783 lr: [1.667718169966658e-05]
# epoch 329, train negloglik: 1.39690,    val negloglik: 1.40799    accuracy: 0.9783 lr: [1.667718169966658e-05]
# epoch 330, train negloglik: 1.39690,    val negloglik: 1.40799    accuracy: 0.9783 lr: [1.667718169966658e-05]
# epoch 331, train negloglik: 1.39689,    val negloglik: 1.40799    accuracy: 0.9783 lr: [1.667718169966658e-05]
# epoch 332, train negloglik: 1.39689,    val negloglik: 1.40799    accuracy: 0.9783 lr: [1.667718169966658e-05]
# epoch 333, train negloglik: 1.39689,    val negloglik: 1.40799    accuracy: 0.9783 lr: [1.667718169966658e-05]
# epoch 334, train negloglik: 1.39689,    val negloglik: 1.40799    accuracy: 0.9783 lr: [1.667718169966658e-05]
# epoch 335, train negloglik: 1.39688,    val negloglik: 1.40799    accuracy: 0.9783 lr: [1.667718169966658e-05]
# epoch 336, train negloglik: 1.39688,    val negloglik: 1.40799    accuracy: 0.9783 lr: [1.667718169966658e-05]
# epoch 337, train negloglik: 1.39688,    val negloglik: 1.40799    accuracy: 0.9783 lr: [1.667718169966658e-05]
# epoch 338, train negloglik: 1.39688,    val negloglik: 1.40799    accuracy: 0.9783 lr: [1.667718169966658e-05]
# epoch 339, train negloglik: 1.39688,    val negloglik: 1.40799    accuracy: 0.9783 lr: [1.667718169966658e-05]
# epoch 340, train negloglik: 1.39687,    val negloglik: 1.40799    accuracy: 0.9783 lr: [1.667718169966658e-05]
# epoch 341, train negloglik: 1.39687,    val negloglik: 1.40799    accuracy: 0.9783 lr: [1.5009463529699922e-05]
# epoch 342, train negloglik: 1.39687,    val negloglik: 1.40799    accuracy: 0.9783 lr: [1.5009463529699922e-05]
# epoch 343, train negloglik: 1.39687,    val negloglik: 1.40799    accuracy: 0.9783 lr: [1.5009463529699922e-05]
# epoch 344, train negloglik: 1.39687,    val negloglik: 1.40799    accuracy: 0.9783 lr: [1.5009463529699922e-05]
# epoch 345, train negloglik: 1.39686,    val negloglik: 1.40799    accuracy: 0.9783 lr: [1.5009463529699922e-05]
# epoch 346, train negloglik: 1.39686,    val negloglik: 1.40799    accuracy: 0.9783 lr: [1.5009463529699922e-05]
# epoch 347, train negloglik: 1.39686,    val negloglik: 1.40799    accuracy: 0.9783 lr: [1.5009463529699922e-05]
# epoch 348, train negloglik: 1.39686,    val negloglik: 1.40799    accuracy: 0.9783 lr: [1.5009463529699922e-05]
# epoch 349, train negloglik: 1.39686,    val negloglik: 1.40799    accuracy: 0.9783 lr: [1.5009463529699922e-05]
# epoch 350, train negloglik: 1.39686,    val negloglik: 1.40799    accuracy: 0.9783 lr: [1.5009463529699922e-05]
# epoch 351, train negloglik: 1.39685,    val negloglik: 1.40799    accuracy: 0.9783 lr: [1.5009463529699922e-05]
# epoch 352, train negloglik: 1.39685,    val negloglik: 1.40799    accuracy: 0.9783 lr: [1.5009463529699922e-05]
# epoch 353, train negloglik: 1.39685,    val negloglik: 1.40799    accuracy: 0.9783 lr: [1.5009463529699922e-05]
# epoch 354, train negloglik: 1.39685,    val negloglik: 1.40799    accuracy: 0.9783 lr: [1.5009463529699922e-05]
# epoch 355, train negloglik: 1.39685,    val negloglik: 1.40799    accuracy: 0.9783 lr: [1.5009463529699922e-05]
# epoch 356, train negloglik: 1.39685,    val negloglik: 1.40799    accuracy: 0.9783 lr: [1.5009463529699922e-05]
# epoch 357, train negloglik: 1.39685,    val negloglik: 1.40799    accuracy: 0.9783 lr: [1.5009463529699922e-05]
# epoch 358, train negloglik: 1.39684,    val negloglik: 1.40799    accuracy: 0.9783 lr: [1.5009463529699922e-05]
# epoch 359, train negloglik: 1.39684,    val negloglik: 1.40799    accuracy: 0.9783 lr: [1.5009463529699922e-05]
# epoch 360, train negloglik: 1.39684,    val negloglik: 1.40798    accuracy: 0.9783 lr: [1.5009463529699922e-05]
# epoch 361, train negloglik: 1.39684,    val negloglik: 1.40799    accuracy: 0.9783 lr: [1.350851717672993e-05]
# epoch 362, train negloglik: 1.39684,    val negloglik: 1.40798    accuracy: 0.9783 lr: [1.350851717672993e-05]
# epoch 363, train negloglik: 1.39684,    val negloglik: 1.40798    accuracy: 0.9783 lr: [1.350851717672993e-05]
# epoch 364, train negloglik: 1.39683,    val negloglik: 1.40798    accuracy: 0.9783 lr: [1.350851717672993e-05]
# epoch 365, train negloglik: 1.39683,    val negloglik: 1.40799    accuracy: 0.9783 lr: [1.350851717672993e-05]
# epoch 366, train negloglik: 1.39683,    val negloglik: 1.40799    accuracy: 0.9783 lr: [1.350851717672993e-05]
# epoch 367, train negloglik: 1.39683,    val negloglik: 1.40799    accuracy: 0.9783 lr: [1.350851717672993e-05]
# epoch 368, train negloglik: 1.39683,    val negloglik: 1.40799    accuracy: 0.9783 lr: [1.350851717672993e-05]
# epoch 369, train negloglik: 1.39683,    val negloglik: 1.40798    accuracy: 0.9783 lr: [1.350851717672993e-05]
# epoch 370, train negloglik: 1.39683,    val negloglik: 1.40798    accuracy: 0.9783 lr: [1.350851717672993e-05]
# epoch 371, train negloglik: 1.39683,    val negloglik: 1.40799    accuracy: 0.9783 lr: [1.350851717672993e-05]
# epoch 372, train negloglik: 1.39683,    val negloglik: 1.40799    accuracy: 0.9783 lr: [1.350851717672993e-05]
# epoch 373, train negloglik: 1.39682,    val negloglik: 1.40799    accuracy: 0.9783 lr: [1.350851717672993e-05]
# epoch 374, train negloglik: 1.39682,    val negloglik: 1.40798    accuracy: 0.9783 lr: [1.350851717672993e-05]
# epoch 375, train negloglik: 1.39682,    val negloglik: 1.40799    accuracy: 0.9783 lr: [1.350851717672993e-05]
# epoch 376, train negloglik: 1.39682,    val negloglik: 1.40798    accuracy: 0.9783 lr: [1.350851717672993e-05]
# epoch 377, train negloglik: 1.39682,    val negloglik: 1.40798    accuracy: 0.9783 lr: [1.350851717672993e-05]
# epoch 378, train negloglik: 1.39682,    val negloglik: 1.40799    accuracy: 0.9783 lr: [1.350851717672993e-05]
# epoch 379, train negloglik: 1.39682,    val negloglik: 1.40798    accuracy: 0.9783 lr: [1.350851717672993e-05]
# epoch 380, train negloglik: 1.39682,    val negloglik: 1.40799    accuracy: 0.9783 lr: [1.350851717672993e-05]
# epoch 381, train negloglik: 1.39681,    val negloglik: 1.40799    accuracy: 0.9783 lr: [1.2157665459056937e-05]
# epoch 382, train negloglik: 1.39681,    val negloglik: 1.40799    accuracy: 0.9783 lr: [1.2157665459056937e-05]
# epoch 383, train negloglik: 1.39681,    val negloglik: 1.40799    accuracy: 0.9783 lr: [1.2157665459056937e-05]
# epoch 384, train negloglik: 1.39681,    val negloglik: 1.40799    accuracy: 0.9783 lr: [1.2157665459056937e-05]
# epoch 385, train negloglik: 1.39681,    val negloglik: 1.40798    accuracy: 0.9783 lr: [1.2157665459056937e-05]
# epoch 386, train negloglik: 1.39681,    val negloglik: 1.40799    accuracy: 0.9783 lr: [1.2157665459056937e-05]
# epoch 387, train negloglik: 1.39681,    val negloglik: 1.40799    accuracy: 0.9783 lr: [1.2157665459056937e-05]
# epoch 388, train negloglik: 1.39681,    val negloglik: 1.40799    accuracy: 0.9783 lr: [1.2157665459056937e-05]
# epoch 389, train negloglik: 1.39681,    val negloglik: 1.40799    accuracy: 0.9783 lr: [1.2157665459056937e-05]
# epoch 390, train negloglik: 1.39681,    val negloglik: 1.40799    accuracy: 0.9783 lr: [1.2157665459056937e-05]
# epoch 391, train negloglik: 1.39681,    val negloglik: 1.40799    accuracy: 0.9783 lr: [1.2157665459056937e-05]
# epoch 392, train negloglik: 1.39680,    val negloglik: 1.40799    accuracy: 0.9783 lr: [1.2157665459056937e-05]
# epoch 393, train negloglik: 1.39680,    val negloglik: 1.40799    accuracy: 0.9783 lr: [1.2157665459056937e-05]
# epoch 394, train negloglik: 1.39680,    val negloglik: 1.40799    accuracy: 0.9783 lr: [1.2157665459056937e-05]
# epoch 395, train negloglik: 1.39680,    val negloglik: 1.40799    accuracy: 0.9783 lr: [1.2157665459056937e-05]
# epoch 396, train negloglik: 1.39680,    val negloglik: 1.40799    accuracy: 0.9783 lr: [1.2157665459056937e-05]
# epoch 397, train negloglik: 1.39680,    val negloglik: 1.40799    accuracy: 0.9783 lr: [1.2157665459056937e-05]
# epoch 398, train negloglik: 1.39680,    val negloglik: 1.40799    accuracy: 0.9783 lr: [1.2157665459056937e-05]
# epoch 399, train negloglik: 1.39680,    val negloglik: 1.40799    accuracy: 0.9783 lr: [1.2157665459056937e-05]
# Test MSE: 0.992314
# Test RMSE: 0.996150
# Residual Statistics:
# Mean: 0.124626
# Std: 0.988323
# Min: -1.181741
# Max: 1.178650
# plot completed

# %% [markdown]
# ## 3.結果評価
# 以下の項目に従ってカーネル行列の分析結果をまとめる：
#
# **カーネル行列分析項目**
# - 各層のカーネル行列ランクと条件数の分析
# - 誘導点の分布と配置の可視化
# - カーネル行列のヒートマップ（Jitter項適用前後）
# - 固有値分布の分析
# - 誘導点間距離の統計的分析

# %%
# 1層目
model.layers[0].save_fig("./outputs/layer_fused0.png")
model.layers[1].save_fig("./outputs/layer_fused1.png")

# %%
# カーネル行列のランク可視化・分析
import matplotlib.pyplot as plt
import numpy as np
import torch


def analyze_kernel_matrices(model):
    """
    GP-KANの各層のカーネル行列ランクと条件数を分析・可視化する
    """
    print("=== カーネル行列分析 ===")

    # 各層の分析
    for layer_idx, layer in enumerate(model.layers):
        print(f"\n--- Layer {layer_idx} ---")

        # 誘導点を取得
        z_range = layer.get_z().detach()  # 入力値
        h_range = layer.h.detach()  # 出力値
        jitter = layer.get_jitter().detach()  # Shape: [1, 1]
        print(
            f"z(誘導点)の範囲: [{z_range.min().item():.4f}, {z_range.max().item():.4f}]"
        )
        print(
            f"h(関数値)の範囲: [{h_range.min().item():.4f}, {h_range.max().item():.4f}]"
        )

        # カーネル行列を計算
        with torch.no_grad():
            # カーネル行列を計算
            lengthscale = layer.l.detach()  # Shape: [1, 1]
            variance = layer.s.detach()  # Shape: [1, 1]

            # Set i=j=1 for processing (assuming we want the first GP component)
            i, j = 0, 0  # Using 0-based indexing for tensor access

            # Get parameters for this specific GP
            z_ij = z_range[i, j, :]  # Shape: [X]
            l_ij = lengthscale[i, j]  # Scalar
            s_ij = variance[i, j]  # Scalar

            # Reshape inducing points for distance computation
            z_ij = z_ij.unsqueeze(1)  # Shape: [X, 1]

            # Compute kernel matrix for this GP
            pairwise_sq_dists = torch.cdist(z_ij, z_ij, p=2) ** 2
            # 誘導点間のカーネル行列
            K = s_ij * torch.exp(-pairwise_sq_dists / (2 * l_ij**2))

            print("計算開始")
            # ランク計算
            rank_clean = torch.linalg.matrix_rank(K)

            # 条件数計算
            cond_clean = torch.linalg.cond(K)

            # 固有値
            eigenvals_clean = torch.linalg.eigvals(K).real

            print("計算完了")

            print(f"カーネル行列ランク: {rank_clean.item()}")
            print(f"条件数: {cond_clean.item():.2e}")
            print(f"最小固有値: {eigenvals_clean.min().item():.2e}")
            print(
                f"パラメータ値 - s_ij: {s_ij.item():.4f}, l_ij: {l_ij.item():.4f}, jitter: {jitter.item():.4f}"
            )

        # 可視化
        fig, axes = plt.subplots(2, 3, figsize=(15, 10))

        # 誘導点の分布
        axes[0, 0].scatter(
            z_range.numpy(),
            h_range.numpy(),
            alpha=0.7,
            s=50,
        )
        axes[0, 0].set_title(f"Layer {layer_idx}: 誘導点分布")
        axes[0, 0].set_xlabel("誘導点位置")
        axes[0, 0].grid(True, alpha=0.3)

        # カーネル行列のヒートマップ
        im1 = axes[0, 1].imshow(K.numpy(), cmap="viridis")
        axes[0, 1].set_title(f"カーネル行列\nRank: {rank_clean.item()}")
        plt.colorbar(im1, ax=axes[0, 1])

        # パラメータ値のプロット
        params = ["s", "l", "jitter"]
        values = [s_ij.item(), l_ij.item(), jitter.item()]
        axes[0, 2].bar(params, values)
        axes[0, 2].set_title("パラメータ値")
        axes[0, 2].set_ylabel("値")
        for i, v in enumerate(values):
            axes[0, 2].text(i, v, f"{v:.4f}", ha="center", va="bottom")

        # 固有値分布
        eigenvals_sorted = torch.sort(eigenvals_clean, descending=True)[0]
        axes[1, 0].semilogy(eigenvals_sorted.numpy(), "o-")
        axes[1, 0].set_title("固有値分布")
        axes[1, 0].set_xlabel("固有値インデックス")
        axes[1, 0].set_ylabel("固有値 (log scale)")
        axes[1, 0].grid(True, alpha=0.3)

        # 条件数とランクの可視化
        metrics = ["Rank", "Condition Number (log)"]
        metric_values = [rank_clean.item(), np.log10(cond_clean.item())]
        axes[1, 1].bar(metrics, metric_values)
        axes[1, 1].set_title("行列特性")
        axes[1, 1].set_ylabel("値")
        for i, v in enumerate(metric_values):
            if i == 0:
                axes[1, 1].text(i, v, f"{int(v)}", ha="center", va="bottom")
            else:
                axes[1, 1].text(i, v, f"{v:.2f}", ha="center", va="bottom")

        # パラメータ値の詳細プロット（対数スケール）
        axes[1, 2].bar(params, np.log10(np.abs(values)))
        axes[1, 2].set_title("パラメータ値 (log10)")
        axes[1, 2].set_ylabel("log10(値)")
        for i, v in enumerate(values):
            axes[1, 2].text(i, np.log10(abs(v)), f"{v:.4f}", ha="center", va="bottom")

        plt.tight_layout()
        plt.show()

        # 誘導点間の距離分析
        distances = torch.cdist(z_ij.unsqueeze(0), z_ij.unsqueeze(0)).squeeze(
            0
        )  # Shape: [X, X]
        min_dist = distances[distances > 0].min()
        max_dist = distances[distances > 0].max()
        mean_dist = distances[distances > 0].mean()

        print(
            f"誘導点間距離 - 最小: {min_dist.item():.4f}, 最大: {max_dist.item():.4f}, 平均: {mean_dist.item():.4f}"
        )

        # 距離分布のヒストグラム
        plt.figure(figsize=(10, 6))
        dist_flat = distances[distances > 0].numpy()
        plt.hist(dist_flat, bins=20, alpha=0.7, edgecolor="black")
        plt.axvline(
            min_dist.item(),
            color="red",
            linestyle="--",
            label=f"最小距離: {min_dist.item():.4f}",
        )
        plt.axvline(
            mean_dist.item(),
            color="green",
            linestyle="--",
            label=f"平均距離: {mean_dist.item():.4f}",
        )
        plt.xlabel("誘導点間距離")
        plt.ylabel("頻度")
        plt.title(f"Layer {layer_idx}: 誘導点間距離分布")
        plt.legend()
        plt.grid(True, alpha=0.3)
        plt.show()


# 実行
analyze_kernel_matrices(model)
# Out:
# posx and posy should be finite values
# === カーネル行列分析 ===
#
# --- Layer 0 ---
# z(誘導点)の範囲: [-1.0000, 1.0000]
# h(関数値)の範囲: [-9.2986, 6.6679]
# 計算開始
# 計算完了
# カーネル行列ランク: 2
# 条件数: inf
# 最小固有値: -1.59e+02
# パラメータ値 - s_ij: -15.8713, l_ij: 50.9794, jitter: 3.3653
# posx and posy should be finite values
# 誘導点間距離 - 最小: 0.0000, 最大: 2.0000, 平均: 1.3827
# --- Layer 1 ---
# z(誘導点)の範囲: [-1.0000, 1.0000]
# h(関数値)の範囲: [-1.1668, 2.2212]
# 計算開始
# 計算完了
# カーネル行列ランク: 2
# 条件数: 2.70e+09
# 最小固有値: -1.03e+00
# パラメータ値 - s_ij: -0.1066, l_ij: -5.4054, jitter: 0.0084
# 誘導点間距離 - 最小: 0.0000, 最大: 2.0000, 平均: 1.0614

# %% [markdown]
# ### 考察
# カーネルのハイパーパラメータ$s,l$が学習中に負の値を取ってしまっている。
# 原因として考えられるのは以下
# 1) 学習率高すぎて$s,l$小さくする時に更新しすぎた→学習率小さくした結果を別notebookで確認
# 2) バッチサイズが小さすぎて変な方向にパラメータ更新された→バッチサイズ大きくした結果を別notebookで確認

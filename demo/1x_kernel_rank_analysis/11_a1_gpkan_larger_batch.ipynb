# %% [markdown]
# # GP-KANの学習安定化方法調査: a.バッチサイズ増加

# %% [markdown]
# ## 0.背景/目的
# GP-KANの学習(誘導点・カーネルパラメータの同時学習)時、処理がうまくいかない現象が発生していた。
#
# 原因として考えられるのは以下の通り：
#
# * a. バッチサイズが小さいことで、ミニバッチデータに偏りが生じる
# * b. カーネル行列のJitter項が大きい※1ため、出力層以外の誘導点が縦に並んでいる(x軸:入力,y軸:中間層出力)
# * c. 損失関数(負の対数尤度)は誘導点が近いほど小さい値を取るため、カーネル行列が縮退しやすい
#
# ※1. 関数値を取る確率変数 $f\sim GP(m(\cdot),k(\cdot, \cdot))$ と独立なノイズが多く含まれることに相当する。
# ここで、GPの出力 $y$ に対して
# $$
# y = f(x)+\epsilon,\ \ \  \epsilon\sim \mathcal{N}(0, \sigma_\epsilon^2)
# $$
#
# そのため、以下の追加実験を行いGP-KANの学習が安定しない原因のあたりをつける。
#
# * a. バッチサイズを大きくする
# * b. Jitter項のパラメータ設定値を小さくして学習実行
# * c. 誘導点が近づかないようなペナルティ項入れて学習
#
# 本notebookでは、<span style="color: red;">**a.の検証**</span>として以下設定で学習を行い結果を評価する：
# ### モデル構成
# - **ネットワーク構造**: 2層GP-KAN (入力1次元 → 中間層1次元 → 出力1次元)
# - **誘導点数**: 各GPあたり10点
# - **GP構成**: (0,0), (1,0) の2つのガウス過程
#
# ### 学習パラメータ
# - **エポック数**: 400エポック
# - **学習率**: 1e-5
# - **バッチサイズ**: 32→<span style="color: red;">**128**</span>
# - **事前学習**: 無効 (pretrain=False)
#
# ### 正則化パラメータ
# - **global_jitter**: 1e-3
# - **baseline_jitter**: 1e-3

# %%
JITTER_VALUE = 1e-3  # Jitter項の値

# %%
SAVELOAD_PATH = "model_12_a1.pt"

# %% [markdown]
# ## 1.問題設定
#
# 真の関数: フーリエ級数
# $$f(t) = \frac{4}{\pi} \sum_{n=1}^{N} \frac{1}{n} \sin(nt), \quad n = 1, 3, 5, \ldots, \quad t \in [0, 1]$$
# ※$N=15$
#
# データ:
# - 合計1,000件: 学習700件/検証150件/評価150件
# - tは$(-1,1)$から一様ランダムサンプリング
#
# モデル:
# - 2層のGPKAN: 入力1次元/中間層1次元/出力1次元
#     - それぞれのGPを(<1層目のindex>,<2層目のindex>)形式で表すことにすると、GPKANは$(0,0),(1,0)$の2つのGPで構成

# %% [markdown]
# ## 2.メイン処理
# 本ノートブックのメイン処理を実行する。実行順は以下の通り：
#
# 2-1.データセット作成
#
# 2-2.GPKANの学習
#
# 2-3.精度評価
#
# 2-4.学習中のカーネル行列ランク可視化

# %% [markdown]
# ### 2-1.データセット作成

# %%
# 初期設定: 必要なライブラリをインポートし、パスを設定
import os
import sys

sys.path.append("../")
import japanize_matplotlib
import torch.utils.data
from lib import model as gplib
from lib import runner
from torch.utils.data import DataLoader

# %%
import random

import matplotlib.pyplot as plt
import numpy as np
import torch
from torch.utils.data import DataLoader, TensorDataset


# Generate synthetic data with Fourier series function
def set_seed(seed=42):
    """完全な再現性のための乱数シード設定"""
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)


def worker_init_fn(worker_id):
    """DataLoaderワーカープロセス用の乱数シード設定"""
    worker_seed = torch.initial_seed() % 2**32
    np.random.seed(worker_seed)
    random.seed(worker_seed)


set_seed(42)  # 全体の乱数シード設定
num_samples = 1000

# Generate random input points t from [-1, 1]
t = np.random.uniform(-1, 1, num_samples)


# Compute target values: f(t) = (4/π) * Σ(1/n * sin(nt)) for odd n up to N=15
def fourier_series(t, N=15):
    result = np.zeros_like(t)
    for n in range(1, N + 1, 2):  # odd numbers only: 1, 3, 5, 7, 9, 11, 13, 15
        result += (1 / n) * np.sin(n * t)
    return (4 / np.pi) * result


targets = fourier_series(t, N=15)

# Reshape inputs (t is 1D, but we need it as 2D for compatibility)
inputs = t.reshape(-1, 1)

# Convert to PyTorch tensors
X_tensor = torch.FloatTensor(inputs)
y_tensor = torch.FloatTensor(targets).reshape(-1, 1)

# Split data into train, validation, and test sets
train_size = int(0.7 * num_samples)
val_size = int(0.15 * num_samples)
test_size = num_samples - train_size - val_size

X_train = X_tensor[:train_size]
y_train = y_tensor[:train_size]

X_val = X_tensor[train_size : train_size + val_size]
y_val = y_tensor[train_size : train_size + val_size]

X_test = X_tensor[train_size + val_size :]
y_test = y_tensor[train_size + val_size :]

# データを昇順にソート（X_testとy_testを対応を保ちながら）
sorted_indices = torch.argsort(X_test.squeeze())
X_test = X_test[sorted_indices]
y_test = y_test[sorted_indices]

# Create datasets
train_dataset = TensorDataset(X_train, y_train)
val_dataset = TensorDataset(X_val, y_val)
test_dataset = TensorDataset(X_test, y_test)

# Create dataloaders
batch_size = 128  # 32から128に変更
# Out:
# Train samples: 700
# Validation samples: 150
# Test samples: 150

# %%
# Create dataloaders with reproducible worker processes
generator = torch.Generator()
generator.manual_seed(42)

train_dataloader = DataLoader(
    train_dataset,
    batch_size=batch_size,
    shuffle=True,
    num_workers=0,  # Single process for reproducibility
    worker_init_fn=worker_init_fn,
    generator=generator,
)
val_dataloader = DataLoader(
    val_dataset,
    batch_size=batch_size,
    shuffle=False,
    num_workers=0,  # Single process for reproducibility
    worker_init_fn=worker_init_fn,
    generator=generator,
)
test_dataloader = DataLoader(
    test_dataset,
    batch_size=batch_size,
    shuffle=False,
    num_workers=0,  # Single process for reproducibility
    worker_init_fn=worker_init_fn,
    generator=generator,
)

# %%
# サンプル数確認
print(f"Train samples: {len(train_dataset)}")
print(f"Validation samples: {len(val_dataset)}")
print(f"Test samples: {len(test_dataset)}")

# Fourier級数関数のプロット
t_plot = np.linspace(-1, 1, 1000)
y_plot = fourier_series(t_plot, N=15)
plt.figure(figsize=(10, 6))
plt.plot(t_plot, y_plot, "b-", label="Fourier Series (N=15)")
plt.scatter(t, targets, alpha=0.3, s=3, c="red", label="Training Data")
plt.xlabel("t")
plt.ylabel("f(t)")
plt.title("Fourier Series Function")
plt.legend()
plt.grid(True)
plt.show()

# %%
# y（目的変数）の分布をヒストグラムで可視化
plt.figure(figsize=(15, 10))


# 学習データのヒストグラム
plt.subplot(1, 1, 1)
plt.hist(
    y_train.numpy().flatten(), bins=30, alpha=0.7, color="green", edgecolor="black"
)
plt.xlabel("y (target values)")
plt.ylabel("Frequency")
plt.title("Training Data Distribution")
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()


# 値の分布特性
print(f"\n=== 値の分布特性 ===")
print(f"正の値の割合: {np.sum(targets > 0) / len(targets) * 100:.1f}%")
print(f"負の値の割合: {np.sum(targets < 0) / len(targets) * 100:.1f}%")
print(
    f"ゼロ近傍(-0.1 < y < 0.1)の割合: {np.sum(np.abs(targets) < 0.1) / len(targets) * 100:.1f}%"
)
# Out:
# === 値の分布特性 ===
# 正の値の割合: 49.7%
# 負の値の割合: 50.3%
# ゼロ近傍(-0.1 < y < 0.1)の割合: 1.3%

# %% [markdown]
# ### 2-2.モデル学習

# %%
num_gp_pts = 10  # Number of Gaussian Process points
model = gplib.GP_Model(
    [
        gplib.LayerFused(1, 1, num_gp_pts),
        gplib.LayerFused(1, 1, num_gp_pts),
    ],
    saveload_path=SAVELOAD_PATH,  # Path to save/load the model
)
np.random.seed(42)  # for reproducibility
torch.manual_seed(42)  # for reproducibility

# %%
# 精度評価/可視化関数
def plot_result(model):
    # テストデータでの予測
    with torch.no_grad():
        # バッチごとに予測を行う
        test_predictions = []
        test_targets = []
        test_variances = []

        for X_batch, y_batch in test_dataloader:
            pred = model.predict(X_batch).mean
            var = model.predict(X_batch).var
            test_predictions.append(pred)
            test_variances.append(var)
            test_targets.append(y_batch)

        # 結果を結合
        test_predictions = torch.cat(test_predictions, dim=0)
        test_targets = torch.cat(test_targets, dim=0)
        test_variances = torch.cat(test_variances, dim=0)

    # MSE計算
    mse = torch.mean((test_predictions - test_targets) ** 2)
    rmse = torch.sqrt(mse)

    print(f"Test MSE: {mse.item():.6f}")
    print(f"Test RMSE: {rmse.item():.6f}")

    # 可視化用のデータ準備
    t_test = X_test.numpy().flatten()
    y_test_true = y_test.numpy().flatten()
    y_test_pred = test_predictions.numpy().flatten()

    # 真の関数の連続プロット用
    t_continuous = np.linspace(-1, 1, 500)
    y_continuous = fourier_series(t_continuous, N=15)

    # グラフ作成
    plt.figure(figsize=(12, 8))

    # 真の関数
    plt.plot(
        t_continuous,
        y_continuous,
        "b-",
        linewidth=2,
        label="True Function (Fourier Series)",
        alpha=0.8,
    )

    # テストデータの真値
    plt.scatter(
        t_test,
        y_test_true,
        c="red",
        s=30,
        alpha=0.6,
        label="Test Data (True)",
        marker="o",
    )

    # 予測値
    plt.scatter(
        t_test, y_test_pred, c="green", s=30, alpha=0.6, label="Predictions", marker="x"
    )

    # 予測の不確実性を帯で表示
    lower_bound = y_test_pred - 2 * np.sqrt(test_variances.numpy().flatten())
    upper_bound = y_test_pred + 2 * np.sqrt(test_variances.numpy().flatten())
    plt.fill_between(
        t_test,
        lower_bound,
        upper_bound,
        color="lightgreen",
        alpha=0.3,
        label="Prediction Interval(2σ)",
    )

    plt.xlabel("t")
    plt.ylabel("f(t)")
    plt.title(f"GP-KAN Prediction vs True Function\nTest RMSE: {rmse.item():.6f}")
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.show()

    # 残差プロット
    plt.figure(figsize=(10, 6))
    residuals = y_test_pred - y_test_true
    plt.scatter(t_test, residuals, c="purple", s=30, alpha=0.6)
    plt.axhline(y=0, color="red", linestyle="--", alpha=0.7)
    plt.xlabel("t")
    plt.ylabel("Residuals (Predicted - True)")
    plt.title("Residual Plot")
    plt.grid(True, alpha=0.3)
    plt.show()

    # 残差の統計情報
    print(f"\nResidual Statistics:")
    print(f"Mean: {np.mean(residuals):.6f}")
    print(f"Std: {np.std(residuals):.6f}")
    print(f"Min: {np.min(residuals):.6f}")
    print(f"Max: {np.max(residuals):.6f}")

    print("plot completed")
    return 0

# %%
for epoch in range(1):
    runner.train_model(
        train_dataloader,
        val_dataloader,
        model,
        epochs=400,
        learning_rate=1e-5,
        use_gpu=False,  # True,
        pretrain=False,  # True,
        global_jitter=JITTER_VALUE,
        baseline_jitter=JITTER_VALUE,
    )
    model.save_model()  # optionally save the model after training

    # 可視化
    plot_result(model)
# Out:
# epoch 0  , train negloglik: 705.95690,    val negloglik: 199.90811    accuracy: 4.9198 lr: [1e-05]
# epoch 1  , train negloglik: 162.09913,    val negloglik: 129.16623    accuracy: 2.7415 lr: [9e-06]
# epoch 2  , train negloglik: 165.43638,    val negloglik: 73.78082    accuracy: 2.5717 lr: [9e-06]
# epoch 3  , train negloglik: 97.53839,    val negloglik: 60.76729    accuracy: 1.4063 lr: [9e-06]
# epoch 4  , train negloglik: 63.00330,    val negloglik: 47.29587    accuracy: 1.3368 lr: [9e-06]
# epoch 5  , train negloglik: 57.73593,    val negloglik: 82.84850    accuracy: 1.1624 lr: [9e-06]
# epoch 6  , train negloglik: 66.78307,    val negloglik: 40.97923    accuracy: 0.9709 lr: [9e-06]
# epoch 7  , train negloglik: 47.85943,    val negloglik: 34.23028    accuracy: 0.9418 lr: [9e-06]
# epoch 8  , train negloglik: 32.85047,    val negloglik: 29.16851    accuracy: 0.9081 lr: [9e-06]
# epoch 9  , train negloglik: 26.91526,    val negloglik: 26.98038    accuracy: 0.8915 lr: [9e-06]
# epoch 10 , train negloglik: 37.96106,    val negloglik: 28.65743    accuracy: 0.8813 lr: [9e-06]
# epoch 11 , train negloglik: 39.30403,    val negloglik: 46.05989    accuracy: 0.8502 lr: [9e-06]
# epoch 12 , train negloglik: 34.64226,    val negloglik: 38.89750    accuracy: 0.8023 lr: [9e-06]
# epoch 13 , train negloglik: 49.10997,    val negloglik: 25.35710    accuracy: 0.7991 lr: [9e-06]
# epoch 14 , train negloglik: 26.85352,    val negloglik: 40.68661    accuracy: 0.8344 lr: [9e-06]
# epoch 15 , train negloglik: 36.49929,    val negloglik: 24.42110    accuracy: 0.8678 lr: [9e-06]
# epoch 16 , train negloglik: 29.95094,    val negloglik: 29.21809    accuracy: 0.8966 lr: [9e-06]
# epoch 17 , train negloglik: 25.36721,    val negloglik: 30.35101    accuracy: 0.9011 lr: [9e-06]
# epoch 18 , train negloglik: 29.26294,    val negloglik: 29.09579    accuracy: 0.9335 lr: [9e-06]
# epoch 19 , train negloglik: 18.48667,    val negloglik: 10.40948    accuracy: 0.9939 lr: [9e-06]
# epoch 20 , train negloglik: 12.08719,    val negloglik: 26.06251    accuracy: 1.0807 lr: [9e-06]
# epoch 21 , train negloglik: 15.77541,    val negloglik: 18.15126    accuracy: 0.9515 lr: [8.1e-06]
# epoch 22 , train negloglik: 17.68788,    val negloglik: 16.49397    accuracy: 0.9013 lr: [8.1e-06]
# epoch 23 , train negloglik: 13.88505,    val negloglik: 22.74243    accuracy: 0.9696 lr: [8.1e-06]
# epoch 24 , train negloglik: 17.98115,    val negloglik: 43.00319    accuracy: 0.9450 lr: [8.1e-06]
# epoch 25 , train negloglik: 19.33133,    val negloglik: 8.49375    accuracy: 0.8913 lr: [8.1e-06]
# epoch 26 , train negloglik: 11.44982,    val negloglik: 11.85534    accuracy: 0.9780 lr: [8.1e-06]
# epoch 27 , train negloglik: 3.30715,    val negloglik: 11.91039    accuracy: 0.9647 lr: [8.1e-06]
# epoch 28 , train negloglik: 5.66657,    val negloglik: 12.18780    accuracy: 0.9694 lr: [8.1e-06]
# epoch 29 , train negloglik: 14.66385,    val negloglik: 10.70086    accuracy: 0.9666 lr: [8.1e-06]
# epoch 30 , train negloglik: 13.16801,    val negloglik: 14.45827    accuracy: 0.9825 lr: [8.1e-06]
# epoch 31 , train negloglik: 8.89255,    val negloglik: 8.52769    accuracy: 0.9589 lr: [8.1e-06]
# epoch 32 , train negloglik: 10.37736,    val negloglik: 12.55112    accuracy: 0.9721 lr: [8.1e-06]
# epoch 33 , train negloglik: 10.17605,    val negloglik: 13.70539    accuracy: 0.9631 lr: [8.1e-06]
# epoch 34 , train negloglik: 13.32417,    val negloglik: 21.29816    accuracy: 0.9882 lr: [8.1e-06]
# epoch 35 , train negloglik: 11.54822,    val negloglik: 8.46029    accuracy: 0.9731 lr: [8.1e-06]
# epoch 36 , train negloglik: 8.82285,    val negloglik: 9.97999    accuracy: 0.9519 lr: [8.1e-06]
# epoch 37 , train negloglik: 10.45077,    val negloglik: 8.93461    accuracy: 0.9542 lr: [8.1e-06]
# epoch 38 , train negloglik: 6.96709,    val negloglik: 11.21662    accuracy: 0.9603 lr: [8.1e-06]
# epoch 39 , train negloglik: 10.07185,    val negloglik: 13.03586    accuracy: 0.9655 lr: [8.1e-06]
# epoch 40 , train negloglik: 8.09483,    val negloglik: 11.19391    accuracy: 0.9607 lr: [8.1e-06]
# epoch 41 , train negloglik: 8.55718,    val negloglik: 10.01336    accuracy: 0.9487 lr: [7.2900000000000005e-06]
# epoch 42 , train negloglik: 7.39774,    val negloglik: 8.31773    accuracy: 0.9580 lr: [7.2900000000000005e-06]
# epoch 43 , train negloglik: 8.73338,    val negloglik: 13.22256    accuracy: 0.9602 lr: [7.2900000000000005e-06]
# epoch 44 , train negloglik: 11.34476,    val negloglik: 8.12589    accuracy: 0.9487 lr: [7.2900000000000005e-06]
# epoch 45 , train negloglik: 8.49764,    val negloglik: 13.28504    accuracy: 0.9499 lr: [7.2900000000000005e-06]
# epoch 46 , train negloglik: 10.32351,    val negloglik: 12.53890    accuracy: 0.9570 lr: [7.2900000000000005e-06]
# epoch 47 , train negloglik: 10.01774,    val negloglik: 13.61140    accuracy: 0.9257 lr: [7.2900000000000005e-06]
# epoch 48 , train negloglik: 10.62459,    val negloglik: 13.93427    accuracy: 0.9517 lr: [7.2900000000000005e-06]
# epoch 49 , train negloglik: 9.20683,    val negloglik: 14.68949    accuracy: 0.9343 lr: [7.2900000000000005e-06]
# epoch 50 , train negloglik: 10.85207,    val negloglik: 10.87640    accuracy: 0.9360 lr: [7.2900000000000005e-06]
# epoch 51 , train negloglik: 9.47617,    val negloglik: 12.35252    accuracy: 0.9430 lr: [7.2900000000000005e-06]
# epoch 52 , train negloglik: 9.02063,    val negloglik: 12.88300    accuracy: 0.9478 lr: [7.2900000000000005e-06]
# epoch 53 , train negloglik: 7.76018,    val negloglik: 11.39277    accuracy: 0.9383 lr: [7.2900000000000005e-06]
# epoch 54 , train negloglik: 8.13549,    val negloglik: 10.43932    accuracy: 0.9301 lr: [7.2900000000000005e-06]
# epoch 55 , train negloglik: 10.13022,    val negloglik: 8.05556    accuracy: 0.9847 lr: [7.2900000000000005e-06]
# epoch 56 , train negloglik: 6.21681,    val negloglik: 6.82473    accuracy: 0.9891 lr: [7.2900000000000005e-06]
# epoch 57 , train negloglik: 4.75065,    val negloglik: 5.26093    accuracy: 0.9953 lr: [7.2900000000000005e-06]
# epoch 58 , train negloglik: 4.05098,    val negloglik: 9.67254    accuracy: 0.9804 lr: [7.2900000000000005e-06]
# epoch 59 , train negloglik: 5.48772,    val negloglik: 8.30491    accuracy: 0.9911 lr: [7.2900000000000005e-06]
# epoch 60 , train negloglik: 5.26782,    val negloglik: 6.78361    accuracy: 0.9873 lr: [7.2900000000000005e-06]
# epoch 61 , train negloglik: 6.43978,    val negloglik: 4.34700    accuracy: 1.0149 lr: [6.561e-06]
# epoch 62 , train negloglik: 12.70334,    val negloglik: 25.82359    accuracy: 1.0045 lr: [6.561e-06]
# epoch 63 , train negloglik: 19.83186,    val negloglik: 15.58929    accuracy: 0.9746 lr: [6.561e-06]
# epoch 64 , train negloglik: 5.73752,    val negloglik: 14.27967    accuracy: 0.9800 lr: [6.561e-06]
# epoch 65 , train negloglik: 7.09212,    val negloglik: 14.98986    accuracy: 0.9730 lr: [6.561e-06]
# epoch 66 , train negloglik: 5.69372,    val negloglik: 14.34768    accuracy: 0.9697 lr: [6.561e-06]
# epoch 67 , train negloglik: 6.05116,    val negloglik: 9.66863    accuracy: 0.9666 lr: [6.561e-06]
# epoch 68 , train negloglik: 5.43890,    val negloglik: 15.58060    accuracy: 0.9765 lr: [6.561e-06]
# epoch 69 , train negloglik: 6.85230,    val negloglik: 13.36273    accuracy: 0.9687 lr: [6.561e-06]
# epoch 70 , train negloglik: 5.12787,    val negloglik: 9.09396    accuracy: 0.9608 lr: [6.561e-06]
# epoch 71 , train negloglik: 4.63884,    val negloglik: 13.98084    accuracy: 0.9732 lr: [6.561e-06]
# epoch 72 , train negloglik: 5.52091,    val negloglik: 12.30381    accuracy: 0.9718 lr: [6.561e-06]
# epoch 73 , train negloglik: 3.65564,    val negloglik: 8.31937    accuracy: 0.9617 lr: [6.561e-06]
# epoch 74 , train negloglik: 6.24378,    val negloglik: 11.43764    accuracy: 0.9700 lr: [6.561e-06]
# epoch 75 , train negloglik: 5.00877,    val negloglik: 10.29361    accuracy: 0.9676 lr: [6.561e-06]
# epoch 76 , train negloglik: 5.56400,    val negloglik: 12.42192    accuracy: 0.9696 lr: [6.561e-06]
# epoch 77 , train negloglik: 3.84690,    val negloglik: 9.83817    accuracy: 0.9667 lr: [6.561e-06]
# epoch 78 , train negloglik: 3.63535,    val negloglik: 11.81048    accuracy: 0.9650 lr: [6.561e-06]
# epoch 79 , train negloglik: 4.23392,    val negloglik: 11.44342    accuracy: 0.9671 lr: [6.561e-06]
# epoch 80 , train negloglik: 4.10664,    val negloglik: 9.21275    accuracy: 0.9619 lr: [6.561e-06]
# epoch 81 , train negloglik: 4.60062,    val negloglik: 13.20442    accuracy: 0.9638 lr: [5.904900000000001e-06]
# epoch 82 , train negloglik: 3.65557,    val negloglik: 10.55295    accuracy: 0.9593 lr: [5.904900000000001e-06]
# epoch 83 , train negloglik: 2.84145,    val negloglik: 10.46182    accuracy: 0.9623 lr: [5.904900000000001e-06]
# epoch 84 , train negloglik: 4.11559,    val negloglik: 12.41780    accuracy: 0.9671 lr: [5.904900000000001e-06]
# epoch 85 , train negloglik: 5.93976,    val negloglik: 12.42700    accuracy: 0.9650 lr: [5.904900000000001e-06]
# epoch 86 , train negloglik: 3.29279,    val negloglik: 11.04372    accuracy: 0.9646 lr: [5.904900000000001e-06]
# epoch 87 , train negloglik: 4.73174,    val negloglik: 12.03116    accuracy: 0.9715 lr: [5.904900000000001e-06]
# epoch 88 , train negloglik: 4.16854,    val negloglik: 11.93121    accuracy: 0.9630 lr: [5.904900000000001e-06]
# epoch 89 , train negloglik: 4.57495,    val negloglik: 12.71675    accuracy: 0.9708 lr: [5.904900000000001e-06]
# epoch 90 , train negloglik: 3.80327,    val negloglik: 14.17214    accuracy: 0.9740 lr: [5.904900000000001e-06]
# epoch 91 , train negloglik: 5.26558,    val negloglik: 15.65162    accuracy: 0.9718 lr: [5.904900000000001e-06]
# epoch 92 , train negloglik: 4.01174,    val negloglik: 13.25903    accuracy: 0.9688 lr: [5.904900000000001e-06]
# epoch 93 , train negloglik: 5.63498,    val negloglik: 12.58980    accuracy: 0.9703 lr: [5.904900000000001e-06]
# epoch 94 , train negloglik: 4.39680,    val negloglik: 11.72413    accuracy: 0.9655 lr: [5.904900000000001e-06]
# epoch 95 , train negloglik: 4.89504,    val negloglik: 12.28406    accuracy: 0.9646 lr: [5.904900000000001e-06]
# epoch 96 , train negloglik: 2.88005,    val negloglik: 10.51121    accuracy: 0.9612 lr: [5.904900000000001e-06]
# epoch 97 , train negloglik: 3.86256,    val negloglik: 9.68035    accuracy: 0.9599 lr: [5.904900000000001e-06]
# epoch 98 , train negloglik: 3.81720,    val negloglik: 12.87687    accuracy: 0.9689 lr: [5.904900000000001e-06]
# epoch 99 , train negloglik: 4.69091,    val negloglik: 11.41072    accuracy: 0.9652 lr: [5.904900000000001e-06]
# epoch 100, train negloglik: 3.85467,    val negloglik: 10.96589    accuracy: 0.9635 lr: [5.904900000000001e-06]
# epoch 101, train negloglik: 4.27551,    val negloglik: 14.53480    accuracy: 0.9730 lr: [5.314410000000001e-06]
# epoch 102, train negloglik: 2.91067,    val negloglik: 13.76928    accuracy: 0.9783 lr: [5.314410000000001e-06]
# epoch 103, train negloglik: 3.50459,    val negloglik: 8.82075    accuracy: 0.9617 lr: [5.314410000000001e-06]
# epoch 104, train negloglik: 3.65097,    val negloglik: 13.72336    accuracy: 0.9750 lr: [5.314410000000001e-06]
# epoch 105, train negloglik: 4.28941,    val negloglik: 11.17033    accuracy: 0.9893 lr: [5.314410000000001e-06]
# epoch 106, train negloglik: 5.03548,    val negloglik: 10.89077    accuracy: 0.9909 lr: [5.314410000000001e-06]
# epoch 107, train negloglik: 3.12504,    val negloglik: 17.40038    accuracy: 0.9752 lr: [5.314410000000001e-06]
# epoch 108, train negloglik: 4.06171,    val negloglik: 15.90598    accuracy: 0.9801 lr: [5.314410000000001e-06]
# epoch 109, train negloglik: 4.37986,    val negloglik: 7.24407    accuracy: 0.9987 lr: [5.314410000000001e-06]
# epoch 110, train negloglik: 4.00254,    val negloglik: 14.82453    accuracy: 0.9690 lr: [5.314410000000001e-06]
# epoch 111, train negloglik: 3.80543,    val negloglik: 13.04560    accuracy: 0.9795 lr: [5.314410000000001e-06]
# epoch 112, train negloglik: 4.60786,    val negloglik: 14.03724    accuracy: 0.9693 lr: [5.314410000000001e-06]
# epoch 113, train negloglik: 3.25314,    val negloglik: 10.20902    accuracy: 0.9587 lr: [5.314410000000001e-06]
# epoch 114, train negloglik: 2.90143,    val negloglik: 9.79223    accuracy: 0.9577 lr: [5.314410000000001e-06]
# epoch 115, train negloglik: 4.41458,    val negloglik: 9.20788    accuracy: 0.9646 lr: [5.314410000000001e-06]
# epoch 116, train negloglik: 3.96960,    val negloglik: 8.20291    accuracy: 0.9886 lr: [5.314410000000001e-06]
# epoch 117, train negloglik: 3.73601,    val negloglik: 14.39960    accuracy: 0.9809 lr: [5.314410000000001e-06]
# epoch 118, train negloglik: 3.45316,    val negloglik: 16.52792    accuracy: 0.9724 lr: [5.314410000000001e-06]
# epoch 119, train negloglik: 3.93591,    val negloglik: 18.79705    accuracy: 0.9757 lr: [5.314410000000001e-06]
# epoch 120, train negloglik: 4.30296,    val negloglik: 10.87231    accuracy: 0.9677 lr: [5.314410000000001e-06]
# epoch 121, train negloglik: 3.82950,    val negloglik: 11.55579    accuracy: 0.9707 lr: [4.782969000000001e-06]
# epoch 122, train negloglik: 3.77462,    val negloglik: 11.16651    accuracy: 0.9674 lr: [4.782969000000001e-06]
# epoch 123, train negloglik: 3.92433,    val negloglik: 11.23939    accuracy: 0.9596 lr: [4.782969000000001e-06]
# epoch 124, train negloglik: 4.08710,    val negloglik: 12.17156    accuracy: 0.9870 lr: [4.782969000000001e-06]
# epoch 125, train negloglik: 4.81207,    val negloglik: 11.54887    accuracy: 0.9651 lr: [4.782969000000001e-06]
# epoch 126, train negloglik: 3.61972,    val negloglik: 15.00631    accuracy: 0.9712 lr: [4.782969000000001e-06]
# epoch 127, train negloglik: 4.49413,    val negloglik: 11.81684    accuracy: 1.0017 lr: [4.782969000000001e-06]
# epoch 128, train negloglik: 4.38868,    val negloglik: 13.18241    accuracy: 0.9844 lr: [4.782969000000001e-06]
# epoch 129, train negloglik: 3.85818,    val negloglik: 11.91605    accuracy: 0.9681 lr: [4.782969000000001e-06]
# epoch 130, train negloglik: 4.43339,    val negloglik: 9.61875    accuracy: 1.0006 lr: [4.782969000000001e-06]
# epoch 131, train negloglik: 3.16833,    val negloglik: 13.32846    accuracy: 0.9879 lr: [4.782969000000001e-06]
# epoch 132, train negloglik: 3.24630,    val negloglik: 8.88326    accuracy: 0.9553 lr: [4.782969000000001e-06]
# epoch 133, train negloglik: 2.90918,    val negloglik: 13.13909    accuracy: 0.9642 lr: [4.782969000000001e-06]
# epoch 134, train negloglik: 2.97265,    val negloglik: 10.41734    accuracy: 0.9681 lr: [4.782969000000001e-06]
# epoch 135, train negloglik: 3.66660,    val negloglik: 12.24484    accuracy: 0.9779 lr: [4.782969000000001e-06]
# epoch 136, train negloglik: 4.15702,    val negloglik: 10.64917    accuracy: 0.9617 lr: [4.782969000000001e-06]
# epoch 137, train negloglik: 4.37282,    val negloglik: 13.69543    accuracy: 0.9791 lr: [4.782969000000001e-06]
# epoch 138, train negloglik: 3.84629,    val negloglik: 15.93776    accuracy: 0.9692 lr: [4.782969000000001e-06]
# epoch 139, train negloglik: 3.21050,    val negloglik: 14.00247    accuracy: 0.9737 lr: [4.782969000000001e-06]
# epoch 140, train negloglik: 3.14176,    val negloglik: 12.70523    accuracy: 0.9694 lr: [4.782969000000001e-06]
# epoch 141, train negloglik: 3.23473,    val negloglik: 12.34876    accuracy: 0.9636 lr: [4.3046721000000005e-06]
# epoch 142, train negloglik: 2.88290,    val negloglik: 12.85418    accuracy: 0.9675 lr: [4.3046721000000005e-06]
# epoch 143, train negloglik: 3.05767,    val negloglik: 11.43977    accuracy: 0.9760 lr: [4.3046721000000005e-06]
# epoch 144, train negloglik: 2.86288,    val negloglik: 13.10586    accuracy: 0.9684 lr: [4.3046721000000005e-06]
# epoch 145, train negloglik: 3.20988,    val negloglik: 10.42554    accuracy: 0.9629 lr: [4.3046721000000005e-06]
# epoch 146, train negloglik: 4.16127,    val negloglik: 11.39338    accuracy: 0.9614 lr: [4.3046721000000005e-06]
# epoch 147, train negloglik: 2.76899,    val negloglik: 12.89295    accuracy: 0.9641 lr: [4.3046721000000005e-06]
# epoch 148, train negloglik: 4.17391,    val negloglik: 10.57875    accuracy: 0.9671 lr: [4.3046721000000005e-06]
# epoch 149, train negloglik: 5.07260,    val negloglik: 10.53917    accuracy: 0.9687 lr: [4.3046721000000005e-06]
# epoch 150, train negloglik: 4.62843,    val negloglik: 14.30179    accuracy: 0.9731 lr: [4.3046721000000005e-06]
# epoch 151, train negloglik: 4.28975,    val negloglik: 11.71655    accuracy: 0.9634 lr: [4.3046721000000005e-06]
# epoch 152, train negloglik: 3.10483,    val negloglik: 12.81300    accuracy: 0.9867 lr: [4.3046721000000005e-06]
# epoch 153, train negloglik: 2.90116,    val negloglik: 10.84165    accuracy: 0.9664 lr: [4.3046721000000005e-06]
# epoch 154, train negloglik: 2.83711,    val negloglik: 15.45526    accuracy: 0.9766 lr: [4.3046721000000005e-06]
# epoch 155, train negloglik: 3.45830,    val negloglik: 12.88190    accuracy: 0.9836 lr: [4.3046721000000005e-06]
# epoch 156, train negloglik: 3.56539,    val negloglik: 13.64755    accuracy: 0.9685 lr: [4.3046721000000005e-06]
# epoch 157, train negloglik: 3.36046,    val negloglik: 13.11775    accuracy: 0.9661 lr: [4.3046721000000005e-06]
# epoch 158, train negloglik: 2.89134,    val negloglik: 13.39588    accuracy: 0.9724 lr: [4.3046721000000005e-06]
# epoch 159, train negloglik: 2.69546,    val negloglik: 12.81805    accuracy: 0.9715 lr: [4.3046721000000005e-06]
# epoch 160, train negloglik: 3.25543,    val negloglik: 13.39289    accuracy: 0.9672 lr: [4.3046721000000005e-06]
# epoch 161, train negloglik: 3.50419,    val negloglik: 11.40210    accuracy: 0.9691 lr: [3.874204890000001e-06]
# epoch 162, train negloglik: 3.20110,    val negloglik: 15.73891    accuracy: 0.9773 lr: [3.874204890000001e-06]
# epoch 163, train negloglik: 2.99767,    val negloglik: 15.34555    accuracy: 0.9728 lr: [3.874204890000001e-06]
# epoch 164, train negloglik: 3.06416,    val negloglik: 12.43582    accuracy: 0.9748 lr: [3.874204890000001e-06]
# epoch 165, train negloglik: 3.44309,    val negloglik: 14.30690    accuracy: 0.9678 lr: [3.874204890000001e-06]
# epoch 166, train negloglik: 2.61507,    val negloglik: 9.24142    accuracy: 0.9849 lr: [3.874204890000001e-06]
# epoch 167, train negloglik: 3.04097,    val negloglik: 13.09705    accuracy: 0.9663 lr: [3.874204890000001e-06]
# epoch 168, train negloglik: 3.22088,    val negloglik: 14.20160    accuracy: 0.9739 lr: [3.874204890000001e-06]
# epoch 169, train negloglik: 2.64632,    val negloglik: 12.95486    accuracy: 0.9666 lr: [3.874204890000001e-06]
# epoch 170, train negloglik: 3.22219,    val negloglik: 10.77975    accuracy: 0.9673 lr: [3.874204890000001e-06]
# epoch 171, train negloglik: 3.04545,    val negloglik: 11.42470    accuracy: 0.9680 lr: [3.874204890000001e-06]
# epoch 172, train negloglik: 2.98538,    val negloglik: 11.55595    accuracy: 0.9651 lr: [3.874204890000001e-06]
# epoch 173, train negloglik: 3.19375,    val negloglik: 15.74327    accuracy: 0.9803 lr: [3.874204890000001e-06]
# epoch 174, train negloglik: 3.63938,    val negloglik: 13.94853    accuracy: 0.9732 lr: [3.874204890000001e-06]
# epoch 175, train negloglik: 3.12452,    val negloglik: 10.13809    accuracy: 0.9655 lr: [3.874204890000001e-06]
# epoch 176, train negloglik: 3.65802,    val negloglik: 13.83367    accuracy: 0.9708 lr: [3.874204890000001e-06]
# epoch 177, train negloglik: 2.75001,    val negloglik: 13.10911    accuracy: 0.9644 lr: [3.874204890000001e-06]
# epoch 178, train negloglik: 3.15673,    val negloglik: 11.18069    accuracy: 0.9827 lr: [3.874204890000001e-06]
# epoch 179, train negloglik: 2.84433,    val negloglik: 14.68209    accuracy: 0.9743 lr: [3.874204890000001e-06]
# epoch 180, train negloglik: 2.61213,    val negloglik: 11.30950    accuracy: 0.9784 lr: [3.874204890000001e-06]
# epoch 181, train negloglik: 2.65575,    val negloglik: 14.82050    accuracy: 0.9719 lr: [3.4867844010000007e-06]
# epoch 182, train negloglik: 2.78940,    val negloglik: 13.42261    accuracy: 0.9735 lr: [3.4867844010000007e-06]
# epoch 183, train negloglik: 2.40767,    val negloglik: 6.15834    accuracy: 0.9909 lr: [3.4867844010000007e-06]
# epoch 184, train negloglik: 3.17824,    val negloglik: 12.45554    accuracy: 0.9657 lr: [3.4867844010000007e-06]
# epoch 185, train negloglik: 2.98724,    val negloglik: 6.48754    accuracy: 0.9919 lr: [3.4867844010000007e-06]
# epoch 186, train negloglik: 3.28999,    val negloglik: 8.03915    accuracy: 0.9933 lr: [3.4867844010000007e-06]
# epoch 187, train negloglik: 2.82387,    val negloglik: 11.31036    accuracy: 0.9657 lr: [3.4867844010000007e-06]
# epoch 188, train negloglik: 3.26533,    val negloglik: 8.54844    accuracy: 0.9992 lr: [3.4867844010000007e-06]
# epoch 189, train negloglik: 2.64922,    val negloglik: 14.37065    accuracy: 0.9718 lr: [3.4867844010000007e-06]
# epoch 190, train negloglik: 2.90094,    val negloglik: 15.55733    accuracy: 0.9729 lr: [3.4867844010000007e-06]
# epoch 191, train negloglik: 2.94928,    val negloglik: 9.27637    accuracy: 0.9926 lr: [3.4867844010000007e-06]
# epoch 192, train negloglik: 2.56431,    val negloglik: 10.34813    accuracy: 0.9602 lr: [3.4867844010000007e-06]
# epoch 193, train negloglik: 3.21441,    val negloglik: 13.84876    accuracy: 0.9715 lr: [3.4867844010000007e-06]
# epoch 194, train negloglik: 4.14703,    val negloglik: 12.16990    accuracy: 0.9715 lr: [3.4867844010000007e-06]
# epoch 195, train negloglik: 2.63066,    val negloglik: 14.14588    accuracy: 0.9765 lr: [3.4867844010000007e-06]
# epoch 196, train negloglik: 2.75693,    val negloglik: 8.51896    accuracy: 0.9873 lr: [3.4867844010000007e-06]
# epoch 197, train negloglik: 3.05220,    val negloglik: 12.64617    accuracy: 0.9835 lr: [3.4867844010000007e-06]
# epoch 198, train negloglik: 3.02920,    val negloglik: 13.27901    accuracy: 0.9833 lr: [3.4867844010000007e-06]
# epoch 199, train negloglik: 2.73116,    val negloglik: 13.86207    accuracy: 0.9675 lr: [3.4867844010000007e-06]
# epoch 200, train negloglik: 3.92439,    val negloglik: 12.82176    accuracy: 0.9680 lr: [3.4867844010000007e-06]
# epoch 201, train negloglik: 3.05312,    val negloglik: 14.82453    accuracy: 0.9700 lr: [3.1381059609000006e-06]
# epoch 202, train negloglik: 2.90910,    val negloglik: 14.39158    accuracy: 0.9690 lr: [3.1381059609000006e-06]
# epoch 203, train negloglik: 2.97195,    val negloglik: 10.31676    accuracy: 0.9598 lr: [3.1381059609000006e-06]
# epoch 204, train negloglik: 2.50370,    val negloglik: 12.38860    accuracy: 0.9675 lr: [3.1381059609000006e-06]
# epoch 205, train negloglik: 2.27143,    val negloglik: 12.18359    accuracy: 0.9655 lr: [3.1381059609000006e-06]
# epoch 206, train negloglik: 2.62375,    val negloglik: 11.87567    accuracy: 0.9668 lr: [3.1381059609000006e-06]
# epoch 207, train negloglik: 3.74016,    val negloglik: 13.90591    accuracy: 0.9689 lr: [3.1381059609000006e-06]
# epoch 208, train negloglik: 2.48641,    val negloglik: 13.09924    accuracy: 0.9668 lr: [3.1381059609000006e-06]
# epoch 209, train negloglik: 3.94324,    val negloglik: 11.54839    accuracy: 0.9677 lr: [3.1381059609000006e-06]
# epoch 210, train negloglik: 2.69027,    val negloglik: 12.30838    accuracy: 0.9650 lr: [3.1381059609000006e-06]
# epoch 211, train negloglik: 2.72726,    val negloglik: 13.77776    accuracy: 0.9733 lr: [3.1381059609000006e-06]
# epoch 212, train negloglik: 3.03568,    val negloglik: 12.12119    accuracy: 0.9815 lr: [3.1381059609000006e-06]
# epoch 213, train negloglik: 2.56024,    val negloglik: 11.13388    accuracy: 0.9631 lr: [3.1381059609000006e-06]
# epoch 214, train negloglik: 2.53440,    val negloglik: 12.69158    accuracy: 0.9645 lr: [3.1381059609000006e-06]
# epoch 215, train negloglik: 2.17605,    val negloglik: 5.58661    accuracy: 0.9885 lr: [3.1381059609000006e-06]
# epoch 216, train negloglik: 2.46162,    val negloglik: 14.05318    accuracy: 0.9658 lr: [3.1381059609000006e-06]
# epoch 217, train negloglik: 1.90202,    val negloglik: 13.09588    accuracy: 0.9659 lr: [3.1381059609000006e-06]
# epoch 218, train negloglik: 3.16918,    val negloglik: 11.21903    accuracy: 0.9625 lr: [3.1381059609000006e-06]
# epoch 219, train negloglik: 3.02273,    val negloglik: 10.34488    accuracy: 0.9632 lr: [3.1381059609000006e-06]
# epoch 220, train negloglik: 2.89960,    val negloglik: 11.63108    accuracy: 0.9600 lr: [3.1381059609000006e-06]
# epoch 221, train negloglik: 3.28610,    val negloglik: 14.70364    accuracy: 0.9681 lr: [2.8242953648100006e-06]
# epoch 222, train negloglik: 2.63839,    val negloglik: 10.85407    accuracy: 0.9645 lr: [2.8242953648100006e-06]
# epoch 223, train negloglik: 3.48595,    val negloglik: 10.61262    accuracy: 0.9657 lr: [2.8242953648100006e-06]
# epoch 224, train negloglik: 2.48961,    val negloglik: 13.38083    accuracy: 0.9778 lr: [2.8242953648100006e-06]
# epoch 225, train negloglik: 2.06304,    val negloglik: 14.32661    accuracy: 0.9783 lr: [2.8242953648100006e-06]
# epoch 226, train negloglik: 3.02483,    val negloglik: 10.51206    accuracy: 0.9614 lr: [2.8242953648100006e-06]
# epoch 227, train negloglik: 2.22305,    val negloglik: 9.43754    accuracy: 0.9784 lr: [2.8242953648100006e-06]
# epoch 228, train negloglik: 3.36693,    val negloglik: 15.29492    accuracy: 0.9716 lr: [2.8242953648100006e-06]
# epoch 229, train negloglik: 3.26129,    val negloglik: 12.25593    accuracy: 0.9635 lr: [2.8242953648100006e-06]
# epoch 230, train negloglik: 2.32284,    val negloglik: 11.11316    accuracy: 0.9631 lr: [2.8242953648100006e-06]
# epoch 231, train negloglik: 2.79197,    val negloglik: 11.34294    accuracy: 0.9800 lr: [2.8242953648100006e-06]
# epoch 232, train negloglik: 2.33569,    val negloglik: 11.65184    accuracy: 0.9730 lr: [2.8242953648100006e-06]
# epoch 233, train negloglik: 2.48745,    val negloglik: 4.66247    accuracy: 0.9739 lr: [2.8242953648100006e-06]
# epoch 234, train negloglik: 2.54428,    val negloglik: 8.02505    accuracy: 0.9733 lr: [2.8242953648100006e-06]
# epoch 235, train negloglik: 2.60150,    val negloglik: 4.25511    accuracy: 0.9764 lr: [2.8242953648100006e-06]
# epoch 236, train negloglik: 2.01728,    val negloglik: 2.88438    accuracy: 0.9897 lr: [2.8242953648100006e-06]
# epoch 237, train negloglik: 2.00526,    val negloglik: 6.96312    accuracy: 0.9707 lr: [2.8242953648100006e-06]
# epoch 238, train negloglik: 2.42807,    val negloglik: 3.72356    accuracy: 0.9751 lr: [2.8242953648100006e-06]
# epoch 239, train negloglik: 2.76747,    val negloglik: 11.79128    accuracy: 0.9649 lr: [2.8242953648100006e-06]
# epoch 240, train negloglik: 1.88096,    val negloglik: 12.40238    accuracy: 0.9647 lr: [2.8242953648100006e-06]
# epoch 241, train negloglik: 2.81095,    val negloglik: 9.19042    accuracy: 0.9609 lr: [2.5418658283290006e-06]
# epoch 242, train negloglik: 2.31300,    val negloglik: 12.83234    accuracy: 0.9721 lr: [2.5418658283290006e-06]
# epoch 243, train negloglik: 1.99361,    val negloglik: 12.15929    accuracy: 0.9693 lr: [2.5418658283290006e-06]
# epoch 244, train negloglik: 2.09877,    val negloglik: 5.66835    accuracy: 0.9714 lr: [2.5418658283290006e-06]
# epoch 245, train negloglik: 2.66842,    val negloglik: 10.89237    accuracy: 0.9619 lr: [2.5418658283290006e-06]
# epoch 246, train negloglik: 2.50690,    val negloglik: 13.90033    accuracy: 0.9745 lr: [2.5418658283290006e-06]
# epoch 247, train negloglik: 2.30212,    val negloglik: 12.43183    accuracy: 0.9709 lr: [2.5418658283290006e-06]
# epoch 248, train negloglik: 2.60360,    val negloglik: 11.92878    accuracy: 0.9660 lr: [2.5418658283290006e-06]
# epoch 249, train negloglik: 2.40309,    val negloglik: 9.90489    accuracy: 0.9583 lr: [2.5418658283290006e-06]
# epoch 250, train negloglik: 2.45022,    val negloglik: 10.70521    accuracy: 0.9615 lr: [2.5418658283290006e-06]
# epoch 251, train negloglik: 2.06116,    val negloglik: 10.61679    accuracy: 0.9719 lr: [2.5418658283290006e-06]
# epoch 252, train negloglik: 2.15971,    val negloglik: 5.96712    accuracy: 0.9640 lr: [2.5418658283290006e-06]
# epoch 253, train negloglik: 2.50044,    val negloglik: 3.92088    accuracy: 0.9737 lr: [2.5418658283290006e-06]
# epoch 254, train negloglik: 2.38102,    val negloglik: 4.96423    accuracy: 0.9727 lr: [2.5418658283290006e-06]
# epoch 255, train negloglik: 2.38364,    val negloglik: 11.05449    accuracy: 0.9703 lr: [2.5418658283290006e-06]
# epoch 256, train negloglik: 3.67002,    val negloglik: 11.52903    accuracy: 0.9684 lr: [2.5418658283290006e-06]
# epoch 257, train negloglik: 2.16652,    val negloglik: 4.57047    accuracy: 0.9743 lr: [2.5418658283290006e-06]
# epoch 258, train negloglik: 2.84890,    val negloglik: 11.88048    accuracy: 0.9694 lr: [2.5418658283290006e-06]
# epoch 259, train negloglik: 2.54546,    val negloglik: 4.80990    accuracy: 0.9765 lr: [2.5418658283290006e-06]
# epoch 260, train negloglik: 2.01424,    val negloglik: 13.65778    accuracy: 0.9703 lr: [2.5418658283290006e-06]
# epoch 261, train negloglik: 2.54410,    val negloglik: 4.56940    accuracy: 0.9779 lr: [2.2876792454961005e-06]
# epoch 262, train negloglik: 2.39295,    val negloglik: 12.92420    accuracy: 0.9681 lr: [2.2876792454961005e-06]
# epoch 263, train negloglik: 2.12635,    val negloglik: 5.47756    accuracy: 0.9782 lr: [2.2876792454961005e-06]
# epoch 264, train negloglik: 2.44923,    val negloglik: 5.78683    accuracy: 0.9733 lr: [2.2876792454961005e-06]
# epoch 265, train negloglik: 2.32368,    val negloglik: 12.58457    accuracy: 0.9689 lr: [2.2876792454961005e-06]
# epoch 266, train negloglik: 2.02305,    val negloglik: 9.30848    accuracy: 0.9652 lr: [2.2876792454961005e-06]
# epoch 267, train negloglik: 2.42220,    val negloglik: 11.74085    accuracy: 0.9651 lr: [2.2876792454961005e-06]
# epoch 268, train negloglik: 2.22787,    val negloglik: 10.36664    accuracy: 0.9621 lr: [2.2876792454961005e-06]
# epoch 269, train negloglik: 2.59395,    val negloglik: 11.09293    accuracy: 0.9752 lr: [2.2876792454961005e-06]
# epoch 270, train negloglik: 2.57813,    val negloglik: 7.08515    accuracy: 0.9720 lr: [2.2876792454961005e-06]
# epoch 271, train negloglik: 2.49211,    val negloglik: 4.64001    accuracy: 0.9793 lr: [2.2876792454961005e-06]
# epoch 272, train negloglik: 2.89639,    val negloglik: 8.29009    accuracy: 0.9701 lr: [2.2876792454961005e-06]
# epoch 273, train negloglik: 2.70875,    val negloglik: 12.63062    accuracy: 0.9688 lr: [2.2876792454961005e-06]
# epoch 274, train negloglik: 2.32730,    val negloglik: 12.53070    accuracy: 0.9676 lr: [2.2876792454961005e-06]
# epoch 275, train negloglik: 2.25615,    val negloglik: 6.87398    accuracy: 0.9738 lr: [2.2876792454961005e-06]
# epoch 276, train negloglik: 1.88129,    val negloglik: 12.35132    accuracy: 0.9677 lr: [2.2876792454961005e-06]
# epoch 277, train negloglik: 2.27595,    val negloglik: 8.68479    accuracy: 0.9741 lr: [2.2876792454961005e-06]
# epoch 278, train negloglik: 2.31484,    val negloglik: 11.42912    accuracy: 0.9864 lr: [2.2876792454961005e-06]
# epoch 279, train negloglik: 2.28727,    val negloglik: 2.63449    accuracy: 0.9833 lr: [2.2876792454961005e-06]
# epoch 280, train negloglik: 2.41145,    val negloglik: 7.12836    accuracy: 0.9692 lr: [2.2876792454961005e-06]
# epoch 281, train negloglik: 1.98610,    val negloglik: 9.75011    accuracy: 0.9664 lr: [2.0589113209464906e-06]
# epoch 282, train negloglik: 2.44995,    val negloglik: 11.19375    accuracy: 0.9681 lr: [2.0589113209464906e-06]
# epoch 283, train negloglik: 2.02730,    val negloglik: 10.47505    accuracy: 0.9652 lr: [2.0589113209464906e-06]
# epoch 284, train negloglik: 2.73824,    val negloglik: 9.11883    accuracy: 0.9745 lr: [2.0589113209464906e-06]
# epoch 285, train negloglik: 2.25063,    val negloglik: 8.79665    accuracy: 0.9664 lr: [2.0589113209464906e-06]
# epoch 286, train negloglik: 2.54889,    val negloglik: 10.64911    accuracy: 0.9702 lr: [2.0589113209464906e-06]
# epoch 287, train negloglik: 2.01238,    val negloglik: 2.67439    accuracy: 0.9596 lr: [2.0589113209464906e-06]
# epoch 288, train negloglik: 2.87701,    val negloglik: 11.98158    accuracy: 0.9722 lr: [2.0589113209464906e-06]
# epoch 289, train negloglik: 1.78693,    val negloglik: 12.67840    accuracy: 0.9723 lr: [2.0589113209464906e-06]
# epoch 290, train negloglik: 2.81360,    val negloglik: 7.01940    accuracy: 0.9741 lr: [2.0589113209464906e-06]
# epoch 291, train negloglik: 3.23463,    val negloglik: 4.32450    accuracy: 0.9813 lr: [2.0589113209464906e-06]
# epoch 292, train negloglik: 2.23540,    val negloglik: 11.85089    accuracy: 0.9718 lr: [2.0589113209464906e-06]
# epoch 293, train negloglik: 2.39712,    val negloglik: 5.63550    accuracy: 0.9688 lr: [2.0589113209464906e-06]
# epoch 294, train negloglik: 2.63944,    val negloglik: 8.34430    accuracy: 0.9608 lr: [2.0589113209464906e-06]
# epoch 295, train negloglik: 2.38538,    val negloglik: 3.94601    accuracy: 0.9749 lr: [2.0589113209464906e-06]
# epoch 296, train negloglik: 2.44118,    val negloglik: 10.98273    accuracy: 0.9631 lr: [2.0589113209464906e-06]
# epoch 297, train negloglik: 2.29724,    val negloglik: 10.40421    accuracy: 0.9771 lr: [2.0589113209464906e-06]
# epoch 298, train negloglik: 2.04095,    val negloglik: 4.33766    accuracy: 0.9778 lr: [2.0589113209464906e-06]
# epoch 299, train negloglik: 2.29669,    val negloglik: 11.55546    accuracy: 0.9721 lr: [2.0589113209464906e-06]
# epoch 300, train negloglik: 2.24554,    val negloglik: 10.21493    accuracy: 0.9705 lr: [2.0589113209464906e-06]
# epoch 301, train negloglik: 2.79728,    val negloglik: 11.94062    accuracy: 0.9710 lr: [1.8530201888518416e-06]
# epoch 302, train negloglik: 2.26899,    val negloglik: 9.94413    accuracy: 0.9700 lr: [1.8530201888518416e-06]
# epoch 303, train negloglik: 2.71505,    val negloglik: 10.40923    accuracy: 0.9756 lr: [1.8530201888518416e-06]
# epoch 304, train negloglik: 2.57786,    val negloglik: 10.58037    accuracy: 0.9677 lr: [1.8530201888518416e-06]
# epoch 305, train negloglik: 2.98019,    val negloglik: 9.97933    accuracy: 0.9684 lr: [1.8530201888518416e-06]
# epoch 306, train negloglik: 2.20575,    val negloglik: 11.61053    accuracy: 0.9714 lr: [1.8530201888518416e-06]
# epoch 307, train negloglik: 2.92532,    val negloglik: 13.92483    accuracy: 0.9732 lr: [1.8530201888518416e-06]
# epoch 308, train negloglik: 2.51097,    val negloglik: 11.65436    accuracy: 0.9685 lr: [1.8530201888518416e-06]
# epoch 309, train negloglik: 2.47146,    val negloglik: 11.89528    accuracy: 0.9680 lr: [1.8530201888518416e-06]
# epoch 310, train negloglik: 2.02842,    val negloglik: 10.43058    accuracy: 0.9682 lr: [1.8530201888518416e-06]
# epoch 311, train negloglik: 2.00469,    val negloglik: 7.68656    accuracy: 0.9760 lr: [1.8530201888518416e-06]
# epoch 312, train negloglik: 2.20581,    val negloglik: 8.13915    accuracy: 0.9584 lr: [1.8530201888518416e-06]
# epoch 313, train negloglik: 2.03790,    val negloglik: 7.46018    accuracy: 0.9706 lr: [1.8530201888518416e-06]
# epoch 314, train negloglik: 2.22135,    val negloglik: 12.04061    accuracy: 0.9716 lr: [1.8530201888518416e-06]
# epoch 315, train negloglik: 2.49963,    val negloglik: 8.70889    accuracy: 0.9708 lr: [1.8530201888518416e-06]
# epoch 316, train negloglik: 2.36201,    val negloglik: 11.59466    accuracy: 0.9732 lr: [1.8530201888518416e-06]
# epoch 317, train negloglik: 2.24868,    val negloglik: 10.13364    accuracy: 0.9756 lr: [1.8530201888518416e-06]
# epoch 318, train negloglik: 2.38751,    val negloglik: 11.72512    accuracy: 0.9695 lr: [1.8530201888518416e-06]
# epoch 319, train negloglik: 2.49385,    val negloglik: 9.81897    accuracy: 0.9721 lr: [1.8530201888518416e-06]
# epoch 320, train negloglik: 2.18583,    val negloglik: 6.76175    accuracy: 0.9751 lr: [1.8530201888518416e-06]
# epoch 321, train negloglik: 2.08498,    val negloglik: 9.04560    accuracy: 0.9736 lr: [1.6677181699666574e-06]
# epoch 322, train negloglik: 2.71192,    val negloglik: 5.31014    accuracy: 0.9765 lr: [1.6677181699666574e-06]
# epoch 323, train negloglik: 2.15060,    val negloglik: 11.17592    accuracy: 0.9697 lr: [1.6677181699666574e-06]
# epoch 324, train negloglik: 2.63631,    val negloglik: 9.05390    accuracy: 0.9748 lr: [1.6677181699666574e-06]
# epoch 325, train negloglik: 2.10260,    val negloglik: 10.38589    accuracy: 0.9747 lr: [1.6677181699666574e-06]
# epoch 326, train negloglik: 2.06572,    val negloglik: 6.04491    accuracy: 0.9726 lr: [1.6677181699666574e-06]
# epoch 327, train negloglik: 2.10692,    val negloglik: 4.08228    accuracy: 0.9823 lr: [1.6677181699666574e-06]
# epoch 328, train negloglik: 2.95687,    val negloglik: 3.21113    accuracy: 0.9719 lr: [1.6677181699666574e-06]
# epoch 329, train negloglik: 2.45768,    val negloglik: 8.86231    accuracy: 0.9668 lr: [1.6677181699666574e-06]
# epoch 330, train negloglik: 2.14070,    val negloglik: 10.29429    accuracy: 0.9690 lr: [1.6677181699666574e-06]
# epoch 331, train negloglik: 2.59137,    val negloglik: 8.44959    accuracy: 0.9761 lr: [1.6677181699666574e-06]
# epoch 332, train negloglik: 2.83916,    val negloglik: 11.47835    accuracy: 0.9696 lr: [1.6677181699666574e-06]
# epoch 333, train negloglik: 2.77138,    val negloglik: 5.92556    accuracy: 0.9847 lr: [1.6677181699666574e-06]
# epoch 334, train negloglik: 2.96592,    val negloglik: 8.27857    accuracy: 0.9666 lr: [1.6677181699666574e-06]
# epoch 335, train negloglik: 2.58011,    val negloglik: 6.87128    accuracy: 0.9712 lr: [1.6677181699666574e-06]
# epoch 336, train negloglik: 1.84176,    val negloglik: 7.60490    accuracy: 0.9629 lr: [1.6677181699666574e-06]
# epoch 337, train negloglik: 2.39446,    val negloglik: 10.81816    accuracy: 0.9715 lr: [1.6677181699666574e-06]
# epoch 338, train negloglik: 2.07593,    val negloglik: 11.34206    accuracy: 0.9658 lr: [1.6677181699666574e-06]
# epoch 339, train negloglik: 2.17845,    val negloglik: 8.06956    accuracy: 0.9584 lr: [1.6677181699666574e-06]
# epoch 340, train negloglik: 2.47934,    val negloglik: 6.65294    accuracy: 0.9694 lr: [1.6677181699666574e-06]
# epoch 341, train negloglik: 2.37448,    val negloglik: 12.15316    accuracy: 0.9777 lr: [1.5009463529699917e-06]
# epoch 342, train negloglik: 2.24780,    val negloglik: 4.13136    accuracy: 0.9733 lr: [1.5009463529699917e-06]
# epoch 343, train negloglik: 1.84419,    val negloglik: 4.83102    accuracy: 0.9854 lr: [1.5009463529699917e-06]
# epoch 344, train negloglik: 2.15115,    val negloglik: 2.11393    accuracy: 0.9581 lr: [1.5009463529699917e-06]
# epoch 345, train negloglik: 2.28107,    val negloglik: 12.30513    accuracy: 0.9720 lr: [1.5009463529699917e-06]
# epoch 346, train negloglik: 2.06667,    val negloglik: 5.28116    accuracy: 0.9829 lr: [1.5009463529699917e-06]
# epoch 347, train negloglik: 2.18212,    val negloglik: 9.08781    accuracy: 0.9764 lr: [1.5009463529699917e-06]
# epoch 348, train negloglik: 2.28456,    val negloglik: 10.50255    accuracy: 0.9747 lr: [1.5009463529699917e-06]
# epoch 349, train negloglik: 1.98278,    val negloglik: 8.69490    accuracy: 0.9757 lr: [1.5009463529699917e-06]
# epoch 350, train negloglik: 2.73032,    val negloglik: 4.97217    accuracy: 0.9751 lr: [1.5009463529699917e-06]
# epoch 351, train negloglik: 2.45164,    val negloglik: 12.72012    accuracy: 0.9858 lr: [1.5009463529699917e-06]
# epoch 352, train negloglik: 2.15921,    val negloglik: 12.00614    accuracy: 0.9681 lr: [1.5009463529699917e-06]
# epoch 353, train negloglik: 2.15088,    val negloglik: 7.04463    accuracy: 0.9793 lr: [1.5009463529699917e-06]
# epoch 354, train negloglik: 2.14450,    val negloglik: 4.02839    accuracy: 0.9889 lr: [1.5009463529699917e-06]
# epoch 355, train negloglik: 1.99740,    val negloglik: 2.63501    accuracy: 0.9789 lr: [1.5009463529699917e-06]
# epoch 356, train negloglik: 2.15394,    val negloglik: 10.08515    accuracy: 0.9680 lr: [1.5009463529699917e-06]
# epoch 357, train negloglik: 2.09548,    val negloglik: 3.92925    accuracy: 1.0138 lr: [1.5009463529699917e-06]
# epoch 358, train negloglik: 2.34127,    val negloglik: 2.70603    accuracy: 0.9827 lr: [1.5009463529699917e-06]
# epoch 359, train negloglik: 1.91474,    val negloglik: 5.10345    accuracy: 0.9927 lr: [1.5009463529699917e-06]
# epoch 360, train negloglik: 2.49302,    val negloglik: 5.65245    accuracy: 0.9839 lr: [1.5009463529699917e-06]
# epoch 361, train negloglik: 1.99763,    val negloglik: 8.88998    accuracy: 0.9701 lr: [1.3508517176729926e-06]
# epoch 362, train negloglik: 2.28250,    val negloglik: 12.58467    accuracy: 0.9748 lr: [1.3508517176729926e-06]
# epoch 363, train negloglik: 2.24015,    val negloglik: 6.09186    accuracy: 0.9803 lr: [1.3508517176729926e-06]
# epoch 364, train negloglik: 1.95472,    val negloglik: 6.13608    accuracy: 0.9736 lr: [1.3508517176729926e-06]
# epoch 365, train negloglik: 2.44249,    val negloglik: 9.21675    accuracy: 0.9666 lr: [1.3508517176729926e-06]
# epoch 366, train negloglik: 2.19691,    val negloglik: 11.00793    accuracy: 0.9824 lr: [1.3508517176729926e-06]
# epoch 367, train negloglik: 2.01660,    val negloglik: 3.34761    accuracy: 0.9915 lr: [1.3508517176729926e-06]
# epoch 368, train negloglik: 2.59135,    val negloglik: 2.99361    accuracy: 0.9937 lr: [1.3508517176729926e-06]
# epoch 369, train negloglik: 1.89283,    val negloglik: 3.58251    accuracy: 0.9862 lr: [1.3508517176729926e-06]
# epoch 370, train negloglik: 2.38266,    val negloglik: 8.82863    accuracy: 0.9684 lr: [1.3508517176729926e-06]
# epoch 371, train negloglik: 2.33164,    val negloglik: 9.37199    accuracy: 0.9753 lr: [1.3508517176729926e-06]
# epoch 372, train negloglik: 1.87610,    val negloglik: 12.88876    accuracy: 0.9727 lr: [1.3508517176729926e-06]
# epoch 373, train negloglik: 2.78057,    val negloglik: 8.78968    accuracy: 0.9802 lr: [1.3508517176729926e-06]
# epoch 374, train negloglik: 2.36804,    val negloglik: 3.07756    accuracy: 0.9902 lr: [1.3508517176729926e-06]
# epoch 375, train negloglik: 2.03033,    val negloglik: 4.00536    accuracy: 0.9879 lr: [1.3508517176729926e-06]
# epoch 376, train negloglik: 2.26954,    val negloglik: 10.54960    accuracy: 0.9800 lr: [1.3508517176729926e-06]
# epoch 377, train negloglik: 2.07412,    val negloglik: 3.95198    accuracy: 0.9869 lr: [1.3508517176729926e-06]
# epoch 378, train negloglik: 2.05034,    val negloglik: 11.76614    accuracy: 0.9705 lr: [1.3508517176729926e-06]
# epoch 379, train negloglik: 1.92930,    val negloglik: 10.07381    accuracy: 0.9769 lr: [1.3508517176729926e-06]
# epoch 380, train negloglik: 2.33268,    val negloglik: 10.81958    accuracy: 0.9812 lr: [1.3508517176729926e-06]
# epoch 381, train negloglik: 2.28852,    val negloglik: 6.73082    accuracy: 0.9837 lr: [1.2157665459056933e-06]
# epoch 382, train negloglik: 2.24785,    val negloglik: 4.43013    accuracy: 0.9880 lr: [1.2157665459056933e-06]
# epoch 383, train negloglik: 1.97659,    val negloglik: 5.08161    accuracy: 0.9781 lr: [1.2157665459056933e-06]
# epoch 384, train negloglik: 1.90988,    val negloglik: 7.39215    accuracy: 0.9865 lr: [1.2157665459056933e-06]
# epoch 385, train negloglik: 2.54637,    val negloglik: 5.48812    accuracy: 0.9848 lr: [1.2157665459056933e-06]
# epoch 386, train negloglik: 1.95845,    val negloglik: 8.90364    accuracy: 0.9837 lr: [1.2157665459056933e-06]
# epoch 387, train negloglik: 1.89088,    val negloglik: 12.11307    accuracy: 0.9794 lr: [1.2157665459056933e-06]
# epoch 388, train negloglik: 2.41068,    val negloglik: 8.13788    accuracy: 0.9850 lr: [1.2157665459056933e-06]
# epoch 389, train negloglik: 1.98704,    val negloglik: 4.41262    accuracy: 0.9755 lr: [1.2157665459056933e-06]
# epoch 390, train negloglik: 2.14989,    val negloglik: 2.19991    accuracy: 0.9863 lr: [1.2157665459056933e-06]
# epoch 391, train negloglik: 2.13074,    val negloglik: 7.10339    accuracy: 1.0041 lr: [1.2157665459056933e-06]
# epoch 392, train negloglik: 2.34271,    val negloglik: 5.69597    accuracy: 0.9764 lr: [1.2157665459056933e-06]
# epoch 393, train negloglik: 2.15437,    val negloglik: 3.51358    accuracy: 0.9916 lr: [1.2157665459056933e-06]
# epoch 394, train negloglik: 2.03753,    val negloglik: 9.82068    accuracy: 0.9710 lr: [1.2157665459056933e-06]
# epoch 395, train negloglik: 2.28570,    val negloglik: 3.75120    accuracy: 0.9919 lr: [1.2157665459056933e-06]
# epoch 396, train negloglik: 2.55116,    val negloglik: 11.67371    accuracy: 0.9744 lr: [1.2157665459056933e-06]
# epoch 397, train negloglik: 2.32298,    val negloglik: 9.78873    accuracy: 0.9677 lr: [1.2157665459056933e-06]
# epoch 398, train negloglik: 2.28978,    val negloglik: 11.35526    accuracy: 0.9808 lr: [1.2157665459056933e-06]
# epoch 399, train negloglik: 3.01882,    val negloglik: 6.32871    accuracy: 0.9867 lr: [1.2157665459056933e-06]
# Test MSE: 0.990960
# Test RMSE: 0.995470
# Residual Statistics:
# Mean: 0.139360
# Std: 0.985667
# Min: -1.180223
# Max: 1.180167
# plot completed

# %% [markdown]
# ## 3.結果評価
# 以下の項目に従ってカーネル行列の分析結果をまとめる：
#
# **カーネル行列分析項目**
# - 各層のカーネル行列ランクと条件数の分析
# - 誘導点の分布と配置の可視化
# - カーネル行列のヒートマップ（Jitter項適用前後）
# - 固有値分布の分析
# - 誘導点間距離の統計的分析

# %%
# 1層目
model.layers[0].save_fig("./outputs/layer_fused0.png")
model.layers[1].save_fig("./outputs/layer_fused1.png")

# %%
# カーネル行列のランク可視化・分析
import matplotlib.pyplot as plt
import numpy as np
import torch


def analyze_kernel_matrices(model):
    """
    GP-KANの各層のカーネル行列ランクと条件数を分析・可視化する
    """
    print("=== カーネル行列分析 ===")

    # 各層の分析
    for layer_idx, layer in enumerate(model.layers):
        print(f"\n--- Layer {layer_idx} ---")

        # 誘導点を取得
        inducing_points = layer.z.detach()  # Shape: [1, 1, X]
        jitter = layer.get_jitter().detach()  # Shape: [1, 1]
        print(f"誘導点の形状: {inducing_points.shape}")
        print(
            f"誘導点の範囲: [{inducing_points.min().item():.4f}, {inducing_points.max().item():.4f}]"
        )

        # カーネル行列を計算
        with torch.no_grad():
            # カーネル行列を計算
            lengthscale = layer.l.detach()  # Shape: [1, 1]
            variance = layer.s.detach()  # Shape: [1, 1]

            # Set i=j=1 for processing (assuming we want the first GP component)
            i, j = 0, 0  # Using 0-based indexing for tensor access

            # Get parameters for this specific GP
            z_ij = inducing_points[i, j, :]  # Shape: [X]
            l_ij = lengthscale[i, j]  # Scalar
            s_ij = variance[i, j]  # Scalar

            # Reshape inducing points for distance computation
            z_ij = z_ij.unsqueeze(1)  # Shape: [X, 1]

            # Compute kernel matrix for this GP
            pairwise_sq_dists = torch.cdist(z_ij, z_ij, p=2) ** 2
            # 誘導点間のカーネル行列
            K = s_ij * torch.exp(-pairwise_sq_dists / (2 * l_ij**2))

            print("計算開始")
            # ランク計算
            rank_clean = torch.linalg.matrix_rank(K)

            # 条件数計算
            cond_clean = torch.linalg.cond(K)

            # 固有値
            eigenvals_clean = torch.linalg.eigvals(K).real

            print("計算完了")

            print(f"カーネル行列ランク: {rank_clean.item()}")
            print(f"条件数: {cond_clean.item():.2e}")
            print(f"最小固有値: {eigenvals_clean.min().item():.2e}")
            print(
                f"パラメータ値 - s_ij: {s_ij.item():.4f}, l_ij: {l_ij.item():.4f}, jitter: {jitter.item():.4f}"
            )

        # 可視化
        fig, axes = plt.subplots(2, 3, figsize=(15, 10))

        # 誘導点の分布
        axes[0, 0].scatter(
            inducing_points.numpy(),
            np.zeros_like(inducing_points.numpy()),
            alpha=0.7,
            s=50,
        )
        axes[0, 0].set_title(f"Layer {layer_idx}: 誘導点分布")
        axes[0, 0].set_xlabel("誘導点位置")
        axes[0, 0].grid(True, alpha=0.3)

        # カーネル行列のヒートマップ
        im1 = axes[0, 1].imshow(K.numpy(), cmap="viridis")
        axes[0, 1].set_title(f"カーネル行列\nRank: {rank_clean.item()}")
        plt.colorbar(im1, ax=axes[0, 1])

        # パラメータ値のプロット
        params = ["s", "l", "jitter"]
        values = [s_ij.item(), l_ij.item(), jitter.item()]
        axes[0, 2].bar(params, values)
        axes[0, 2].set_title("パラメータ値")
        axes[0, 2].set_ylabel("値")
        for i, v in enumerate(values):
            axes[0, 2].text(i, v, f"{v:.4f}", ha="center", va="bottom")

        # 固有値分布
        eigenvals_sorted = torch.sort(eigenvals_clean, descending=True)[0]
        axes[1, 0].semilogy(eigenvals_sorted.numpy(), "o-")
        axes[1, 0].set_title("固有値分布")
        axes[1, 0].set_xlabel("固有値インデックス")
        axes[1, 0].set_ylabel("固有値 (log scale)")
        axes[1, 0].grid(True, alpha=0.3)

        # 条件数とランクの可視化
        metrics = ["Rank", "Condition Number (log)"]
        metric_values = [rank_clean.item(), np.log10(cond_clean.item())]
        axes[1, 1].bar(metrics, metric_values)
        axes[1, 1].set_title("行列特性")
        axes[1, 1].set_ylabel("値")
        for i, v in enumerate(metric_values):
            if i == 0:
                axes[1, 1].text(i, v, f"{int(v)}", ha="center", va="bottom")
            else:
                axes[1, 1].text(i, v, f"{v:.2f}", ha="center", va="bottom")

        # パラメータ値の詳細プロット（対数スケール）
        axes[1, 2].bar(params, np.log10(np.abs(values)))
        axes[1, 2].set_title("パラメータ値 (log10)")
        axes[1, 2].set_ylabel("log10(値)")
        for i, v in enumerate(values):
            axes[1, 2].text(i, np.log10(abs(v)), f"{v:.4f}", ha="center", va="bottom")

        plt.tight_layout()
        plt.show()

        # 誘導点間の距離分析
        distances = torch.cdist(z_ij.unsqueeze(0), z_ij.unsqueeze(0)).squeeze(
            0
        )  # Shape: [X, X]
        min_dist = distances[distances > 0].min()
        max_dist = distances[distances > 0].max()
        mean_dist = distances[distances > 0].mean()

        print(
            f"誘導点間距離 - 最小: {min_dist.item():.4f}, 最大: {max_dist.item():.4f}, 平均: {mean_dist.item():.4f}"
        )

        # 距離分布のヒストグラム
        plt.figure(figsize=(10, 6))
        dist_flat = distances[distances > 0].numpy()
        plt.hist(dist_flat, bins=20, alpha=0.7, edgecolor="black")
        plt.axvline(
            min_dist.item(),
            color="red",
            linestyle="--",
            label=f"最小距離: {min_dist.item():.4f}",
        )
        plt.axvline(
            mean_dist.item(),
            color="green",
            linestyle="--",
            label=f"平均距離: {mean_dist.item():.4f}",
        )
        plt.xlabel("誘導点間距離")
        plt.ylabel("頻度")
        plt.title(f"Layer {layer_idx}: 誘導点間距離分布")
        plt.legend()
        plt.grid(True, alpha=0.3)
        plt.show()


# 実行
analyze_kernel_matrices(model)
# Out:
# === カーネル行列分析 ===
#
# --- Layer 0 ---
# 誘導点の形状: torch.Size([1, 1, 10])
# 誘導点の範囲: [-5.3461, 3.0551]
# 計算開始
# 計算完了
# カーネル行列ランク: 7
# 条件数: 3.32e+08
# 最小固有値: -4.52e-09
# パラメータ値 - s_ij: 0.4366, l_ij: -2.4281, jitter: 0.0018
# 誘導点間距離 - 最小: 0.1209, 最大: 8.4012, 平均: 3.5930
# --- Layer 1 ---
# 誘導点の形状: torch.Size([1, 1, 10])
# 誘導点の範囲: [-2.2488, 2.1875]
# 計算開始
# 計算完了
# カーネル行列ランク: 6
# 条件数: 1.41e+09
# 最小固有値: -2.86e-08
# パラメータ値 - s_ij: 0.4371, l_ij: -2.5654, jitter: 0.0021
# 誘導点間距離 - 最小: 0.0023, 最大: 4.4363, 平均: 1.5550

# %% [markdown]
# ### 考察
# バッチサイズ増大によるGP-KANの学習安定化効果は確認できず。

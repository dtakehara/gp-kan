# %% [markdown]
# # GP-KANの学習安定化方法調査: ベースライン

# %% [markdown]
# ## 0.背景/目的
# GP-KANの学習(誘導点・カーネルパラメータの同時学習)時、処理がうまくいかない現象が発生していた。
#
# 原因として考えられるのは以下の通り：
#
# * a. バッチサイズが小さいことで、ミニバッチデータに偏りが生じる
# * b. カーネル行列のJitter項が大きい※1ため、出力層以外の誘導点が縦に並んでいる(x軸:入力,y軸:中間層出力)
# * c. 損失関数(負の対数尤度)は誘導点が近いほど小さい値を取るため、カーネル行列が縮退しやすい
#
# ※1. 関数値を取る確率変数 $f\sim GP(m(\cdot),k(\cdot, \cdot))$ と独立なノイズが多く含まれることに相当する。
# ここで、GPの出力 $y$ に対して
# $$
# y = f(x)+\epsilon,\ \ \  \epsilon\sim \mathcal{N}(0, \sigma_\epsilon^2)
# $$
#
# そのため、以下の追加実験を行いGP-KANの学習が安定しない原因のあたりをつける。
#
# * a. バッチサイズ(現在32; 学習データ全体750件)を大きくする
# * b. Jitter項のパラメータ設定値を小さくして学習実行
# * c. 誘導点が近づかないようなペナルティ項入れて学習
#
# 本notebookでは、baselineとして02のnotebookに基本準拠した以下の設定で学習を行い結果を評価する：
# ### モデル構成
# - **ネットワーク構造**: 2層GP-KAN (入力1次元 → 中間層1次元 → 出力1次元)
# - **誘導点数**: 各GPあたり10点
# - **GP構成**: (0,0), (1,0) の2つのガウス過程
#
# ### 学習パラメータ
# - **エポック数**: 400エポック→可視化する数が多すぎて分かりづらくなっていたので、まとめて結果表示
# - **学習率**: 1e-5
# - **バッチサイズ**: 32
# - **事前学習**: 無効 (pretrain=False)
#
# ### 正則化パラメータ
# - **global_jitter**: 1e-3
# - **baseline_jitter**: 1e-3

# %%
JITTER_VALUE = 1e-3  # Jitter項の値

# %%
SAVELOAD_PATH = "model_12__1.pt"

# %% [markdown]
# ## 1.問題設定
#
# 真の関数: フーリエ級数
# $$f(t) = \frac{4}{\pi} \sum_{n=1}^{N} \frac{1}{n} \sin(nt), \quad n = 1, 3, 5, \ldots, \quad t \in [0, 1]$$
# ※$N=15$
#
# データ:
# - 合計1,000件: 学習700件/検証150件/評価150件
# - tは$(-1,1)$から一様ランダムサンプリング
#
# モデル:
# - 2層のGPKAN: 入力1次元/中間層1次元/出力1次元
#     - それぞれのGPを(<1層目のindex>,<2層目のindex>)形式で表すことにすると、GPKANは$(0,0),(1,0)$の2つのGPで構成

# %% [markdown]
# ## 2.メイン処理
# 本ノートブックのメイン処理を実行する。実行順は以下の通り：
#
# 2-1.データセット作成
#
# 2-2.GPKANの学習
#
# 2-3.精度評価
#
# 2-4.学習中のカーネル行列ランク可視化

# %% [markdown]
# ### 2-1.データセット作成

# %%
# 初期設定: 必要なライブラリをインポートし、パスを設定
import os
import sys

sys.path.append("../../")
import japanize_matplotlib
import torch.utils.data
from lib import model as gplib
from lib import runner
from torch.utils.data import DataLoader

# %%
import random

import matplotlib.pyplot as plt
import numpy as np
import torch
from torch.utils.data import DataLoader, TensorDataset


# Generate synthetic data with Fourier series function
def set_seed(seed=42):
    """完全な再現性のための乱数シード設定"""
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)


def worker_init_fn(worker_id):
    """DataLoaderワーカープロセス用の乱数シード設定"""
    worker_seed = torch.initial_seed() % 2**32
    np.random.seed(worker_seed)
    random.seed(worker_seed)


set_seed(42)  # 全体の乱数シード設定
num_samples = 1000

# Generate random input points t from [-1, 1]
t = np.random.uniform(-1, 1, num_samples)


# Compute target values: f(t) = (4/π) * Σ(1/n * sin(nt)) for odd n up to N=15
def fourier_series(t, N=15):
    result = np.zeros_like(t)
    for n in range(1, N + 1, 2):  # odd numbers only: 1, 3, 5, 7, 9, 11, 13, 15
        result += (1 / n) * np.sin(n * t)
    return (4 / np.pi) * result


targets = fourier_series(t, N=15)

# Reshape inputs (t is 1D, but we need it as 2D for compatibility)
inputs = t.reshape(-1, 1)

# Convert to PyTorch tensors
X_tensor = torch.FloatTensor(inputs)
y_tensor = torch.FloatTensor(targets).reshape(-1, 1)

# Split data into train, validation, and test sets
train_size = int(0.7 * num_samples)
val_size = int(0.15 * num_samples)
test_size = num_samples - train_size - val_size

X_train = X_tensor[:train_size]
y_train = y_tensor[:train_size]

X_val = X_tensor[train_size : train_size + val_size]
y_val = y_tensor[train_size : train_size + val_size]

X_test = X_tensor[train_size + val_size :]
y_test = y_tensor[train_size + val_size :]

# データを昇順にソート（X_testとy_testを対応を保ちながら）
sorted_indices = torch.argsort(X_test.squeeze())
X_test = X_test[sorted_indices]
y_test = y_test[sorted_indices]

# Create datasets
train_dataset = TensorDataset(X_train, y_train)
val_dataset = TensorDataset(X_val, y_val)
test_dataset = TensorDataset(X_test, y_test)

# Create dataloaders
batch_size = 32

# %%
# Create dataloaders with reproducible worker processes
generator = torch.Generator()
generator.manual_seed(42)

train_dataloader = DataLoader(
    train_dataset,
    batch_size=batch_size,
    shuffle=True,
    num_workers=0,  # Single process for reproducibility
    worker_init_fn=worker_init_fn,
    generator=generator,
)
val_dataloader = DataLoader(
    val_dataset,
    batch_size=batch_size,
    shuffle=False,
    num_workers=0,  # Single process for reproducibility
    worker_init_fn=worker_init_fn,
    generator=generator,
)
test_dataloader = DataLoader(
    test_dataset,
    batch_size=batch_size,
    shuffle=False,
    num_workers=0,  # Single process for reproducibility
    worker_init_fn=worker_init_fn,
    generator=generator,
)

# %%
# サンプル数確認
print(f"Train samples: {len(train_dataset)}")
print(f"Validation samples: {len(val_dataset)}")
print(f"Test samples: {len(test_dataset)}")

# Fourier級数関数のプロット
t_plot = np.linspace(-1, 1, 1000)
y_plot = fourier_series(t_plot, N=15)
plt.figure(figsize=(10, 6))
plt.plot(t_plot, y_plot, "b-", label="Fourier Series (N=15)")
plt.scatter(t, targets, alpha=0.3, s=3, c="red", label="Training Data")
plt.xlabel("t")
plt.ylabel("f(t)")
plt.title("Fourier Series Function")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Train samples: 700
# Validation samples: 150
# Test samples: 150

# %%
# y（目的変数）の分布をヒストグラムで可視化
plt.figure(figsize=(15, 10))


# 学習データのヒストグラム
plt.subplot(1, 1, 1)
plt.hist(
    y_train.numpy().flatten(), bins=30, alpha=0.7, color="green", edgecolor="black"
)
plt.xlabel("y (target values)")
plt.ylabel("Frequency")
plt.title("Training Data Distribution")
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()


# 値の分布特性
print(f"\n=== 値の分布特性 ===")
print(f"正の値の割合: {np.sum(targets > 0) / len(targets) * 100:.1f}%")
print(f"負の値の割合: {np.sum(targets < 0) / len(targets) * 100:.1f}%")
print(
    f"ゼロ近傍(-0.1 < y < 0.1)の割合: {np.sum(np.abs(targets) < 0.1) / len(targets) * 100:.1f}%"
)
# Out:
# === 値の分布特性 ===
# 正の値の割合: 49.7%
# 負の値の割合: 50.3%
# ゼロ近傍(-0.1 < y < 0.1)の割合: 1.3%

# %% [markdown]
# ### 2-2.モデル学習

# %%
num_gp_pts = 10  # Number of Gaussian Process points
model = gplib.GP_Model(
    [
        gplib.LayerFused(1, 1, num_gp_pts),
        gplib.LayerFused(1, 1, num_gp_pts),
    ],
    saveload_path=SAVELOAD_PATH,  # Path to save/load the model
)
np.random.seed(42)  # for reproducibility
torch.manual_seed(42)  # for reproducibility

# %%
# 精度評価/可視化関数
def plot_result(model):
    # テストデータでの予測
    with torch.no_grad():
        # バッチごとに予測を行う
        test_predictions = []
        test_targets = []
        test_variances = []

        for X_batch, y_batch in test_dataloader:
            pred = model.predict(X_batch).mean
            var = model.predict(X_batch).var
            test_predictions.append(pred)
            test_variances.append(var)
            test_targets.append(y_batch)

        # 結果を結合
        test_predictions = torch.cat(test_predictions, dim=0)
        test_targets = torch.cat(test_targets, dim=0)
        test_variances = torch.cat(test_variances, dim=0)

    # MSE計算
    mse = torch.mean((test_predictions - test_targets) ** 2)
    rmse = torch.sqrt(mse)

    print(f"Test MSE: {mse.item():.6f}")
    print(f"Test RMSE: {rmse.item():.6f}")

    # 可視化用のデータ準備
    t_test = X_test.numpy().flatten()
    y_test_true = y_test.numpy().flatten()
    y_test_pred = test_predictions.numpy().flatten()

    # 真の関数の連続プロット用
    t_continuous = np.linspace(-1, 1, 500)
    y_continuous = fourier_series(t_continuous, N=15)

    # グラフ作成
    plt.figure(figsize=(12, 8))

    # 真の関数
    plt.plot(
        t_continuous,
        y_continuous,
        "b-",
        linewidth=2,
        label="True Function (Fourier Series)",
        alpha=0.8,
    )

    # テストデータの真値
    plt.scatter(
        t_test,
        y_test_true,
        c="red",
        s=30,
        alpha=0.6,
        label="Test Data (True)",
        marker="o",
    )

    # 予測値
    plt.scatter(
        t_test, y_test_pred, c="green", s=30, alpha=0.6, label="Predictions", marker="x"
    )

    # 予測の不確実性を帯で表示
    lower_bound = y_test_pred - 2 * np.sqrt(test_variances.numpy().flatten())
    upper_bound = y_test_pred + 2 * np.sqrt(test_variances.numpy().flatten())
    plt.fill_between(
        t_test,
        lower_bound,
        upper_bound,
        color="lightgreen",
        alpha=0.3,
        label="Prediction Interval(2σ)",
    )

    plt.xlabel("t")
    plt.ylabel("f(t)")
    plt.title(f"GP-KAN Prediction vs True Function\nTest RMSE: {rmse.item():.6f}")
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.show()

    # 残差プロット
    plt.figure(figsize=(10, 6))
    residuals = y_test_pred - y_test_true
    plt.scatter(t_test, residuals, c="purple", s=30, alpha=0.6)
    plt.axhline(y=0, color="red", linestyle="--", alpha=0.7)
    plt.xlabel("t")
    plt.ylabel("Residuals (Predicted - True)")
    plt.title("Residual Plot")
    plt.grid(True, alpha=0.3)
    plt.show()

    # 残差の統計情報
    print(f"\nResidual Statistics:")
    print(f"Mean: {np.mean(residuals):.6f}")
    print(f"Std: {np.std(residuals):.6f}")
    print(f"Min: {np.min(residuals):.6f}")
    print(f"Max: {np.max(residuals):.6f}")

    print("plot completed")
    return 0

# %%
for epoch in range(1):
    runner.train_model(
        train_dataloader,
        val_dataloader,
        model,
        epochs=400,
        learning_rate=1e-5,  # 1e-4 -> 1e-5
        use_gpu=False,  # True,
        pretrain=False,  # True,
        global_jitter=JITTER_VALUE,
        baseline_jitter=JITTER_VALUE,
    )
    model.save_model()  # optionally save the model after training

    # 可視化
    plot_result(model)
# Out:
# epoch 0  , train negloglik: 558.40025,    val negloglik: 107.14924    accuracy: 0.5113 lr: [1e-05]
# epoch 1  , train negloglik: 98.90657,    val negloglik: 86.26584    accuracy: 0.4021 lr: [9e-06]
# epoch 2  , train negloglik: 33.65921,    val negloglik: 24.53038    accuracy: 0.2671 lr: [9e-06]
# epoch 3  , train negloglik: 13.47509,    val negloglik: 23.46427    accuracy: 0.2602 lr: [9e-06]
# epoch 4  , train negloglik: 9.32127,    val negloglik: 19.87159    accuracy: 0.4079 lr: [9e-06]
# epoch 5  , train negloglik: 8.63031,    val negloglik: 22.68173    accuracy: 0.5750 lr: [9e-06]
# epoch 6  , train negloglik: 8.00046,    val negloglik: 17.51968    accuracy: 0.3204 lr: [9e-06]
# epoch 7  , train negloglik: 6.10758,    val negloglik: 13.61888    accuracy: 0.2865 lr: [9e-06]
# epoch 8  , train negloglik: 6.04707,    val negloglik: 13.83727    accuracy: 0.3174 lr: [9e-06]
# epoch 9  , train negloglik: 5.20028,    val negloglik: 12.61809    accuracy: 0.2776 lr: [9e-06]
# epoch 10 , train negloglik: 5.15932,    val negloglik: 12.27029    accuracy: 0.3084 lr: [9e-06]
# epoch 11 , train negloglik: 4.85317,    val negloglik: 9.73217    accuracy: 0.3041 lr: [9e-06]
# epoch 12 , train negloglik: 4.74656,    val negloglik: 11.18575    accuracy: 0.3084 lr: [9e-06]
# epoch 13 , train negloglik: 4.08069,    val negloglik: 9.38205    accuracy: 0.2909 lr: [9e-06]
# epoch 14 , train negloglik: 3.46556,    val negloglik: 10.49991    accuracy: 0.3192 lr: [9e-06]
# epoch 15 , train negloglik: 3.81090,    val negloglik: 10.44928    accuracy: 0.3018 lr: [9e-06]
# epoch 16 , train negloglik: 3.39889,    val negloglik: 10.01260    accuracy: 0.2803 lr: [9e-06]
# epoch 17 , train negloglik: 3.89676,    val negloglik: 6.07063    accuracy: 0.2807 lr: [9e-06]
# epoch 18 , train negloglik: 3.65169,    val negloglik: 8.76904    accuracy: 0.3340 lr: [9e-06]
# epoch 19 , train negloglik: 2.54387,    val negloglik: 5.83660    accuracy: 0.3239 lr: [9e-06]
# epoch 20 , train negloglik: 2.21452,    val negloglik: 8.60028    accuracy: 0.3542 lr: [9e-06]
# epoch 21 , train negloglik: 3.16592,    val negloglik: 7.83061    accuracy: 0.4252 lr: [8.1e-06]
# epoch 22 , train negloglik: 2.87301,    val negloglik: 5.24121    accuracy: 0.4014 lr: [8.1e-06]
# epoch 23 , train negloglik: 3.07318,    val negloglik: 3.72214    accuracy: 0.4726 lr: [8.1e-06]
# epoch 24 , train negloglik: 3.31429,    val negloglik: 7.42277    accuracy: 0.3400 lr: [8.1e-06]
# epoch 25 , train negloglik: 4.14232,    val negloglik: 3.47440    accuracy: 0.3373 lr: [8.1e-06]
# epoch 26 , train negloglik: 2.70871,    val negloglik: 3.90763    accuracy: 0.3323 lr: [8.1e-06]
# epoch 27 , train negloglik: 2.47186,    val negloglik: 5.86260    accuracy: 0.2893 lr: [8.1e-06]
# epoch 28 , train negloglik: 3.48813,    val negloglik: 5.65634    accuracy: 0.2742 lr: [8.1e-06]
# epoch 29 , train negloglik: 2.99101,    val negloglik: 3.01338    accuracy: 0.2948 lr: [8.1e-06]
# epoch 30 , train negloglik: 1.98834,    val negloglik: 3.86074    accuracy: 0.3264 lr: [8.1e-06]
# epoch 31 , train negloglik: 2.83013,    val negloglik: 1.47676    accuracy: 0.3637 lr: [8.1e-06]
# epoch 32 , train negloglik: 2.93232,    val negloglik: 6.70526    accuracy: 0.2721 lr: [8.1e-06]
# epoch 33 , train negloglik: 1.99889,    val negloglik: 3.72935    accuracy: 0.2716 lr: [8.1e-06]
# epoch 34 , train negloglik: 1.19394,    val negloglik: 2.45989    accuracy: 0.2676 lr: [8.1e-06]
# epoch 35 , train negloglik: 1.13655,    val negloglik: 2.55180    accuracy: 0.2667 lr: [8.1e-06]
# epoch 36 , train negloglik: 1.13472,    val negloglik: 2.23562    accuracy: 0.2633 lr: [8.1e-06]
# epoch 37 , train negloglik: 0.96581,    val negloglik: 1.61059    accuracy: 0.2687 lr: [8.1e-06]
# epoch 38 , train negloglik: 1.48010,    val negloglik: 2.54792    accuracy: 0.2656 lr: [8.1e-06]
# epoch 39 , train negloglik: 0.98834,    val negloglik: 4.07594    accuracy: 0.2630 lr: [8.1e-06]
# epoch 40 , train negloglik: 1.00138,    val negloglik: 2.91664    accuracy: 0.2596 lr: [8.1e-06]
# epoch 41 , train negloglik: 1.40230,    val negloglik: 2.31931    accuracy: 0.2612 lr: [7.2900000000000005e-06]
# epoch 42 , train negloglik: 1.29228,    val negloglik: 2.14207    accuracy: 0.2646 lr: [7.2900000000000005e-06]
# epoch 43 , train negloglik: 1.12673,    val negloglik: 4.47731    accuracy: 0.2547 lr: [7.2900000000000005e-06]
# epoch 44 , train negloglik: 1.16437,    val negloglik: 1.81487    accuracy: 0.2604 lr: [7.2900000000000005e-06]
# epoch 45 , train negloglik: 1.10727,    val negloglik: 3.02041    accuracy: 0.2732 lr: [7.2900000000000005e-06]
# epoch 46 , train negloglik: 1.42046,    val negloglik: 1.99568    accuracy: 0.2576 lr: [7.2900000000000005e-06]
# epoch 47 , train negloglik: 1.40684,    val negloglik: 1.92102    accuracy: 0.2576 lr: [7.2900000000000005e-06]
# epoch 48 , train negloglik: 0.68961,    val negloglik: 3.27767    accuracy: 0.2595 lr: [7.2900000000000005e-06]
# epoch 49 , train negloglik: 0.80351,    val negloglik: 2.58848    accuracy: 0.2613 lr: [7.2900000000000005e-06]
# epoch 50 , train negloglik: 1.20552,    val negloglik: 1.72719    accuracy: 0.2622 lr: [7.2900000000000005e-06]
# epoch 51 , train negloglik: 2.75890,    val negloglik: 1.27886    accuracy: 0.3301 lr: [7.2900000000000005e-06]
# epoch 52 , train negloglik: 1.81546,    val negloglik: 3.18235    accuracy: 0.3322 lr: [7.2900000000000005e-06]
# epoch 53 , train negloglik: 1.42347,    val negloglik: 3.60819    accuracy: 0.2832 lr: [7.2900000000000005e-06]
# epoch 54 , train negloglik: 1.12533,    val negloglik: 3.34425    accuracy: 0.2570 lr: [7.2900000000000005e-06]
# epoch 55 , train negloglik: 0.90098,    val negloglik: 3.61027    accuracy: 0.2578 lr: [7.2900000000000005e-06]
# epoch 56 , train negloglik: 1.07994,    val negloglik: 2.22426    accuracy: 0.2584 lr: [7.2900000000000005e-06]
# epoch 57 , train negloglik: 1.30344,    val negloglik: 4.90830    accuracy: 0.2590 lr: [7.2900000000000005e-06]
# epoch 58 , train negloglik: 1.94694,    val negloglik: 3.20105    accuracy: 0.2641 lr: [7.2900000000000005e-06]
# epoch 59 , train negloglik: 3.17176,    val negloglik: 2.30538    accuracy: 0.3074 lr: [7.2900000000000005e-06]
# epoch 60 , train negloglik: 2.00074,    val negloglik: 2.39692    accuracy: 0.2803 lr: [7.2900000000000005e-06]
# epoch 61 , train negloglik: 1.77570,    val negloglik: 1.50029    accuracy: 0.3068 lr: [6.561e-06]
# epoch 62 , train negloglik: 2.11697,    val negloglik: 1.54508    accuracy: 0.2745 lr: [6.561e-06]
# epoch 63 , train negloglik: 1.30983,    val negloglik: 2.06246    accuracy: 0.2490 lr: [6.561e-06]
# epoch 64 , train negloglik: 0.92382,    val negloglik: 1.68248    accuracy: 0.2616 lr: [6.561e-06]
# epoch 65 , train negloglik: 0.92055,    val negloglik: 1.93658    accuracy: 0.2731 lr: [6.561e-06]
# epoch 66 , train negloglik: 0.88507,    val negloglik: 2.43771    accuracy: 0.2614 lr: [6.561e-06]
# epoch 67 , train negloglik: 0.72650,    val negloglik: 1.46825    accuracy: 0.2643 lr: [6.561e-06]
# epoch 68 , train negloglik: 0.67954,    val negloglik: 2.61899    accuracy: 0.2681 lr: [6.561e-06]
# epoch 69 , train negloglik: 0.99314,    val negloglik: 1.42703    accuracy: 0.2683 lr: [6.561e-06]
# epoch 70 , train negloglik: 0.69725,    val negloglik: 1.54741    accuracy: 0.2681 lr: [6.561e-06]
# epoch 71 , train negloglik: 0.70078,    val negloglik: 1.53086    accuracy: 0.2575 lr: [6.561e-06]
# epoch 72 , train negloglik: 0.76518,    val negloglik: 1.50729    accuracy: 0.2557 lr: [6.561e-06]
# epoch 73 , train negloglik: 0.88460,    val negloglik: 1.66535    accuracy: 0.2533 lr: [6.561e-06]
# epoch 74 , train negloglik: 0.76597,    val negloglik: 2.45204    accuracy: 0.2502 lr: [6.561e-06]
# epoch 75 , train negloglik: 0.97698,    val negloglik: 2.01134    accuracy: 0.2519 lr: [6.561e-06]
# epoch 76 , train negloglik: 1.21331,    val negloglik: 1.43909    accuracy: 0.2546 lr: [6.561e-06]
# epoch 77 , train negloglik: 0.92231,    val negloglik: 2.34124    accuracy: 0.2546 lr: [6.561e-06]
# epoch 78 , train negloglik: 0.74227,    val negloglik: 1.40183    accuracy: 0.2540 lr: [6.561e-06]
# epoch 79 , train negloglik: 0.75214,    val negloglik: 2.15061    accuracy: 0.2531 lr: [6.561e-06]
# epoch 80 , train negloglik: 0.69052,    val negloglik: 1.55883    accuracy: 0.2493 lr: [6.561e-06]
# epoch 81 , train negloglik: 1.01402,    val negloglik: 1.55982    accuracy: 0.2535 lr: [5.904900000000001e-06]
# epoch 82 , train negloglik: 0.80296,    val negloglik: 2.12604    accuracy: 0.2509 lr: [5.904900000000001e-06]
# epoch 83 , train negloglik: 0.68202,    val negloglik: 1.77072    accuracy: 0.2524 lr: [5.904900000000001e-06]
# epoch 84 , train negloglik: 0.64918,    val negloglik: 1.60069    accuracy: 0.2505 lr: [5.904900000000001e-06]
# epoch 85 , train negloglik: 0.88230,    val negloglik: 1.67514    accuracy: 0.2436 lr: [5.904900000000001e-06]
# epoch 86 , train negloglik: 0.82516,    val negloglik: 1.75469    accuracy: 0.2444 lr: [5.904900000000001e-06]
# epoch 87 , train negloglik: 0.82767,    val negloglik: 1.25648    accuracy: 0.2431 lr: [5.904900000000001e-06]
# epoch 88 , train negloglik: 0.90275,    val negloglik: 1.33799    accuracy: 0.2453 lr: [5.904900000000001e-06]
# epoch 89 , train negloglik: 1.36807,    val negloglik: 1.69665    accuracy: 0.2540 lr: [5.904900000000001e-06]
# epoch 90 , train negloglik: 1.37721,    val negloglik: 2.13563    accuracy: 0.2497 lr: [5.904900000000001e-06]
# epoch 91 , train negloglik: 1.43641,    val negloglik: 1.29477    accuracy: 0.2500 lr: [5.904900000000001e-06]
# epoch 92 , train negloglik: 1.44920,    val negloglik: 1.28725    accuracy: 0.2590 lr: [5.904900000000001e-06]
# epoch 93 , train negloglik: 1.81102,    val negloglik: 1.21921    accuracy: 0.2664 lr: [5.904900000000001e-06]
# epoch 94 , train negloglik: 1.61597,    val negloglik: 1.23549    accuracy: 0.2693 lr: [5.904900000000001e-06]
# epoch 95 , train negloglik: 1.58174,    val negloglik: 1.04408    accuracy: 0.2674 lr: [5.904900000000001e-06]
# epoch 96 , train negloglik: 1.39095,    val negloglik: 1.45403    accuracy: 0.2740 lr: [5.904900000000001e-06]
# epoch 97 , train negloglik: 2.24173,    val negloglik: 1.40937    accuracy: 0.2823 lr: [5.904900000000001e-06]
# epoch 98 , train negloglik: 1.22827,    val negloglik: 2.27834    accuracy: 0.2494 lr: [5.904900000000001e-06]
# epoch 99 , train negloglik: 1.05836,    val negloglik: 1.91923    accuracy: 0.2768 lr: [5.904900000000001e-06]
# epoch 100, train negloglik: 0.82624,    val negloglik: 1.70552    accuracy: 0.2820 lr: [5.904900000000001e-06]
# epoch 101, train negloglik: 1.19826,    val negloglik: 1.65522    accuracy: 0.2726 lr: [5.314410000000001e-06]
# epoch 102, train negloglik: 1.01287,    val negloglik: 2.05957    accuracy: 0.2619 lr: [5.314410000000001e-06]
# epoch 103, train negloglik: 0.69602,    val negloglik: 1.76385    accuracy: 0.2732 lr: [5.314410000000001e-06]
# epoch 104, train negloglik: 0.95300,    val negloglik: 2.29798    accuracy: 0.2826 lr: [5.314410000000001e-06]
# epoch 105, train negloglik: 0.96328,    val negloglik: 1.89567    accuracy: 0.2748 lr: [5.314410000000001e-06]
# epoch 106, train negloglik: 0.80512,    val negloglik: 1.86869    accuracy: 0.2601 lr: [5.314410000000001e-06]
# epoch 107, train negloglik: 1.01978,    val negloglik: 1.04688    accuracy: 0.2633 lr: [5.314410000000001e-06]
# epoch 108, train negloglik: 0.79237,    val negloglik: 1.89341    accuracy: 0.2484 lr: [5.314410000000001e-06]
# epoch 109, train negloglik: 1.09826,    val negloglik: 1.32986    accuracy: 0.2350 lr: [5.314410000000001e-06]
# epoch 110, train negloglik: 0.65717,    val negloglik: 1.56208    accuracy: 0.2336 lr: [5.314410000000001e-06]
# epoch 111, train negloglik: 0.71792,    val negloglik: 1.43393    accuracy: 0.2287 lr: [5.314410000000001e-06]
# epoch 112, train negloglik: 0.58363,    val negloglik: 1.08632    accuracy: 0.2303 lr: [5.314410000000001e-06]
# epoch 113, train negloglik: 0.53017,    val negloglik: 1.39653    accuracy: 0.2349 lr: [5.314410000000001e-06]
# epoch 114, train negloglik: 0.54346,    val negloglik: 0.86802    accuracy: 0.2284 lr: [5.314410000000001e-06]
# epoch 115, train negloglik: 0.56226,    val negloglik: 1.24063    accuracy: 0.2269 lr: [5.314410000000001e-06]
# epoch 116, train negloglik: 0.50597,    val negloglik: 1.27314    accuracy: 0.2314 lr: [5.314410000000001e-06]
# epoch 117, train negloglik: 0.52725,    val negloglik: 1.84549    accuracy: 0.2288 lr: [5.314410000000001e-06]
# epoch 118, train negloglik: 0.63301,    val negloglik: 1.32209    accuracy: 0.2259 lr: [5.314410000000001e-06]
# epoch 119, train negloglik: 0.63903,    val negloglik: 0.85724    accuracy: 0.2301 lr: [5.314410000000001e-06]
# epoch 120, train negloglik: 0.85722,    val negloglik: 0.84899    accuracy: 0.2346 lr: [5.314410000000001e-06]
# epoch 121, train negloglik: 0.62687,    val negloglik: 1.09077    accuracy: 0.2289 lr: [4.782969000000001e-06]
# epoch 122, train negloglik: 0.56134,    val negloglik: 1.33171    accuracy: 0.2273 lr: [4.782969000000001e-06]
# epoch 123, train negloglik: 0.63887,    val negloglik: 0.96858    accuracy: 0.2263 lr: [4.782969000000001e-06]
# epoch 124, train negloglik: 0.49783,    val negloglik: 0.89753    accuracy: 0.2280 lr: [4.782969000000001e-06]
# epoch 125, train negloglik: 0.48861,    val negloglik: 1.11209    accuracy: 0.2256 lr: [4.782969000000001e-06]
# epoch 126, train negloglik: 0.67085,    val negloglik: 1.00945    accuracy: 0.2286 lr: [4.782969000000001e-06]
# epoch 127, train negloglik: 0.71374,    val negloglik: 0.97843    accuracy: 0.2264 lr: [4.782969000000001e-06]
# epoch 128, train negloglik: 0.59194,    val negloglik: 1.37341    accuracy: 0.2252 lr: [4.782969000000001e-06]
# epoch 129, train negloglik: 0.53773,    val negloglik: 2.35054    accuracy: 0.2254 lr: [4.782969000000001e-06]
# epoch 130, train negloglik: 0.53260,    val negloglik: 1.06561    accuracy: 0.2252 lr: [4.782969000000001e-06]
# epoch 131, train negloglik: 0.53224,    val negloglik: 1.22593    accuracy: 0.2238 lr: [4.782969000000001e-06]
# epoch 132, train negloglik: 0.48048,    val negloglik: 1.35765    accuracy: 0.2206 lr: [4.782969000000001e-06]
# epoch 133, train negloglik: 0.68849,    val negloglik: 1.42752    accuracy: 0.2206 lr: [4.782969000000001e-06]
# epoch 134, train negloglik: 0.66940,    val negloglik: 2.32196    accuracy: 0.2241 lr: [4.782969000000001e-06]
# epoch 135, train negloglik: 0.73366,    val negloglik: 1.53591    accuracy: 0.2233 lr: [4.782969000000001e-06]
# epoch 136, train negloglik: 0.58520,    val negloglik: 1.48191    accuracy: 0.2185 lr: [4.782969000000001e-06]
# epoch 137, train negloglik: 0.90030,    val negloglik: 1.47265    accuracy: 0.2185 lr: [4.782969000000001e-06]
# epoch 138, train negloglik: 1.00350,    val negloglik: 1.82056    accuracy: 0.2167 lr: [4.782969000000001e-06]
# epoch 139, train negloglik: 0.68999,    val negloglik: 0.87991    accuracy: 0.2196 lr: [4.782969000000001e-06]
# epoch 140, train negloglik: 0.62444,    val negloglik: 2.16470    accuracy: 0.2188 lr: [4.782969000000001e-06]
# epoch 141, train negloglik: 0.49723,    val negloglik: 1.05453    accuracy: 0.2199 lr: [4.3046721000000005e-06]
# epoch 142, train negloglik: 0.49961,    val negloglik: 0.90634    accuracy: 0.2205 lr: [4.3046721000000005e-06]
# epoch 143, train negloglik: 0.47195,    val negloglik: 1.14436    accuracy: 0.2190 lr: [4.3046721000000005e-06]
# epoch 144, train negloglik: 0.53454,    val negloglik: 1.52550    accuracy: 0.2182 lr: [4.3046721000000005e-06]
# epoch 145, train negloglik: 0.49731,    val negloglik: 0.82188    accuracy: 0.2148 lr: [4.3046721000000005e-06]
# epoch 146, train negloglik: 0.60574,    val negloglik: 1.66035    accuracy: 0.2136 lr: [4.3046721000000005e-06]
# epoch 147, train negloglik: 0.70060,    val negloglik: 1.85141    accuracy: 0.2167 lr: [4.3046721000000005e-06]
# epoch 148, train negloglik: 0.52404,    val negloglik: 1.16740    accuracy: 0.2160 lr: [4.3046721000000005e-06]
# epoch 149, train negloglik: 0.47058,    val negloglik: 1.06474    accuracy: 0.2194 lr: [4.3046721000000005e-06]
# epoch 150, train negloglik: 0.47138,    val negloglik: 0.82178    accuracy: 0.2196 lr: [4.3046721000000005e-06]
# epoch 151, train negloglik: 0.41633,    val negloglik: 1.31418    accuracy: 0.2182 lr: [4.3046721000000005e-06]
# epoch 152, train negloglik: 0.49307,    val negloglik: 0.96387    accuracy: 0.2160 lr: [4.3046721000000005e-06]
# epoch 153, train negloglik: 0.50717,    val negloglik: 1.59563    accuracy: 0.2144 lr: [4.3046721000000005e-06]
# epoch 154, train negloglik: 0.46786,    val negloglik: 1.26500    accuracy: 0.2177 lr: [4.3046721000000005e-06]
# epoch 155, train negloglik: 0.44055,    val negloglik: 1.00734    accuracy: 0.2153 lr: [4.3046721000000005e-06]
# epoch 156, train negloglik: 0.69587,    val negloglik: 0.84882    accuracy: 0.2154 lr: [4.3046721000000005e-06]
# epoch 157, train negloglik: 0.59186,    val negloglik: 0.78580    accuracy: 0.2186 lr: [4.3046721000000005e-06]
# epoch 158, train negloglik: 0.46485,    val negloglik: 1.67338    accuracy: 0.2170 lr: [4.3046721000000005e-06]
# epoch 159, train negloglik: 0.57185,    val negloglik: 1.27551    accuracy: 0.2170 lr: [4.3046721000000005e-06]
# epoch 160, train negloglik: 0.48232,    val negloglik: 1.22923    accuracy: 0.2171 lr: [4.3046721000000005e-06]
# epoch 161, train negloglik: 0.42700,    val negloglik: 1.12016    accuracy: 0.2157 lr: [3.874204890000001e-06]
# epoch 162, train negloglik: 0.48338,    val negloglik: 0.94607    accuracy: 0.2148 lr: [3.874204890000001e-06]
# epoch 163, train negloglik: 0.42214,    val negloglik: 0.98051    accuracy: 0.2156 lr: [3.874204890000001e-06]
# epoch 164, train negloglik: 0.40997,    val negloglik: 0.98983    accuracy: 0.2144 lr: [3.874204890000001e-06]
# epoch 165, train negloglik: 0.57342,    val negloglik: 1.87812    accuracy: 0.2136 lr: [3.874204890000001e-06]
# epoch 166, train negloglik: 0.42825,    val negloglik: 1.02297    accuracy: 0.2148 lr: [3.874204890000001e-06]
# epoch 167, train negloglik: 0.61786,    val negloglik: 1.17074    accuracy: 0.2178 lr: [3.874204890000001e-06]
# epoch 168, train negloglik: 0.48159,    val negloglik: 0.79828    accuracy: 0.2156 lr: [3.874204890000001e-06]
# epoch 169, train negloglik: 0.41256,    val negloglik: 1.90146    accuracy: 0.2121 lr: [3.874204890000001e-06]
# epoch 170, train negloglik: 0.53239,    val negloglik: 1.25586    accuracy: 0.2197 lr: [3.874204890000001e-06]
# epoch 171, train negloglik: 0.40024,    val negloglik: 0.75408    accuracy: 0.2171 lr: [3.874204890000001e-06]
# epoch 172, train negloglik: 0.41998,    val negloglik: 2.02989    accuracy: 0.2131 lr: [3.874204890000001e-06]
# epoch 173, train negloglik: 0.47313,    val negloglik: 1.19147    accuracy: 0.2146 lr: [3.874204890000001e-06]
# epoch 174, train negloglik: 0.40447,    val negloglik: 0.80880    accuracy: 0.2154 lr: [3.874204890000001e-06]
# epoch 175, train negloglik: 0.43271,    val negloglik: 1.18063    accuracy: 0.2141 lr: [3.874204890000001e-06]
# epoch 176, train negloglik: 0.42906,    val negloglik: 0.80170    accuracy: 0.2157 lr: [3.874204890000001e-06]
# epoch 177, train negloglik: 0.45641,    val negloglik: 1.42804    accuracy: 0.2148 lr: [3.874204890000001e-06]
# epoch 178, train negloglik: 0.42260,    val negloglik: 0.92284    accuracy: 0.2180 lr: [3.874204890000001e-06]
# epoch 179, train negloglik: 0.46971,    val negloglik: 0.84605    accuracy: 0.2174 lr: [3.874204890000001e-06]
# epoch 180, train negloglik: 0.40233,    val negloglik: 0.93175    accuracy: 0.2157 lr: [3.874204890000001e-06]
# epoch 181, train negloglik: 0.44527,    val negloglik: 0.98080    accuracy: 0.2132 lr: [3.4867844010000007e-06]
# epoch 182, train negloglik: 0.45709,    val negloglik: 1.12272    accuracy: 0.2150 lr: [3.4867844010000007e-06]
# epoch 183, train negloglik: 0.37897,    val negloglik: 0.75454    accuracy: 0.2159 lr: [3.4867844010000007e-06]
# epoch 184, train negloglik: 0.40070,    val negloglik: 1.96538    accuracy: 0.2127 lr: [3.4867844010000007e-06]
# epoch 185, train negloglik: 0.40265,    val negloglik: 1.35971    accuracy: 0.2144 lr: [3.4867844010000007e-06]
# epoch 186, train negloglik: 0.37491,    val negloglik: 0.88895    accuracy: 0.2163 lr: [3.4867844010000007e-06]
# epoch 187, train negloglik: 0.41196,    val negloglik: 0.75152    accuracy: 0.2184 lr: [3.4867844010000007e-06]
# epoch 188, train negloglik: 0.38143,    val negloglik: 0.75934    accuracy: 0.2154 lr: [3.4867844010000007e-06]
# epoch 189, train negloglik: 0.47404,    val negloglik: 0.93717    accuracy: 0.2167 lr: [3.4867844010000007e-06]
# epoch 190, train negloglik: 0.45481,    val negloglik: 1.52698    accuracy: 0.2122 lr: [3.4867844010000007e-06]
# epoch 191, train negloglik: 0.49415,    val negloglik: 0.85137    accuracy: 0.2141 lr: [3.4867844010000007e-06]
# epoch 192, train negloglik: 0.48745,    val negloglik: 1.23438    accuracy: 0.2155 lr: [3.4867844010000007e-06]
# epoch 193, train negloglik: 0.41017,    val negloglik: 1.31485    accuracy: 0.2153 lr: [3.4867844010000007e-06]
# epoch 194, train negloglik: 0.55777,    val negloglik: 0.88473    accuracy: 0.2240 lr: [3.4867844010000007e-06]
# epoch 195, train negloglik: 0.55370,    val negloglik: 0.80315    accuracy: 0.2207 lr: [3.4867844010000007e-06]
# epoch 196, train negloglik: 0.39869,    val negloglik: 0.71747    accuracy: 0.2188 lr: [3.4867844010000007e-06]
# epoch 197, train negloglik: 0.48393,    val negloglik: 0.91401    accuracy: 0.2154 lr: [3.4867844010000007e-06]
# epoch 198, train negloglik: 0.50130,    val negloglik: 1.89787    accuracy: 0.2121 lr: [3.4867844010000007e-06]
# epoch 199, train negloglik: 0.65661,    val negloglik: 1.70063    accuracy: 0.2129 lr: [3.4867844010000007e-06]
# epoch 200, train negloglik: 0.57961,    val negloglik: 1.65144    accuracy: 0.2099 lr: [3.4867844010000007e-06]
# epoch 201, train negloglik: 0.62678,    val negloglik: 1.60498    accuracy: 0.2113 lr: [3.1381059609000006e-06]
# epoch 202, train negloglik: 0.59008,    val negloglik: 1.53039    accuracy: 0.2063 lr: [3.1381059609000006e-06]
# epoch 203, train negloglik: 0.56020,    val negloglik: 1.59756    accuracy: 0.2127 lr: [3.1381059609000006e-06]
# epoch 204, train negloglik: 0.61866,    val negloglik: 1.09283    accuracy: 0.2197 lr: [3.1381059609000006e-06]
# epoch 205, train negloglik: 0.38605,    val negloglik: 1.20106    accuracy: 0.2160 lr: [3.1381059609000006e-06]
# epoch 206, train negloglik: 0.43653,    val negloglik: 1.03879    accuracy: 0.2171 lr: [3.1381059609000006e-06]
# epoch 207, train negloglik: 0.40108,    val negloglik: 0.87700    accuracy: 0.2168 lr: [3.1381059609000006e-06]
# epoch 208, train negloglik: 0.41872,    val negloglik: 1.08308    accuracy: 0.2160 lr: [3.1381059609000006e-06]
# epoch 209, train negloglik: 0.37449,    val negloglik: 0.69004    accuracy: 0.2166 lr: [3.1381059609000006e-06]
# epoch 210, train negloglik: 0.41849,    val negloglik: 0.92738    accuracy: 0.2182 lr: [3.1381059609000006e-06]
# epoch 211, train negloglik: 0.42348,    val negloglik: 0.84802    accuracy: 0.2170 lr: [3.1381059609000006e-06]
# epoch 212, train negloglik: 0.39688,    val negloglik: 1.32517    accuracy: 0.2173 lr: [3.1381059609000006e-06]
# epoch 213, train negloglik: 0.38808,    val negloglik: 1.65439    accuracy: 0.2166 lr: [3.1381059609000006e-06]
# epoch 214, train negloglik: 0.36824,    val negloglik: 0.95713    accuracy: 0.2155 lr: [3.1381059609000006e-06]
# epoch 215, train negloglik: 0.40393,    val negloglik: 2.05144    accuracy: 0.2137 lr: [3.1381059609000006e-06]
# epoch 216, train negloglik: 0.41354,    val negloglik: 1.22674    accuracy: 0.2175 lr: [3.1381059609000006e-06]
# epoch 217, train negloglik: 0.51245,    val negloglik: 1.68280    accuracy: 0.2137 lr: [3.1381059609000006e-06]
# epoch 218, train negloglik: 0.43622,    val negloglik: 0.77085    accuracy: 0.2237 lr: [3.1381059609000006e-06]
# epoch 219, train negloglik: 0.46194,    val negloglik: 1.51781    accuracy: 0.2162 lr: [3.1381059609000006e-06]
# epoch 220, train negloglik: 0.43018,    val negloglik: 0.89143    accuracy: 0.2208 lr: [3.1381059609000006e-06]
# epoch 221, train negloglik: 0.47971,    val negloglik: 0.86625    accuracy: 0.2207 lr: [2.8242953648100006e-06]
# epoch 222, train negloglik: 0.36045,    val negloglik: 0.82525    accuracy: 0.2250 lr: [2.8242953648100006e-06]
# epoch 223, train negloglik: 0.40504,    val negloglik: 0.72477    accuracy: 0.2222 lr: [2.8242953648100006e-06]
# epoch 224, train negloglik: 0.49540,    val negloglik: 0.78522    accuracy: 0.2221 lr: [2.8242953648100006e-06]
# epoch 225, train negloglik: 0.37531,    val negloglik: 0.72864    accuracy: 0.2215 lr: [2.8242953648100006e-06]
# epoch 226, train negloglik: 0.41539,    val negloglik: 1.26422    accuracy: 0.2197 lr: [2.8242953648100006e-06]
# epoch 227, train negloglik: 0.37886,    val negloglik: 0.88887    accuracy: 0.2207 lr: [2.8242953648100006e-06]
# epoch 228, train negloglik: 0.39176,    val negloglik: 0.83997    accuracy: 0.2260 lr: [2.8242953648100006e-06]
# epoch 229, train negloglik: 0.42554,    val negloglik: 0.86786    accuracy: 0.2207 lr: [2.8242953648100006e-06]
# epoch 230, train negloglik: 0.37610,    val negloglik: 1.25654    accuracy: 0.2191 lr: [2.8242953648100006e-06]
# epoch 231, train negloglik: 0.36457,    val negloglik: 0.82312    accuracy: 0.2247 lr: [2.8242953648100006e-06]
# epoch 232, train negloglik: 0.37690,    val negloglik: 1.22208    accuracy: 0.2235 lr: [2.8242953648100006e-06]
# epoch 233, train negloglik: 0.48955,    val negloglik: 1.05831    accuracy: 0.2208 lr: [2.8242953648100006e-06]
# epoch 234, train negloglik: 0.35939,    val negloglik: 0.86398    accuracy: 0.2249 lr: [2.8242953648100006e-06]
# epoch 235, train negloglik: 0.44536,    val negloglik: 1.61698    accuracy: 0.2195 lr: [2.8242953648100006e-06]
# epoch 236, train negloglik: 0.41500,    val negloglik: 0.88609    accuracy: 0.2255 lr: [2.8242953648100006e-06]
# epoch 237, train negloglik: 0.38535,    val negloglik: 0.86825    accuracy: 0.2233 lr: [2.8242953648100006e-06]
# epoch 238, train negloglik: 0.37239,    val negloglik: 1.16341    accuracy: 0.2266 lr: [2.8242953648100006e-06]
# epoch 239, train negloglik: 0.36389,    val negloglik: 1.46762    accuracy: 0.2251 lr: [2.8242953648100006e-06]
# epoch 240, train negloglik: 0.47259,    val negloglik: 1.42733    accuracy: 0.2213 lr: [2.8242953648100006e-06]
# epoch 241, train negloglik: 0.39682,    val negloglik: 0.82637    accuracy: 0.2272 lr: [2.5418658283290006e-06]
# epoch 242, train negloglik: 0.36948,    val negloglik: 1.06091    accuracy: 0.2214 lr: [2.5418658283290006e-06]
# epoch 243, train negloglik: 0.45378,    val negloglik: 1.18768    accuracy: 0.2221 lr: [2.5418658283290006e-06]
# epoch 244, train negloglik: 0.34904,    val negloglik: 1.33522    accuracy: 0.2213 lr: [2.5418658283290006e-06]
# epoch 245, train negloglik: 0.60744,    val negloglik: 2.02461    accuracy: 0.2171 lr: [2.5418658283290006e-06]
# epoch 246, train negloglik: 0.44178,    val negloglik: 0.95574    accuracy: 0.2272 lr: [2.5418658283290006e-06]
# epoch 247, train negloglik: 0.38456,    val negloglik: 0.74954    accuracy: 0.2264 lr: [2.5418658283290006e-06]
# epoch 248, train negloglik: 0.45111,    val negloglik: 0.75482    accuracy: 0.2260 lr: [2.5418658283290006e-06]
# epoch 249, train negloglik: 0.34987,    val negloglik: 1.04565    accuracy: 0.2281 lr: [2.5418658283290006e-06]
# epoch 250, train negloglik: 0.37926,    val negloglik: 0.85999    accuracy: 0.2286 lr: [2.5418658283290006e-06]
# epoch 251, train negloglik: 0.40195,    val negloglik: 1.00958    accuracy: 0.2239 lr: [2.5418658283290006e-06]
# epoch 252, train negloglik: 0.43902,    val negloglik: 0.80201    accuracy: 0.2241 lr: [2.5418658283290006e-06]
# epoch 253, train negloglik: 0.34804,    val negloglik: 0.74898    accuracy: 0.2290 lr: [2.5418658283290006e-06]
# epoch 254, train negloglik: 0.45846,    val negloglik: 0.98416    accuracy: 0.2240 lr: [2.5418658283290006e-06]
# epoch 255, train negloglik: 0.38313,    val negloglik: 0.74798    accuracy: 0.2319 lr: [2.5418658283290006e-06]
# epoch 256, train negloglik: 0.33895,    val negloglik: 0.83731    accuracy: 0.2274 lr: [2.5418658283290006e-06]
# epoch 257, train negloglik: 0.38999,    val negloglik: 1.57241    accuracy: 0.2227 lr: [2.5418658283290006e-06]
# epoch 258, train negloglik: 0.38196,    val negloglik: 0.83936    accuracy: 0.2230 lr: [2.5418658283290006e-06]
# epoch 259, train negloglik: 0.41388,    val negloglik: 1.28255    accuracy: 0.2253 lr: [2.5418658283290006e-06]
# epoch 260, train negloglik: 0.48534,    val negloglik: 1.03017    accuracy: 0.2264 lr: [2.5418658283290006e-06]
# epoch 261, train negloglik: 0.43584,    val negloglik: 0.75322    accuracy: 0.2233 lr: [2.2876792454961005e-06]
# epoch 262, train negloglik: 0.36332,    val negloglik: 0.89326    accuracy: 0.2250 lr: [2.2876792454961005e-06]
# epoch 263, train negloglik: 0.35152,    val negloglik: 1.24230    accuracy: 0.2265 lr: [2.2876792454961005e-06]
# epoch 264, train negloglik: 0.47728,    val negloglik: 0.69965    accuracy: 0.2293 lr: [2.2876792454961005e-06]
# epoch 265, train negloglik: 0.36327,    val negloglik: 0.64133    accuracy: 0.2286 lr: [2.2876792454961005e-06]
# epoch 266, train negloglik: 0.40864,    val negloglik: 0.80553    accuracy: 0.2266 lr: [2.2876792454961005e-06]
# epoch 267, train negloglik: 0.35646,    val negloglik: 0.64131    accuracy: 0.2269 lr: [2.2876792454961005e-06]
# epoch 268, train negloglik: 0.37359,    val negloglik: 1.49731    accuracy: 0.2246 lr: [2.2876792454961005e-06]
# epoch 269, train negloglik: 0.34240,    val negloglik: 0.70179    accuracy: 0.2242 lr: [2.2876792454961005e-06]
# epoch 270, train negloglik: 0.45106,    val negloglik: 0.86065    accuracy: 0.2317 lr: [2.2876792454961005e-06]
# epoch 271, train negloglik: 0.47857,    val negloglik: 0.94867    accuracy: 0.2285 lr: [2.2876792454961005e-06]
# epoch 272, train negloglik: 0.40672,    val negloglik: 0.95334    accuracy: 0.2239 lr: [2.2876792454961005e-06]
# epoch 273, train negloglik: 0.38870,    val negloglik: 1.75574    accuracy: 0.2222 lr: [2.2876792454961005e-06]
# epoch 274, train negloglik: 0.40982,    val negloglik: 0.77748    accuracy: 0.2282 lr: [2.2876792454961005e-06]
# epoch 275, train negloglik: 0.38056,    val negloglik: 1.82456    accuracy: 0.2262 lr: [2.2876792454961005e-06]
# epoch 276, train negloglik: 0.40983,    val negloglik: 1.26705    accuracy: 0.2255 lr: [2.2876792454961005e-06]
# epoch 277, train negloglik: 0.38050,    val negloglik: 0.67200    accuracy: 0.2272 lr: [2.2876792454961005e-06]
# epoch 278, train negloglik: 0.37712,    val negloglik: 1.16370    accuracy: 0.2263 lr: [2.2876792454961005e-06]
# epoch 279, train negloglik: 0.45091,    val negloglik: 0.75426    accuracy: 0.2303 lr: [2.2876792454961005e-06]
# epoch 280, train negloglik: 0.36883,    val negloglik: 1.25326    accuracy: 0.2277 lr: [2.2876792454961005e-06]
# epoch 281, train negloglik: 0.41214,    val negloglik: 0.91557    accuracy: 0.2286 lr: [2.0589113209464906e-06]
# epoch 282, train negloglik: 0.36987,    val negloglik: 1.20845    accuracy: 0.2267 lr: [2.0589113209464906e-06]
# epoch 283, train negloglik: 0.38106,    val negloglik: 1.21441    accuracy: 0.2297 lr: [2.0589113209464906e-06]
# epoch 284, train negloglik: 0.37352,    val negloglik: 1.12778    accuracy: 0.2241 lr: [2.0589113209464906e-06]
# epoch 285, train negloglik: 0.34684,    val negloglik: 1.28489    accuracy: 0.2273 lr: [2.0589113209464906e-06]
# epoch 286, train negloglik: 0.34850,    val negloglik: 0.99030    accuracy: 0.2276 lr: [2.0589113209464906e-06]
# epoch 287, train negloglik: 0.33520,    val negloglik: 1.55951    accuracy: 0.2274 lr: [2.0589113209464906e-06]
# epoch 288, train negloglik: 0.38237,    val negloglik: 0.81444    accuracy: 0.2311 lr: [2.0589113209464906e-06]
# epoch 289, train negloglik: 0.38119,    val negloglik: 0.81615    accuracy: 0.2326 lr: [2.0589113209464906e-06]
# epoch 290, train negloglik: 0.48361,    val negloglik: 0.87573    accuracy: 0.2296 lr: [2.0589113209464906e-06]
# epoch 291, train negloglik: 0.34928,    val negloglik: 1.37619    accuracy: 0.2254 lr: [2.0589113209464906e-06]
# epoch 292, train negloglik: 0.43183,    val negloglik: 0.88213    accuracy: 0.2291 lr: [2.0589113209464906e-06]
# epoch 293, train negloglik: 0.37607,    val negloglik: 1.59972    accuracy: 0.2253 lr: [2.0589113209464906e-06]
# epoch 294, train negloglik: 0.34397,    val negloglik: 0.87906    accuracy: 0.2275 lr: [2.0589113209464906e-06]
# epoch 295, train negloglik: 0.39644,    val negloglik: 0.92976    accuracy: 0.2297 lr: [2.0589113209464906e-06]
# epoch 296, train negloglik: 0.34376,    val negloglik: 1.19402    accuracy: 0.2258 lr: [2.0589113209464906e-06]
# epoch 297, train negloglik: 0.34640,    val negloglik: 1.32959    accuracy: 0.2262 lr: [2.0589113209464906e-06]
# epoch 298, train negloglik: 0.37988,    val negloglik: 0.62963    accuracy: 0.2308 lr: [2.0589113209464906e-06]
# epoch 299, train negloglik: 0.36679,    val negloglik: 0.79811    accuracy: 0.2311 lr: [2.0589113209464906e-06]
# epoch 300, train negloglik: 0.37346,    val negloglik: 0.70521    accuracy: 0.2333 lr: [2.0589113209464906e-06]
# epoch 301, train negloglik: 0.47868,    val negloglik: 0.86967    accuracy: 0.2315 lr: [1.8530201888518416e-06]
# epoch 302, train negloglik: 0.34155,    val negloglik: 0.77729    accuracy: 0.2287 lr: [1.8530201888518416e-06]
# epoch 303, train negloglik: 0.37890,    val negloglik: 1.28599    accuracy: 0.2272 lr: [1.8530201888518416e-06]
# epoch 304, train negloglik: 0.46768,    val negloglik: 1.52713    accuracy: 0.2271 lr: [1.8530201888518416e-06]
# epoch 305, train negloglik: 0.35075,    val negloglik: 1.21070    accuracy: 0.2288 lr: [1.8530201888518416e-06]
# epoch 306, train negloglik: 0.36634,    val negloglik: 0.78805    accuracy: 0.2308 lr: [1.8530201888518416e-06]
# epoch 307, train negloglik: 0.35319,    val negloglik: 1.43965    accuracy: 0.2299 lr: [1.8530201888518416e-06]
# epoch 308, train negloglik: 0.36054,    val negloglik: 1.17489    accuracy: 0.2282 lr: [1.8530201888518416e-06]
# epoch 309, train negloglik: 0.35533,    val negloglik: 0.95470    accuracy: 0.2277 lr: [1.8530201888518416e-06]
# epoch 310, train negloglik: 0.33719,    val negloglik: 1.41793    accuracy: 0.2273 lr: [1.8530201888518416e-06]
# epoch 311, train negloglik: 0.38997,    val negloglik: 0.70906    accuracy: 0.2308 lr: [1.8530201888518416e-06]
# epoch 312, train negloglik: 0.35080,    val negloglik: 1.05128    accuracy: 0.2292 lr: [1.8530201888518416e-06]
# epoch 313, train negloglik: 0.32722,    val negloglik: 1.00164    accuracy: 0.2323 lr: [1.8530201888518416e-06]
# epoch 314, train negloglik: 0.51953,    val negloglik: 1.06881    accuracy: 0.2285 lr: [1.8530201888518416e-06]
# epoch 315, train negloglik: 0.42284,    val negloglik: 1.05641    accuracy: 0.2277 lr: [1.8530201888518416e-06]
# epoch 316, train negloglik: 0.34075,    val negloglik: 0.95205    accuracy: 0.2314 lr: [1.8530201888518416e-06]
# epoch 317, train negloglik: 0.36981,    val negloglik: 1.13817    accuracy: 0.2256 lr: [1.8530201888518416e-06]
# epoch 318, train negloglik: 0.32493,    val negloglik: 1.01293    accuracy: 0.2306 lr: [1.8530201888518416e-06]
# epoch 319, train negloglik: 0.42714,    val negloglik: 1.02546    accuracy: 0.2288 lr: [1.8530201888518416e-06]
# epoch 320, train negloglik: 0.36370,    val negloglik: 0.81692    accuracy: 0.2327 lr: [1.8530201888518416e-06]
# epoch 321, train negloglik: 0.37105,    val negloglik: 1.61627    accuracy: 0.2289 lr: [1.6677181699666574e-06]
# epoch 322, train negloglik: 0.40905,    val negloglik: 0.77698    accuracy: 0.2304 lr: [1.6677181699666574e-06]
# epoch 323, train negloglik: 0.33650,    val negloglik: 0.78828    accuracy: 0.2318 lr: [1.6677181699666574e-06]
# epoch 324, train negloglik: 0.37008,    val negloglik: 1.07626    accuracy: 0.2289 lr: [1.6677181699666574e-06]
# epoch 325, train negloglik: 0.35484,    val negloglik: 1.28153    accuracy: 0.2311 lr: [1.6677181699666574e-06]
# epoch 326, train negloglik: 0.39889,    val negloglik: 0.66372    accuracy: 0.2315 lr: [1.6677181699666574e-06]
# epoch 327, train negloglik: 0.32582,    val negloglik: 0.92399    accuracy: 0.2303 lr: [1.6677181699666574e-06]
# epoch 328, train negloglik: 0.41282,    val negloglik: 1.28348    accuracy: 0.2299 lr: [1.6677181699666574e-06]
# epoch 329, train negloglik: 0.38530,    val negloglik: 0.93147    accuracy: 0.2298 lr: [1.6677181699666574e-06]
# epoch 330, train negloglik: 0.41500,    val negloglik: 0.74464    accuracy: 0.2328 lr: [1.6677181699666574e-06]
# epoch 331, train negloglik: 0.35574,    val negloglik: 0.92742    accuracy: 0.2306 lr: [1.6677181699666574e-06]
# epoch 332, train negloglik: 0.38323,    val negloglik: 0.71853    accuracy: 0.2291 lr: [1.6677181699666574e-06]
# epoch 333, train negloglik: 0.32518,    val negloglik: 1.09330    accuracy: 0.2290 lr: [1.6677181699666574e-06]
# epoch 334, train negloglik: 0.35366,    val negloglik: 0.81011    accuracy: 0.2291 lr: [1.6677181699666574e-06]
# epoch 335, train negloglik: 0.42827,    val negloglik: 0.84333    accuracy: 0.2317 lr: [1.6677181699666574e-06]
# epoch 336, train negloglik: 0.39198,    val negloglik: 0.88557    accuracy: 0.2325 lr: [1.6677181699666574e-06]
# epoch 337, train negloglik: 0.35413,    val negloglik: 0.75155    accuracy: 0.2312 lr: [1.6677181699666574e-06]
# epoch 338, train negloglik: 0.34345,    val negloglik: 0.75866    accuracy: 0.2336 lr: [1.6677181699666574e-06]
# epoch 339, train negloglik: 0.41473,    val negloglik: 1.10798    accuracy: 0.2319 lr: [1.6677181699666574e-06]
# epoch 340, train negloglik: 0.35885,    val negloglik: 0.91291    accuracy: 0.2284 lr: [1.6677181699666574e-06]
# epoch 341, train negloglik: 0.39085,    val negloglik: 1.17572    accuracy: 0.2287 lr: [1.5009463529699917e-06]
# epoch 342, train negloglik: 0.40036,    val negloglik: 1.00929    accuracy: 0.2310 lr: [1.5009463529699917e-06]
# epoch 343, train negloglik: 0.34869,    val negloglik: 1.63511    accuracy: 0.2285 lr: [1.5009463529699917e-06]
# epoch 344, train negloglik: 0.33115,    val negloglik: 1.19153    accuracy: 0.2257 lr: [1.5009463529699917e-06]
# epoch 345, train negloglik: 0.38616,    val negloglik: 0.65171    accuracy: 0.2327 lr: [1.5009463529699917e-06]
# epoch 346, train negloglik: 0.36772,    val negloglik: 0.96169    accuracy: 0.2298 lr: [1.5009463529699917e-06]
# epoch 347, train negloglik: 0.45083,    val negloglik: 0.91724    accuracy: 0.2307 lr: [1.5009463529699917e-06]
# epoch 348, train negloglik: 0.39445,    val negloglik: 1.02030    accuracy: 0.2332 lr: [1.5009463529699917e-06]
# epoch 349, train negloglik: 0.34857,    val negloglik: 0.87750    accuracy: 0.2326 lr: [1.5009463529699917e-06]
# epoch 350, train negloglik: 0.37564,    val negloglik: 1.02774    accuracy: 0.2309 lr: [1.5009463529699917e-06]
# epoch 351, train negloglik: 0.35943,    val negloglik: 1.37912    accuracy: 0.2279 lr: [1.5009463529699917e-06]
# epoch 352, train negloglik: 0.34583,    val negloglik: 0.71475    accuracy: 0.2320 lr: [1.5009463529699917e-06]
# epoch 353, train negloglik: 0.36545,    val negloglik: 0.98293    accuracy: 0.2318 lr: [1.5009463529699917e-06]
# epoch 354, train negloglik: 0.32787,    val negloglik: 0.77989    accuracy: 0.2351 lr: [1.5009463529699917e-06]
# epoch 355, train negloglik: 0.36670,    val negloglik: 0.63820    accuracy: 0.2318 lr: [1.5009463529699917e-06]
# epoch 356, train negloglik: 0.37614,    val negloglik: 0.65622    accuracy: 0.2313 lr: [1.5009463529699917e-06]
# epoch 357, train negloglik: 0.39989,    val negloglik: 0.77092    accuracy: 0.2325 lr: [1.5009463529699917e-06]
# epoch 358, train negloglik: 0.33840,    val negloglik: 0.89527    accuracy: 0.2322 lr: [1.5009463529699917e-06]
# epoch 359, train negloglik: 0.39101,    val negloglik: 0.79036    accuracy: 0.2347 lr: [1.5009463529699917e-06]
# epoch 360, train negloglik: 0.38499,    val negloglik: 0.81703    accuracy: 0.2301 lr: [1.5009463529699917e-06]
# epoch 361, train negloglik: 0.38477,    val negloglik: 1.16918    accuracy: 0.2312 lr: [1.3508517176729926e-06]
# epoch 362, train negloglik: 0.37839,    val negloglik: 0.74533    accuracy: 0.2346 lr: [1.3508517176729926e-06]
# epoch 363, train negloglik: 0.42782,    val negloglik: 0.79831    accuracy: 0.2363 lr: [1.3508517176729926e-06]
# epoch 364, train negloglik: 0.36350,    val negloglik: 0.70074    accuracy: 0.2328 lr: [1.3508517176729926e-06]
# epoch 365, train negloglik: 0.35189,    val negloglik: 1.08993    accuracy: 0.2345 lr: [1.3508517176729926e-06]
# epoch 366, train negloglik: 0.32397,    val negloglik: 0.84332    accuracy: 0.2359 lr: [1.3508517176729926e-06]
# epoch 367, train negloglik: 0.35888,    val negloglik: 0.65594    accuracy: 0.2339 lr: [1.3508517176729926e-06]
# epoch 368, train negloglik: 0.36356,    val negloglik: 0.75140    accuracy: 0.2343 lr: [1.3508517176729926e-06]
# epoch 369, train negloglik: 0.33313,    val negloglik: 0.70269    accuracy: 0.2312 lr: [1.3508517176729926e-06]
# epoch 370, train negloglik: 0.37592,    val negloglik: 0.77378    accuracy: 0.2331 lr: [1.3508517176729926e-06]
# epoch 371, train negloglik: 0.36497,    val negloglik: 0.91501    accuracy: 0.2355 lr: [1.3508517176729926e-06]
# epoch 372, train negloglik: 0.31993,    val negloglik: 0.96458    accuracy: 0.2327 lr: [1.3508517176729926e-06]
# epoch 373, train negloglik: 0.44026,    val negloglik: 0.76219    accuracy: 0.2331 lr: [1.3508517176729926e-06]
# epoch 374, train negloglik: 0.39376,    val negloglik: 1.03641    accuracy: 0.2303 lr: [1.3508517176729926e-06]
# epoch 375, train negloglik: 0.39172,    val negloglik: 0.96727    accuracy: 0.2300 lr: [1.3508517176729926e-06]
# epoch 376, train negloglik: 0.44574,    val negloglik: 0.72112    accuracy: 0.2316 lr: [1.3508517176729926e-06]
# epoch 377, train negloglik: 0.41105,    val negloglik: 0.64649    accuracy: 0.2376 lr: [1.3508517176729926e-06]
# epoch 378, train negloglik: 0.36219,    val negloglik: 0.79416    accuracy: 0.2329 lr: [1.3508517176729926e-06]
# epoch 379, train negloglik: 0.35449,    val negloglik: 1.18494    accuracy: 0.2335 lr: [1.3508517176729926e-06]
# epoch 380, train negloglik: 0.41808,    val negloglik: 0.82677    accuracy: 0.2345 lr: [1.3508517176729926e-06]
# epoch 381, train negloglik: 0.38343,    val negloglik: 0.76664    accuracy: 0.2350 lr: [1.2157665459056933e-06]
# epoch 382, train negloglik: 0.37039,    val negloglik: 0.85998    accuracy: 0.2330 lr: [1.2157665459056933e-06]
# epoch 383, train negloglik: 0.32258,    val negloglik: 1.01904    accuracy: 0.2305 lr: [1.2157665459056933e-06]
# epoch 384, train negloglik: 0.32785,    val negloglik: 1.12684    accuracy: 0.2295 lr: [1.2157665459056933e-06]
# epoch 385, train negloglik: 0.31321,    val negloglik: 1.04769    accuracy: 0.2287 lr: [1.2157665459056933e-06]
# epoch 386, train negloglik: 0.35689,    val negloglik: 0.61785    accuracy: 0.2349 lr: [1.2157665459056933e-06]
# epoch 387, train negloglik: 0.35793,    val negloglik: 0.87392    accuracy: 0.2370 lr: [1.2157665459056933e-06]
# epoch 388, train negloglik: 0.41049,    val negloglik: 0.70681    accuracy: 0.2340 lr: [1.2157665459056933e-06]
# epoch 389, train negloglik: 0.40711,    val negloglik: 1.03093    accuracy: 0.2318 lr: [1.2157665459056933e-06]
# epoch 390, train negloglik: 0.34500,    val negloglik: 1.16309    accuracy: 0.2321 lr: [1.2157665459056933e-06]
# epoch 391, train negloglik: 0.35572,    val negloglik: 0.75946    accuracy: 0.2344 lr: [1.2157665459056933e-06]
# epoch 392, train negloglik: 0.41273,    val negloglik: 1.00939    accuracy: 0.2332 lr: [1.2157665459056933e-06]
# epoch 393, train negloglik: 0.36820,    val negloglik: 0.79177    accuracy: 0.2335 lr: [1.2157665459056933e-06]
# epoch 394, train negloglik: 0.33059,    val negloglik: 1.19104    accuracy: 0.2305 lr: [1.2157665459056933e-06]
# epoch 395, train negloglik: 0.40035,    val negloglik: 1.09436    accuracy: 0.2346 lr: [1.2157665459056933e-06]
# epoch 396, train negloglik: 0.37587,    val negloglik: 1.50953    accuracy: 0.2306 lr: [1.2157665459056933e-06]
# epoch 397, train negloglik: 0.31674,    val negloglik: 1.02912    accuracy: 0.2321 lr: [1.2157665459056933e-06]
# epoch 398, train negloglik: 0.35210,    val negloglik: 0.85898    accuracy: 0.2295 lr: [1.2157665459056933e-06]
# epoch 399, train negloglik: 0.34265,    val negloglik: 0.75251    accuracy: 0.2319 lr: [1.2157665459056933e-06]
# Test MSE: 0.152146
# Test RMSE: 0.390059
# Residual Statistics:
# Mean: 0.014658
# Std: 0.389783
# Min: -2.269163
# Max: 0.854219
# plot completed

# %% [markdown]
# ## 3.結果評価
# 以下の項目に従ってカーネル行列の分析結果をまとめる：
#
# **カーネル行列分析項目**
# - 各層のカーネル行列ランクと条件数の分析
# - 誘導点の分布と配置の可視化
# - カーネル行列のヒートマップ（Jitter項適用前後）
# - 固有値分布の分析
# - 誘導点間距離の統計的分析

# %%
# 1層目
model.layers[0].save_fig("../outputs/layer_fused0.png")
model.layers[1].save_fig("../outputs/layer_fused1.png")

# %%
# カーネル行列のランク可視化・分析
import matplotlib.pyplot as plt
import numpy as np
import torch


def analyze_kernel_matrices(model):
    """
    GP-KANの各層のカーネル行列ランクと条件数を分析・可視化する
    """
    print("=== カーネル行列分析 ===")

    # 各層の分析
    for layer_idx, layer in enumerate(model.layers):
        print(f"\n--- Layer {layer_idx} ---")

        # 誘導点を取得
        z_range = layer.get_z().detach()  # 入力値
        h_range = layer.h.detach()  # 出力値
        jitter = layer.get_jitter().detach()  # Shape: [1, 1]
        print(
            f"z(誘導点)の範囲: [{z_range.min().item():.4f}, {z_range.max().item():.4f}]"
        )
        print(
            f"h(関数値)の範囲: [{h_range.min().item():.4f}, {h_range.max().item():.4f}]"
        )

        # カーネル行列を計算
        with torch.no_grad():
            # カーネル行列を計算
            lengthscale = layer.l.detach()  # Shape: [1, 1]
            variance = layer.s.detach()  # Shape: [1, 1]

            # Set i=j=1 for processing (assuming we want the first GP component)
            i, j = 0, 0  # Using 0-based indexing for tensor access

            # Get parameters for this specific GP
            z_ij = z_range[i, j, :]  # Shape: [X]
            l_ij = lengthscale[i, j]  # Scalar
            s_ij = variance[i, j]  # Scalar

            # Reshape inducing points for distance computation
            z_ij = z_ij.unsqueeze(1)  # Shape: [X, 1]

            # Compute kernel matrix for this GP
            pairwise_sq_dists = torch.cdist(z_ij, z_ij, p=2) ** 2
            # 誘導点間のカーネル行列
            K = s_ij * torch.exp(-pairwise_sq_dists / (2 * l_ij**2))

            print("計算開始")
            # ランク計算
            rank_clean = torch.linalg.matrix_rank(K)

            # 条件数計算
            cond_clean = torch.linalg.cond(K)

            # 固有値
            eigenvals_clean = torch.linalg.eigvals(K).real

            print("計算完了")

            print(f"カーネル行列ランク: {rank_clean.item()}")
            print(f"条件数: {cond_clean.item():.2e}")
            print(f"最小固有値: {eigenvals_clean.min().item():.2e}")
            print(
                f"パラメータ値 - s_ij: {s_ij.item():.4f}, l_ij: {l_ij.item():.4f}, jitter: {jitter.item():.4f}"
            )

        # 可視化
        fig, axes = plt.subplots(2, 3, figsize=(15, 10))

        # 誘導点の分布
        axes[0, 0].scatter(
            z_range.numpy(),
            h_range.numpy(),
            alpha=0.7,
            s=50,
        )
        axes[0, 0].set_title(f"Layer {layer_idx}: 誘導点分布")
        axes[0, 0].set_xlabel("誘導点位置")
        axes[0, 0].grid(True, alpha=0.3)

        # カーネル行列のヒートマップ
        im1 = axes[0, 1].imshow(K.numpy(), cmap="viridis")
        axes[0, 1].set_title(f"カーネル行列\nRank: {rank_clean.item()}")
        plt.colorbar(im1, ax=axes[0, 1])

        # パラメータ値のプロット
        params = ["s", "l", "jitter"]
        values = [s_ij.item(), l_ij.item(), jitter.item()]
        axes[0, 2].bar(params, values)
        axes[0, 2].set_title("パラメータ値")
        axes[0, 2].set_ylabel("値")
        for i, v in enumerate(values):
            axes[0, 2].text(i, v, f"{v:.4f}", ha="center", va="bottom")

        # 固有値分布
        eigenvals_sorted = torch.sort(eigenvals_clean, descending=True)[0]
        axes[1, 0].semilogy(eigenvals_sorted.numpy(), "o-")
        axes[1, 0].set_title("固有値分布")
        axes[1, 0].set_xlabel("固有値インデックス")
        axes[1, 0].set_ylabel("固有値 (log scale)")
        axes[1, 0].grid(True, alpha=0.3)

        # 条件数とランクの可視化
        metrics = ["Rank", "Condition Number (log)"]
        metric_values = [rank_clean.item(), np.log10(cond_clean.item())]
        axes[1, 1].bar(metrics, metric_values)
        axes[1, 1].set_title("行列特性")
        axes[1, 1].set_ylabel("値")
        for i, v in enumerate(metric_values):
            if i == 0:
                axes[1, 1].text(i, v, f"{int(v)}", ha="center", va="bottom")
            else:
                axes[1, 1].text(i, v, f"{v:.2f}", ha="center", va="bottom")

        # パラメータ値の詳細プロット（対数スケール）
        axes[1, 2].bar(params, np.log10(np.abs(values)))
        axes[1, 2].set_title("パラメータ値 (log10)")
        axes[1, 2].set_ylabel("log10(値)")
        for i, v in enumerate(values):
            axes[1, 2].text(i, np.log10(abs(v)), f"{v:.4f}", ha="center", va="bottom")

        plt.tight_layout()
        plt.show()

        # 誘導点間の距離分析
        distances = torch.cdist(z_ij.unsqueeze(0), z_ij.unsqueeze(0)).squeeze(
            0
        )  # Shape: [X, X]
        min_dist = distances[distances > 0].min()
        max_dist = distances[distances > 0].max()
        mean_dist = distances[distances > 0].mean()

        print(
            f"誘導点間距離 - 最小: {min_dist.item():.4f}, 最大: {max_dist.item():.4f}, 平均: {mean_dist.item():.4f}"
        )

        # 距離分布のヒストグラム
        plt.figure(figsize=(10, 6))
        dist_flat = distances[distances > 0].numpy()
        plt.hist(dist_flat, bins=20, alpha=0.7, edgecolor="black")
        plt.axvline(
            min_dist.item(),
            color="red",
            linestyle="--",
            label=f"最小距離: {min_dist.item():.4f}",
        )
        plt.axvline(
            mean_dist.item(),
            color="green",
            linestyle="--",
            label=f"平均距離: {mean_dist.item():.4f}",
        )
        plt.xlabel("誘導点間距離")
        plt.ylabel("頻度")
        plt.title(f"Layer {layer_idx}: 誘導点間距離分布")
        plt.legend()
        plt.grid(True, alpha=0.3)
        plt.show()


# 実行
analyze_kernel_matrices(model)
# Out:
# === カーネル行列分析 ===
#
# --- Layer 0 ---
# z(誘導点)の範囲: [-1.0000, 0.9971]
# h(関数値)の範囲: [-0.8820, 0.8808]
# 計算開始
# 計算完了
# カーネル行列ランク: 9
# 条件数: 9.57e+07
# 最小固有値: -3.32e+00
# パラメータ値 - s_ij: -0.7547, l_ij: 0.5173, jitter: 0.0025
# /var/folders/sh/nky4c839309dmt8714wl6msr0000gn/T/ipykernel_67665/691919597.py:124: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   plt.tight_layout()
# 誘導点間距離 - 最小: 0.0260, 最大: 1.9971, 平均: 0.9594
# --- Layer 1 ---
# z(誘導点)の範囲: [-0.9825, 0.9810]
# h(関数値)の範囲: [-0.1154, 1.0647]
# 計算開始
# 計算完了
# カーネル行列ランク: 4
# 条件数: 4.85e+08
# 最小固有値: -4.97e-08
# パラメータ値 - s_ij: 0.7332, l_ij: -3.1052, jitter: 0.0021
# 誘導点間距離 - 最小: 0.0124, 最大: 1.9635, 平均: 0.9543

# %% [markdown]
# ### 考察
# 関数への当てはまりはよくなったが、ハイパーパラメータが負値を取る問題が解消せず。
#
# またカーネル行列も縮退している
#
# →実験a/b/cの結果で学習安定させられるか確認する:
#
# * a: バッチサイズ(現在32/750件ずつ学習)を大きくする
# * b: 正則化項小さくする
# * c: 誘導点が近付かないようなペナルティ項を入れて学習
